# %%
pip install python-binance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
api_key = ''
api_secret = ''

# %%
from binance.client import Client

#create a client
client = Client(api_key, api_secret)

# get market depth
depth = client.get_order_book(symbol='BNBBTC')
print(f'depth: {type(depth)}')

# get all symbol prices
prices = client.get_all_tickers()
print(f'prices: {type(prices)}')
# Out:
# depth: <class 'dict'>
# prices: <class 'list'>

# %%
print(f'{depth}')
# Out:
# {'lastUpdateId': 2663517252, 'bids': [['0.01113100', '3.92100000'], ['0.01113000', '6.23100000'], ['0.01112900', '2.75100000'], ['0.01112800', '10.55600000'], ['0.01112700', '1.19000000'], ['0.01112600', '20.81300000'], ['0.01112500', '37.89600000'], ['0.01112400', '8.84600000'], ['0.01112300', '20.45600000'], ['0.01112200', '20.19100000'], ['0.01112100', '3.15800000'], ['0.01112000', '23.59100000'], ['0.01111900', '9.41500000'], ['0.01111800', '1.64700000'], ['0.01111700', '1.76600000'], ['0.01111600', '65.19100000'], ['0.01111500', '3.57200000'], ['0.01111400', '10.93200000'], ['0.01111300', '23.13500000'], ['0.01111200', '6.26000000'], ['0.01111100', '11.37600000'], ['0.01111000', '4.10400000'], ['0.01110900', '13.43500000'], ['0.01110800', '14.27400000'], ['0.01110700', '126.17400000'], ['0.01110600', '20.31500000'], ['0.01110500', '4.03000000'], ['0.01110400', '1.56500000'], ['0.01110300', '1.25100000'], ['0.01110200', '10.30600000'], ['0.01110100', '11.15900000'], ['0.01110000'
# ...

# %%
"""
>>>return depth
>>>
{
    'lastUpdateId': 2663517252, 'bids': [['0.01113100', '3.92100000'], ['0.01113000', '6.23100000'], ['0.01112900', '2.75100000'], ['0.01112800', '10.55600000'], ['0.01112700', '1.19000000'], ['0.01112600', '20.81300000'], ['0.01112500', '37.89600000'], ['0.01112400', '8.84600000'], ['0.01112300', '20.45600000'], ['0.01112200', '20.19100000'], ['0.01112100', '3.15800000'], ['0.01112000', '23.59100000'], ['0.01111900', '9.41500000'], ['0.01111800', '1.64700000'], ['0.01111700', '1.76600000'], ['0.01111600', '65.19100000'], ['0.01111500', '3.57200000'], ['0.01111400', '10.93200000'], ['0.01111300', '23.13500000'], ['0.01111200', '6.26000000'], ['0.01111100', '11.37600000'], ['0.01111000', '4.10400000'], ['0.01110900', '13.43500000'], ['0.01110800', '14.27400000'], ['0.01110700', '126.17400000'], ['0.01110600', '20.31500000'], ['0.01110500', '4.03000000'], ['0.01110400', '1.56500000'], ['0.01110300', '1.25100000'], ['0.01110200', '10.30600000'], ['0.01110100', '11.15900000'], ['0.01110000', '57.94500000'], ['0.01109900', '2.00000000'], ['0.01109800', '7.38300000'], ['0.01109700', '2.71900000'], ['0.01109600', '1.35500000'], ['0.01109500', '3.88100000'], ['0.01109400', '1.90900000'], ['0.01109300', '1.78300000'], ['0.01109200', '1.57500000'], ['0.01109100', '1.54300000'], ['0.01109000', '1.19900000'], ['0.01108900', '5.78000000'], ['0.01108800', '1.45700000'], ['0.01108700', '12.51500000'], ['0.01108600', '1.27400000'], ['0.01108500', '350.83900000'], ['0.01108400', '1.42300000'], ['0.01108300', '2.86700000'], ['0.01108200', '32.86300000'], ['0.01108100', '8.32500000'], ['0.01108000', '4.80200000'], ['0.01107900', '1.37200000'], ['0.01107800', '1.54900000'], ['0.01107700', '1.39300000'], ['0.01107600', '1.32000000'], ['0.01107500', '2.18300000'], ['0.01107400', '1.46500000'], ['0.01107300', '9.31600000'], ['0.01107200', '57.71200000'], ['0.01107100', '35.41400000'], ['0.01107000', '2.31800000'], ['0.01106900', '1.19700000'], ['0.01106800', '1.26100000'], ['0.01106700', '1.66800000'], ['0.01106600', '148.68000000'], ['0.01106500', '6.21400000'], ['0.01106400', '2.57400000'], ['0.01106300', '3.89500000'], ['0.01106200', '1.75000000'], ['0.01106100', '3.32200000'], ['0.01106000', '2.21200000'], ['0.01105900', '1.24200000'], ['0.01105800', '11.57100000'], ['0.01105700', '3.26600000'], ['0.01105600', '49.94400000'], ['0.01105500', '1.58900000'], ['0.01105400', '2.52600000'], ['0.01105300', '1.77800000'], ['0.01105200', '1.69600000'], ['0.01105100', '1.94200000'], ['0.01105000', '20.37600000'], ['0.01104900', '1.41600000'], ['0.01104800', '5.18700000'], ['0.01104700', '1.98800000'], ['0.01104600', '1.39900000'], ['0.01104500', '1.15500000'], ['0.01104400', '9.10100000'], ['0.01104300', '3.13200000'], ['0.01104200', '14.76100000'], ['0.01104100', '1.88400000'], ['0.01104000', '5.97800000'], ['0.01103900', '160.46900000'], ['0.01103800', '0.37400000'], ['0.01103700', '2.81100000'], ['0.01103600', '3.22900000'], ['0.01103500', '1.24600000'], ['0.01103400', '2.73500000'], ['0.01103300', '166.10500000'], ['0.01103200', '2.55200000']], 'asks': [['0.01113200', '0.03600000'], ['0.01113300', '0.02000000'], ['0.01113500', '1.10700000'], ['0.01113600', '7.22900000'], ['0.01113700', '8.71800000'], ['0.01113800', '4.49100000'], ['0.01113900', '9.44900000'], ['0.01114000', '18.37100000'], ['0.01114100', '17.03300000'], ['0.01114200', '7.28700000'], ['0.01114300', '16.27400000'], ['0.01114400', '13.98000000'], ['0.01114500', '1.26900000'], ['0.01114600', '7.38700000'], ['0.01114700', '12.99100000'], ['0.01114800', '1.04800000'], ['0.01114900', '7.24000000'], ['0.01115000', '1.00000000'], ['0.01115100', '52.63300000'], ['0.01115200', '53.28800000'], ['0.01115300', '1.26900000'], ['0.01115400', '16.85300000'], ['0.01115500', '18.43400000'], ['0.01115600', '14.00000000'], ['0.01115700', '1.00000000'], ['0.01115800', '19.37600000'], ['0.01115900', '3.82900000'], ['0.01116000', '5.82100000'], ['0.01116100', '1.26900000'], ['0.01116200', '1.01700000'], ['0.01116300', '1.22000000'], ['0.01116400', '2.62500000'], ['0.01116500', '10.02400000'], ['0.01116600', '12.19700000'], ['0.01116700', '125.70900000'], ['0.01116800', '3.90000000'], ['0.01116900', '5.44900000'], ['0.01117000', '7.43300000'], ['0.01117100', '1.53300000'], ['0.01117200', '10.15700000'], ['0.01117300', '2.64200000'], ['0.01117400', '4.98100000'], ['0.01117500', '18.74000000'], ['0.01117600', '3.36400000'], ['0.01117700', '3.95400000'], ['0.01117800', '1.35600000'], ['0.01117900', '1.27000000'], ['0.01118000', '7.31300000'], ['0.01118100', '8.97700000'], ['0.01118200', '1.52200000'], ['0.01118300', '20.96800000'], ['0.01118400', '2.77600000'], ['0.01118500', '4.61700000'], ['0.01118600', '1.11800000'], ['0.01118700', '2.87000000'], ['0.01118800', '12.98600000'], ['0.01118900', '6.49900000'], ['0.01119000', '4.38600000'], ['0.01119100', '3.84800000'], ['0.01119200', '34.12300000'], ['0.01119300', '2.30200000'], ['0.01119400', '354.88500000'], ['0.01119500', '9.16800000'], ['0.01119600', '2.29900000'], ['0.01119700', '2.04200000'], ['0.01119800', '23.59100000'], ['0.01119900', '40.48800000'], ['0.01120000', '261.42400000'], ['0.01120100', '1.51200000'], ['0.01120200', '185.42900000'], ['0.01120300', '6.21200000'], ['0.01120400', '50.99800000'], ['0.01120500', '1.88200000'], ['0.01120600', '1.79300000'], ['0.01120700', '4.01400000'], ['0.01120800', '5.33500000'], ['0.01120900', '2.38800000'], ['0.01121000', '20.63400000'], ['0.01121100', '1.95300000'], ['0.01121200', '1.89800000'], ['0.01121300', '1.28900000'], ['0.01121400', '1.76600000'], ['0.01121500', '1.94200000'], ['0.01121600', '3.66400000'], ['0.01121700', '2.72900000'], ['0.01121800', '20.37800000'], ['0.01121900', '2.75200000'], ['0.01122000', '1.64000000'], ['0.01122100', '1.14400000'], ['0.01122200', '2.99800000'], ['0.01122300', '1.85100000'], ['0.01122400', '12.51200000'], ['0.01122500', '9.54700000'], ['0.01122600', '11.90900000'], ['0.01122700', '151.49300000'], ['0.01122800', '3.11400000'], ['0.01122900', '1.76400000'], ['0.01123000', '3.95700000'], ['0.01123100', '4.58000000'], ['0.01123200', '1.83700000']]}

"""
# Out:
# "\n>>>return depth\n>>>\n{\n    'lastUpdateId': 2663517252, 'bids': [['0.01113100', '3.92100000'], ['0.01113000', '6.23100000'], ['0.01112900', '2.75100000'], ['0.01112800', '10.55600000'], ['0.01112700', '1.19000000'], ['0.01112600', '20.81300000'], ['0.01112500', '37.89600000'], ['0.01112400', '8.84600000'], ['0.01112300', '20.45600000'], ['0.01112200', '20.19100000'], ['0.01112100', '3.15800000'], ['0.01112000', '23.59100000'], ['0.01111900', '9.41500000'], ['0.01111800', '1.64700000'], ['0.01111700', '1.76600000'], ['0.01111600', '65.19100000'], ['0.01111500', '3.57200000'], ['0.01111400', '10.93200000'], ['0.01111300', '23.13500000'], ['0.01111200', '6.26000000'], ['0.01111100', '11.37600000'], ['0.01111000', '4.10400000'], ['0.01110900', '13.43500000'], ['0.01110800', '14.27400000'], ['0.01110700', '126.17400000'], ['0.01110600', '20.31500000'], ['0.01110500', '4.03000000'], ['0.01110400', '1.56500000'], ['0.01110300', '1.25100000'], ['0.01110200', '10.30600000'], ['0.01110100'
# ...

# %%
print(f'{prices}')
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.05791700'}, {'symbol': 'LTCBTC', 'price': '0.00277100'}, {'symbol': 'BNBBTC', 'price': '0.01113100'}, {'symbol': 'NEOBTC', 'price': '0.00045200'}, {'symbol': 'QTUMETH', 'price': '0.00255400'}, {'symbol': 'EOSETH', 'price': '0.00081400'}, {'symbol': 'SNTETH', 'price': '0.00002417'}, {'symbol': 'BNTETH', 'price': '0.00044100'}, {'symbol': 'BCCBTC', 'price': '0.07908100'}, {'symbol': 'GASBTC', 'price': '0.00013140'}, {'symbol': 'BNBETH', 'price': '0.19220000'}, {'symbol': 'BTCUSDT', 'price': '21458.15000000'}, {'symbol': 'ETHUSDT', 'price': '1242.88000000'}, {'symbol': 'HSRBTC', 'price': '0.00041400'}, {'symbol': 'OAXETH', 'price': '0.00017780'}, {'symbol': 'DNTETH', 'price': '0.00002801'}, {'symbol': 'MCOETH', 'price': '0.00577200'}, {'symbol': 'ICNETH', 'price': '0.00166300'}, {'symbol': 'MCOBTC', 'price': '0.00021140'}, {'symbol': 'WTCBTC', 'price': '0.00000885'}, {'symbol': 'WTCETH', 'price': '0.00023700'}, {'symbol': 'LRCBTC', 'price': '0.00002060'
# ...

# %%
"""
#Binance::[List]
return prices
[{'symbol': 'ETHBTC', 'price': '0.05791700'}, {'symbol': 'LTCBTC', 'price': '0.00277100'}, {'symbol': 'BNBBTC', 'price': '0.01113100'}, {'symbol': 'NEOBTC', 'price': '0.00045200'}, {'symbol': 'QTUMETH', 'price': '0.00255400'}, {'symbol': 'EOSETH', 'price': '0.00081400'}, {'symbol': 'SNTETH', 'price': '0.00002417'}, {'symbol': 'BNTETH', 'price': '0.00044100'}, {'symbol': 'BCCBTC', 'price': '0.07908100'}, {'symbol': 'GASBTC', 'price': '0.00013140'}, {'symbol': 'BNBETH', 'price': '0.19220000'}, {'symbol': 'BTCUSDT', 'price': '21458.15000000'}, {'symbol': 'ETHUSDT', 'price': '1242.88000000'}, {'symbol': 'HSRBTC', 'price': '0.00041400'}, {'symbol': 'OAXETH', 'price': '0.00017780'}, {'symbol': 'DNTETH', 'price': '0.00002801'}, {'symbol': 'MCOETH', 'price': '0.00577200'}, {'symbol': 'ICNETH', 'price': '0.00166300'}, {'symbol': 'MCOBTC', 'price': '0.00021140'}, {'symbol': 'WTCBTC', 'price': '0.00000885'}, {'symbol': 'WTCETH', 'price': '0.00023700'}, {'symbol': 'LRCBTC', 'price': '0.00002060'}, {'symbol': 'LRCETH', 'price': '0.00035590'}, {'symbol': 'QTUMBTC', 'price': '0.00014780'}, {'symbol': 'YOYOBTC', 'price': '0.00000008'}, {'symbol': 'OMGBTC', 'price': '0.00009490'}, {'symbol': 'OMGETH', 'price': '0.00164000'}, {'symbol': 'ZRXBTC', 'price': '0.00001451'}, {'symbol': 'ZRXETH', 'price': '0.00024970'}, {'symbol': 'STRATBTC', 'price': '0.00003085'}, {'symbol': 'STRATETH', 'price': '0.00105300'}, {'symbol': 'SNGLSBTC', 'price': '0.00000013'}, {'symbol': 'SNGLSETH', 'price': '0.00005306'}, {'symbol': 'BQXBTC', 'price': '0.00008703'}, {'symbol': 'BQXETH', 'price': '0.00126350'}, {'symbol': 'KNCBTC', 'price': '0.00007062'}, {'symbol': 'KNCETH', 'price': '0.00121760'}, {'symbol': 'FUNBTC', 'price': '0.00000029'}, {'symbol': 'FUNETH', 'price': '0.00000625'}, {'symbol': 'SNMBTC', 'price': '0.00000228'}, {'symbol': 'SNMETH', 'price': '0.00004986'}, {'symbol': 'NEOETH', 'price': '0.00782000'}, {'symbol': 'IOTABTC', 'price': '0.00001421'}, {'symbol': 'IOTAETH', 'price': '0.00024550'}, {'symbol': 'LINKBTC', 'price': '0.00033280'}, {'symbol': 'LINKETH', 'price': '0.00574300'}, {'symbol': 'XVGBTC', 'price': '0.00000015'}, {'symbol': 'XVGETH', 'price': '0.00000269'}, {'symbol': 'SALTBTC', 'price': '0.00004250'}, {'symbol': 'SALTETH', 'price': '0.00113800'}, {'symbol': 'MDABTC', 'price': '0.00000633'}, {'symbol': 'MDAETH', 'price': '0.00181150'}, {'symbol': 'MTLBTC', 'price': '0.00006822'}, {'symbol': 'MTLETH', 'price': '0.00117380'}, {'symbol': 'SUBBTC', 'price': '0.00000457'}, {'symbol': 'SUBETH', 'price': '0.00012334'}, {'symbol': 'EOSBTC', 'price': '0.00004720'}, {'symbol': 'SNTBTC', 'price': '0.00000140'}, {'symbol': 'ETCETH', 'price': '0.01327000'}, {'symbol': 'ETCBTC', 'price': '0.00077000'}, {'symbol': 'MTHBTC', 'price': '0.00000023'}, {'symbol': 'MTHETH', 'price': '0.00004135'}, {'symbol': 'ENGBTC', 'price': '0.00006200'}, {'symbol': 'ENGETH', 'price': '0.00186480'}, {'symbol': 'DNTBTC', 'price': '0.00000209'}, {'symbol': 'ZECBTC', 'price': '0.00318000'}, {'symbol': 'ZECETH', 'price': '0.05484000'}, {'symbol': 'BNTBTC', 'price': '0.00002549'}, {'symbol': 'ASTBTC', 'price': '0.00000345'}, {'symbol': 'ASTETH', 'price': '0.00006960'}, {'symbol': 'DASHBTC', 'price': '0.00243500'}, {'symbol': 'DASHETH', 'price': '0.04204000'}, {'symbol': 'OAXBTC', 'price': '0.00000182'}, {'symbol': 'ICNBTC', 'price': '0.00005742'}, {'symbol': 'BTGBTC', 'price': '0.00081800'}, {'symbol': 'BTGETH', 'price': '0.05274500'}, {'symbol': 'EVXBTC', 'price': '0.00000274'}, {'symbol': 'EVXETH', 'price': '0.00062490'}, {'symbol': 'REQBTC', 'price': '0.00000467'}, {'symbol': 'REQETH', 'price': '0.00004995'}, {'symbol': 'VIBBTC', 'price': '0.00000061'}, {'symbol': 'VIBETH', 'price': '0.00001035'}, {'symbol': 'HSRETH', 'price': '0.01247400'}, {'symbol': 'TRXBTC', 'price': '0.00000302'}, {'symbol': 'TRXETH', 'price': '0.00005212'}, {'symbol': 'POWRBTC', 'price': '0.00001072'}, {'symbol': 'POWRETH', 'price': '0.00018510'}, {'symbol': 'ARKBTC', 'price': '0.00002117'}, {'symbol': 'ARKETH', 'price': '0.00104600'}, {'symbol': 'YOYOETH', 'price': '0.00005828'}, {'symbol': 'XRPBTC', 'price': '0.00001703'}, {'symbol': 'XRPETH', 'price': '0.00029390'}, {'symbol': 'MODBTC', 'price': '0.00004280'}, {'symbol': 'MODETH', 'price': '0.00116700'}, {'symbol': 'ENJBTC', 'price': '0.00002838'}, {'symbol': 'ENJETH', 'price': '0.00049250'}, {'symbol': 'STORJBTC', 'price': '0.00004293'}, {'symbol': 'STORJETH', 'price': '0.00029910'}, {'symbol': 'BNBUSDT', 'price': '239.00000000'}, {'symbol': 'VENBNB', 'price': '0.14920000'}, {'symbol': 'YOYOBNB', 'price': '0.00059800'}, {'symbol': 'POWRBNB', 'price': '0.00385000'}, {'symbol': 'VENBTC', 'price': '0.00013928'}, {'symbol': 'VENETH', 'price': '0.00325194'}, {'symbol': 'KMDBTC', 'price': '0.00000964'}, {'symbol': 'KMDETH', 'price': '0.00020970'}, {'symbol': 'NULSBNB', 'price': '0.01257000'}, {'symbol': 'RCNBTC', 'price': '0.00000074'}, {'symbol': 'RCNETH', 'price': '0.00037604'}, {'symbol': 'RCNBNB', 'price': '0.00347300'}, {'symbol': 'NULSBTC', 'price': '0.00000868'}, {'symbol': 'NULSETH', 'price': '0.00051926'}, {'symbol': 'RDNBTC', 'price': '0.00000447'}, {'symbol': 'RDNETH', 'price': '0.00071530'}, {'symbol': 'RDNBNB', 'price': '0.00623000'}, {'symbol': 'XMRBTC', 'price': '0.00591700'}, {'symbol': 'XMRETH', 'price': '0.10234000'}, {'symbol': 'DLTBNB', 'price': '0.00240000'}, {'symbol': 'WTCBNB', 'price': '0.00180500'}, {'symbol': 'DLTBTC', 'price': '0.00000071'}, {'symbol': 'DLTETH', 'price': '0.00016807'}, {'symbol': 'AMBBTC', 'price': '0.00000029'}, {'symbol': 'AMBETH', 'price': '0.00004100'}, {'symbol': 'AMBBNB', 'price': '0.00068500'}, {'symbol': 'BCCETH', 'price': '2.47246000'}, {'symbol': 'BCCUSDT', 'price': '448.70000000'}, {'symbol': 'BCCBNB', 'price': '54.29000000'}, {'symbol': 'BATBTC', 'price': '0.00001975'}, {'symbol': 'BATETH', 'price': '0.00034230'}, {'symbol': 'BATBNB', 'price': '0.00183100'}, {'symbol': 'BCPTBTC', 'price': '0.00000048'}, {'symbol': 'BCPTETH', 'price': '0.00008181'}, {'symbol': 'BCPTBNB', 'price': '0.00116200'}, {'symbol': 'ARNBTC', 'price': '0.00000761'}, {'symbol': 'ARNETH', 'price': '0.00029362'}, {'symbol': 'GVTBTC', 'price': '0.00001792'}, {'symbol': 'GVTETH', 'price': '0.00384600'}, {'symbol': 'CDTBTC', 'price': '0.00000317'}, {'symbol': 'CDTETH', 'price': '0.00005119'}, {'symbol': 'GXSBTC', 'price': '0.00004581'}, {'symbol': 'GXSETH', 'price': '0.00062460'}, {'symbol': 'NEOUSDT', 'price': '9.72000000'}, {'symbol': 'NEOBNB', 'price': '0.04070000'}, {'symbol': 'POEBTC', 'price': '0.00000005'}, {'symbol': 'POEETH', 'price': '0.00000664'}, {'symbol': 'QSPBTC', 'price': '0.00000112'}, {'symbol': 'QSPETH', 'price': '0.00002249'}, {'symbol': 'QSPBNB', 'price': '0.00052350'}, {'symbol': 'BTSBTC', 'price': '0.00000052'}, {'symbol': 'BTSETH', 'price': '0.00009498'}, {'symbol': 'BTSBNB', 'price': '0.00144800'}, {'symbol': 'XZCBTC', 'price': '0.00013550'}, {'symbol': 'XZCETH', 'price': '0.00310000'}, {'symbol': 'XZCBNB', 'price': '0.26750000'}, {'symbol': 'LSKBTC', 'price': '0.00005129'}, {'symbol': 'LSKETH', 'price': '0.00088800'}, {'symbol': 'LSKBNB', 'price': '0.06494000'}, {'symbol': 'TNTBTC', 'price': '0.00000261'}, {'symbol': 'TNTETH', 'price': '0.00000920'}, {'symbol': 'FUELBTC', 'price': '0.00000026'}, {'symbol': 'FUELETH', 'price': '0.00002221'}, {'symbol': 'MANABTC', 'price': '0.00004849'}, {'symbol': 'MANAETH', 'price': '0.00084010'}, {'symbol': 'BCDBTC', 'price': '0.00001351'}, {'symbol': 'BCDETH', 'price': '0.00251000'}, {'symbol': 'DGDBTC', 'price': '0.00393100'}, {'symbol': 'DGDETH', 'price': '0.19260000'}, {'symbol': 'IOTABNB', 'price': '0.00126900'}, {'symbol': 'ADXBTC', 'price': '0.00000748'}, {'symbol': 'ADXETH', 'price': '0.00012930'}, {'symbol': 'ADXBNB', 'price': '0.00492900'}, {'symbol': 'ADABTC', 'price': '0.00002324'}, {'symbol': 'ADAETH', 'price': '0.00040130'}, {'symbol': 'PPTBTC', 'price': '0.00001855'}, {'symbol': 'PPTETH', 'price': '0.00141000'}, {'symbol': 'CMTBTC', 'price': '0.00000028'}, {'symbol': 'CMTETH', 'price': '0.00000625'}, {'symbol': 'CMTBNB', 'price': '0.00057700'}, {'symbol': 'XLMBTC', 'price': '0.00000593'}, {'symbol': 'XLMETH', 'price': '0.00010220'}, {'symbol': 'XLMBNB', 'price': '0.00053150'}, {'symbol': 'CNDBTC', 'price': '0.00000006'}, {'symbol': 'CNDETH', 'price': '0.00002599'}, {'symbol': 'CNDBNB', 'price': '0.00033990'}, {'symbol': 'LENDBTC', 'price': '0.00004512'}, {'symbol': 'LENDETH', 'price': '0.00137174'}, {'symbol': 'WABIBTC', 'price': '0.00000185'}, {'symbol': 'WABIETH', 'price': '0.00040308'}, {'symbol': 'WABIBNB', 'price': '0.00024130'}, {'symbol': 'LTCETH', 'price': '0.04790000'}, {'symbol': 'LTCUSDT', 'price': '59.45000000'}, {'symbol': 'LTCBNB', 'price': '0.24910000'}, {'symbol': 'TNBBTC', 'price': '0.00000007'}, {'symbol': 'TNBETH', 'price': '0.00000752'}, {'symbol': 'WAVESBTC', 'price': '0.00030040'}, {'symbol': 'WAVESETH', 'price': '0.00517400'}, {'symbol': 'WAVESBNB', 'price': '0.02695000'}, {'symbol': 'GTOBTC', 'price': '0.00000089'}, {'symbol': 'GTOETH', 'price': '0.00003197'}, {'symbol': 'GTOBNB', 'price': '0.00035200'}, {'symbol': 'ICXBTC', 'price': '0.00001403'}, {'symbol': 'ICXETH', 'price': '0.00024240'}, {'symbol': 'ICXBNB', 'price': '0.00465400'}, {'symbol': 'OSTBTC', 'price': '0.00000032'}, {'symbol': 'OSTETH', 'price': '0.00000225'}, {'symbol': 'OSTBNB', 'price': '0.00052500'}, {'symbol': 'ELFBTC', 'price': '0.00000707'}, {'symbol': 'ELFETH', 'price': '0.00012210'}, {'symbol': 'AIONBTC', 'price': '0.00000135'}, {'symbol': 'AIONETH', 'price': '0.00002318'}, {'symbol': 'AIONBNB', 'price': '0.00261300'}, {'symbol': 'NEBLBTC', 'price': '0.00000972'}, {'symbol': 'NEBLBNB', 'price': '0.01356000'}, {'symbol': 'BRDBTC', 'price': '0.00000283'}, {'symbol': 'BRDETH', 'price': '0.00004860'}, {'symbol': 'BRDBNB', 'price': '0.00247000'}, {'symbol': 'MCOBNB', 'price': '0.26837000'}, {'symbol': 'EDOBTC', 'price': '0.00005609'}, {'symbol': 'EDOETH', 'price': '0.00226600'}, {'symbol': 'WINGSBTC', 'price': '0.00001193'}, {'symbol': 'WINGSETH', 'price': '0.00033460'}, {'symbol': 'NAVBTC', 'price': '0.00000450'}, {'symbol': 'NAVETH', 'price': '0.00011870'}, {'symbol': 'NAVBNB', 'price': '0.00423700'}, {'symbol': 'LUNBTC', 'price': '0.00008510'}, {'symbol': 'LUNETH', 'price': '0.00489100'}, {'symbol': 'TRIGBTC', 'price': '0.00001980'}, {'symbol': 'TRIGETH', 'price': '0.00059400'}, {'symbol': 'TRIGBNB', 'price': '0.01218000'}, {'symbol': 'APPCBTC', 'price': '0.00000055'}, {'symbol': 'APPCETH', 'price': '0.00014600'}, {'symbol': 'APPCBNB', 'price': '0.00189100'}, {'symbol': 'VIBEBTC', 'price': '0.00000042'}, {'symbol': 'VIBEETH', 'price': '0.00005720'}, {'symbol': 'RLCBTC', 'price': '0.00003756'}, {'symbol': 'RLCETH', 'price': '0.00064700'}, {'symbol': 'RLCBNB', 'price': '0.03344000'}, {'symbol': 'INSBTC', 'price': '0.00000618'}, {'symbol': 'INSETH', 'price': '0.00050100'}, {'symbol': 'PIVXBTC', 'price': '0.00000494'}, {'symbol': 'PIVXBNB', 'price': '0.01660000'}, {'symbol': 'IOSTBTC', 'price': '0.00000070'}, {'symbol': 'IOSTETH', 'price': '0.00001210'}, {'symbol': 'CHATBTC', 'price': '0.00000195'}, {'symbol': 'CHATETH', 'price': '0.00006585'}, {'symbol': 'STEEMBTC', 'price': '0.00001055'}, {'symbol': 'STEEMETH', 'price': '0.00018310'}, {'symbol': 'STEEMBNB', 'price': '0.00448000'}, {'symbol': 'NANOBTC', 'price': '0.00006280'}, {'symbol': 'NANOETH', 'price': '0.00090500'}, {'symbol': 'NANOBNB', 'price': '0.05589000'}, {'symbol': 'VIABTC', 'price': '0.00000681'}, {'symbol': 'VIAETH', 'price': '0.00085600'}, {'symbol': 'VIABNB', 'price': '0.00958000'}, {'symbol': 'BLZBTC', 'price': '0.00000484'}, {'symbol': 'BLZETH', 'price': '0.00008352'}, {'symbol': 'BLZBNB', 'price': '0.00062190'}, {'symbol': 'AEBTC', 'price': '0.00000292'}, {'symbol': 'AEETH', 'price': '0.00021900'}, {'symbol': 'AEBNB', 'price': '0.00777000'}, {'symbol': 'RPXBTC', 'price': '0.00000224'}, {'symbol': 'RPXETH', 'price': '0.00005449'}, {'symbol': 'RPXBNB', 'price': '0.00145700'}, {'symbol': 'NCASHBTC', 'price': '0.00000005'}, {'symbol': 'NCASHETH', 'price': '0.00000013'}, {'symbol': 'NCASHBNB', 'price': '0.00006790'}, {'symbol': 'POABTC', 'price': '0.00000041'}, {'symbol': 'POAETH', 'price': '0.00004891'}, {'symbol': 'POABNB', 'price': '0.00092100'}, {'symbol': 'ZILBTC', 'price': '0.00000228'}, {'symbol': 'ZILETH', 'price': '0.00003961'}, {'symbol': 'ZILBNB', 'price': '0.00020550'}, {'symbol': 'ONTBTC', 'price': '0.00001150'}, {'symbol': 'ONTETH', 'price': '0.00019860'}, {'symbol': 'ONTBNB', 'price': '0.00246200'}, {'symbol': 'STORMBTC', 'price': '0.00000035'}, {'symbol': 'STORMETH', 'price': '0.00001398'}, {'symbol': 'STORMBNB', 'price': '0.00006550'}, {'symbol': 'QTUMBNB', 'price': '0.09597000'}, {'symbol': 'QTUMUSDT', 'price': '3.17100000'}, {'symbol': 'XEMBTC', 'price': '0.00000200'}, {'symbol': 'XEMETH', 'price': '0.00003593'}, {'symbol': 'XEMBNB', 'price': '0.00244100'}, {'symbol': 'WANBTC', 'price': '0.00000933'}, {'symbol': 'WANETH', 'price': '0.00016100'}, {'symbol': 'WANBNB', 'price': '0.00181000'}, {'symbol': 'WPRBTC', 'price': '0.00000027'}, {'symbol': 'WPRETH', 'price': '0.00004020'}, {'symbol': 'QLCBTC', 'price': '0.00000025'}, {'symbol': 'QLCETH', 'price': '0.00000603'}, {'symbol': 'SYSBTC', 'price': '0.00000714'}, {'symbol': 'SYSETH', 'price': '0.00011047'}, {'symbol': 'SYSBNB', 'price': '0.00163500'}, {'symbol': 'QLCBNB', 'price': '0.00092200'}, {'symbol': 'GRSBTC', 'price': '0.00001746'}, {'symbol': 'GRSETH', 'price': '0.00076455'}, {'symbol': 'ADAUSDT', 'price': '0.49900000'}, {'symbol': 'ADABNB', 'price': '0.00208800'}, {'symbol': 'CLOAKBTC', 'price': '0.00015550'}, {'symbol': 'CLOAKETH', 'price': '0.00414200'}, {'symbol': 'GNTBTC', 'price': '0.00000678'}, {'symbol': 'GNTETH', 'price': '0.00022071'}, {'symbol': 'GNTBNB', 'price': '0.00243900'}, {'symbol': 'LOOMBTC', 'price': '0.00000211'}, {'symbol': 'LOOMETH', 'price': '0.00003623'}, {'symbol': 'LOOMBNB', 'price': '0.00088500'}, {'symbol': 'XRPUSDT', 'price': '0.36540000'}, {'symbol': 'BCNBTC', 'price': '0.00000022'}, {'symbol': 'BCNETH', 'price': '0.00000707'}, {'symbol': 'BCNBNB', 'price': '0.00002000'}, {'symbol': 'REPBTC', 'price': '0.00043080'}, {'symbol': 'REPBNB', 'price': '0.44670000'}, {'symbol': 'BTCTUSD', 'price': '21426.01000000'}, {'symbol': 'TUSDBTC', 'price': '0.00025971'}, {'symbol': 'ETHTUSD', 'price': '1242.22000000'}, {'symbol': 'TUSDETH', 'price': '0.00762097'}, {'symbol': 'TUSDBNB', 'price': '0.06777000'}, {'symbol': 'ZENBTC', 'price': '0.00075200'}, {'symbol': 'ZENETH', 'price': '0.01295000'}, {'symbol': 'ZENBNB', 'price': '0.06740000'}, {'symbol': 'SKYBTC', 'price': '0.00000829'}, {'symbol': 'SKYETH', 'price': '0.00222000'}, {'symbol': 'SKYBNB', 'price': '0.03022000'}, {'symbol': 'EOSUSDT', 'price': '1.01200000'}, {'symbol': 'EOSBNB', 'price': '0.00423000'}, {'symbol': 'CVCBTC', 'price': '0.00000698'}, {'symbol': 'CVCETH', 'price': '0.00009930'}, {'symbol': 'CVCBNB', 'price': '0.00211200'}, {'symbol': 'THETABTC', 'price': '0.00006870'}, {'symbol': 'THETAETH', 'price': '0.00118400'}, {'symbol': 'THETABNB', 'price': '0.00617000'}, {'symbol': 'XRPBNB', 'price': '0.00153000'}, {'symbol': 'TUSDUSDT', 'price': '1.00060000'}, {'symbol': 'IOTAUSDT', 'price': '0.30490000'}, {'symbol': 'XLMUSDT', 'price': '0.12710000'}, {'symbol': 'IOTXBTC', 'price': '0.00000136'}, {'symbol': 'IOTXETH', 'price': '0.00002363'}, {'symbol': 'QKCBTC', 'price': '0.00000048'}, {'symbol': 'QKCETH', 'price': '0.00000842'}, {'symbol': 'AGIBTC', 'price': '0.00000668'}, {'symbol': 'AGIETH', 'price': '0.00007363'}, {'symbol': 'AGIBNB', 'price': '0.00077200'}, {'symbol': 'NXSBTC', 'price': '0.00000587'}, {'symbol': 'NXSETH', 'price': '0.00077300'}, {'symbol': 'NXSBNB', 'price': '0.01087000'}, {'symbol': 'ENJBNB', 'price': '0.00255500'}, {'symbol': 'DATABTC', 'price': '0.00000129'}, {'symbol': 'DATAETH', 'price': '0.00002210'}, {'symbol': 'ONTUSDT', 'price': '0.24690000'}, {'symbol': 'TRXBNB', 'price': '0.00027110'}, {'symbol': 'TRXUSDT', 'price': '0.06478000'}, {'symbol': 'ETCUSDT', 'price': '16.55000000'}, {'symbol': 'ETCBNB', 'price': '0.06930000'}, {'symbol': 'ICXUSDT', 'price': '0.30100000'}, {'symbol': 'SCBTC', 'price': '0.00000017'}, {'symbol': 'SCETH', 'price': '0.00000335'}, {'symbol': 'NPXSBTC', 'price': '0.00000003'}, {'symbol': 'NPXSETH', 'price': '0.00000345'}, {'symbol': 'VENUSDT', 'price': '0.00010000'}, {'symbol': 'KEYBTC', 'price': '0.00000013'}, {'symbol': 'KEYETH', 'price': '0.00000293'}, {'symbol': 'NASBTC', 'price': '0.00000330'}, {'symbol': 'NASETH', 'price': '0.00005680'}, {'symbol': 'NASBNB', 'price': '0.02337000'}, {'symbol': 'MFTBTC', 'price': '0.00000008'}, {'symbol': 'MFTETH', 'price': '0.00000320'}, {'symbol': 'MFTBNB', 'price': '0.00001485'}, {'symbol': 'DENTBTC', 'price': '0.00000004'}, {'symbol': 'DENTETH', 'price': '0.00000079'}, {'symbol': 'ARDRBTC', 'price': '0.00000481'}, {'symbol': 'ARDRETH', 'price': '0.00018870'}, {'symbol': 'ARDRBNB', 'price': '0.00316800'}, {'symbol': 'NULSUSDT', 'price': '0.18690000'}, {'symbol': 'HOTBTC', 'price': '0.00000002'}, {'symbol': 'HOTETH', 'price': '0.00000192'}, {'symbol': 'VETBTC', 'price': '0.00000122'}, {'symbol': 'VETETH', 'price': '0.00002107'}, {'symbol': 'VETUSDT', 'price': '0.02620000'}, {'symbol': 'VETBNB', 'price': '0.00010960'}, {'symbol': 'DOCKBTC', 'price': '0.00000081'}, {'symbol': 'DOCKETH', 'price': '0.00003283'}, {'symbol': 'POLYBTC', 'price': '0.00000950'}, {'symbol': 'POLYBNB', 'price': '0.00145900'}, {'symbol': 'PHXBTC', 'price': '0.00000180'}, {'symbol': 'PHXETH', 'price': '0.00005617'}, {'symbol': 'PHXBNB', 'price': '0.00045600'}, {'symbol': 'HCBTC', 'price': '0.00002000'}, {'symbol': 'HCETH', 'price': '0.00513400'}, {'symbol': 'GOBTC', 'price': '0.00000049'}, {'symbol': 'GOBNB', 'price': '0.00069230'}, {'symbol': 'PAXBTC', 'price': '0.00025175'}, {'symbol': 'PAXBNB', 'price': '0.20121000'}, {'symbol': 'PAXUSDT', 'price': '0.99960000'}, {'symbol': 'PAXETH', 'price': '0.00888047'}, {'symbol': 'RVNBTC', 'price': '0.00000121'}, {'symbol': 'DCRBTC', 'price': '0.00120700'}, {'symbol': 'DCRBNB', 'price': '0.78100000'}, {'symbol': 'USDCBNB', 'price': '0.21755000'}, {'symbol': 'MITHBTC', 'price': '0.00000073'}, {'symbol': 'MITHBNB', 'price': '0.00006550'}, {'symbol': 'BCHABCBTC', 'price': '0.02933000'}, {'symbol': 'BCHSVBTC', 'price': '0.01117900'}, {'symbol': 'BCHABCUSDT', 'price': '220.08000000'}, {'symbol': 'BCHSVUSDT', 'price': '58.90000000'}, {'symbol': 'BNBPAX', 'price': '495.10000000'}, {'symbol': 'BTCPAX', 'price': '51529.15000000'}, {'symbol': 'ETHPAX', 'price': '3904.41000000'}, {'symbol': 'XRPPAX', 'price': '0.88960000'}, {'symbol': 'EOSPAX', 'price': '2.58450000'}, {'symbol': 'XLMPAX', 'price': '0.04221000'}, {'symbol': 'RENBTC', 'price': '0.00000577'}, {'symbol': 'RENBNB', 'price': '0.00458500'}, {'symbol': 'BNBTUSD', 'price': '238.70000000'}, {'symbol': 'XRPTUSD', 'price': '0.36550000'}, {'symbol': 'EOSTUSD', 'price': '4.11590000'}, {'symbol': 'XLMTUSD', 'price': '0.06833000'}, {'symbol': 'BNBUSDC', 'price': '238.60000000'}, {'symbol': 'BTCUSDC', 'price': '21442.86000000'}, {'symbol': 'ETHUSDC', 'price': '1242.14000000'}, {'symbol': 'XRPUSDC', 'price': '0.36550000'}, {'symbol': 'EOSUSDC', 'price': '1.01400000'}, {'symbol': 'XLMUSDC', 'price': '0.04970000'}, {'symbol': 'USDCUSDT', 'price': '1.00070000'}, {'symbol': 'ADATUSD', 'price': '0.49540000'}, {'symbol': 'TRXTUSD', 'price': '0.06474000'}, {'symbol': 'NEOTUSD', 'price': '11.81800000'}, {'symbol': 'TRXXRP', 'price': '0.17696000'}, {'symbol': 'XZCXRP', 'price': '20.79200000'}, {'symbol': 'PAXTUSD', 'price': '0.99950000'}, {'symbol': 'USDCTUSD', 'price': '1.00000000'}, {'symbol': 'USDCPAX', 'price': '1.00020000'}, {'symbol': 'LINKUSDT', 'price': '7.15000000'}, {'symbol': 'LINKTUSD', 'price': '28.87000000'}, {'symbol': 'LINKPAX', 'price': '3.98340000'}, {'symbol': 'LINKUSDC', 'price': '7.13000000'}, {'symbol': 'WAVESUSDT', 'price': '6.44000000'}, {'symbol': 'WAVESTUSD', 'price': '1.07200000'}, {'symbol': 'WAVESPAX', 'price': '0.80290000'}, {'symbol': 'WAVESUSDC', 'price': '1.20360000'}, {'symbol': 'BCHABCTUSD', 'price': '220.20000000'}, {'symbol': 'BCHABCPAX', 'price': '221.20000000'}, {'symbol': 'BCHABCUSDC', 'price': '220.30000000'}, {'symbol': 'BCHSVTUSD', 'price': '59.17000000'}, {'symbol': 'BCHSVPAX', 'price': '58.18000000'}, {'symbol': 'BCHSVUSDC', 'price': '57.50000000'}, {'symbol': 'LTCTUSD', 'price': '150.10000000'}, {'symbol': 'LTCPAX', 'price': '171.13000000'}, {'symbol': 'LTCUSDC', 'price': '59.80000000'}, {'symbol': 'TRXPAX', 'price': '0.07661000'}, {'symbol': 'TRXUSDC', 'price': '0.06475000'}, {'symbol': 'BTTBTC', 'price': '0.00000005'}, {'symbol': 'BTTBNB', 'price': '0.00000573'}, {'symbol': 'BTTUSDT', 'price': '0.00277700'}, {'symbol': 'BNBUSDS', 'price': '22.27880000'}, {'symbol': 'BTCUSDS', 'price': '9604.59000000'}, {'symbol': 'USDSUSDT', 'price': '0.99680000'}, {'symbol': 'USDSPAX', 'price': '1.00020000'}, {'symbol': 'USDSTUSD', 'price': '1.00000000'}, {'symbol': 'USDSUSDC', 'price': '1.00000000'}, {'symbol': 'BTTPAX', 'price': '0.00038660'}, {'symbol': 'BTTTUSD', 'price': '0.00277000'}, {'symbol': 'BTTUSDC', 'price': '0.00277600'}, {'symbol': 'ONGBNB', 'price': '0.00545000'}, {'symbol': 'ONGBTC', 'price': '0.00001829'}, {'symbol': 'ONGUSDT', 'price': '0.39160000'}, {'symbol': 'HOTBNB', 'price': '0.00000862'}, {'symbol': 'HOTUSDT', 'price': '0.00239800'}, {'symbol': 'ZILUSDT', 'price': '0.04903000'}, {'symbol': 'ZRXBNB', 'price': '0.01045000'}, {'symbol': 'ZRXUSDT', 'price': '0.31150000'}, {'symbol': 'FETBNB', 'price': '0.00037400'}, {'symbol': 'FETBTC', 'price': '0.00000418'}, {'symbol': 'FETUSDT', 'price': '0.08950000'}, {'symbol': 'BATUSDT', 'price': '0.42390000'}, {'symbol': 'XMRBNB', 'price': '0.53130000'}, {'symbol': 'XMRUSDT', 'price': '127.10000000'}, {'symbol': 'ZECBNB', 'price': '0.28560000'}, {'symbol': 'ZECUSDT', 'price': '68.30000000'}, {'symbol': 'ZECPAX', 'price': '42.10000000'}, {'symbol': 'ZECTUSD', 'price': '51.48000000'}, {'symbol': 'ZECUSDC', 'price': '67.00000000'}, {'symbol': 'IOSTUSDT', 'price': '0.01503000'}, {'symbol': 'CELRBNB', 'price': '0.00007868'}, {'symbol': 'CELRBTC', 'price': '0.00000087'}, {'symbol': 'CELRUSDT', 'price': '0.01885000'}, {'symbol': 'ADAPAX', 'price': '0.03257000'}, {'symbol': 'ADAUSDC', 'price': '0.49860000'}, {'symbol': 'NEOPAX', 'price': '11.12200000'}, {'symbol': 'NEOUSDC', 'price': '28.27000000'}, {'symbol': 'DASHBNB', 'price': '0.21780000'}, {'symbol': 'DASHUSDT', 'price': '52.20000000'}, {'symbol': 'NANOUSDT', 'price': '2.22400000'}, {'symbol': 'OMGBNB', 'price': '0.03938000'}, {'symbol': 'OMGUSDT', 'price': '2.03600000'}, {'symbol': 'THETAUSDT', 'price': '1.47300000'}, {'symbol': 'ENJUSDT', 'price': '0.61000000'}, {'symbol': 'MITHUSDT', 'price': '0.01562000'}, {'symbol': 'MATICBNB', 'price': '0.00253200'}, {'symbol': 'MATICBTC', 'price': '0.00002818'}, {'symbol': 'MATICUSDT', 'price': '0.60500000'}, {'symbol': 'ATOMBNB', 'price': '0.03572000'}, {'symbol': 'ATOMBTC', 'price': '0.00039790'}, {'symbol': 'ATOMUSDT', 'price': '8.55000000'}, {'symbol': 'ATOMUSDC', 'price': '8.53000000'}, {'symbol': 'ATOMPAX', 'price': '3.17800000'}, {'symbol': 'ATOMTUSD', 'price': '2.59800000'}, {'symbol': 'ETCUSDC', 'price': '4.71000000'}, {'symbol': 'ETCPAX', 'price': '4.83800000'}, {'symbol': 'ETCTUSD', 'price': '3.79500000'}, {'symbol': 'BATUSDC', 'price': '0.63130000'}, {'symbol': 'BATPAX', 'price': '0.25560000'}, {'symbol': 'BATTUSD', 'price': '0.22220000'}, {'symbol': 'PHBBNB', 'price': '0.00013700'}, {'symbol': 'PHBBTC', 'price': '0.00000546'}, {'symbol': 'PHBUSDC', 'price': '0.00587000'}, {'symbol': 'PHBTUSD', 'price': '0.22900000'}, {'symbol': 'PHBPAX', 'price': '0.00639000'}, {'symbol': 'TFUELBNB', 'price': '0.00012590'}, {'symbol': 'TFUELBTC', 'price': '0.00000261'}, {'symbol': 'TFUELUSDT', 'price': '0.05580000'}, {'symbol': 'TFUELUSDC', 'price': '0.00356500'}, {'symbol': 'TFUELTUSD', 'price': '0.00307700'}, {'symbol': 'TFUELPAX', 'price': '0.00348700'}, {'symbol': 'ONEBNB', 'price': '0.00010570'}, {'symbol': 'ONEBTC', 'price': '0.00000117'}, {'symbol': 'ONEUSDT', 'price': '0.02508000'}, {'symbol': 'ONETUSD', 'price': '0.00472000'}, {'symbol': 'ONEPAX', 'price': '0.00496000'}, {'symbol': 'ONEUSDC', 'price': '0.00520000'}, {'symbol': 'FTMBNB', 'price': '0.00126170'}, {'symbol': 'FTMBTC', 'price': '0.00001404'}, {'symbol': 'FTMUSDT', 'price': '0.30110000'}, {'symbol': 'FTMTUSD', 'price': '0.01095000'}, {'symbol': 'FTMPAX', 'price': '0.01028000'}, {'symbol': 'FTMUSDC', 'price': '0.01107000'}, {'symbol': 'BTCBBTC', 'price': '1.00000000'}, {'symbol': 'BCPTTUSD', 'price': '0.02606000'}, {'symbol': 'BCPTPAX', 'price': '0.02761000'}, {'symbol': 'BCPTUSDC', 'price': '0.02728000'}, {'symbol': 'ALGOBNB', 'price': '0.00146700'}, {'symbol': 'ALGOBTC', 'price': '0.00001632'}, {'symbol': 'ALGOUSDT', 'price': '0.35010000'}, {'symbol': 'ALGOTUSD', 'price': '1.01700000'}, {'symbol': 'ALGOPAX', 'price': '0.20390000'}, {'symbol': 'ALGOUSDC', 'price': '0.23800000'}, {'symbol': 'USDSBUSDT', 'price': '0.99970000'}, {'symbol': 'USDSBUSDS', 'price': '0.99990000'}, {'symbol': 'GTOUSDT', 'price': '0.01897000'}, {'symbol': 'GTOPAX', 'price': '0.01361000'}, {'symbol': 'GTOTUSD', 'price': '0.01236000'}, {'symbol': 'GTOUSDC', 'price': '0.01196000'}, {'symbol': 'ERDBNB', 'price': '0.00083273'}, {'symbol': 'ERDBTC', 'price': '0.00000168'}, {'symbol': 'ERDUSDT', 'price': '0.01971000'}, {'symbol': 'ERDPAX', 'price': '0.00125270'}, {'symbol': 'ERDUSDC', 'price': '0.00135730'}, {'symbol': 'DOGEBNB', 'price': '0.00015270'}, {'symbol': 'DOGEBTC', 'price': '0.00000320'}, {'symbol': 'DOGEUSDT', 'price': '0.06848000'}, {'symbol': 'DOGEPAX', 'price': '0.00216820'}, {'symbol': 'DOGEUSDC', 'price': '0.00212770'}, {'symbol': 'DUSKBNB', 'price': '0.00118000'}, {'symbol': 'DUSKBTC', 'price': '0.00000679'}, {'symbol': 'DUSKUSDT', 'price': '0.14580000'}, {'symbol': 'DUSKUSDC', 'price': '0.01790000'}, {'symbol': 'DUSKPAX', 'price': '0.01890000'}, {'symbol': 'BGBPUSDC', 'price': '1.39000000'}, {'symbol': 'ANKRBNB', 'price': '0.00013150'}, {'symbol': 'ANKRBTC', 'price': '0.00000146'}, {'symbol': 'ANKRUSDT', 'price': '0.03147000'}, {'symbol': 'ANKRTUSD', 'price': '0.00212800'}, {'symbol': 'ANKRPAX', 'price': '0.00209300'}, {'symbol': 'ANKRUSDC', 'price': '0.00209700'}, {'symbol': 'ONTPAX', 'price': '0.84510000'}, {'symbol': 'ONTUSDC', 'price': '0.57080000'}, {'symbol': 'WINBNB', 'price': '0.00000050'}, {'symbol': 'WINBTC', 'price': '0.00000001'}, {'symbol': 'WINUSDT', 'price': '0.00011940'}, {'symbol': 'WINUSDC', 'price': '0.00011930'}, {'symbol': 'COSBNB', 'price': '0.00002823'}, {'symbol': 'COSBTC', 'price': '0.00000031'}, {'symbol': 'COSUSDT', 'price': '0.00674000'}, {'symbol': 'TUSDBTUSD', 'price': '0.99750000'}, {'symbol': 'NPXSUSDT', 'price': '0.00703010'}, {'symbol': 'NPXSUSDC', 'price': '0.00017020'}, {'symbol': 'COCOSBNB', 'price': '0.00299900'}, {'symbol': 'COCOSBTC', 'price': '0.00000003'}, {'symbol': 'COCOSUSDT', 'price': '0.71950000'}, {'symbol': 'MTLUSDT', 'price': '1.46700000'}, {'symbol': 'TOMOBNB', 'price': '0.03255000'}, {'symbol': 'TOMOBTC', 'price': '0.00002479'}, {'symbol': 'TOMOUSDT', 'price': '0.53100000'}, {'symbol': 'TOMOUSDC', 'price': '0.36700000'}, {'symbol': 'PERLBNB', 'price': '0.00007180'}, {'symbol': 'PERLBTC', 'price': '0.00000082'}, {'symbol': 'PERLUSDC', 'price': '0.02447000'}, {'symbol': 'PERLUSDT', 'price': '0.01759000'}, {'symbol': 'DENTUSDT', 'price': '0.00098500'}, {'symbol': 'MFTUSDT', 'price': '0.00398100'}, {'symbol': 'KEYUSDT', 'price': '0.00364300'}, {'symbol': 'STORMUSDT', 'price': '0.00339700'}, {'symbol': 'DOCKUSDT', 'price': '0.01726000'}, {'symbol': 'WANUSDT', 'price': '0.19980000'}, {'symbol': 'FUNUSDT', 'price': '0.00777000'}, {'symbol': 'CVCUSDT', 'price': '0.14990000'}, {'symbol': 'BTTTRX', 'price': '0.03945000'}, {'symbol': 'WINTRX', 'price': '0.00184100'}, {'symbol': 'CHZBNB', 'price': '0.00044150'}, {'symbol': 'CHZBTC', 'price': '0.00000491'}, {'symbol': 'CHZUSDT', 'price': '0.10520000'}, {'symbol': 'BANDBNB', 'price': '0.02248000'}, {'symbol': 'BANDBTC', 'price': '0.00007170'}, {'symbol': 'BANDUSDT', 'price': '1.54100000'}, {'symbol': 'BNBBUSD', 'price': '238.70000000'}, {'symbol': 'BTCBUSD', 'price': '21445.24000000'}, {'symbol': 'BUSDUSDT', 'price': '1.00070000'}, {'symbol': 'BEAMBNB', 'price': '0.02177000'}, {'symbol': 'BEAMBTC', 'price': '0.00000626'}, {'symbol': 'BEAMUSDT', 'price': '0.13510000'}, {'symbol': 'XTZBNB', 'price': '0.00640200'}, {'symbol': 'XTZBTC', 'price': '0.00007110'}, {'symbol': 'XTZUSDT', 'price': '1.52700000'}, {'symbol': 'RENUSDT', 'price': '0.12380000'}, {'symbol': 'RVNUSDT', 'price': '0.02610000'}, {'symbol': 'HCUSDT', 'price': '0.84230000'}, {'symbol': 'HBARBNB', 'price': '0.00030860'}, {'symbol': 'HBARBTC', 'price': '0.00000343'}, {'symbol': 'HBARUSDT', 'price': '0.07350000'}, {'symbol': 'NKNBNB', 'price': '0.00074700'}, {'symbol': 'NKNBTC', 'price': '0.00000468'}, {'symbol': 'NKNUSDT', 'price': '0.10010000'}, {'symbol': 'XRPBUSD', 'price': '0.36530000'}, {'symbol': 'ETHBUSD', 'price': '1241.95000000'}, {'symbol': 'BCHABCBUSD', 'price': '220.16000000'}, {'symbol': 'LTCBUSD', 'price': '59.46000000'}, {'symbol': 'LINKBUSD', 'price': '7.14000000'}, {'symbol': 'ETCBUSD', 'price': '16.54000000'}, {'symbol': 'STXBNB', 'price': '0.00168700'}, {'symbol': 'STXBTC', 'price': '0.00001898'}, {'symbol': 'STXUSDT', 'price': '0.40600000'}, {'symbol': 'KAVABNB', 'price': '0.00765000'}, {'symbol': 'KAVABTC', 'price': '0.00008510'}, {'symbol': 'KAVAUSDT', 'price': '1.82300000'}, {'symbol': 'BUSDNGN', 'price': '462.64000000'}, {'symbol': 'BNBNGN', 'price': '43608.00000000'}, {'symbol': 'BTCNGN', 'price': '25941597.00000000'}, {'symbol': 'ARPABNB', 'price': '0.00017220'}, {'symbol': 'ARPABTC', 'price': '0.00000191'}, {'symbol': 'ARPAUSDT', 'price': '0.04113000'}, {'symbol': 'TRXBUSD', 'price': '0.06472000'}, {'symbol': 'EOSBUSD', 'price': '1.01200000'}, {'symbol': 'IOTXUSDT', 'price': '0.02934000'}, {'symbol': 'RLCUSDT', 'price': '0.80600000'}, {'symbol': 'MCOUSDT', 'price': '2.74400000'}, {'symbol': 'XLMBUSD', 'price': '0.12690000'}, {'symbol': 'ADABUSD', 'price': '0.49860000'}, {'symbol': 'CTXCBNB', 'price': '0.00412200'}, {'symbol': 'CTXCBTC', 'price': '0.00000555'}, {'symbol': 'CTXCUSDT', 'price': '0.11950000'}, {'symbol': 'BCHBNB', 'price': '0.48100000'}, {'symbol': 'BCHBTC', 'price': '0.00537000'}, {'symbol': 'BCHUSDT', 'price': '115.10000000'}, {'symbol': 'BCHUSDC', 'price': '114.70000000'}, {'symbol': 'BCHTUSD', 'price': '630.00000000'}, {'symbol': 'BCHPAX', 'price': '617.72000000'}, {'symbol': 'BCHBUSD', 'price': '115.00000000'}, {'symbol': 'BTCRUB', 'price': '1202797.00000000'}, {'symbol': 'ETHRUB', 'price': '69728.80000000'}, {'symbol': 'XRPRUB', 'price': '20.62000000'}, {'symbol': 'BNBRUB', 'price': '13403.61000000'}, {'symbol': 'TROYBNB', 'price': '0.00001499'}, {'symbol': 'TROYBTC', 'price': '0.00000018'}, {'symbol': 'TROYUSDT', 'price': '0.00359100'}, {'symbol': 'BUSDRUB', 'price': '56.11000000'}, {'symbol': 'QTUMBUSD', 'price': '3.16300000'}, {'symbol': 'VETBUSD', 'price': '0.02616000'}, {'symbol': 'VITEBNB', 'price': '0.00070700'}, {'symbol': 'VITEBTC', 'price': '0.00000107'}, {'symbol': 'VITEUSDT', 'price': '0.02273000'}, {'symbol': 'FTTBNB', 'price': '0.11650000'}, {'symbol': 'FTTBTC', 'price': '0.00129770'}, {'symbol': 'FTTUSDT', 'price': '27.83000000'}, {'symbol': 'BTCTRY', 'price': '364155.00000000'}, {'symbol': 'BNBTRY', 'price': '4053.00000000'}, {'symbol': 'BUSDTRY', 'price': '16.98300000'}, {'symbol': 'ETHTRY', 'price': '21089.00000000'}, {'symbol': 'XRPTRY', 'price': '6.19500000'}, {'symbol': 'USDTTRY', 'price': '16.96800000'}, {'symbol': 'USDTRUB', 'price': '56.09000000'}, {'symbol': 'BTCEUR', 'price': '20358.91000000'}, {'symbol': 'ETHEUR', 'price': '1179.56000000'}, {'symbol': 'BNBEUR', 'price': '226.80000000'}, {'symbol': 'XRPEUR', 'price': '0.34660000'}, {'symbol': 'EURBUSD', 'price': '1.05330000'}, {'symbol': 'EURUSDT', 'price': '1.05390000'}, {'symbol': 'OGNBNB', 'price': '0.00113000'}, {'symbol': 'OGNBTC', 'price': '0.00001235'}, {'symbol': 'OGNUSDT', 'price': '0.26540000'}, {'symbol': 'DREPBNB', 'price': '0.00009380'}, {'symbol': 'DREPBTC', 'price': '0.00002972'}, {'symbol': 'DREPUSDT', 'price': '0.63860000'}, {'symbol': 'BULLUSDT', 'price': '1370.28000000'}, {'symbol': 'BULLBUSD', 'price': '1368.56000000'}, {'symbol': 'BEARUSDT', 'price': '11.16000000'}, {'symbol': 'BEARBUSD', 'price': '11.14000000'}, {'symbol': 'ETHBULLUSDT', 'price': '79.18000000'}, {'symbol': 'ETHBULLBUSD', 'price': '78.46000000'}, {'symbol': 'ETHBEARUSDT', 'price': '12.20000000'}, {'symbol': 'ETHBEARBUSD', 'price': '12.24000000'}, {'symbol': 'TCTBNB', 'price': '0.00041860'}, {'symbol': 'TCTBTC', 'price': '0.00000048'}, {'symbol': 'TCTUSDT', 'price': '0.01013000'}, {'symbol': 'WRXBNB', 'price': '0.00095900'}, {'symbol': 'WRXBTC', 'price': '0.00001073'}, {'symbol': 'WRXUSDT', 'price': '0.23100000'}, {'symbol': 'ICXBUSD', 'price': '0.30000000'}, {'symbol': 'BTSUSDT', 'price': '0.01123000'}, {'symbol': 'BTSBUSD', 'price': '0.01930000'}, {'symbol': 'LSKUSDT', 'price': '1.10100000'}, {'symbol': 'BNTUSDT', 'price': '0.54700000'}, {'symbol': 'BNTBUSD', 'price': '0.54800000'}, {'symbol': 'LTOBNB', 'price': '0.00248000'}, {'symbol': 'LTOBTC', 'price': '0.00000414'}, {'symbol': 'LTOUSDT', 'price': '0.08930000'}, {'symbol': 'ATOMBUSD', 'price': '8.53000000'}, {'symbol': 'DASHBUSD', 'price': '52.10000000'}, {'symbol': 'NEOBUSD', 'price': '9.69000000'}, {'symbol': 'WAVESBUSD', 'price': '6.44000000'}, {'symbol': 'XTZBUSD', 'price': '1.52600000'}, {'symbol': 'EOSBULLUSDT', 'price': '3.85000000'}, {'symbol': 'EOSBULLBUSD', 'price': '3.90000000'}, {'symbol': 'EOSBEARUSDT', 'price': '30.21000000'}, {'symbol': 'EOSBEARBUSD', 'price': '29.81000000'}, {'symbol': 'XRPBULLUSDT', 'price': '8.74000000'}, {'symbol': 'XRPBULLBUSD', 'price': '8.78000000'}, {'symbol': 'XRPBEARUSDT', 'price': '548.55000000'}, {'symbol': 'XRPBEARBUSD', 'price': '547.33000000'}, {'symbol': 'BATBUSD', 'price': '0.42370000'}, {'symbol': 'ENJBUSD', 'price': '0.60900000'}, {'symbol': 'NANOBUSD', 'price': '2.22500000'}, {'symbol': 'ONTBUSD', 'price': '0.24680000'}, {'symbol': 'RVNBUSD', 'price': '0.02614000'}, {'symbol': 'STRATBUSD', 'price': '0.49150000'}, {'symbol': 'STRATBNB', 'price': '0.01900000'}, {'symbol': 'STRATUSDT', 'price': '0.49040000'}, {'symbol': 'AIONBUSD', 'price': '0.07210000'}, {'symbol': 'AIONUSDT', 'price': '0.02900000'}, {'symbol': 'MBLBNB', 'price': '0.00001202'}, {'symbol': 'MBLBTC', 'price': '0.00000005'}, {'symbol': 'MBLUSDT', 'price': '0.00298700'}, {'symbol': 'COTIBNB', 'price': '0.00042260'}, {'symbol': 'COTIBTC', 'price': '0.00000474'}, {'symbol': 'COTIUSDT', 'price': '0.10160000'}, {'symbol': 'ALGOBUSD', 'price': '0.34970000'}, {'symbol': 'BTTBUSD', 'price': '0.00277800'}, {'symbol': 'TOMOBUSD', 'price': '0.53200000'}, {'symbol': 'XMRBUSD', 'price': '126.80000000'}, {'symbol': 'ZECBUSD', 'price': '68.30000000'}, {'symbol': 'BNBBULLUSDT', 'price': '57.21000000'}, {'symbol': 'BNBBULLBUSD', 'price': '58.37000000'}, {'symbol': 'BNBBEARUSDT', 'price': '58.61000000'}, {'symbol': 'BNBBEARBUSD', 'price': '57.21000000'}, {'symbol': 'STPTBNB', 'price': '0.00067000'}, {'symbol': 'STPTBTC', 'price': '0.00000201'}, {'symbol': 'STPTUSDT', 'price': '0.04291000'}, {'symbol': 'BTCZAR', 'price': '857014.00000000'}, {'symbol': 'ETHZAR', 'price': '27850.40000000'}, {'symbol': 'BNBZAR', 'price': '5000.00000000'}, {'symbol': 'USDTZAR', 'price': '14.02300000'}, {'symbol': 'BUSDZAR', 'price': '13.88800000'}, {'symbol': 'BTCBKRW', 'price': '42029197.00000000'}, {'symbol': 'ETHBKRW', 'price': '1277799.00000000'}, {'symbol': 'BNBBKRW', 'price': '44687.00000000'}, {'symbol': 'WTCUSDT', 'price': '0.18950000'}, {'symbol': 'DATABUSD', 'price': '0.02751000'}, {'symbol': 'DATAUSDT', 'price': '0.02763000'}, {'symbol': 'XZCUSDT', 'price': '4.44600000'}, {'symbol': 'SOLBNB', 'price': '0.17580000'}, {'symbol': 'SOLBTC', 'price': '0.00195480'}, {'symbol': 'SOLUSDT', 'price': '41.93000000'}, {'symbol': 'SOLBUSD', 'price': '41.90000000'}, {'symbol': 'BTCIDRT', 'price': '693891182.00'}, {'symbol': 'BNBIDRT', 'price': '4286985.00'}, {'symbol': 'USDTIDRT', 'price': '14861.00'}, {'symbol': 'BUSDIDRT', 'price': '14389.00'}, {'symbol': 'CTSIBTC', 'price': '0.00000786'}, {'symbol': 'CTSIUSDT', 'price': '0.16860000'}, {'symbol': 'CTSIBNB', 'price': '0.00070700'}, {'symbol': 'CTSIBUSD', 'price': '0.16860000'}, {'symbol': 'HIVEBNB', 'price': '0.00429000'}, {'symbol': 'HIVEBTC', 'price': '0.00001916'}, {'symbol': 'HIVEUSDT', 'price': '0.41200000'}, {'symbol': 'CHRBNB', 'price': '0.00093750'}, {'symbol': 'CHRBTC', 'price': '0.00001040'}, {'symbol': 'CHRUSDT', 'price': '0.22340000'}, {'symbol': 'BTCUPUSDT', 'price': '5.31000000'}, {'symbol': 'BTCDOWNUSDT', 'price': '0.03494700'}, {'symbol': 'GXSUSDT', 'price': '1.79230000'}, {'symbol': 'ARDRUSDT', 'price': '0.10310000'}, {'symbol': 'ERDBUSD', 'price': '0.01966100'}, {'symbol': 'LENDUSDT', 'price': '0.51431000'}, {'symbol': 'HBARBUSD', 'price': '0.07360000'}, {'symbol': 'MATICBUSD', 'price': '0.60400000'}, {'symbol': 'WRXBUSD', 'price': '0.23100000'}, {'symbol': 'ZILBUSD', 'price': '0.04900000'}, {'symbol': 'MDTBNB', 'price': '0.00073720'}, {'symbol': 'MDTBTC', 'price': '0.00000128'}, {'symbol': 'MDTUSDT', 'price': '0.02756000'}, {'symbol': 'STMXBTC', 'price': '0.00000033'}, {'symbol': 'STMXETH', 'price': '0.00000567'}, {'symbol': 'STMXUSDT', 'price': '0.00707000'}, {'symbol': 'KNCBUSD', 'price': '1.51200000'}, {'symbol': 'KNCUSDT', 'price': '1.51400000'}, {'symbol': 'REPBUSD', 'price': '13.67300000'}, {'symbol': 'REPUSDT', 'price': '9.20000000'}, {'symbol': 'LRCBUSD', 'price': '0.44200000'}, {'symbol': 'LRCUSDT', 'price': '0.44220000'}, {'symbol': 'IQBNB', 'price': '0.00002243'}, {'symbol': 'IQBUSD', 'price': '0.00467000'}, {'symbol': 'PNTBTC', 'price': '0.00001024'}, {'symbol': 'PNTUSDT', 'price': '0.22000000'}, {'symbol': 'BTCGBP', 'price': '17495.18000000'}, {'symbol': 'ETHGBP', 'price': '1012.92000000'}, {'symbol': 'XRPGBP', 'price': '0.29820000'}, {'symbol': 'BNBGBP', 'price': '194.70000000'}, {'symbol': 'GBPBUSD', 'price': '1.22600000'}, {'symbol': 'DGBBTC', 'price': '0.00000053'}, {'symbol': 'DGBBUSD', 'price': '0.01125000'}, {'symbol': 'BTCUAH', 'price': '739373.00000000'}, {'symbol': 'USDTUAH', 'price': '34.46000000'}, {'symbol': 'COMPBTC', 'price': '0.00241000'}, {'symbol': 'COMPBNB', 'price': '5.71900000'}, {'symbol': 'COMPBUSD', 'price': '51.60000000'}, {'symbol': 'COMPUSDT', 'price': '51.60000000'}, {'symbol': 'BTCBIDR', 'price': '318921088.00'}, {'symbol': 'ETHBIDR', 'price': '18479139.00'}, {'symbol': 'BNBBIDR', 'price': '3549413.00'}, {'symbol': 'BUSDBIDR', 'price': '14879.00'}, {'symbol': 'USDTBIDR', 'price': '14867.00'}, {'symbol': 'BKRWUSDT', 'price': '0.00084530'}, {'symbol': 'BKRWBUSD', 'price': '0.00084550'}, {'symbol': 'SCUSDT', 'price': '0.00418000'}, {'symbol': 'ZENUSDT', 'price': '16.12000000'}, {'symbol': 'SXPBTC', 'price': '0.00002035'}, {'symbol': 'SXPBNB', 'price': '0.00182200'}, {'symbol': 'SXPBUSD', 'price': '0.43800000'}, {'symbol': 'SNXBTC', 'price': '0.00013560'}, {'symbol': 'SNXBNB', 'price': '0.01219000'}, {'symbol': 'SNXBUSD', 'price': '2.90900000'}, {'symbol': 'SNXUSDT', 'price': '2.91000000'}, {'symbol': 'ETHUPUSDT', 'price': '3.08000000'}, {'symbol': 'ETHDOWNUSDT', 'price': '1.83870000'}, {'symbol': 'ADAUPUSDT', 'price': '1.08200000'}, {'symbol': 'ADADOWNUSDT', 'price': '0.00526700'}, {'symbol': 'LINKUPUSDT', 'price': '0.01424000'}, {'symbol': 'LINKDOWNUSDT', 'price': '0.01091000'}, {'symbol': 'VTHOBNB', 'price': '0.00000673'}, {'symbol': 'VTHOBUSD', 'price': '0.00071800'}, {'symbol': 'VTHOUSDT', 'price': '0.00170000'}, {'symbol': 'DCRBUSD', 'price': '16.03500000'}, {'symbol': 'DGBUSDT', 'price': '0.01128000'}, {'symbol': 'GBPUSDT', 'price': '1.22600000'}, {'symbol': 'STORJBUSD', 'price': '0.91780000'}, {'symbol': 'SXPUSDT', 'price': '0.43700000'}, {'symbol': 'IRISBNB', 'price': '0.00166200'}, {'symbol': 'IRISBTC', 'price': '0.00000083'}, {'symbol': 'IRISBUSD', 'price': '0.06080000'}, {'symbol': 'MKRBNB', 'price': '6.90300000'}, {'symbol': 'MKRBTC', 'price': '0.04876000'}, {'symbol': 'MKRUSDT', 'price': '1046.00000000'}, {'symbol': 'MKRBUSD', 'price': '1048.00000000'}, {'symbol': 'DAIBNB', 'price': '0.04876000'}, {'symbol': 'DAIBTC', 'price': '0.00008966'}, {'symbol': 'DAIUSDT', 'price': '1.01890000'}, {'symbol': 'DAIBUSD', 'price': '1.01810000'}, {'symbol': 'RUNEBNB', 'price': '0.01010000'}, {'symbol': 'RUNEBTC', 'price': '0.00011250'}, {'symbol': 'RUNEBUSD', 'price': '2.41300000'}, {'symbol': 'MANABUSD', 'price': '1.03980000'}, {'symbol': 'DOGEBUSD', 'price': '0.06845000'}, {'symbol': 'LENDBUSD', 'price': '0.51530000'}, {'symbol': 'ZRXBUSD', 'price': '0.31120000'}, {'symbol': 'DCRUSDT', 'price': '25.90000000'}, {'symbol': 'STORJUSDT', 'price': '0.91900000'}, {'symbol': 'XRPBKRW', 'price': '319.76000000'}, {'symbol': 'ADABKRW', 'price': '327.55000000'}, {'symbol': 'BTCAUD', 'price': '30881.96000000'}, {'symbol': 'ETHAUD', 'price': '1790.00000000'}, {'symbol': 'AUDBUSD', 'price': '0.69410000'}, {'symbol': 'FIOBNB', 'price': '0.00017080'}, {'symbol': 'FIOBTC', 'price': '0.00000194'}, {'symbol': 'FIOBUSD', 'price': '0.04140000'}, {'symbol': 'BNBUPUSDT', 'price': '28.65000000'}, {'symbol': 'BNBDOWNUSDT', 'price': '0.08181000'}, {'symbol': 'XTZUPUSDT', 'price': '0.00255100'}, {'symbol': 'XTZDOWNUSDT', 'price': '2.60010000'}, {'symbol': 'AVABNB', 'price': '0.00218800'}, {'symbol': 'AVABTC', 'price': '0.00002967'}, {'symbol': 'AVABUSD', 'price': '0.63700000'}, {'symbol': 'USDTBKRW', 'price': '1125.00000000'}, {'symbol': 'BUSDBKRW', 'price': '1097.18000000'}, {'symbol': 'IOTABUSD', 'price': '0.30470000'}, {'symbol': 'MANAUSDT', 'price': '1.04030000'}, {'symbol': 'XRPAUD', 'price': '0.52650000'}, {'symbol': 'BNBAUD', 'price': '344.30000000'}, {'symbol': 'AUDUSDT', 'price': '0.69470000'}, {'symbol': 'BALBNB', 'price': '0.42580000'}, {'symbol': 'BALBTC', 'price': '0.00026160'}, {'symbol': 'BALBUSD', 'price': '5.60000000'}, {'symbol': 'YFIBNB', 'price': '82.19000000'}, {'symbol': 'YFIBTC', 'price': '0.31710000'}, {'symbol': 'YFIBUSD', 'price': '6798.93000000'}, {'symbol': 'YFIUSDT', 'price': '6800.00000000'}, {'symbol': 'BLZBUSD', 'price': '0.10380000'}, {'symbol': 'KMDBUSD', 'price': '0.46760000'}, {'symbol': 'BALUSDT', 'price': '5.60000000'}, {'symbol': 'BLZUSDT', 'price': '0.10380000'}, {'symbol': 'IRISUSDT', 'price': '0.01772000'}, {'symbol': 'KMDUSDT', 'price': '0.20690000'}, {'symbol': 'BTCDAI', 'price': '21451.72000000'}, {'symbol': 'ETHDAI', 'price': '1242.13000000'}, {'symbol': 'BNBDAI', 'price': '237.50000000'}, {'symbol': 'USDTDAI', 'price': '0.99930000'}, {'symbol': 'BUSDDAI', 'price': '1.00010000'}, {'symbol': 'JSTBNB', 'price': '0.00021850'}, {'symbol': 'JSTBTC', 'price': '0.00000138'}, {'symbol': 'JSTBUSD', 'price': '0.02957000'}, {'symbol': 'JSTUSDT', 'price': '0.02964000'}, {'symbol': 'SRMBNB', 'price': '0.00403000'}, {'symbol': 'SRMBTC', 'price': '0.00004490'}, {'symbol': 'SRMBUSD', 'price': '0.96300000'}, {'symbol': 'SRMUSDT', 'price': '0.96600000'}, {'symbol': 'ANTBNB', 'price': '0.00790000'}, {'symbol': 'ANTBTC', 'price': '0.00008793'}, {'symbol': 'ANTBUSD', 'price': '1.88600000'}, {'symbol': 'ANTUSDT', 'price': '1.88900000'}, {'symbol': 'CRVBNB', 'price': '0.00687000'}, {'symbol': 'CRVBTC', 'price': '0.00003832'}, {'symbol': 'CRVBUSD', 'price': '0.82400000'}, {'symbol': 'CRVUSDT', 'price': '0.82300000'}, {'symbol': 'SANDBNB', 'price': '0.00550800'}, {'symbol': 'SANDBTC', 'price': '0.00006125'}, {'symbol': 'SANDUSDT', 'price': '1.31370000'}, {'symbol': 'SANDBUSD', 'price': '1.31420000'}, {'symbol': 'OCEANBNB', 'price': '0.00085000'}, {'symbol': 'OCEANBTC', 'price': '0.00000946'}, {'symbol': 'OCEANBUSD', 'price': '0.20350000'}, {'symbol': 'OCEANUSDT', 'price': '0.20340000'}, {'symbol': 'NMRBTC', 'price': '0.00044100'}, {'symbol': 'NMRBUSD', 'price': '9.39000000'}, {'symbol': 'NMRUSDT', 'price': '9.45000000'}, {'symbol': 'DOTBNB', 'price': '0.03404000'}, {'symbol': 'DOTBTC', 'price': '0.00037850'}, {'symbol': 'DOTBUSD', 'price': '8.12000000'}, {'symbol': 'DOTUSDT', 'price': '8.13000000'}, {'symbol': 'LUNABNB', 'price': '0.00000019'}, {'symbol': 'LUNABTC', 'price': '0.00000001'}, {'symbol': 'LUNABUSD', 'price': '1.99290000'}, {'symbol': 'LUNAUSDT', 'price': '1.99380000'}, {'symbol': 'IDEXBTC', 'price': '0.00000373'}, {'symbol': 'IDEXBUSD', 'price': '0.08000000'}, {'symbol': 'RSRBNB', 'price': '0.00003760'}, {'symbol': 'RSRBTC', 'price': '0.00000016'}, {'symbol': 'RSRBUSD', 'price': '0.00898000'}, {'symbol': 'RSRUSDT', 'price': '0.00898000'}, {'symbol': 'PAXGBNB', 'price': '7.64000000'}, {'symbol': 'PAXGBTC', 'price': '0.08513000'}, {'symbol': 'PAXGBUSD', 'price': '1826.00000000'}, {'symbol': 'PAXGUSDT', 'price': '1827.00000000'}, {'symbol': 'WNXMBNB', 'price': '0.17350000'}, {'symbol': 'WNXMBTC', 'price': '0.00067200'}, {'symbol': 'WNXMBUSD', 'price': '22.16500000'}, {'symbol': 'WNXMUSDT', 'price': '16.87000000'}, {'symbol': 'TRBBNB', 'price': '0.51700000'}, {'symbol': 'TRBBTC', 'price': '0.00055700'}, {'symbol': 'TRBBUSD', 'price': '11.93000000'}, {'symbol': 'TRBUSDT', 'price': '11.96000000'}, {'symbol': 'ETHNGN', 'price': '805670.00000000'}, {'symbol': 'DOTBIDR', 'price': '120955.00'}, {'symbol': 'LINKAUD', 'price': '10.23000000'}, {'symbol': 'SXPAUD', 'price': '1.86800000'}, {'symbol': 'BZRXBNB', 'price': '0.00514000'}, {'symbol': 'BZRXBTC', 'price': '0.00000463'}, {'symbol': 'BZRXBUSD', 'price': '0.21640000'}, {'symbol': 'BZRXUSDT', 'price': '0.21560000'}, {'symbol': 'WBTCBTC', 'price': '0.99900000'}, {'symbol': 'WBTCETH', 'price': '17.25000000'}, {'symbol': 'SUSHIBNB', 'price': '0.00527000'}, {'symbol': 'SUSHIBTC', 'price': '0.00005860'}, {'symbol': 'SUSHIBUSD', 'price': '1.25800000'}, {'symbol': 'SUSHIUSDT', 'price': '1.25900000'}, {'symbol': 'YFIIBNB', 'price': '4.42000000'}, {'symbol': 'YFIIBTC', 'price': '0.07030000'}, {'symbol': 'YFIIBUSD', 'price': '1192.00000000'}, {'symbol': 'YFIIUSDT', 'price': '1514.00000000'}, {'symbol': 'KSMBNB', 'price': '0.23940000'}, {'symbol': 'KSMBTC', 'price': '0.00266500'}, {'symbol': 'KSMBUSD', 'price': '57.30000000'}, {'symbol': 'KSMUSDT', 'price': '57.30000000'}, {'symbol': 'EGLDBNB', 'price': '0.26190000'}, {'symbol': 'EGLDBTC', 'price': '0.00290200'}, {'symbol': 'EGLDBUSD', 'price': '62.16000000'}, {'symbol': 'EGLDUSDT', 'price': '62.24000000'}, {'symbol': 'DIABNB', 'price': '0.00381300'}, {'symbol': 'DIABTC', 'price': '0.00001943'}, {'symbol': 'DIABUSD', 'price': '0.41500000'}, {'symbol': 'DIAUSDT', 'price': '0.41400000'}, {'symbol': 'RUNEUSDT', 'price': '2.41500000'}, {'symbol': 'FIOUSDT', 'price': '0.04150000'}, {'symbol': 'UMABTC', 'price': '0.00013080'}, {'symbol': 'UMAUSDT', 'price': '2.80600000'}, {'symbol': 'EOSUPUSDT', 'price': '0.21130000'}, {'symbol': 'EOSDOWNUSDT', 'price': '0.00036650'}, {'symbol': 'TRXUPUSDT', 'price': '0.05318000'}, {'symbol': 'TRXDOWNUSDT', 'price': '1.70200000'}, {'symbol': 'XRPUPUSDT', 'price': '0.14530000'}, {'symbol': 'XRPDOWNUSDT', 'price': '0.00109140'}, {'symbol': 'DOTUPUSDT', 'price': '0.27990000'}, {'symbol': 'DOTDOWNUSDT', 'price': '17.60900000'}, {'symbol': 'SRMBIDR', 'price': '26748.00'}, {'symbol': 'ONEBIDR', 'price': '119.92'}, {'symbol': 'LINKTRY', 'price': '121.10000000'}, {'symbol': 'USDTNGN', 'price': '611.80000000'}, {'symbol': 'BELBNB', 'price': '0.00384800'}, {'symbol': 'BELBTC', 'price': '0.00004311'}, {'symbol': 'BELBUSD', 'price': '0.92600000'}, {'symbol': 'BELUSDT', 'price': '0.92500000'}, {'symbol': 'WINGBNB', 'price': '0.04865000'}, {'symbol': 'WINGBTC', 'price': '0.00023900'}, {'symbol': 'SWRVBNB', 'price': '0.00150400'}, {'symbol': 'SWRVBUSD', 'price': '0.56490000'}, {'symbol': 'WINGBUSD', 'price': '5.13000000'}, {'symbol': 'WINGUSDT', 'price': '5.15000000'}, {'symbol': 'LTCUPUSDT', 'price': '0.48010000'}, {'symbol': 'LTCDOWNUSDT', 'price': '2.22790000'}, {'symbol': 'LENDBKRW', 'price': '579.46000000'}, {'symbol': 'SXPEUR', 'price': '0.41400000'}, {'symbol': 'CREAMBNB', 'price': '0.07230000'}, {'symbol': 'CREAMBUSD', 'price': '19.20000000'}, {'symbol': 'UNIBNB', 'price': '0.02378000'}, {'symbol': 'UNIBTC', 'price': '0.00026490'}, {'symbol': 'UNIBUSD', 'price': '5.68000000'}, {'symbol': 'UNIUSDT', 'price': '5.68000000'}, {'symbol': 'NBSBTC', 'price': '0.00000031'}, {'symbol': 'NBSUSDT', 'price': '0.00327000'}, {'symbol': 'OXTBTC', 'price': '0.00000487'}, {'symbol': 'OXTUSDT', 'price': '0.10450000'}, {'symbol': 'SUNBTC', 'price': '0.00071100'}, {'symbol': 'SUNUSDT', 'price': '0.00619000'}, {'symbol': 'AVAXBNB', 'price': '0.08919000'}, {'symbol': 'AVAXBTC', 'price': '0.00099300'}, {'symbol': 'AVAXBUSD', 'price': '21.28000000'}, {'symbol': 'AVAXUSDT', 'price': '21.31000000'}, {'symbol': 'HNTBTC', 'price': '0.00054630'}, {'symbol': 'HNTUSDT', 'price': '11.71000000'}, {'symbol': 'BAKEBNB', 'price': '0.00113100'}, {'symbol': 'BURGERBNB', 'price': '0.00279000'}, {'symbol': 'SXPBIDR', 'price': '19956.00'}, {'symbol': 'LINKBKRW', 'price': '16948.99000000'}, {'symbol': 'FLMBNB', 'price': '0.00333000'}, {'symbol': 'FLMBTC', 'price': '0.00000527'}, {'symbol': 'FLMBUSD', 'price': '0.23210000'}, {'symbol': 'FLMUSDT', 'price': '0.11310000'}, {'symbol': 'SCRTBTC', 'price': '0.00005144'}, {'symbol': 'SCRTETH', 'price': '0.00088830'}, {'symbol': 'CAKEBNB', 'price': '0.01399000'}, {'symbol': 'CAKEBUSD', 'price': '3.34200000'}, {'symbol': 'SPARTABNB', 'price': '0.00014960'}, {'symbol': 'UNIUPUSDT', 'price': '1.05500000'}, {'symbol': 'UNIDOWNUSDT', 'price': '2.17200000'}, {'symbol': 'ORNBTC', 'price': '0.00006660'}, {'symbol': 'ORNUSDT', 'price': '1.42900000'}, {'symbol': 'TRXNGN', 'price': '20.71000000'}, {'symbol': 'SXPTRY', 'price': '7.41000000'}, {'symbol': 'UTKBTC', 'price': '0.00000598'}, {'symbol': 'UTKUSDT', 'price': '0.12880000'}, {'symbol': 'XVSBNB', 'price': '0.02107000'}, {'symbol': 'XVSBTC', 'price': '0.00023470'}, {'symbol': 'XVSBUSD', 'price': '5.03000000'}, {'symbol': 'XVSUSDT', 'price': '5.03000000'}, {'symbol': 'ALPHABNB', 'price': '0.00055000'}, {'symbol': 'ALPHABTC', 'price': '0.00000615'}, {'symbol': 'ALPHABUSD', 'price': '0.13170000'}, {'symbol': 'ALPHAUSDT', 'price': '0.13150000'}, {'symbol': 'VIDTBTC', 'price': '0.00000871'}, {'symbol': 'VIDTBUSD', 'price': '0.18810000'}, {'symbol': 'AAVEBNB', 'price': '0.29670000'}, {'symbol': 'BTCBRL', 'price': '112510.00000000'}, {'symbol': 'USDTBRL', 'price': '5.24500000'}, {'symbol': 'AAVEBTC', 'price': '0.00330700'}, {'symbol': 'AAVEETH', 'price': '0.05710000'}, {'symbol': 'AAVEBUSD', 'price': '70.90000000'}, {'symbol': 'AAVEUSDT', 'price': '70.90000000'}, {'symbol': 'AAVEBKRW', 'price': '164167.00000000'}, {'symbol': 'NEARBNB', 'price': '0.01772100'}, {'symbol': 'NEARBTC', 'price': '0.00019698'}, {'symbol': 'NEARBUSD', 'price': '4.22300000'}, {'symbol': 'NEARUSDT', 'price': '4.22800000'}, {'symbol': 'SXPUPUSDT', 'price': '0.17426000'}, {'symbol': 'SXPDOWNUSDT', 'price': '0.08950000'}, {'symbol': 'DOTBKRW', 'price': '13514.98000000'}, {'symbol': 'SXPGBP', 'price': '0.40800000'}, {'symbol': 'FILBNB', 'price': '0.02550000'}, {'symbol': 'FILBTC', 'price': '0.00028400'}, {'symbol': 'FILBUSD', 'price': '6.10000000'}, {'symbol': 'FILUSDT', 'price': '6.10000000'}, {'symbol': 'FILUPUSDT', 'price': '0.15150000'}, {'symbol': 'FILDOWNUSDT', 'price': '0.00076660'}, {'symbol': 'YFIUPUSDT', 'price': '0.11690000'}, {'symbol': 'YFIDOWNUSDT', 'price': '0.90090000'}, {'symbol': 'INJBNB', 'price': '0.00603000'}, {'symbol': 'INJBTC', 'price': '0.00006720'}, {'symbol': 'INJBUSD', 'price': '1.44500000'}, {'symbol': 'INJUSDT', 'price': '1.43800000'}, {'symbol': 'AERGOBTC', 'price': '0.00000572'}, {'symbol': 'AERGOBUSD', 'price': '0.12250000'}, {'symbol': 'LINKEUR', 'price': '6.76000000'}, {'symbol': 'ONEBUSD', 'price': '0.02509000'}, {'symbol': 'EASYETH', 'price': '0.00623000'}, {'symbol': 'AUDIOBTC', 'price': '0.00001789'}, {'symbol': 'AUDIOBUSD', 'price': '0.38400000'}, {'symbol': 'AUDIOUSDT', 'price': '0.38400000'}, {'symbol': 'CTKBNB', 'price': '0.00360400'}, {'symbol': 'CTKBTC', 'price': '0.00004010'}, {'symbol': 'CTKBUSD', 'price': '0.85700000'}, {'symbol': 'CTKUSDT', 'price': '0.86100000'}, {'symbol': 'BCHUPUSDT', 'price': '0.07240000'}, {'symbol': 'BCHDOWNUSDT', 'price': '0.22470000'}, {'symbol': 'BOTBTC', 'price': '0.04906000'}, {'symbol': 'BOTBUSD', 'price': '2783.23000000'}, {'symbol': 'ETHBRL', 'price': '6511.19000000'}, {'symbol': 'DOTEUR', 'price': '7.71000000'}, {'symbol': 'AKROBTC', 'price': '0.00000013'}, {'symbol': 'AKROUSDT', 'price': '0.00477000'}, {'symbol': 'KP3RBNB', 'price': '0.59430000'}, {'symbol': 'KP3RBUSD', 'price': '141.63000000'}, {'symbol': 'AXSBNB', 'price': '0.07460000'}, {'symbol': 'AXSBTC', 'price': '0.00083100'}, {'symbol': 'AXSBUSD', 'price': '17.82000000'}, {'symbol': 'AXSUSDT', 'price': '17.83000000'}, {'symbol': 'HARDBNB', 'price': '0.00083700'}, {'symbol': 'HARDBTC', 'price': '0.00000936'}, {'symbol': 'HARDBUSD', 'price': '0.20040000'}, {'symbol': 'HARDUSDT', 'price': '0.20030000'}, {'symbol': 'BNBBRL', 'price': '1253.00000000'}, {'symbol': 'LTCEUR', 'price': '56.44000000'}, {'symbol': 'RENBTCBTC', 'price': '0.99310000'}, {'symbol': 'RENBTCETH', 'price': '16.29900000'}, {'symbol': 'DNTBUSD', 'price': '0.04440000'}, {'symbol': 'DNTUSDT', 'price': '0.04480000'}, {'symbol': 'SLPETH', 'price': '0.00000338'}, {'symbol': 'ADAEUR', 'price': '0.47350000'}, {'symbol': 'LTCNGN', 'price': '78132.00000000'}, {'symbol': 'CVPETH', 'price': '0.00022460'}, {'symbol': 'CVPBUSD', 'price': '0.28000000'}, {'symbol': 'STRAXBTC', 'price': '0.00002299'}, {'symbol': 'STRAXETH', 'price': '0.00039650'}, {'symbol': 'STRAXBUSD', 'price': '0.49200000'}, {'symbol': 'STRAXUSDT', 'price': '0.49200000'}, {'symbol': 'FORBTC', 'price': '0.00000082'}, {'symbol': 'FORBUSD', 'price': '0.01738000'}, {'symbol': 'UNFIBNB', 'price': '0.02654000'}, {'symbol': 'UNFIBTC', 'price': '0.00023610'}, {'symbol': 'UNFIBUSD', 'price': '5.06100000'}, {'symbol': 'UNFIUSDT', 'price': '5.06500000'}, {'symbol': 'FRONTETH', 'price': '0.00033040'}, {'symbol': 'FRONTBUSD', 'price': '0.20630000'}, {'symbol': 'BCHABUSD', 'price': '43.64100000'}, {'symbol': 'ROSEBTC', 'price': '0.00000256'}, {'symbol': 'ROSEBUSD', 'price': '0.05471000'}, {'symbol': 'ROSEUSDT', 'price': '0.05476000'}, {'symbol': 'AVAXTRY', 'price': '361.50000000'}, {'symbol': 'BUSDBRL', 'price': '5.24600000'}, {'symbol': 'AVAUSDT', 'price': '0.63700000'}, {'symbol': 'SYSBUSD', 'price': '0.15360000'}, {'symbol': 'XEMUSDT', 'price': '0.04290000'}, {'symbol': 'HEGICETH', 'price': '0.00001647'}, {'symbol': 'HEGICBUSD', 'price': '0.02120000'}, {'symbol': 'AAVEUPUSDT', 'price': '0.60080000'}, {'symbol': 'AAVEDOWNUSDT', 'price': '0.00467300'}, {'symbol': 'PROMBNB', 'price': '0.01556000'}, {'symbol': 'PROMBUSD', 'price': '3.74000000'}, {'symbol': 'XRPBRL', 'price': '1.91700000'}, {'symbol': 'XRPNGN', 'price': '214.17000000'}, {'symbol': 'SKLBTC', 'price': '0.00000269'}, {'symbol': 'SKLBUSD', 'price': '0.05790000'}, {'symbol': 'SKLUSDT', 'price': '0.05780000'}, {'symbol': 'BCHEUR', 'price': '108.70000000'}, {'symbol': 'YFIEUR', 'price': '6472.90000000'}, {'symbol': 'ZILBIDR', 'price': '729.00'}, {'symbol': 'SUSDBTC', 'price': '0.00002065'}, {'symbol': 'SUSDETH', 'price': '0.00052700'}, {'symbol': 'SUSDUSDT', 'price': '0.99600000'}, {'symbol': 'COVERETH', 'price': '0.06373000'}, {'symbol': 'COVERBUSD', 'price': '193.60000000'}, {'symbol': 'GLMBTC', 'price': '0.00001161'}, {'symbol': 'GLMETH', 'price': '0.00020180'}, {'symbol': 'GHSTETH', 'price': '0.00107140'}, {'symbol': 'GHSTBUSD', 'price': '1.33400000'}, {'symbol': 'SUSHIUPUSDT', 'price': '0.00471400'}, {'symbol': 'SUSHIDOWNUSDT', 'price': '37.37000000'}, {'symbol': 'XLMUPUSDT', 'price': '0.02430000'}, {'symbol': 'XLMDOWNUSDT', 'price': '4.30400000'}, {'symbol': 'LINKBRL', 'price': '37.60000000'}, {'symbol': 'LINKNGN', 'price': '11772.00000000'}, {'symbol': 'LTCRUB', 'price': '3330.40000000'}, {'symbol': 'TRXTRY', 'price': '1.10010000'}, {'symbol': 'XLMEUR', 'price': '0.12060000'}, {'symbol': 'DFETH', 'price': '0.00007020'}, {'symbol': 'DFBUSD', 'price': '0.03830000'}, {'symbol': 'GRTBTC', 'price': '0.00000547'}, {'symbol': 'GRTETH', 'price': '0.00009460'}, {'symbol': 'GRTUSDT', 'price': '0.11760000'}, {'symbol': 'JUVBTC', 'price': '0.00018960'}, {'symbol': 'JUVBUSD', 'price': '4.05000000'}, {'symbol': 'JUVUSDT', 'price': '4.04000000'}, {'symbol': 'PSGBTC', 'price': '0.00031670'}, {'symbol': 'PSGBUSD', 'price': '6.80000000'}, {'symbol': 'PSGUSDT', 'price': '6.81000000'}, {'symbol': 'BUSDBVND', 'price': '23720.00'}, {'symbol': 'USDTBVND', 'price': '23710.00'}, {'symbol': '1INCHBTC', 'price': '0.00003392'}, {'symbol': '1INCHUSDT', 'price': '0.72800000'}, {'symbol': 'REEFBTC', 'price': '0.00000014'}, {'symbol': 'REEFUSDT', 'price': '0.00385000'}, {'symbol': 'OGBTC', 'price': '0.00017410'}, {'symbol': 'OGUSDT', 'price': '3.74000000'}, {'symbol': 'ATMBTC', 'price': '0.00015610'}, {'symbol': 'ATMUSDT', 'price': '3.37000000'}, {'symbol': 'ASRBTC', 'price': '0.00015500'}, {'symbol': 'ASRUSDT', 'price': '3.36100000'}, {'symbol': 'CELOBTC', 'price': '0.00004664'}, {'symbol': 'CELOUSDT', 'price': '0.99700000'}, {'symbol': 'RIFBTC', 'price': '0.00000258'}, {'symbol': 'RIFUSDT', 'price': '0.05530000'}, {'symbol': 'CHZTRY', 'price': '1.78500000'}, {'symbol': 'XLMTRY', 'price': '2.15800000'}, {'symbol': 'LINKGBP', 'price': '5.82000000'}, {'symbol': 'GRTEUR', 'price': '0.11100000'}, {'symbol': 'BTCSTBTC', 'price': '0.00028890'}, {'symbol': 'BTCSTBUSD', 'price': '6.23000000'}, {'symbol': 'BTCSTUSDT', 'price': '6.20000000'}, {'symbol': 'TRUBTC', 'price': '0.00000354'}, {'symbol': 'TRUBUSD', 'price': '0.53570000'}, {'symbol': 'TRUUSDT', 'price': '0.07640000'}, {'symbol': 'DEXEETH', 'price': '0.00240300'}, {'symbol': 'DEXEBUSD', 'price': '2.95000000'}, {'symbol': 'EOSEUR', 'price': '0.95900000'}, {'symbol': 'LTCBRL', 'price': '311.90000000'}, {'symbol': 'USDCBUSD', 'price': '1.00000000'}, {'symbol': 'TUSDBUSD', 'price': '1.00000000'}, {'symbol': 'PAXBUSD', 'price': '1.00000000'}, {'symbol': 'CKBBTC', 'price': '0.00000015'}, {'symbol': 'CKBBUSD', 'price': '0.00366000'}, {'symbol': 'CKBUSDT', 'price': '0.00367000'}, {'symbol': 'TWTBTC', 'price': '0.00004251'}, {'symbol': 'TWTBUSD', 'price': '0.91160000'}, {'symbol': 'TWTUSDT', 'price': '0.91280000'}, {'symbol': 'FIROBTC', 'price': '0.00007120'}, {'symbol': 'FIROETH', 'price': '0.00133300'}, {'symbol': 'FIROUSDT', 'price': '1.53400000'}, {'symbol': 'BETHETH', 'price': '0.95130000'}, {'symbol': 'DOGEEUR', 'price': '0.06498000'}, {'symbol': 'DOGETRY', 'price': '1.16200000'}, {'symbol': 'DOGEAUD', 'price': '0.09850000'}, {'symbol': 'DOGEBRL', 'price': '0.35970000'}, {'symbol': 'DOTNGN', 'price': '10716.00000000'}, {'symbol': 'PROSETH', 'price': '0.00013840'}, {'symbol': 'LITBTC', 'price': '0.00004904'}, {'symbol': 'LITBUSD', 'price': '1.05100000'}, {'symbol': 'LITUSDT', 'price': '1.05200000'}, {'symbol': 'BTCVAI', 'price': '56876.40000000'}, {'symbol': 'BUSDVAI', 'price': '1.05300000'}, {'symbol': 'SFPBTC', 'price': '0.00001911'}, {'symbol': 'SFPBUSD', 'price': '0.41050000'}, {'symbol': 'SFPUSDT', 'price': '0.41080000'}, {'symbol': 'DOGEGBP', 'price': '0.05610000'}, {'symbol': 'DOTTRY', 'price': '138.00000000'}, {'symbol': 'FXSBTC', 'price': '0.00024787'}, {'symbol': 'FXSBUSD', 'price': '5.32000000'}, {'symbol': 'DODOBTC', 'price': '0.00000602'}, {'symbol': 'DODOBUSD', 'price': '0.12860000'}, {'symbol': 'DODOUSDT', 'price': '0.12910000'}, {'symbol': 'FRONTBTC', 'price': '0.00000960'}, {'symbol': 'EASYBTC', 'price': '0.00029250'}, {'symbol': 'CAKEBTC', 'price': '0.00015560'}, {'symbol': 'CAKEUSDT', 'price': '3.34100000'}, {'symbol': 'BAKEBUSD', 'price': '0.27100000'}, {'symbol': 'UFTETH', 'price': '0.00012960'}, {'symbol': 'UFTBUSD', 'price': '0.16050000'}, {'symbol': '1INCHBUSD', 'price': '0.72800000'}, {'symbol': 'BANDBUSD', 'price': '1.53500000'}, {'symbol': 'GRTBUSD', 'price': '0.11750000'}, {'symbol': 'IOSTBUSD', 'price': '0.01503000'}, {'symbol': 'OMGBUSD', 'price': '2.03900000'}, {'symbol': 'REEFBUSD', 'price': '0.00384000'}, {'symbol': 'ACMBTC', 'price': '0.00014430'}, {'symbol': 'ACMBUSD', 'price': '3.07900000'}, {'symbol': 'ACMUSDT', 'price': '3.09400000'}, {'symbol': 'AUCTIONBTC', 'price': '0.00025740'}, {'symbol': 'AUCTIONBUSD', 'price': '5.54000000'}, {'symbol': 'PHABTC', 'price': '0.00000526'}, {'symbol': 'PHABUSD', 'price': '0.11250000'}, {'symbol': 'DOTGBP', 'price': '6.62000000'}, {'symbol': 'ADATRY', 'price': '8.47000000'}, {'symbol': 'ADABRL', 'price': '2.61400000'}, {'symbol': 'ADAGBP', 'price': '0.40630000'}, {'symbol': 'TVKBTC', 'price': '0.00000164'}, {'symbol': 'TVKBUSD', 'price': '0.03520000'}, {'symbol': 'BADGERBTC', 'price': '0.00015900'}, {'symbol': 'BADGERBUSD', 'price': '3.41000000'}, {'symbol': 'BADGERUSDT', 'price': '3.42000000'}, {'symbol': 'FISBTC', 'price': '0.00001632'}, {'symbol': 'FISBUSD', 'price': '0.34610000'}, {'symbol': 'FISUSDT', 'price': '0.34540000'}, {'symbol': 'DOTBRL', 'price': '42.63000000'}, {'symbol': 'ADAAUD', 'price': '0.71800000'}, {'symbol': 'HOTTRY', 'price': '0.04067000'}, {'symbol': 'EGLDEUR', 'price': '59.05000000'}, {'symbol': 'OMBTC', 'price': '0.00000190'}, {'symbol': 'OMBUSD', 'price': '0.04060000'}, {'symbol': 'OMUSDT', 'price': '0.04060000'}, {'symbol': 'PONDBTC', 'price': '0.00000051'}, {'symbol': 'PONDBUSD', 'price': '0.01074000'}, {'symbol': 'PONDUSDT', 'price': '0.01077000'}, {'symbol': 'DEGOBTC', 'price': '0.00006820'}, {'symbol': 'DEGOBUSD', 'price': '1.46000000'}, {'symbol': 'DEGOUSDT', 'price': '1.47000000'}, {'symbol': 'AVAXEUR', 'price': '20.21000000'}, {'symbol': 'BTTTRY', 'price': '0.03783000'}, {'symbol': 'CHZBRL', 'price': '0.55300000'}, {'symbol': 'UNIEUR', 'price': '5.37000000'}, {'symbol': 'ALICEBTC', 'price': '0.00013140'}, {'symbol': 'ALICEBUSD', 'price': '2.81800000'}, {'symbol': 'ALICEUSDT', 'price': '2.81700000'}, {'symbol': 'CHZBUSD', 'price': '0.10530000'}, {'symbol': 'CHZEUR', 'price': '0.09960000'}, {'symbol': 'CHZGBP', 'price': '0.08600000'}, {'symbol': 'BIFIBNB', 'price': '2.77700000'}, {'symbol': 'BIFIBUSD', 'price': '452.90000000'}, {'symbol': 'LINABTC', 'price': '0.00000044'}, {'symbol': 'LINABUSD', 'price': '0.00948000'}, {'symbol': 'LINAUSDT', 'price': '0.00948000'}, {'symbol': 'ADARUB', 'price': '27.92000000'}, {'symbol': 'ENJBRL', 'price': '3.18700000'}, {'symbol': 'ENJEUR', 'price': '0.57900000'}, {'symbol': 'MATICEUR', 'price': '0.57380000'}, {'symbol': 'NEOTRY', 'price': '164.60000000'}, {'symbol': 'PERPBTC', 'price': '0.00003664'}, {'symbol': 'PERPBUSD', 'price': '0.78600000'}, {'symbol': 'PERPUSDT', 'price': '0.78700000'}, {'symbol': 'RAMPBTC', 'price': '0.00000194'}, {'symbol': 'RAMPBUSD', 'price': '0.04170000'}, {'symbol': 'RAMPUSDT', 'price': '0.04170000'}, {'symbol': 'SUPERBTC', 'price': '0.00000701'}, {'symbol': 'SUPERBUSD', 'price': '0.15090000'}, {'symbol': 'SUPERUSDT', 'price': '0.15030000'}, {'symbol': 'CFXBTC', 'price': '0.00000272'}, {'symbol': 'CFXBUSD', 'price': '0.05830000'}, {'symbol': 'CFXUSDT', 'price': '0.05840000'}, {'symbol': 'ENJGBP', 'price': '0.49690000'}, {'symbol': 'EOSTRY', 'price': '17.18000000'}, {'symbol': 'LTCGBP', 'price': '48.61000000'}, {'symbol': 'LUNAEUR', 'price': '0.00006000'}, {'symbol': 'RVNTRY', 'price': '0.44280000'}, {'symbol': 'THETAEUR', 'price': '1.39700000'}, {'symbol': 'XVGBUSD', 'price': '0.00335000'}, {'symbol': 'EPSBTC', 'price': '0.00000499'}, {'symbol': 'EPSBUSD', 'price': '0.16790000'}, {'symbol': 'EPSUSDT', 'price': '0.16790000'}, {'symbol': 'AUTOBTC', 'price': '0.01398000'}, {'symbol': 'AUTOBUSD', 'price': '300.60000000'}, {'symbol': 'AUTOUSDT', 'price': '300.90000000'}, {'symbol': 'TKOBTC', 'price': '0.00001389'}, {'symbol': 'TKOBIDR', 'price': '4420.00'}, {'symbol': 'TKOBUSD', 'price': '0.29700000'}, {'symbol': 'TKOUSDT', 'price': '0.29700000'}, {'symbol': 'PUNDIXETH', 'price': '0.00036410'}, {'symbol': 'PUNDIXUSDT', 'price': '0.45000000'}, {'symbol': 'BTTBRL', 'price': '0.01553000'}, {'symbol': 'BTTEUR', 'price': '0.00243600'}, {'symbol': 'HOTEUR', 'price': '0.00225000'}, {'symbol': 'WINEUR', 'price': '0.00011330'}, {'symbol': 'TLMBTC', 'price': '0.00000131'}, {'symbol': 'TLMBUSD', 'price': '0.02800000'}, {'symbol': 'TLMUSDT', 'price': '0.02800000'}, {'symbol': '1INCHUPUSDT', 'price': '0.06570300'}, {'symbol': '1INCHDOWNUSDT', 'price': '0.00614800'}, {'symbol': 'BTGBUSD', 'price': '17.50000000'}, {'symbol': 'BTGUSDT', 'price': '17.57000000'}, {'symbol': 'HOTBUSD', 'price': '0.00239800'}, {'symbol': 'BNBUAH', 'price': '8233.00000000'}, {'symbol': 'ONTTRY', 'price': '4.18600000'}, {'symbol': 'VETEUR', 'price': '0.02487000'}, {'symbol': 'VETGBP', 'price': '0.02138000'}, {'symbol': 'WINBRL', 'price': '0.00062700'}, {'symbol': 'MIRBTC', 'price': '0.00000898'}, {'symbol': 'MIRBUSD', 'price': '0.19330000'}, {'symbol': 'MIRUSDT', 'price': '0.19288000'}, {'symbol': 'BARBTC', 'price': '0.00019370'}, {'symbol': 'BARBUSD', 'price': '4.15000000'}, {'symbol': 'BARUSDT', 'price': '4.14000000'}, {'symbol': 'FORTHBTC', 'price': '0.00015000'}, {'symbol': 'FORTHBUSD', 'price': '3.21000000'}, {'symbol': 'FORTHUSDT', 'price': '3.22000000'}, {'symbol': 'CAKEGBP', 'price': '2.71700000'}, {'symbol': 'DOGERUB', 'price': '3.85800000'}, {'symbol': 'HOTBRL', 'price': '0.03750000'}, {'symbol': 'WRXEUR', 'price': '0.57460000'}, {'symbol': 'EZBTC', 'price': '0.00002248'}, {'symbol': 'EZETH', 'price': '0.00038400'}, {'symbol': 'BAKEUSDT', 'price': '0.27100000'}, {'symbol': 'BURGERBUSD', 'price': '0.66400000'}, {'symbol': 'BURGERUSDT', 'price': '0.66500000'}, {'symbol': 'SLPBUSD', 'price': '0.00419000'}, {'symbol': 'SLPUSDT', 'price': '0.00419000'}, {'symbol': 'TRXAUD', 'price': '0.09810000'}, {'symbol': 'TRXEUR', 'price': '0.06150000'}, {'symbol': 'VETTRY', 'price': '0.44390000'}, {'symbol': 'SHIBUSDT', 'price': '0.00001178'}, {'symbol': 'SHIBBUSD', 'price': '0.00001176'}, {'symbol': 'ICPBTC', 'price': '0.00028900'}, {'symbol': 'ICPBNB', 'price': '0.02590000'}, {'symbol': 'ICPBUSD', 'price': '6.20000000'}, {'symbol': 'ICPUSDT', 'price': '6.20000000'}, {'symbol': 'SHIBEUR', 'price': '0.00001118'}, {'symbol': 'SHIBRUB', 'price': '0.00057730'}, {'symbol': 'ETCEUR', 'price': '15.69000000'}, {'symbol': 'ETCBRL', 'price': '202.40000000'}, {'symbol': 'DOGEBIDR', 'price': '1019.00'}, {'symbol': 'ARBTC', 'price': '0.00049110'}, {'symbol': 'ARBNB', 'price': '0.04404000'}, {'symbol': 'ARBUSD', 'price': '10.50000000'}, {'symbol': 'ARUSDT', 'price': '10.51000000'}, {'symbol': 'POLSBTC', 'price': '0.00002578'}, {'symbol': 'POLSBNB', 'price': '0.00231600'}, {'symbol': 'POLSBUSD', 'price': '0.55500000'}, {'symbol': 'POLSUSDT', 'price': '0.55500000'}, {'symbol': 'MDXBTC', 'price': '0.00000400'}, {'symbol': 'MDXBNB', 'price': '0.00061900'}, {'symbol': 'MDXBUSD', 'price': '0.08600000'}, {'symbol': 'MDXUSDT', 'price': '0.08590000'}, {'symbol': 'MASKBNB', 'price': '0.00650000'}, {'symbol': 'MASKBUSD', 'price': '1.54400000'}, {'symbol': 'MASKUSDT', 'price': '1.54400000'}, {'symbol': 'LPTBTC', 'price': '0.00044590'}, {'symbol': 'LPTBNB', 'price': '0.04000000'}, {'symbol': 'LPTBUSD', 'price': '9.59000000'}, {'symbol': 'LPTUSDT', 'price': '9.56000000'}, {'symbol': 'ETHUAH', 'price': '42787.00000000'}, {'symbol': 'MATICBRL', 'price': '3.16400000'}, {'symbol': 'SOLEUR', 'price': '39.80000000'}, {'symbol': 'SHIBBRL', 'price': '0.00006178'}, {'symbol': 'AGIXBTC', 'price': '0.00000193'}, {'symbol': 'ICPEUR', 'price': '5.85000000'}, {'symbol': 'MATICGBP', 'price': '0.49290000'}, {'symbol': 'SHIBTRY', 'price': '0.00019998'}, {'symbol': 'MATICBIDR', 'price': '8986.00'}, {'symbol': 'MATICRUB', 'price': '33.91000000'}, {'symbol': 'NUBTC', 'price': '0.00001240'}, {'symbol': 'NUBNB', 'price': '0.00126770'}, {'symbol': 'NUBUSD', 'price': '0.54530000'}, {'symbol': 'NUUSDT', 'price': '0.54360000'}, {'symbol': 'XVGUSDT', 'price': '0.00333000'}, {'symbol': 'RLCBUSD', 'price': '1.78300000'}, {'symbol': 'CELRBUSD', 'price': '0.01888000'}, {'symbol': 'ATMBUSD', 'price': '3.36000000'}, {'symbol': 'ZENBUSD', 'price': '16.08000000'}, {'symbol': 'FTMBUSD', 'price': '0.30110000'}, {'symbol': 'THETABUSD', 'price': '1.47200000'}, {'symbol': 'WINBUSD', 'price': '0.00011910'}, {'symbol': 'KAVABUSD', 'price': '1.82300000'}, {'symbol': 'XEMBUSD', 'price': '0.09630000'}, {'symbol': 'ATABTC', 'price': '0.00000938'}, {'symbol': 'ATABNB', 'price': '0.00083900'}, {'symbol': 'ATABUSD', 'price': '0.20150000'}, {'symbol': 'ATAUSDT', 'price': '0.20120000'}, {'symbol': 'GTCBTC', 'price': '0.00013840'}, {'symbol': 'GTCBNB', 'price': '0.01860000'}, {'symbol': 'GTCBUSD', 'price': '2.97200000'}, {'symbol': 'GTCUSDT', 'price': '2.97200000'}, {'symbol': 'TORNBTC', 'price': '0.00092910'}, {'symbol': 'TORNBNB', 'price': '0.09058000'}, {'symbol': 'TORNBUSD', 'price': '19.99000000'}, {'symbol': 'TORNUSDT', 'price': '19.94000000'}, {'symbol': 'MATICTRY', 'price': '10.24100000'}, {'symbol': 'ETCGBP', 'price': '26.54000000'}, {'symbol': 'SOLGBP', 'price': '34.18000000'}, {'symbol': 'BAKEBTC', 'price': '0.00001258'}, {'symbol': 'COTIBUSD', 'price': '0.10160000'}, {'symbol': 'KEEPBTC', 'price': '0.00001432'}, {'symbol': 'KEEPBNB', 'price': '0.00145070'}, {'symbol': 'KEEPBUSD', 'price': '0.62600000'}, {'symbol': 'KEEPUSDT', 'price': '0.62510000'}, {'symbol': 'SOLTRY', 'price': '711.00000000'}, {'symbol': 'RUNEGBP', 'price': '1.97900000'}, {'symbol': 'SOLBRL', 'price': '219.90000000'}, {'symbol': 'SCBUSD', 'price': '0.00417000'}, {'symbol': 'CHRBUSD', 'price': '0.22430000'}, {'symbol': 'STMXBUSD', 'price': '0.00706000'}, {'symbol': 'HNTBUSD', 'price': '11.69000000'}, {'symbol': 'FTTBUSD', 'price': '27.81000000'}, {'symbol': 'DOCKBUSD', 'price': '0.01727000'}, {'symbol': 'ADABIDR', 'price': '7411.00'}, {'symbol': 'ERNBNB', 'price': '0.00630000'}, {'symbol': 'ERNBUSD', 'price': '1.50300000'}, {'symbol': 'ERNUSDT', 'price': '1.51700000'}, {'symbol': 'KLAYBTC', 'price': '0.00001183'}, {'symbol': 'KLAYBNB', 'price': '0.00106100'}, {'symbol': 'KLAYBUSD', 'price': '0.25400000'}, {'symbol': 'KLAYUSDT', 'price': '0.25300000'}, {'symbol': 'RUNEEUR', 'price': '2.29400000'}, {'symbol': 'MATICAUD', 'price': '0.87000000'}, {'symbol': 'DOTRUB', 'price': '456.00000000'}, {'symbol': 'UTKBUSD', 'price': '0.12860000'}, {'symbol': 'IOTXBUSD', 'price': '0.02931000'}, {'symbol': 'PHAUSDT', 'price': '0.11290000'}, {'symbol': 'SOLRUB', 'price': '2351.00000000'}, {'symbol': 'RUNEAUD', 'price': '17.40400000'}, {'symbol': 'BUSDUAH', 'price': '34.47000000'}, {'symbol': 'BONDBTC', 'price': '0.00014040'}, {'symbol': 'BONDBNB', 'price': '0.02969000'}, {'symbol': 'BONDBUSD', 'price': '3.01000000'}, {'symbol': 'BONDUSDT', 'price': '3.01000000'}, {'symbol': 'MLNBTC', 'price': '0.00117800'}, {'symbol': 'MLNBNB', 'price': '0.09880000'}, {'symbol': 'MLNBUSD', 'price': '25.20000000'}, {'symbol': 'MLNUSDT', 'price': '25.20000000'}, {'symbol': 'GRTTRY', 'price': '1.98300000'}, {'symbol': 'CAKEBRL', 'price': '69.72000000'}, {'symbol': 'ICPRUB', 'price': '4589.00000000'}, {'symbol': 'DOTAUD', 'price': '11.71000000'}, {'symbol': 'AAVEBRL', 'price': '1792.00000000'}, {'symbol': 'EOSAUD', 'price': '6.55500000'}, {'symbol': 'DEXEUSDT', 'price': '2.95000000'}, {'symbol': 'LTOBUSD', 'price': '0.08900000'}, {'symbol': 'ADXBUSD', 'price': '0.16050000'}, {'symbol': 'QUICKBTC', 'price': '0.00257200'}, {'symbol': 'QUICKBNB', 'price': '0.42200000'}, {'symbol': 'QUICKBUSD', 'price': '55.40000000'}, {'symbol': 'C98USDT', 'price': '0.54100000'}, {'symbol': 'C98BUSD', 'price': '0.54100000'}, {'symbol': 'C98BNB', 'price': '0.00226300'}, {'symbol': 'C98BTC', 'price': '0.00002525'}, {'symbol': 'CLVBTC', 'price': '0.00000502'}, {'symbol': 'CLVBNB', 'price': '0.00045100'}, {'symbol': 'CLVBUSD', 'price': '0.10800000'}, {'symbol': 'CLVUSDT', 'price': '0.10800000'}, {'symbol': 'QNTBTC', 'price': '0.00294500'}, {'symbol': 'QNTBNB', 'price': '0.26470000'}, {'symbol': 'QNTBUSD', 'price': '63.20000000'}, {'symbol': 'QNTUSDT', 'price': '63.10000000'}, {'symbol': 'FLOWBTC', 'price': '0.00008350'}, {'symbol': 'FLOWBNB', 'price': '0.00748000'}, {'symbol': 'FLOWBUSD', 'price': '1.79000000'}, {'symbol': 'FLOWUSDT', 'price': '1.79000000'}, {'symbol': 'XECBUSD', 'price': '0.00004296'}, {'symbol': 'AXSBRL', 'price': '93.30000000'}, {'symbol': 'AXSAUD', 'price': '25.53000000'}, {'symbol': 'TVKUSDT', 'price': '0.03520000'}, {'symbol': 'MINABTC', 'price': '0.00003404'}, {'symbol': 'MINABNB', 'price': '0.00308100'}, {'symbol': 'MINABUSD', 'price': '0.72900000'}, {'symbol': 'MINAUSDT', 'price': '0.73000000'}, {'symbol': 'RAYBNB', 'price': '0.00316000'}, {'symbol': 'RAYBUSD', 'price': '0.75500000'}, {'symbol': 'RAYUSDT', 'price': '0.75600000'}, {'symbol': 'FARMBTC', 'price': '0.00209700'}, {'symbol': 'FARMBNB', 'price': '0.15150000'}, {'symbol': 'FARMBUSD', 'price': '45.00000000'}, {'symbol': 'FARMUSDT', 'price': '45.00000000'}, {'symbol': 'ALPACABTC', 'price': '0.00001071'}, {'symbol': 'ALPACABNB', 'price': '0.00094400'}, {'symbol': 'ALPACABUSD', 'price': '0.22950000'}, {'symbol': 'ALPACAUSDT', 'price': '0.22950000'}, {'symbol': 'TLMTRY', 'price': '0.47400000'}, {'symbol': 'QUICKUSDT', 'price': '55.20000000'}, {'symbol': 'ORNBUSD', 'price': '1.43100000'}, {'symbol': 'MBOXBTC', 'price': '0.00003013'}, {'symbol': 'MBOXBNB', 'price': '0.00271200'}, {'symbol': 'MBOXBUSD', 'price': '0.64800000'}, {'symbol': 'MBOXUSDT', 'price': '0.64700000'}, {'symbol': 'VGXBTC', 'price': '0.00001793'}, {'symbol': 'VGXETH', 'price': '0.00031000'}, {'symbol': 'FORUSDT', 'price': '0.01741000'}, {'symbol': 'REQUSDT', 'price': '0.10000000'}, {'symbol': 'GHSTUSDT', 'price': '1.33300000'}, {'symbol': 'TRURUB', 'price': '4.35000000'}, {'symbol': 'FISBRL', 'price': '1.81000000'}, {'symbol': 'WAXPUSDT', 'price': '0.10500000'}, {'symbol': 'WAXPBUSD', 'price': '0.10490000'}, {'symbol': 'WAXPBNB', 'price': '0.00043930'}, {'symbol': 'WAXPBTC', 'price': '0.00000489'}, {'symbol': 'TRIBEBTC', 'price': '0.00000749'}, {'symbol': 'TRIBEBNB', 'price': '0.00143100'}, {'symbol': 'TRIBEBUSD', 'price': '0.16000000'}, {'symbol': 'TRIBEUSDT', 'price': '0.16000000'}, {'symbol': 'GNOUSDT', 'price': '126.50000000'}, {'symbol': 'GNOBUSD', 'price': '304.10000000'}, {'symbol': 'GNOBNB', 'price': '0.86500000'}, {'symbol': 'GNOBTC', 'price': '0.00562400'}, {'symbol': 'ARPATRY', 'price': '0.69800000'}, {'symbol': 'PROMBTC', 'price': '0.00017300'}, {'symbol': 'MTLBUSD', 'price': '1.46500000'}, {'symbol': 'OGNBUSD', 'price': '0.26540000'}, {'symbol': 'XECUSDT', 'price': '0.00004292'}, {'symbol': 'C98BRL', 'price': '2.84000000'}, {'symbol': 'SOLAUD', 'price': '60.35000000'}, {'symbol': 'XRPBIDR', 'price': '5440.00'}, {'symbol': 'POLYBUSD', 'price': '0.20380000'}, {'symbol': 'ELFUSDT', 'price': '0.15200000'}, {'symbol': 'DYDXUSDT', 'price': '1.50900000'}, {'symbol': 'DYDXBUSD', 'price': '1.51100000'}, {'symbol': 'DYDXBNB', 'price': '0.00633200'}, {'symbol': 'DYDXBTC', 'price': '0.00007026'}, {'symbol': 'ELFBUSD', 'price': '0.15140000'}, {'symbol': 'POLYUSDT', 'price': '0.20440000'}, {'symbol': 'IDEXUSDT', 'price': '0.07996000'}, {'symbol': 'VIDTUSDT', 'price': '0.18710000'}, {'symbol': 'SOLBIDR', 'price': '625374.00'}, {'symbol': 'AXSBIDR', 'price': '267248.00'}, {'symbol': 'BTCUSDP', 'price': '21474.68000000'}, {'symbol': 'ETHUSDP', 'price': '1237.62000000'}, {'symbol': 'BNBUSDP', 'price': '234.90000000'}, {'symbol': 'USDPBUSD', 'price': '1.00020000'}, {'symbol': 'USDPUSDT', 'price': '1.00070000'}, {'symbol': 'GALAUSDT', 'price': '0.06738000'}, {'symbol': 'GALABUSD', 'price': '0.06736000'}, {'symbol': 'GALABNB', 'price': '0.00028190'}, {'symbol': 'GALABTC', 'price': '0.00000314'}, {'symbol': 'FTMBIDR', 'price': '4487.00'}, {'symbol': 'ALGOBIDR', 'price': '20095.00'}, {'symbol': 'CAKEAUD', 'price': '25.61000000'}, {'symbol': 'KSMAUD', 'price': '234.80000000'}, {'symbol': 'WAVESRUB', 'price': '1190.49000000'}, {'symbol': 'SUNBUSD', 'price': '0.00619000'}, {'symbol': 'ILVUSDT', 'price': '183.50000000'}, {'symbol': 'ILVBUSD', 'price': '183.70000000'}, {'symbol': 'ILVBNB', 'price': '0.77100000'}, {'symbol': 'ILVBTC', 'price': '0.00855000'}, {'symbol': 'RENBUSD', 'price': '0.12390000'}, {'symbol': 'YGGUSDT', 'price': '0.58000000'}, {'symbol': 'YGGBUSD', 'price': '0.57880000'}, {'symbol': 'YGGBNB', 'price': '0.00242300'}, {'symbol': 'YGGBTC', 'price': '0.00002688'}, {'symbol': 'STXBUSD', 'price': '0.40700000'}, {'symbol': 'SYSUSDT', 'price': '0.15310000'}, {'symbol': 'DFUSDT', 'price': '0.03820000'}, {'symbol': 'SOLUSDC', 'price': '41.90000000'}, {'symbol': 'ARPARUB', 'price': '2.30600000'}, {'symbol': 'LTCUAH', 'price': '2050.00000000'}, {'symbol': 'FETBUSD', 'price': '0.08920000'}, {'symbol': 'ARPABUSD', 'price': '0.04107000'}, {'symbol': 'LSKBUSD', 'price': '1.10100000'}, {'symbol': 'AVAXBIDR', 'price': '315235.00'}, {'symbol': 'ALICEBIDR', 'price': '42000.00'}, {'symbol': 'FIDAUSDT', 'price': '0.36900000'}, {'symbol': 'FIDABUSD', 'price': '0.36900000'}, {'symbol': 'FIDABNB', 'price': '0.00543000'}, {'symbol': 'FIDABTC', 'price': '0.00001730'}, {'symbol': 'DENTBUSD', 'price': '0.00098400'}, {'symbol': 'FRONTUSDT', 'price': '0.20700000'}, {'symbol': 'CVPUSDT', 'price': '0.28000000'}, {'symbol': 'AGLDBTC', 'price': '0.00002051'}, {'symbol': 'AGLDBNB', 'price': '0.00190000'}, {'symbol': 'AGLDBUSD', 'price': '0.44100000'}, {'symbol': 'AGLDUSDT', 'price': '0.44000000'}, {'symbol': 'RADBTC', 'price': '0.00007870'}, {'symbol': 'RADBNB', 'price': '0.00710000'}, {'symbol': 'RADBUSD', 'price': '1.68200000'}, {'symbol': 'RADUSDT', 'price': '1.69100000'}, {'symbol': 'UNIAUD', 'price': '34.47000000'}, {'symbol': 'HIVEBUSD', 'price': '0.41020000'}, {'symbol': 'STPTBUSD', 'price': '0.04309000'}, {'symbol': 'BETABTC', 'price': '0.00000497'}, {'symbol': 'BETABNB', 'price': '0.00044970'}, {'symbol': 'BETABUSD', 'price': '0.10692000'}, {'symbol': 'BETAUSDT', 'price': '0.10687000'}, {'symbol': 'SHIBAUD', 'price': '0.00001696'}, {'symbol': 'RAREBTC', 'price': '0.00000940'}, {'symbol': 'RAREBNB', 'price': '0.00084200'}, {'symbol': 'RAREBUSD', 'price': '0.20100000'}, {'symbol': 'RAREUSDT', 'price': '0.20200000'}, {'symbol': 'AVAXBRL', 'price': '111.90000000'}, {'symbol': 'AVAXAUD', 'price': '30.48000000'}, {'symbol': 'LUNAAUD', 'price': '0.00009000'}, {'symbol': 'TROYBUSD', 'price': '0.00359000'}, {'symbol': 'AXSETH', 'price': '0.01435000'}, {'symbol': 'FTMETH', 'price': '0.00024290'}, {'symbol': 'SOLETH', 'price': '0.03373000'}, {'symbol': 'SSVBTC', 'price': '0.00021470'}, {'symbol': 'SSVETH', 'price': '0.00370800'}, {'symbol': 'LAZIOTRY', 'price': '37.64500000'}, {'symbol': 'LAZIOEUR', 'price': '2.07210000'}, {'symbol': 'LAZIOBTC', 'price': '0.00010331'}, {'symbol': 'LAZIOUSDT', 'price': '2.21540000'}, {'symbol': 'CHESSBTC', 'price': '0.00001282'}, {'symbol': 'CHESSBNB', 'price': '0.00188500'}, {'symbol': 'CHESSBUSD', 'price': '0.27500000'}, {'symbol': 'CHESSUSDT', 'price': '0.27600000'}, {'symbol': 'FTMAUD', 'price': '0.43540000'}, {'symbol': 'FTMBRL', 'price': '1.58000000'}, {'symbol': 'SCRTBUSD', 'price': '1.10300000'}, {'symbol': 'ADXUSDT', 'price': '0.16060000'}, {'symbol': 'AUCTIONUSDT', 'price': '5.54000000'}, {'symbol': 'CELOBUSD', 'price': '0.99500000'}, {'symbol': 'FTMRUB', 'price': '16.80000000'}, {'symbol': 'NUAUD', 'price': '0.76900000'}, {'symbol': 'NURUB', 'price': '41.13000000'}, {'symbol': 'REEFTRY', 'price': '0.06520000'}, {'symbol': 'REEFBIDR', 'price': '162.00'}, {'symbol': 'SHIBDOGE', 'price': '0.00017220'}, {'symbol': 'DARUSDT', 'price': '0.33684000'}, {'symbol': 'DARBUSD', 'price': '0.33613000'}, {'symbol': 'DARBNB', 'price': '0.00140905'}, {'symbol': 'DARBTC', 'price': '0.00001562'}, {'symbol': 'BNXBTC', 'price': '0.00597700'}, {'symbol': 'BNXBNB', 'price': '0.54320000'}, {'symbol': 'BNXBUSD', 'price': '128.50000000'}, {'symbol': 'BNXUSDT', 'price': '128.30000000'}, {'symbol': 'RGTUSDT', 'price': '14.44000000'}, {'symbol': 'RGTBTC', 'price': '0.00037960'}, {'symbol': 'RGTBUSD', 'price': '14.46000000'}, {'symbol': 'RGTBNB', 'price': '0.03997000'}, {'symbol': 'LAZIOBUSD', 'price': '2.21660000'}, {'symbol': 'OXTBUSD', 'price': '0.10460000'}, {'symbol': 'MANATRY', 'price': '17.65000000'}, {'symbol': 'ALGORUB', 'price': '19.60000000'}, {'symbol': 'SHIBUAH', 'price': '0.00079300'}, {'symbol': 'LUNABIDR', 'price': '0.88'}, {'symbol': 'AUDUSDC', 'price': '0.69450000'}, {'symbol': 'MOVRBTC', 'price': '0.00059400'}, {'symbol': 'MOVRBNB', 'price': '0.15520000'}, {'symbol': 'MOVRBUSD', 'price': '12.70000000'}, {'symbol': 'MOVRUSDT', 'price': '12.70000000'}, {'symbol': 'CITYBTC', 'price': '0.00022210'}, {'symbol': 'CITYBNB', 'price': '0.01995000'}, {'symbol': 'CITYBUSD', 'price': '4.78000000'}, {'symbol': 'CITYUSDT', 'price': '4.78000000'}, {'symbol': 'ENSBTC', 'price': '0.00046050'}, {'symbol': 'ENSBNB', 'price': '0.04150000'}, {'symbol': 'ENSBUSD', 'price': '9.87000000'}, {'symbol': 'ENSUSDT', 'price': '9.88000000'}, {'symbol': 'SANDETH', 'price': '0.00106150'}, {'symbol': 'DOTETH', 'price': '0.00654100'}, {'symbol': 'MATICETH', 'price': '0.00048600'}, {'symbol': 'ANKRBUSD', 'price': '0.03143000'}, {'symbol': 'SANDTRY', 'price': '22.28000000'}, {'symbol': 'MANABRL', 'price': '5.47000000'}, {'symbol': 'KP3RUSDT', 'price': '141.87000000'}, {'symbol': 'QIUSDT', 'price': '0.01320000'}, {'symbol': 'QIBUSD', 'price': '0.01310000'}, {'symbol': 'QIBNB', 'price': '0.00009910'}, {'symbol': 'QIBTC', 'price': '0.00000061'}, {'symbol': 'PORTOBTC', 'price': '0.00008768'}, {'symbol': 'PORTOUSDT', 'price': '1.88600000'}, {'symbol': 'PORTOTRY', 'price': '31.97000000'}, {'symbol': 'PORTOEUR', 'price': '1.78440000'}, {'symbol': 'POWRUSDT', 'price': '0.23010000'}, {'symbol': 'POWRBUSD', 'price': '0.23120000'}, {'symbol': 'AVAXETH', 'price': '0.01718000'}, {'symbol': 'SLPTRY', 'price': '0.07100000'}, {'symbol': 'FISTRY', 'price': '8.87000000'}, {'symbol': 'LRCTRY', 'price': '7.49000000'}, {'symbol': 'CHRETH', 'price': '0.00017970'}, {'symbol': 'FISBIDR', 'price': '9124.00'}, {'symbol': 'VGXUSDT', 'price': '0.38300000'}, {'symbol': 'GALAETH', 'price': '0.00005416'}, {'symbol': 'JASMYUSDT', 'price': '0.01023000'}, {'symbol': 'JASMYBUSD', 'price': '0.01022000'}, {'symbol': 'JASMYBNB', 'price': '0.00004282'}, {'symbol': 'JASMYBTC', 'price': '0.00000048'}, {'symbol': 'AMPBTC', 'price': '0.00000044'}, {'symbol': 'AMPBNB', 'price': '0.00003999'}, {'symbol': 'AMPBUSD', 'price': '0.00956000'}, {'symbol': 'AMPUSDT', 'price': '0.00955000'}, {'symbol': 'PLABTC', 'price': '0.00001895'}, {'symbol': 'PLABNB', 'price': '0.00170400'}, {'symbol': 'PLABUSD', 'price': '0.40700000'}, {'symbol': 'PLAUSDT', 'price': '0.40500000'}, {'symbol': 'PYRBTC', 'price': '0.00016500'}, {'symbol': 'PYRBUSD', 'price': '3.54000000'}, {'symbol': 'PYRUSDT', 'price': '3.54000000'}, {'symbol': 'RNDRBTC', 'price': '0.00002560'}, {'symbol': 'RNDRUSDT', 'price': '0.55000000'}, {'symbol': 'RNDRBUSD', 'price': '0.54900000'}, {'symbol': 'ALCXBTC', 'price': '0.00130800'}, {'symbol': 'ALCXBUSD', 'price': '27.70000000'}, {'symbol': 'ALCXUSDT', 'price': '27.70000000'}, {'symbol': 'SANTOSBTC', 'price': '0.00017933'}, {'symbol': 'SANTOSUSDT', 'price': '3.84500000'}, {'symbol': 'SANTOSBRL', 'price': '20.16000000'}, {'symbol': 'SANTOSTRY', 'price': '65.26000000'}, {'symbol': 'MCBTC', 'price': '0.00003788'}, {'symbol': 'MCBUSD', 'price': '0.81100000'}, {'symbol': 'MCUSDT', 'price': '0.81300000'}, {'symbol': 'BELTRY', 'price': '15.71000000'}, {'symbol': 'COCOSBUSD', 'price': '0.71800000'}, {'symbol': 'DENTTRY', 'price': '0.01665000'}, {'symbol': 'ENJTRY', 'price': '10.33000000'}, {'symbol': 'NEORUB', 'price': '544.00000000'}, {'symbol': 'SANDAUD', 'price': '1.89960000'}, {'symbol': 'SLPBIDR', 'price': '62.30'}, {'symbol': 'ANYBTC', 'price': '0.00026020'}, {'symbol': 'ANYBUSD', 'price': '12.33000000'}, {'symbol': 'ANYUSDT', 'price': '12.30000000'}, {'symbol': 'BICOBTC', 'price': '0.00002580'}, {'symbol': 'BICOBUSD', 'price': '0.55400000'}, {'symbol': 'BICOUSDT', 'price': '0.55400000'}, {'symbol': 'FLUXBTC', 'price': '0.00002234'}, {'symbol': 'FLUXBUSD', 'price': '0.48000000'}, {'symbol': 'FLUXUSDT', 'price': '0.48000000'}, {'symbol': 'ALICETRY', 'price': '47.92000000'}, {'symbol': 'FXSUSDT', 'price': '5.33600000'}, {'symbol': 'GALABRL', 'price': '0.35400000'}, {'symbol': 'GALATRY', 'price': '1.14400000'}, {'symbol': 'LUNATRY', 'price': '0.00090000'}, {'symbol': 'REQBUSD', 'price': '0.10020000'}, {'symbol': 'SANDBRL', 'price': '6.91000000'}, {'symbol': 'MANABIDR', 'price': '15523.00'}, {'symbol': 'SANDBIDR', 'price': '19576.00'}, {'symbol': 'VOXELBTC', 'price': '0.00001849'}, {'symbol': 'VOXELBNB', 'price': '0.00165950'}, {'symbol': 'VOXELBUSD', 'price': '0.39550000'}, {'symbol': 'VOXELUSDT', 'price': '0.39560000'}, {'symbol': 'COSBUSD', 'price': '0.00672000'}, {'symbol': 'CTXCBUSD', 'price': '0.11900000'}, {'symbol': 'FTMTRY', 'price': '5.11000000'}, {'symbol': 'MANABNB', 'price': '0.00436400'}, {'symbol': 'MINATRY', 'price': '12.37000000'}, {'symbol': 'XTZTRY', 'price': '25.83000000'}, {'symbol': 'HIGHBTC', 'price': '0.00006710'}, {'symbol': 'HIGHBUSD', 'price': '1.44000000'}, {'symbol': 'HIGHUSDT', 'price': '1.44000000'}, {'symbol': 'CVXBTC', 'price': '0.00022940'}, {'symbol': 'CVXBUSD', 'price': '4.92000000'}, {'symbol': 'CVXUSDT', 'price': '4.93000000'}, {'symbol': 'PEOPLEBTC', 'price': '0.00000123'}, {'symbol': 'PEOPLEBUSD', 'price': '0.02638000'}, {'symbol': 'PEOPLEUSDT', 'price': '0.02639000'}, {'symbol': 'OOKIBUSD', 'price': '0.00449000'}, {'symbol': 'OOKIUSDT', 'price': '0.00450000'}, {'symbol': 'COCOSTRY', 'price': '12.19000000'}, {'symbol': 'GXSBNB', 'price': '0.00453800'}, {'symbol': 'LINKBNB', 'price': '0.02986000'}, {'symbol': 'LUNAETH', 'price': '0.00000003'}, {'symbol': 'MDTBUSD', 'price': '0.02746000'}, {'symbol': 'NULSBUSD', 'price': '0.18660000'}, {'symbol': 'SPELLBTC', 'price': '0.00000012'}, {'symbol': 'SPELLUSDT', 'price': '0.00084000'}, {'symbol': 'SPELLBUSD', 'price': '0.00084000'}, {'symbol': 'USTBTC', 'price': '0.00002476'}, {'symbol': 'USTBUSD', 'price': '0.06762946'}, {'symbol': 'USTUSDT', 'price': '0.24577900'}, {'symbol': 'JOEBTC', 'price': '0.00001396'}, {'symbol': 'JOEBUSD', 'price': '0.30000000'}, {'symbol': 'JOEUSDT', 'price': '0.29900000'}, {'symbol': 'ATOMETH', 'price': '0.00687000'}, {'symbol': 'DUSKBUSD', 'price': '0.14560000'}, {'symbol': 'EGLDETH', 'price': '0.05003000'}, {'symbol': 'ICPETH', 'price': '0.00499700'}, {'symbol': 'LUNABRL', 'price': '0.00030000'}, {'symbol': 'LUNAUST', 'price': '0.00004900'}, {'symbol': 'NEARETH', 'price': '0.00340000'}, {'symbol': 'ROSEBNB', 'price': '0.00022880'}, {'symbol': 'VOXELETH', 'price': '0.00031640'}, {'symbol': 'ALICEBNB', 'price': '0.01185600'}, {'symbol': 'ATOMTRY', 'price': '145.00000000'}, {'symbol': 'ETHUST', 'price': '8239.72000000'}, {'symbol': 'GALAAUD', 'price': '0.09757000'}, {'symbol': 'LRCBNB', 'price': '0.00185600'}, {'symbol': 'ONEETH', 'price': '0.00002030'}, {'symbol': 'OOKIBNB', 'price': '0.00001879'}, {'symbol': 'ACHBTC', 'price': '0.00000058'}, {'symbol': 'ACHBUSD', 'price': '0.01240000'}, {'symbol': 'ACHUSDT', 'price': '0.01244000'}, {'symbol': 'IMXBTC', 'price': '0.00004134'}, {'symbol': 'IMXBUSD', 'price': '0.88600000'}, {'symbol': 'IMXUSDT', 'price': '0.88800000'}, {'symbol': 'GLMRBTC', 'price': '0.00003290'}, {'symbol': 'GLMRBUSD', 'price': '0.70450000'}, {'symbol': 'GLMRUSDT', 'price': '0.70560000'}, {'symbol': 'ATOMBIDR', 'price': '307866.00'}, {'symbol': 'DYDXETH', 'price': '0.00159100'}, {'symbol': 'FARMETH', 'price': '0.03152000'}, {'symbol': 'FORBNB', 'price': '0.00009710'}, {'symbol': 'ICPTRY', 'price': '105.10000000'}, {'symbol': 'JASMYETH', 'price': '0.00000820'}, {'symbol': 'LINABNB', 'price': '0.00007811'}, {'symbol': 'OOKIETH', 'price': '0.00000361'}, {'symbol': 'ROSEETH', 'price': '0.00004400'}, {'symbol': 'UMABUSD', 'price': '2.79500000'}, {'symbol': 'UNIETH', 'price': '0.00457200'}, {'symbol': 'XTZETH', 'price': '0.00122800'}, {'symbol': 'LOKABTC', 'price': '0.00002923'}, {'symbol': 'LOKABNB', 'price': '0.00264360'}, {'symbol': 'LOKABUSD', 'price': '0.63100000'}, {'symbol': 'LOKAUSDT', 'price': '0.63120000'}, {'symbol': 'ATOMBRL', 'price': '44.90000000'}, {'symbol': 'BNBUST', 'price': '1129.30000000'}, {'symbol': 'CRVETH', 'price': '0.00066100'}, {'symbol': 'HIGHBNB', 'price': '0.00600000'}, {'symbol': 'NEARRUB', 'price': '236.00000000'}, {'symbol': 'ROSETRY', 'price': '0.92800000'}, {'symbol': 'SCRTUSDT', 'price': '1.10300000'}, {'symbol': 'API3BTC', 'price': '0.00008305'}, {'symbol': 'API3BUSD', 'price': '1.78100000'}, {'symbol': 'API3USDT', 'price': '1.78300000'}, {'symbol': 'BTTCUSDT', 'price': '0.00000088'}, {'symbol': 'BTTCUSDC', 'price': '0.00000088'}, {'symbol': 'BTTCTRY', 'price': '0.00001486'}, {'symbol': 'ACABTC', 'price': '0.00001244'}, {'symbol': 'ACABUSD', 'price': '0.26700000'}, {'symbol': 'ACAUSDT', 'price': '0.26600000'}, {'symbol': 'ANCBTC', 'price': '0.00000614'}, {'symbol': 'ANCBUSD', 'price': '0.13183000'}, {'symbol': 'ANCUSDT', 'price': '0.13177000'}, {'symbol': 'BDOTDOT', 'price': '0.71390000'}, {'symbol': 'XNOBTC', 'price': '0.00004085'}, {'symbol': 'XNOETH', 'price': '0.00070750'}, {'symbol': 'XNOBUSD', 'price': '0.87800000'}, {'symbol': 'XNOUSDT', 'price': '0.88000000'}, {'symbol': 'COSTRY', 'price': '0.11440000'}, {'symbol': 'KAVAETH', 'price': '0.00146000'}, {'symbol': 'MCBNB', 'price': '0.00343200'}, {'symbol': 'ONETRY', 'price': '0.42600000'}, {'symbol': 'WOOBTC', 'price': '0.00001003'}, {'symbol': 'WOOBNB', 'price': '0.00089900'}, {'symbol': 'WOOBUSD', 'price': '0.21480000'}, {'symbol': 'WOOUSDT', 'price': '0.21500000'}, {'symbol': 'CELRETH', 'price': '0.00001538'}, {'symbol': 'PEOPLEBNB', 'price': '0.00011062'}, {'symbol': 'SLPBNB', 'price': '0.00001748'}, {'symbol': 'SPELLBNB', 'price': '0.00000404'}, {'symbol': 'SPELLTRY', 'price': '0.01420000'}, {'symbol': 'TFUELBUSD', 'price': '0.05600000'}, {'symbol': 'AXSTRY', 'price': '301.50000000'}, {'symbol': 'DARTRY', 'price': '5.72000000'}, {'symbol': 'NEARTRY', 'price': '71.70000000'}, {'symbol': 'IDEXBNB', 'price': '0.00033430'}, {'symbol': 'ALPINEEUR', 'price': '2.48700000'}, {'symbol': 'ALPINETRY', 'price': '44.56000000'}, {'symbol': 'ALPINEUSDT', 'price': '2.62680000'}, {'symbol': 'ALPINEBTC', 'price': '0.00012265'}, {'symbol': 'TUSDT', 'price': '0.03750000'}, {'symbol': 'TBUSD', 'price': '0.03740000'}, {'symbol': 'API3BNB', 'price': '0.00533000'}, {'symbol': 'BETAETH', 'price': '0.00008580'}, {'symbol': 'INJTRY', 'price': '24.48000000'}, {'symbol': 'TLMBNB', 'price': '0.00010990'}, {'symbol': 'ASTRBUSD', 'price': '0.04900000'}, {'symbol': 'ASTRUSDT', 'price': '0.04910000'}, {'symbol': 'API3TRY', 'price': '30.21000000'}, {'symbol': 'GLMRBNB', 'price': '0.00295700'}, {'symbol': 'MBOXTRY', 'price': '11.00000000'}, {'symbol': 'NBTBIDR', 'price': '168.00'}, {'symbol': 'NBTUSDT', 'price': '0.01116000'}, {'symbol': 'GMTBTC', 'price': '0.00004431'}, {'symbol': 'GMTBNB', 'price': '0.00398617'}, {'symbol': 'GMTBUSD', 'price': '0.95001000'}, {'symbol': 'GMTUSDT', 'price': '0.95084000'}, {'symbol': 'ANCBNB', 'price': '0.00055210'}, {'symbol': 'ATOMEUR', 'price': '8.12000000'}, {'symbol': 'GALAEUR', 'price': '0.06428000'}, {'symbol': 'KSMETH', 'price': '0.04643000'}, {'symbol': 'UMATRY', 'price': '47.60000000'}, {'symbol': 'KDABTC', 'price': '0.00008190'}, {'symbol': 'KDABUSD', 'price': '1.76000000'}, {'symbol': 'KDAUSDT', 'price': '1.76000000'}, {'symbol': 'APEUSDT', 'price': '4.51310000'}, {'symbol': 'APEBUSD', 'price': '4.51050000'}, {'symbol': 'APEBTC', 'price': '0.00021045'}, {'symbol': 'ALPINEBUSD', 'price': '2.62080000'}, {'symbol': 'LUNAGBP', 'price': '0.00005000'}, {'symbol': 'NEAREUR', 'price': '3.99000000'}, {'symbol': 'TWTTRY', 'price': '15.48000000'}, {'symbol': 'WAVESEUR', 'price': '6.10000000'}, {'symbol': 'APEEUR', 'price': '4.27830000'}, {'symbol': 'APEGBP', 'price': '3.70320000'}, {'symbol': 'APETRY', 'price': '76.60000000'}, {'symbol': 'BSWUSDT', 'price': '0.35390000'}, {'symbol': 'BSWBUSD', 'price': '0.35460000'}, {'symbol': 'BSWBNB', 'price': '0.00148040'}, {'symbol': 'APEBNB', 'price': '0.01889000'}, {'symbol': 'GMTBRL', 'price': '4.99400000'}, {'symbol': 'GMTETH', 'price': '0.00076620'}, {'symbol': 'JASMYTRY', 'price': '0.17333500'}, {'symbol': 'SANTOSBUSD', 'price': '3.83300000'}, {'symbol': 'APEAUD', 'price': '6.38990000'}, {'symbol': 'BIFIUSDT', 'price': '451.30000000'}, {'symbol': 'GMTEUR', 'price': '0.90496000'}, {'symbol': 'IMXBNB', 'price': '0.00368800'}, {'symbol': 'RUNEETH', 'price': '0.00194200'}, {'symbol': 'AVAXGBP', 'price': '17.39000000'}, {'symbol': 'MULTIBTC', 'price': '0.00017780'}, {'symbol': 'MULTIBUSD', 'price': '3.81000000'}, {'symbol': 'MULTIUSDT', 'price': '3.81000000'}, {'symbol': 'APEETH', 'price': '0.00363400'}, {'symbol': 'BSWETH', 'price': '0.00028460'}, {'symbol': 'FILTRY', 'price': '103.70000000'}, {'symbol': 'FTMEUR', 'price': '0.28640000'}, {'symbol': 'GMTGBP', 'price': '0.77697000'}, {'symbol': 'ZILTRY', 'price': '0.83100000'}, {'symbol': 'GMTTRY', 'price': '16.14000000'}, {'symbol': 'WAVESTRY', 'price': '109.30000000'}, {'symbol': 'BTCUST', 'price': '121179.88000000'}, {'symbol': 'ASTRBTC', 'price': '0.00000227'}, {'symbol': 'ASTRETH', 'price': '0.00003948'}, {'symbol': 'BSWTRY', 'price': '6.00000000'}, {'symbol': 'FTTETH', 'price': '0.02240000'}, {'symbol': 'FUNBNB', 'price': '0.00003249'}, {'symbol': 'PORTOBUSD', 'price': '1.88150000'}, {'symbol': 'STEEMUSDT', 'price': '0.22670000'}, {'symbol': 'ZILEUR', 'price': '0.04673000'}, {'symbol': 'APEBRL', 'price': '23.67000000'}, {'symbol': 'AUDIOTRY', 'price': '6.53000000'}, {'symbol': 'BTTCBUSD', 'price': '0.00000088'}, {'symbol': 'GMTAUD', 'price': '1.37010000'}, {'symbol': 'MBLBUSD', 'price': '0.00299900'}, {'symbol': 'MOBUSDT', 'price': '1.15700000'}, {'symbol': 'MOBBUSD', 'price': '1.15700000'}, {'symbol': 'MOBBTC', 'price': '0.00005415'}, {'symbol': 'NEXOUSDT', 'price': '0.73300000'}, {'symbol': 'NEXOBUSD', 'price': '0.73200000'}, {'symbol': 'NEXOBTC', 'price': '0.00003425'}, {'symbol': 'REIUSDT', 'price': '0.03700000'}, {'symbol': 'REIBNB', 'price': '0.00015380'}, {'symbol': 'REIETH', 'price': '0.00002972'}, {'symbol': 'GALUSDT', 'price': '2.94100000'}, {'symbol': 'GALBUSD', 'price': '2.93700000'}, {'symbol': 'GALBNB', 'price': '0.01230800'}, {'symbol': 'GALBTC', 'price': '0.00013709'}, {'symbol': 'JASMYEUR', 'price': '0.00968700'}, {'symbol': 'KNCBNB', 'price': '0.00635700'}, {'symbol': 'SHIBGBP', 'price': '0.00000964'}, {'symbol': 'GALEUR', 'price': '2.78400000'}, {'symbol': 'GALTRY', 'price': '49.80000000'}, {'symbol': 'LDOBUSD', 'price': '0.64200000'}, {'symbol': 'LDOUSDT', 'price': '0.64100000'}, {'symbol': 'LDOBTC', 'price': '0.00002994'}, {'symbol': 'ENSTRY', 'price': '167.70000000'}, {'symbol': 'DAREUR', 'price': '0.32270000'}, {'symbol': 'DARETH', 'price': '0.00027060'}, {'symbol': 'ALGOETH', 'price': '0.00028180'}, {'symbol': 'ALGOTRY', 'price': '5.92000000'}, {'symbol': 'GALETH', 'price': '0.00236800'}, {'symbol': 'EPXUSDT', 'price': '0.00058700'}, {'symbol': 'EPXBUSD', 'price': '0.00059100'}, {'symbol': 'RUNETRY', 'price': '41.03000000'}, {'symbol': 'GALBRL', 'price': '15.44000000'}, {'symbol': 'STEEMBUSD', 'price': '0.22540000'}, {'symbol': 'CVCBUSD', 'price': '0.14960000'}, {'symbol': 'REIBUSD', 'price': '0.03680000'}, {'symbol': 'DREPBUSD', 'price': '0.63560000'}, {'symbol': 'AKROBUSD', 'price': '0.00477000'}, {'symbol': 'PUNDIXBUSD', 'price': '0.45000000'}, {'symbol': 'LUNCBUSD', 'price': '0.00005868'}, {'symbol': 'USTCBUSD', 'price': '0.00989693'}, {'symbol': 'OPBTC', 'price': '0.00002717'}, {'symbol': 'OPBUSD', 'price': '0.58300000'}, {'symbol': 'OPUSDT', 'price': '0.58400000'}, {'symbol': 'OGBUSD', 'price': '3.73000000'}, {'symbol': 'KEYBUSD', 'price': '0.00363100'}, {'symbol': 'ASRBUSD', 'price': '3.37900000'}, {'symbol': 'FIROBUSD', 'price': '1.53200000'}, {'symbol': 'NKNBUSD', 'price': '0.10030000'}, {'symbol': 'OPBNB', 'price': '0.00244600'}, {'symbol': 'OPEUR', 'price': '0.55700000'}, {'symbol': 'GTOBUSD', 'price': '0.01905000'}, {'symbol': 'SNXETH', 'price': '0.00234400'}, {'symbol': 'WBTCBUSD', 'price': '21402.27000000'}]
"""
# type(prices) #list
# Out:
# list

# %%
print(f'{len(prices)}')

k=0
for symbol in prices:
    k+=1
print(k)
for i in range(0, len(prices)):
    print(prices[i])
# Out:
# 2071
# 2071
# {'symbol': 'ETHBTC', 'price': '0.05751700'}
# {'symbol': 'LTCBTC', 'price': '0.00267200'}
# {'symbol': 'BNBBTC', 'price': '0.01119100'}
# {'symbol': 'NEOBTC', 'price': '0.00045400'}
# {'symbol': 'QTUMETH', 'price': '0.00248900'}
# {'symbol': 'EOSETH', 'price': '0.00082000'}
# {'symbol': 'SNTETH', 'price': '0.00002503'}
# {'symbol': 'BNTETH', 'price': '0.00042700'}
# {'symbol': 'BCCBTC', 'price': '0.07908100'}
# {'symbol': 'GASBTC', 'price': '0.00013630'}
# {'symbol': 'BNBETH', 'price': '0.19460000'}
# {'symbol': 'BTCUSDT', 'price': '20931.61000000'}
# {'symbol': 'ETHUSDT', 'price': '1203.77000000'}
# {'symbol': 'HSRBTC', 'price': '0.00041400'}
# {'symbol': 'OAXETH', 'price': '0.00017780'}
# {'symbol': 'DNTETH', 'price': '0.00002801'}
# {'symbol': 'MCOETH', 'price': '0.00577200'}
# {'symbol': 'ICNETH', 'price': '0.00166300'}
# {'symbol': 'MCOBTC', 'price': '0.00021140'}
# {'symbol': 'WTCBTC', 'price': '0.00000871'}
# {'symbol': 'WTCETH', 'price': '0.00023700'}
# ...

# %%
symbols =[]
for symbol in prices:
    symbols.append(symbol)
print(symbols)
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.05751700'}, {'symbol': 'LTCBTC', 'price': '0.00267200'}, {'symbol': 'BNBBTC', 'price': '0.01119100'}, {'symbol': 'NEOBTC', 'price': '0.00045400'}, {'symbol': 'QTUMETH', 'price': '0.00248900'}, {'symbol': 'EOSETH', 'price': '0.00082000'}, {'symbol': 'SNTETH', 'price': '0.00002503'}, {'symbol': 'BNTETH', 'price': '0.00042700'}, {'symbol': 'BCCBTC', 'price': '0.07908100'}, {'symbol': 'GASBTC', 'price': '0.00013630'}, {'symbol': 'BNBETH', 'price': '0.19460000'}, {'symbol': 'BTCUSDT', 'price': '20931.61000000'}, {'symbol': 'ETHUSDT', 'price': '1203.77000000'}, {'symbol': 'HSRBTC', 'price': '0.00041400'}, {'symbol': 'OAXETH', 'price': '0.00017780'}, {'symbol': 'DNTETH', 'price': '0.00002801'}, {'symbol': 'MCOETH', 'price': '0.00577200'}, {'symbol': 'ICNETH', 'price': '0.00166300'}, {'symbol': 'MCOBTC', 'price': '0.00021140'}, {'symbol': 'WTCBTC', 'price': '0.00000871'}, {'symbol': 'WTCETH', 'price': '0.00023700'}, {'symbol': 'LRCBTC', 'price': '0.00001948'
# ...

# %%
def scrub_dict_list(dictList):
    """a function which takes as input a kv dictList from and returns a new dict"""
    new_dict = []
    for i in dictList:
        new_dict.append({i['symbol']: i['price']})
    return new_dict
prices_dict = scrub_dict_list(prices)
for i in range(0, len(prices_dict)):
    print(f'{prices_dict[i]}')
# Out:
# {'ETHBTC': '0.05751700'}
# {'LTCBTC': '0.00267200'}
# {'BNBBTC': '0.01119100'}
# {'NEOBTC': '0.00045400'}
# {'QTUMETH': '0.00248900'}
# {'EOSETH': '0.00082000'}
# {'SNTETH': '0.00002503'}
# {'BNTETH': '0.00042700'}
# {'BCCBTC': '0.07908100'}
# {'GASBTC': '0.00013630'}
# {'BNBETH': '0.19460000'}
# {'BTCUSDT': '20931.61000000'}
# {'ETHUSDT': '1203.77000000'}
# {'HSRBTC': '0.00041400'}
# {'OAXETH': '0.00017780'}
# {'DNTETH': '0.00002801'}
# {'MCOETH': '0.00577200'}
# {'ICNETH': '0.00166300'}
# {'MCOBTC': '0.00021140'}
# {'WTCBTC': '0.00000871'}
# {'WTCETH': '0.00023700'}
# {'LRCBTC': '0.00001948'}
# {'LRCETH': '0.00033925'}
# {'QTUMBTC': '0.00014310'}
# {'YOYOBTC': '0.00000008'}
# {'OMGBTC': '0.00009280'}
# {'OMGETH': '0.00161200'}
# {'ZRXBTC': '0.00001540'}
# {'ZRXETH': '0.00026860'}
# {'STRATBTC': '0.00003085'}
# {'STRATETH': '0.00105300'}
# {'SNGLSBTC': '0.00000013'}
# {'SNGLSETH': '0.00005306'}
# {'BQXBTC': '0.00008703'}
# {'BQXETH': '0.00126350'}
# {'KNCBTC': '0.00006702'}
# ...

# %%
if prices_dict[k] == 'ETHBTC':
    print(prices_dict[v])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-ee093130f70b> in <module>
# ----> 1 if prices_dict[k] == 'ETHBTC':
#       2     print(prices_dict[v])
#
# TypeError: list indices must be integers or slices, not str

# %%
#pretty print json
import json 
file_path = "./Binance_ETHBTC_30m_1512086400000-1514764800000.json"

with open(file=file_path, mode='r') as f:
    object = json.load(f)
    pretty_object = json.dumps(object, indent=4)
    print(pretty_object)
# Out:
# [
#     [
#         1512086400000,
#         "0.04368400",
#         "0.04375100",
#         "0.04334200",
#         "0.04366500",
#         "2081.85600000",
#         1512088199999,
#         "90.79655078",
#         3904,
#         "976.19100000",
#         "42.59074736",
#         "271480.34213668"
#     ],
#     [
#         1512088200000,
#         "0.04360200",
#         "0.04369900",
#         "0.04325100",
#         "0.04350100",
#         "2420.48100000",
#         1512089999999,
#         "105.27683806",
#         2775,
#         "1133.24800000",
#         "49.31486895",
#         "271300.32546398"
#     ],
#     [
#         1512090000000,
#         "0.04350100",
#         "0.04379400",
#         "0.04304900",
#         "0.04370500",
#         "2192.51500000",
#         1512091799999,
#         "95.48824264",
#         2359,
#         "1029.30200000",
#         "44.86783356",
#         "271143.81327337"
#     ],
#     [
#         1512091800000,
#         "0.04374900",
# ...

# %%
import requests
import json
response = requests.get("https://www.boredapi.com/api/activity")
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# ...

# %%
# fetch 1 minute klines for the last day up until now
klines = client.get_historical_klines("BNBBTC", Client.KLINE_INTERVAL_1MINUTE, "1 day ago UTC")
print(f'{klines}')
# Out:
# [[1656030840000, '0.01090900', '0.01091100', '0.01090700', '0.01091100', '17.50100000', 1656030899999, '0.19094237', 22, '17.41400000', '0.18999332', '0'], [1656030900000, '0.01091100', '0.01091100', '0.01089900', '0.01090000', '116.36700000', 1656030959999, '1.26902948', 88, '33.45900000', '0.36494308', '0'], [1656030960000, '0.01089900', '0.01090000', '0.01089900', '0.01090000', '5.31700000', 1656031019999, '0.05795425', 10, '4.27400000', '0.04658660', '0'], [1656031020000, '0.01090100', '0.01090100', '0.01089800', '0.01089800', '28.84200000', 1656031079999, '0.31434437', 38, '27.14500000', '0.29585031', '0'], [1656031080000, '0.01089800', '0.01089800', '0.01089700', '0.01089800', '5.89300000', 1656031139999, '0.06421778', 12, '1.79600000', '0.01957278', '0'], [1656031140000, '0.01089700', '0.01090400', '0.01089600', '0.01090400', '2.54700000', 1656031199999, '0.02775443', 17, '0.43900000', '0.00478559', '0'], [1656031200000, '0.01090400', '0.01090700', '0.01090200', '0.01090200', 
# ...

# %%
# %timeit
# fetch 30 minute klines for the last month of 2017
klines = client.get_historical_klines("ETHBTC", Client.KLINE_INTERVAL_30MINUTE, "1 Dec, 2017", "1 Jan, 2018")
print(f'{klines}')
# %timeit
# Out:
# [[1512086400000, '0.04368400', '0.04375100', '0.04334200', '0.04366500', '2081.85600000', 1512088199999, '90.79655078', 3904, '976.19100000', '42.59074736', '271480.34213668'], [1512088200000, '0.04360200', '0.04369900', '0.04325100', '0.04350100', '2420.48100000', 1512089999999, '105.27683806', 2775, '1133.24800000', '49.31486895', '271300.32546398'], [1512090000000, '0.04350100', '0.04379400', '0.04304900', '0.04370500', '2192.51500000', 1512091799999, '95.48824264', 2359, '1029.30200000', '44.86783356', '271143.81327337'], [1512091800000, '0.04374900', '0.04392000', '0.04361300', '0.04378100', '1482.24800000', 1512093599999, '64.86877196', 2112, '704.81600000', '30.85380066', '271394.84389969'], [1512093600000, '0.04375800', '0.04424900', '0.04364800', '0.04403800', '2073.49800000', 1512095399999, '90.95341447', 2763, '996.44700000', '43.72006243', '271126.63134592'], [1512095400000, '0.04400500', '0.04421400', '0.04380000', '0.04389900', '1675.47800000', 1512097199999, '73.620462
# ...

# %%
"""
>>>return klines
>>>[[1512086400000, '0.04368400', '0.04375100', '0.04334200', '0.04366500', '2081.85600000', 1512088199999, '90.79655078', 3904, '976.19100000', '42.59074736', '271480.34213668'], [1512088200000, '0.04360200', '0.04369900', '0.04325100', '0.04350100', '2420.48100000', 1512089999999, '105.27683806', 2775, '1133.24800000', '49.31486895', '271300.32546398'], [1512090000000, '0.04350100', '0.04379400', '0.04304900', '0.04370500', '2192.51500000', 1512091799999, '95.48824264', 2359, '1029.30200000', '44.86783356', '271143.81327337'], [1512091800000, '0.04374900', '0.04392000', '0.04361300', '0.04378100', '1482.24800000', 1512093599999, '64.86877196', 2112, '704.81600000', '30.85380066', '271394.84389969'], [1512093600000, '0.04375800', '0.04424900', '0.04364800', '0.04403800', '2073.49800000', 1512095399999, '90.95341447', 2763, '996.44700000', '43.72006243', '271126.63134592'], [1512095400000, '0.04400500', '0.04421400', '0.04380000', '0.04389900', '1675.47800000', 1512097199999, '73.62046216', 1817, '808.25500000', '35.52008528', '271368.11447690'], [1512097200000, '0.04390400', '0.04413600', '0.04364200', '0.04400500', '2138.10400000', 1512098999999, '93.95901243', 2260, '1157.93700000', '50.88996640', '271143.40315253'], [1512099000000, '0.04400400', '0.04410200', '0.04370000', '0.04400600', '1591.93000000', 1512100799999, '69.98118119', 1529, '874.83700000', '38.46523233', '271075.24993718'], [1512100800000, '0.04400600', '0.04410800', '0.04364600', '0.04379000', '1402.69200000', 1512102599999, '61.60311019', 1250, '550.56300000', '24.17597239', '270940.41564236'], [1512102600000, '0.04382200', '0.04408300', '0.04375500', '0.04382400', '1164.31100000', 1512104399999, '51.15919777', 1253, '592.09300000', '26.01224917', '271065.95719873'], [1512104400000, '0.04385500', '0.04404800', '0.04380100', '0.04404800', '1397.20300000', 1512106199999, '61.32876628', 1092, '643.21100000', '28.23839877', '270588.97964728'], [1512106200000, '0.04403100', '0.04423600', '0.04395200', '0.04419500', '1499.83700000', 1512107999999, '66.14760437', 1462, '795.25100000', '35.08081632', '270882.62858053'], [1512108000000, '0.04419500', '0.04421100', '0.04396000', '0.04404900', '1263.61500000', 1512109799999, '55.69991208', 966, '625.99400000', '27.58478226', '271271.83553205'], [1512109800000, '0.04404400', '0.04430000', '0.04391600', '0.04420800', '1743.65500000', 1512111599999, '76.92182987', 1209, '918.78800000', '40.53320068', '271230.88821283'], [1512111600000, '0.04420700', '0.04432900', '0.04372900', '0.04409300', '1792.78300000', 1512113399999, '79.12751732', 1461, '866.15700000', '38.23355322', '271153.11333894'], [1512113400000, '0.04407600', '0.04417400', '0.04375500', '0.04396100', '1148.70000000', 1512115199999, '50.57659576', 1058, '573.23900000', '25.23843126', '271258.91202144'], [1512115200000, '0.04397800', '0.04404200', '0.04380000', '0.04382700', '1495.47000000', 1512116999999, '65.70960990', 1251, '674.62400000', '29.65108139', '268401.52293752'], [1512117000000, '0.04382700', '0.04388200', '0.04352100', '0.04358800', '1571.00300000', 1512118799999, '68.68068831', 1332, '821.47400000', '35.92920378', '268400.26521541'], [1512118800000, '0.04360000', '0.04365000', '0.04349500', '0.04349500', '1454.26500000', 1512120599999, '63.40937403', 909, '780.55500000', '34.03939395', '269019.23333844'], [1512120600000, '0.04350000', '0.04354700', '0.04316100', '0.04333900', '2015.03600000', 1512122399999, '87.42351509', 1767, '935.21800000', '40.57642876', '269026.30772107'], [1512122400000, '0.04337100', '0.04400000', '0.04333900', '0.04353200', '1906.78100000', 1512124199999, '83.14194190', 1871, '952.48300000', '41.53065939', '269638.20297130'], [1512124200000, '0.04353200', '0.04382400', '0.04353200', '0.04381600', '1127.09000000', 1512125999999, '49.24903478', 1003, '559.14500000', '24.43620945', '269341.91663180'], [1512126000000, '0.04382000', '0.04382700', '0.04340600', '0.04354400', '1630.30500000', 1512127799999, '71.18938109', 979, '653.73300000', '28.54819560', '268671.99064128'], [1512127800000, '0.04359000', '0.04373500', '0.04346900', '0.04352900', '1467.60400000', 1512129599999, '63.95516427', 1051, '627.46200000', '27.34606705', '268637.33099465'], [1512129600000, '0.04355700', '0.04356900', '0.04308800', '0.04327800', '1989.02000000', 1512131399999, '86.05246609', 2042, '928.28600000', '40.16029234', '267980.75304664'], [1512131400000, '0.04328600', '0.04373000', '0.04326600', '0.04358100', '2634.54900000', 1512133199999, '114.57108585', 2326, '1159.61700000', '50.42924982', '267133.59514106'], [1512133200000, '0.04358100', '0.04378600', '0.04300000', '0.04300100', '2173.46800000', 1512134999999, '94.08338855', 1718, '901.51600000', '39.05729679', '266794.53142228'], [1512135000000, '0.04300100', '0.04309500', '0.04257000', '0.04270000', '2372.55800000', 1512136799999, '101.83383944', 1702, '1235.14600000', '53.04561110', '267110.54927121'], [1512136800000, '0.04264900', '0.04296400', '0.04227500', '0.04257400', '2585.33400000', 1512138599999, '110.25653774', 2197, '1168.40700000', '49.86285816', '267114.73286160'], [1512138600000, '0.04259500', '0.04276900', '0.04244900', '0.04260000', '2138.59900000', 1512140399999, '91.11009973', 1790, '917.07300000', '39.07409926', '266948.60333291'], [1512140400000, '0.04259700', '0.04278200', '0.04252800', '0.04259400', '996.25900000', 1512142199999, '42.46750814', 1211, '508.61400000', '21.67973287', '266957.11155086'], [1512142200000, '0.04259400', '0.04270700', '0.04231100', '0.04267700', '1437.24600000', 1512143999999, '61.15881748', 1366, '700.30000000', '29.79873709', '266448.95055642'], [1512144000000, '0.04266700', '0.04274900', '0.04242500', '0.04250600', '1527.74200000', 1512145799999, '65.10187521', 1599, '712.80900000', '30.38484655', '266721.58475128'], [1512145800000, '0.04255700', '0.04264100', '0.04231100', '0.04262000', '1908.94600000', 1512147599999, '81.17814123', 1573, '999.41200000', '42.50300262', '266621.01683457'], [1512147600000, '0.04262600', '0.04310000', '0.04259800', '0.04285300', '2230.09800000', 1512149399999, '95.57941353', 1598, '1119.67600000', '48.00095182', '266568.21073200'], [1512149400000, '0.04281000', '0.04323600', '0.04277700', '0.04317600', '1678.12400000', 1512151199999, '72.22067033', 1440, '932.43800000', '40.14993169', '266328.26722113'], [1512151200000, '0.04317000', '0.04322200', '0.04290800', '0.04310300', '1442.84900000', 1512152999999, '62.23831236', 1443, '743.31700000', '32.08014817', '266295.70410343'], [1512153000000, '0.04310300', '0.04325000', '0.04292200', '0.04315300', '1508.50100000', 1512154799999, '65.01601936', 1406, '821.56200000', '35.41582426', '266732.09724993'], [1512154800000, '0.04315300', '0.04320400', '0.04275900', '0.04290000', '1181.18600000', 1512156599999, '50.77514033', 1010, '534.41800000', '22.97700619', '266748.74461113'], [1512156600000, '0.04290300', '0.04325000', '0.04270000', '0.04318400', '1739.45500000', 1512158399999, '74.84242335', 1408, '782.68400000', '33.67950383', '267404.76160638'], [1512158400000, '0.04319900', '0.04372000', '0.04315100', '0.04363100', '1846.13600000', 1512160199999, '80.15506917', 1660, '998.40100000', '43.35174996', '267820.82720175'], [1512160200000, '0.04363200', '0.04363500', '0.04285300', '0.04313800', '2073.85800000', 1512161999999, '89.69689423', 1615, '1043.54100000', '45.15202665', '268022.87399258'], [1512162000000, '0.04313800', '0.04325300', '0.04285400', '0.04305700', '1367.38800000', 1512163799999, '58.88012192', 1094, '735.17500000', '31.67018591', '268547.64579087'], [1512163800000, '0.04309800', '0.04325300', '0.04253800', '0.04275500', '1791.68800000', 1512165599999, '76.63667427', 1247, '850.78600000', '36.38223362', '268884.28413891'], [1512165600000, '0.04273400', '0.04275500', '0.04233400', '0.04260300', '1584.89200000', 1512167399999, '67.49509760', 1295, '922.40700000', '39.30820046', '269086.15043271'], [1512167400000, '0.04259700', '0.04281900', '0.04241600', '0.04251900', '1722.19600000', 1512169199999, '73.31420542', 1482, '834.58100000', '35.53113464', '269019.12020339'], [1512169200000, '0.04251900', '0.04290100', '0.04232300', '0.04255900', '1836.06500000', 1512170999999, '78.15352197', 1683, '1013.64600000', '43.15553755', '269140.77434543'], [1512171000000, '0.04256000', '0.04267200', '0.04229100', '0.04239700', '1503.50400000', 1512172799999, '63.88480104', 1465, '819.02400000', '34.80885295', '269562.18933427'], [1512172800000, '0.04239700', '0.04262700', '0.04217100', '0.04247400', '2651.04400000', 1512174599999, '112.46183871', 3801, '1351.67900000', '57.37578550', '269891.38070721'], [1512174600000, '0.04241600', '0.04257600', '0.04217400', '0.04228300', '1880.03900000', 1512176399999, '79.66958846', 2377, '948.91200000', '40.21145065', '270037.64047316'], [1512176400000, '0.04226200', '0.04248200', '0.04201200', '0.04231500', '2045.50100000', 1512178199999, '86.46714898', 2368, '1014.40100000', '42.89770505', '269825.63175234'], [1512178200000, '0.04231500', '0.04237800', '0.04203600', '0.04229900', '2699.29100000', 1512179999999, '114.01790042', 2822, '1248.43600000', '52.75474019', '269501.25468652'], [1512180000000, '0.04230000', '0.04242700', '0.04220200', '0.04230000', '2662.51200000', 1512181799999, '112.74032153', 2311, '1052.77000000', '44.59605908', '269323.30945372'], [1512181800000, '0.04234900', '0.04236000', '0.04203700', '0.04210100', '2740.83700000', 1512183599999, '115.72645675', 2763, '1246.63300000', '52.64793037', '268952.65695185'], [1512183600000, '0.04210100', '0.04227800', '0.04200900', '0.04212400', '2179.18600000', 1512185399999, '91.81652246', 2302, '958.39400000', '40.39209400', '268710.19904002'], [1512185400000, '0.04217100', '0.04221700', '0.04200000', '0.04220700', '1364.58500000', 1512187199999, '57.48066803', 1609, '626.78000000', '26.40724625', '268613.29858871'], [1512187200000, '0.04220600', '0.04236000', '0.04207700', '0.04220000', '2714.66000000', 1512188999999, '114.60544660', 3114, '1260.67400000', '53.22852144', '268222.35598328'], [1512189000000, '0.04220100', '0.04236900', '0.04212200', '0.04215600', '2061.91300000', 1512190799999, '87.08401489', 2154, '1059.49300000', '44.76049841', '268138.12828768'], [1512190800000, '0.04216300', '0.04235000', '0.04214500', '0.04230400', '1497.64000000', 1512192599999, '63.31194815', 1267, '820.26700000', '34.68489659', '268332.45912337'], [1512192600000, '0.04230800', '0.04242000', '0.04218100', '0.04229600', '2226.33800000', 1512194399999, '94.23790233', 1678, '910.90300000', '38.56550483', '268650.81701932'], [1512194400000, '0.04229600', '0.04270000', '0.04221700', '0.04239200', '2189.87300000', 1512196199999, '92.74278092', 2186, '986.53000000', '41.80593513', '268635.04605970'], [1512196200000, '0.04244300', '0.04265100', '0.04236400', '0.04258700', '2312.79000000', 1512197999999, '98.16349974', 1700, '1076.61100000', '45.70608796', '268511.00664759'], [1512198000000, '0.04258700', '0.04264500', '0.04246500', '0.04249600', '1867.80400000', 1512199799999, '79.52196826', 1655, '932.35500000', '39.70486993', '268247.80913883'], [1512199800000, '0.04252000', '0.04263800', '0.04239600', '0.04246600', '2046.04300000', 1512201599999, '87.01337958', 1830, '1027.17500000', '43.67992134', '267950.49551315'], [1512201600000, '0.04246000', '0.04263500', '0.04227000', '0.04233100', '2609.14100000', 1512203399999, '110.82542690', 2063, '1258.12900000', '53.45674785', '267350.72530241'], [1512203400000, '0.04228100', '0.04246000', '0.04216600', '0.04233600', '2517.69100000', 1512205199999, '106.53761744', 2594, '1359.74200000', '57.55516053', '267189.47899880'], [1512205200000, '0.04233600', '0.04238000', '0.04178600', '0.04198600', '3493.13500000', 1512206999999, '146.81352412', 2908, '1562.43700000', '65.65586149', '266523.14601562'], [1512207000000, '0.04194100', '0.04230000', '0.04177500', '0.04210500', '1959.79200000', 1512208799999, '82.46986727', 2322, '1028.91500000', '43.31508613', '266334.59423777'], [1512208800000, '0.04214200', '0.04226300', '0.04200100', '0.04204100', '1420.55900000', 1512210599999, '59.86895082', 2154, '770.23700000', '32.47140908', '266435.99181992'], [1512210600000, '0.04204000', '0.04219200', '0.04182600', '0.04207200', '1819.64000000', 1512212399999, '76.37850953', 2226, '912.50200000', '38.31261934', '265969.33443801'], [1512212400000, '0.04207100', '0.04219200', '0.04175000', '0.04203900', '2469.27000000', 1512214199999, '103.65594534', 2190, '1139.56200000', '47.85126723', '265865.38328610'], [1512214200000, '0.04200200', '0.04228100', '0.04175100', '0.04203000', '2899.57900000', 1512215999999, '121.81795743', 2943, '1389.85000000', '58.42328323', '264376.08503094'], [1512216000000, '0.04203200', '0.04207900', '0.04175700', '0.04192600', '1496.20800000', 1512217799999, '62.73605868', 1757, '796.62500000', '33.41099435', '264396.24959268'], [1512217800000, '0.04190200', '0.04192300', '0.04168600', '0.04170700', '2464.20300000', 1512219599999, '103.03233561', 1946, '1225.52000000', '51.25804818', '264235.40901874'], [1512219600000, '0.04170100', '0.04200000', '0.04167900', '0.04185900', '1812.52100000', 1512221399999, '75.72026348', 1861, '864.79500000', '36.13889201', '263417.61396497'], [1512221400000, '0.04181200', '0.04199900', '0.04170300', '0.04188800', '2095.06800000', 1512223199999, '87.65555453', 2253, '1067.26000000', '44.67431378', '262976.25343743'], [1512223200000, '0.04184500', '0.04212800', '0.04175800', '0.04201400', '1922.82400000', 1512224999999, '80.64672647', 2511, '836.23100000', '35.07837258', '262783.81945662'], [1512225000000, '0.04201300', '0.04206400', '0.04180100', '0.04191700', '1648.84200000', 1512226799999, '69.14799519', 1970, '686.27100000', '28.79882422', '262772.24982636'], [1512226800000, '0.04196300', '0.04212700', '0.04187000', '0.04200000', '1641.84600000', 1512228599999, '68.94401700', 2122, '953.96900000', '40.06990226', '262752.23318637'], [1512228600000, '0.04200000', '0.04212600', '0.04182500', '0.04200700', '1577.44700000', 1512230399999, '66.24202351', 1841, '781.61700000', '32.83018223', '262653.14170909'], [1512230400000, '0.04200700', '0.04214800', '0.04196700', '0.04201300', '1280.55200000', 1512232199999, '53.84543936', 1754, '723.94800000', '30.44518595', '262273.92358782'], [1512232200000, '0.04201300', '0.04216900', '0.04195800', '0.04206300', '1391.48300000', 1512233999999, '58.51472539', 1785, '680.32600000', '28.62265645', '262845.34407801'], [1512234000000, '0.04204500', '0.04244100', '0.04200000', '0.04212100', '1465.72000000', 1512235799999, '61.72468729', 1635, '761.00500000', '32.06432871', '262757.94907289'], [1512235800000, '0.04205500', '0.04217700', '0.04180400', '0.04211600', '1271.12400000', 1512237599999, '53.47809005', 1290, '623.96600000', '26.25998853', '263102.57556952'], [1512237600000, '0.04211500', '0.04211900', '0.04187000', '0.04203200', '1282.91900000', 1512239399999, '53.89971475', 1210, '708.03200000', '29.75125792', '263747.23749350'], [1512239400000, '0.04203200', '0.04215900', '0.04193900', '0.04209300', '1037.33800000', 1512241199999, '43.63340211', 1358, '524.64400000', '22.07314885', '262772.23755131'], [1512241200000, '0.04209300', '0.04220500', '0.04170600', '0.04206500', '1434.52300000', 1512242999999, '60.36939314', 1192, '754.32800000', '31.76630675', '263005.54938133'], [1512243000000, '0.04204500', '0.04214800', '0.04173900', '0.04197700', '1080.67800000', 1512244799999, '45.45928338', 978, '603.79000000', '25.40704558', '262995.60415732'], [1512244800000, '0.04198400', '0.04209100', '0.04175000', '0.04190200', '1095.00600000', 1512246599999, '45.97255572', 1346, '629.97600000', '26.44880311', '263597.01794429'], [1512246600000, '0.04190200', '0.04206900', '0.04178900', '0.04182300', '1358.46400000', 1512248399999, '56.92837396', 1184, '649.86600000', '27.23913536', '263815.36614701'], [1512248400000, '0.04180700', '0.04190500', '0.04160000', '0.04178800', '1315.60200000', 1512250199999, '54.91501137', 1035, '700.47200000', '29.24949579', '263982.47143900'], [1512250200000, '0.04183000', '0.04196900', '0.04160100', '0.04174800', '1031.44900000', 1512251999999, '43.10730923', 1114, '479.25200000', '20.03200406', '264159.53841024'], [1512252000000, '0.04174800', '0.04183900', '0.04160800', '0.04177100', '1033.47200000', 1512253799999, '43.14615032', 999, '631.50500000', '26.36879210', '264559.38896839'], [1512253800000, '0.04179400', '0.04199600', '0.04175400', '0.04187800', '1454.73100000', 1512255599999, '60.90801957', 1350, '739.28700000', '30.96164789', '264572.07897112'], [1512255600000, '0.04192200', '0.04195000', '0.04174000', '0.04192500', '1401.97200000', 1512257399999, '58.70455935', 1260, '605.63400000', '25.36401410', '264216.01639579'], [1512257400000, '0.04192100', '0.04204300', '0.04182200', '0.04197800', '1292.45100000', 1512259199999, '54.19081776', 1290, '750.86200000', '31.48516587', '264122.66674083'], [1512259200000, '0.04193700', '0.04202800', '0.04179500', '0.04200000', '1899.42800000', 1512260999999, '79.57738261', 2207, '900.68000000', '37.76311320', '264263.36630377'], [1512261000000, '0.04200000', '0.04215000', '0.04167600', '0.04190200', '2723.47900000', 1512262799999, '114.28723365', 2756, '1349.89200000', '56.65402581', '264850.59906016'], [1512262800000, '0.04193200', '0.04201700', '0.04179500', '0.04190800', '1889.46500000', 1512264599999, '79.19181355', 2282, '982.57300000', '41.19101746', '265137.89035258'], [1512264600000, '0.04194800', '0.04237100', '0.04190600', '0.04196000', '1706.82100000', 1512266399999, '71.71580866', 2471, '827.27100000', '34.77879333', '265216.80262408'], [1512266400000, '0.04195500', '0.04236900', '0.04183900', '0.04186100', '1698.00600000', 1512268199999, '71.35094944', 2333, '655.30100000', '27.55708854', '265808.77299839'], [1512268200000, '0.04190300', '0.04197200', '0.04158000', '0.04179100', '2081.48600000', 1512269999999, '86.99504804', 2203, '911.47600000', '38.10637081', '266320.01927516'], [1512270000000, '0.04174800', '0.04189900', '0.04163300', '0.04171600', '1654.11400000', 1512271799999, '69.07637496', 2224, '794.63100000', '33.20192385', '266838.03592839'], [1512271800000, '0.04173800', '0.04183000', '0.04150500', '0.04163100', '1639.41400000', 1512273599999, '68.30282551', 2046, '900.29300000', '37.51981846', '266707.52161704'], [1512273600000, '0.04163100', '0.04172400', '0.04150500', '0.04167000', '1594.85300000', 1512275399999, '66.37945512', 2122, '811.65400000', '33.79168301', '266827.94939877'], [1512275400000, '0.04162600', '0.04172000', '0.04150200', '0.04164100', '1648.51900000', 1512277199999, '68.59761027', 1838, '781.38700000', '32.52550791', '268684.75389469'], [1512277200000, '0.04160600', '0.04170000', '0.04134600', '0.04160200', '1978.45400000', 1512278999999, '82.29413312', 2070, '965.41800000', '40.17544734', '268760.51839778'], [1512279000000, '0.04157400', '0.04179500', '0.04150900', '0.04177800', '2504.21700000', 1512280799999, '104.32472397', 1593, '1307.93700000', '54.50822127', '268521.01235542'], [1512280800000, '0.04175600', '0.04216000', '0.04173300', '0.04210900', '1438.79700000', 1512282599999, '60.42296635', 1454, '734.37400000', '30.84021529', '268239.34506859'], [1512282600000, '0.04210900', '0.04221200', '0.04180900', '0.04196700', '1722.33300000', 1512284399999, '72.45425208', 1481, '808.51100000', '34.02851253', '267588.75439027'], [1512284400000, '0.04196700', '0.04196900', '0.04169800', '0.04180600', '1557.96000000', 1512286199999, '65.17218801', 1205, '736.23000000', '30.79624168', '267762.86429975'], [1512286200000, '0.04180600', '0.04189200', '0.04177700', '0.04180600', '1126.50800000', 1512287999999, '47.11140915', 981, '555.28100000', '23.22767087', '267745.05230975'], [1512288000000, '0.04182500', '0.04184800', '0.04171000', '0.04182500', '1129.87700000', 1512289799999, '47.21700248', 974, '348.71700000', '14.58026898', '267338.92046380'], [1512289800000, '0.04179000', '0.04191300', '0.04175400', '0.04183400', '1475.50100000', 1512291599999, '61.71668615', 1073, '667.70700000', '27.93429605', '267907.72504233'], [1512291600000, '0.04183400', '0.04190400', '0.04173300', '0.04182700', '1266.66700000', 1512293399999, '52.96166212', 1064, '759.46200000', '31.76109945', '267469.92025618'], [1512293400000, '0.04182700', '0.04192400', '0.04172300', '0.04190900', '2021.41800000', 1512295199999, '84.56053793', 1575, '963.04400000', '40.30111164', '267844.82567658'], [1512295200000, '0.04190800', '0.04192000', '0.04169400', '0.04180600', '1806.47400000', 1512296999999, '75.50521454', 1371, '941.97400000', '39.38340369', '267844.88823116'], [1512297000000, '0.04176800', '0.04189000', '0.04176500', '0.04184700', '1678.55600000', 1512298799999, '70.19132537', 1495, '762.74600000', '31.89791528', '268208.17654002'], [1512298800000, '0.04186600', '0.04196200', '0.04135500', '0.04148500', '2979.09400000', 1512300599999, '124.16296137', 2077, '1287.25300000', '53.69158540', '268129.05195149'], [1512300600000, '0.04148500', '0.04156100', '0.04100000', '0.04114900', '3183.70200000', 1512302399999, '131.32735580', 2299, '1495.93200000', '61.72691727', '268091.61961302'], [1512302400000, '0.04114900', '0.04125100', '0.04078000', '0.04106000', '2505.16700000', 1512304199999, '102.85715327', 2027, '1004.96200000', '41.25206081', '268479.66078981'], [1512304200000, '0.04110500', '0.04111900', '0.04086100', '0.04091800', '1743.83600000', 1512305999999, '71.49762707', 1579, '781.87800000', '32.06920734', '268338.84215817'], [1512306000000, '0.04091800', '0.04098600', '0.04077400', '0.04091600', '1739.37500000', 1512307799999, '71.13231980', 1442, '870.27300000', '35.60078228', '268318.42989027'], [1512307800000, '0.04093200', '0.04094800', '0.04075300', '0.04089200', '2162.70300000', 1512309599999, '88.39388072', 1628, '1142.69600000', '46.71105360', '269222.02505628'], [1512309600000, '0.04083200', '0.04097100', '0.04065500', '0.04085400', '1941.54600000', 1512311399999, '79.30619816', 2108, '964.28700000', '39.39541358', '269679.53221113'], [1512311400000, '0.04085500', '0.04098700', '0.04075900', '0.04093000', '1702.92200000', 1512313199999, '69.63742468', 1375, '775.56900000', '31.71987264', '269140.68376067'], [1512313200000, '0.04096500', '0.04098700', '0.04056000', '0.04056000', '1770.06400000', 1512314999999, '72.12233040', 2007, '833.28100000', '33.97680187', '269116.76453630'], [1512315000000, '0.04056000', '0.04077000', '0.04047200', '0.04054300', '1656.54100000', 1512316799999, '67.20979834', 1712, '713.47500000', '28.95358768', '269425.37791319'], [1512316800000, '0.04059300', '0.04064900', '0.04041800', '0.04061400', '2619.52300000', 1512318599999, '106.24594819', 2329, '1158.25900000', '46.99515708', '269771.39336151'], [1512318600000, '0.04064700', '0.04080000', '0.04048700', '0.04072500', '2323.51300000', 1512320399999, '94.47927873', 1912, '1091.54700000', '44.39731268', '269262.88326509'], [1512320400000, '0.04072200', '0.04083000', '0.04050000', '0.04067400', '1762.61200000', 1512322199999, '71.73377387', 1559, '851.58400000', '34.67225277', '269408.45794714'], [1512322200000, '0.04061300', '0.04086100', '0.04060200', '0.04076100', '1621.64800000', 1512323999999, '66.03515892', 1371, '681.22100000', '27.75673708', '270103.63723129'], [1512324000000, '0.04078100', '0.04086300', '0.04069100', '0.04077400', '1211.51500000', 1512325799999, '49.42138513', 1126, '580.94100000', '23.71359617', '270445.32458654'], [1512325800000, '0.04082000', '0.04085800', '0.04073700', '0.04080400', '1447.90300000', 1512327599999, '59.04931442', 917, '601.16200000', '24.52619365', '269025.82129279'], [1512327600000, '0.04079800', '0.04086200', '0.04067600', '0.04080000', '1540.15200000', 1512329399999, '62.80944039', 918, '843.89500000', '34.43130582', '268929.11142136'], [1512329400000, '0.04081500', '0.04086300', '0.04069300', '0.04080000', '1005.20400000', 1512331199999, '41.00964458', 643, '506.60400000', '20.66847421', '269870.46081106'], [1512331200000, '0.04078000', '0.04085300', '0.04050000', '0.04061700', '1295.32300000', 1512332999999, '52.69095773', 1000, '654.22300000', '26.60160568', '270037.32968776'], [1512333000000, '0.04061800', '0.04150000', '0.04053600', '0.04106300', '2636.16000000', 1512334799999, '108.03747182', 2300, '1283.39500000', '52.59402182', '269425.01265026'], [1512334800000, '0.04102900', '0.04137100', '0.04080500', '0.04120900', '1242.79300000', 1512336599999, '50.99872274', 1317, '621.43000000', '25.50813913', '269701.66468532'], [1512336600000, '0.04120400', '0.04204000', '0.04090200', '0.04160500', '3926.45900000', 1512338399999, '163.12663318', 2897, '1785.67700000', '74.31614869', '269093.16859918'], [1512338400000, '0.04153900', '0.04203400', '0.04119500', '0.04140600', '2075.53600000', 1512340199999, '86.33514048', 2019, '960.16100000', '39.96731280', '270084.77106728'], [1512340200000, '0.04142300', '0.04177200', '0.04102100', '0.04138400', '1365.72800000', 1512341999999, '56.46007250', 1665, '691.42800000', '28.59352140', '269947.72529590'], [1512342000000, '0.04138500', '0.04148800', '0.04115200', '0.04131800', '1594.20900000', 1512343799999, '65.92165142', 1417, '878.95600000', '36.36512993', '269997.02764502'], [1512343800000, '0.04131800', '0.04143700', '0.04103300', '0.04114100', '1230.27100000', 1512345599999, '50.72588749', 1616, '597.20000000', '24.62054677', '270057.36612993'], [1512345600000, '0.04115500', '0.04120100', '0.04096900', '0.04116800', '1875.98400000', 1512347399999, '77.09714853', 2002, '1017.18300000', '41.81554176', '270394.12603924'], [1512347400000, '0.04114900', '0.04131200', '0.04098800', '0.04107800', '1902.33600000', 1512349199999, '78.23126955', 1706, '864.70400000', '35.56715107', '269854.62725198'], [1512349200000, '0.04107500', '0.04111700', '0.04053300', '0.04072100', '2133.64500000', 1512350999999, '86.95524120', 1953, '997.57600000', '40.66797000', '269790.05808361'], [1512351000000, '0.04072000', '0.04085600', '0.04053100', '0.04054600', '2155.55500000', 1512352799999, '87.73059174', 2036, '1108.05300000', '45.11778998', '269826.97414352'], [1512352800000, '0.04054600', '0.04095900', '0.04053100', '0.04079500', '2377.16500000', 1512354599999, '96.91237818', 2068, '1155.17300000', '47.11154650', '269187.36312073'], [1512354600000, '0.04079300', '0.04092000', '0.04053000', '0.04060000', '2244.44700000', 1512356399999, '91.39262890', 1991, '1179.83900000', '48.06104807', '270545.03178646'], [1512356400000, '0.04060000', '0.04073500', '0.04040600', '0.04071400', '2473.87800000', 1512358199999, '100.39450836', 2599, '1230.03400000', '49.94157391', '271289.34654157'], [1512358200000, '0.04067600', '0.04075100', '0.04050000', '0.04057200', '2103.95400000', 1512359999999, '85.47283896', 2104, '979.83800000', '39.81268716', '272771.67203739'], [1512360000000, '0.04054000', '0.04063000', '0.04035500', '0.04044400', '2503.33200000', 1512361799999, '101.26544303', 2522, '1097.35600000', '44.41737257', '273595.07827301'], [1512361800000, '0.04039800', '0.04064300', '0.04032100', '0.04034000', '2753.95800000', 1512363599999, '111.30202784', 2549, '1231.38200000', '49.79175895', '274959.07498964'], [1512363600000, '0.04033800', '0.04060800', '0.04015100', '0.04057000', '4492.67700000', 1512365399999, '181.28798647', 3533, '2205.23100000', '89.02387402', '275221.42654397'], [1512365400000, '0.04051100', '0.04087400', '0.04018000', '0.04057100', '4108.03400000', 1512367199999, '166.67419670', 3984, '2019.73900000', '82.02860089', '276233.21342833'], [1512367200000, '0.04053000', '0.04057800', '0.04049300', '0.04054900', '33.59700000', 1512368999999, '1.36180483', 44, '16.38800000', '0.66459325', '276233.21342833'], [1512369000000, '0.04053800', '0.04070300', '0.04048800', '0.04061800', '95.36000000', 1512370799999, '3.87163904', 96, '71.82500000', '2.91663417', '277080.61184807'], [1512370800000, '0.04061800', '0.04098500', '0.04035000', '0.04074300', '1491.59300000', 1512372599999, '60.66268806', 825, '780.18700000', '31.71638291', '276340.93018644'], [1512372600000, '0.04071800', '0.04079200', '0.04035100', '0.04066400', '2125.24800000', 1512374399999, '86.37566805', 1254, '964.36800000', '39.20410850', '275497.35524323'], [1512374400000, '0.04062500', '0.04086500', '0.04041300', '0.04067200', '1748.16700000', 1512376199999, '71.10183757', 1418, '667.68500000', '27.16635986', '275568.14425562'], [1512376200000, '0.04071600', '0.04076600', '0.04011400', '0.04064500', '1592.38300000', 1512377999999, '64.67548640', 1545, '732.22900000', '29.75807798', '275730.75315523'], [1512378000000, '0.04065100', '0.04100000', '0.04060000', '0.04087300', '1072.13600000', 1512379799999, '43.73174862', 1048, '479.02200000', '19.55440167', '273085.41981765'], [1512379800000, '0.04086800', '0.04100000', '0.04073600', '0.04088300', '1038.77700000', 1512381599999, '42.42985011', 1368, '502.89600000', '20.55136496', '273778.74044479'], [1512381600000, '0.04085000', '0.04099600', '0.04064600', '0.04071800', '1762.13400000', 1512383399999, '71.91069120', 1842, '643.90200000', '26.28947777', '272369.21947925'], [1512383400000, '0.04072300', '0.04086800', '0.04052300', '0.04067100', '1635.30900000', 1512385199999, '66.52009852', 1549, '717.60200000', '29.20249440', '272973.24704183'], [1512385200000, '0.04067100', '0.04100000', '0.04064000', '0.04096600', '1927.05500000', 1512386999999, '78.61710101', 2505, '875.60000000', '35.75465132', '273530.13588410'], [1512387000000, '0.04092100', '0.04104300', '0.04061900', '0.04077200', '2725.82700000', 1512388799999, '111.28965587', 2893, '1418.32300000', '57.92469749', '272614.81355864'], [1512388800000, '0.04077200', '0.04101200', '0.04060100', '0.04072800', '2056.74300000', 1512390599999, '83.89014104', 2609, '896.45300000', '36.58351080', '273550.84928045'], [1512390600000, '0.04072600', '0.04082300', '0.04051000', '0.04073400', '699.30400000', 1512392399999, '28.43441512', 864, '369.70600000', '15.04537634', '273838.82158505'], [1512392400000, '0.04077900', '0.04110700', '0.04061700', '0.04074500', '555.48300000', 1512394199999, '22.69111877', 1097, '305.15800000', '12.47439793', '273721.11081612'], [1512394200000, '0.04070800', '0.04109000', '0.04061100', '0.04080700', '1718.47700000', 1512395999999, '70.13663631', 2114, '891.30500000', '36.38948503', '272280.89637142'], [1512396000000, '0.04080600', '0.04085500', '0.04053500', '0.04070000', '2156.40600000', 1512397799999, '87.77706036', 2009, '1060.22900000', '43.17354028', '271616.45335570'], [1512397800000, '0.04070000', '0.04076800', '0.04025100', '0.04057400', '2309.49400000', 1512399599999, '93.86860897', 1949, '1115.79200000', '45.36295577', '271187.84317435'], [1512399600000, '0.04058100', '0.04072100', '0.04043000', '0.04052000', '3386.98600000', 1512401399999, '137.52702181', 3076, '1594.81800000', '64.79395283', '271070.05728087'], [1512401400000, '0.04062000', '0.04069300', '0.04034200', '0.04060900', '3106.48200000', 1512403199999, '126.05835442', 3152, '1454.85800000', '59.06644857', '272085.12721086'], [1512403200000, '0.04061300', '0.04068500', '0.04029500', '0.04051000', '3423.63700000', 1512404999999, '138.79358365', 3839, '1685.28800000', '68.35422995', '272865.62488770'], [1512405000000, '0.04051000', '0.04065000', '0.04035000', '0.04058300', '3588.99900000', 1512406799999, '145.48605856', 2969, '1903.08900000', '77.16854555', '273538.55386529'], [1512406800000, '0.04062900', '0.04072300', '0.04030000', '0.04030000', '2028.72200000', 1512408599999, '82.28195583', 2227, '875.39000000', '35.51700613', '273951.95096273'], [1512408600000, '0.04029700', '0.04065300', '0.04027200', '0.04065300', '2697.47000000', 1512410399999, '109.37895644', 1853, '1473.79000000', '59.76620491', '274489.98941179'], [1512410400000, '0.04063900', '0.04073500', '0.04036400', '0.04052000', '3530.26900000', 1512412199999, '143.25154582', 2616, '1585.77100000', '64.36525765', '275253.90876893'], [1512412200000, '0.04051600', '0.04067900', '0.04038100', '0.04052400', '2011.29800000', 1512413999999, '81.52074205', 1912, '951.41100000', '38.58806547', '275156.82267028'], [1512414000000, '0.04052700', '0.04057900', '0.04040000', '0.04051500', '1538.37400000', 1512415799999, '62.28802012', 1651, '815.45400000', '33.02923358', '276121.07830242'], [1512415800000, '0.04052500', '0.04081900', '0.04038300', '0.04081900', '2402.05100000', 1512417599999, '97.56233960', 1562, '1176.93300000', '47.82812961', '276258.11135955'], [1512417600000, '0.04078000', '0.04081800', '0.04039500', '0.04066200', '1738.40000000', 1512419399999, '70.63816443', 1845, '749.85700000', '30.47827126', '276480.07634755'], [1512419400000, '0.04067400', '0.04067400', '0.04022400', '0.04022500', '2082.74900000', 1512421199999, '84.11068817', 1431, '688.93600000', '27.82877362', '276232.09430409'], [1512421200000, '0.04024000', '0.04028700', '0.04010000', '0.04020800', '1342.87700000', 1512422999999, '53.94666659', 1521, '738.29900000', '29.66445483', '276293.77068901'], [1512423000000, '0.04019000', '0.04044000', '0.04007100', '0.04015500', '1730.94000000', 1512424799999, '69.61194773', 1783, '885.82700000', '35.64904612', '277442.68688289'], [1512424800000, '0.04020300', '0.04040000', '0.04011300', '0.04035700', '1780.26500000', 1512426599999, '71.66405795', 1345, '899.71400000', '36.21922031', '278445.31279992'], [1512426600000, '0.04034700', '0.04044600', '0.04015700', '0.04036800', '1216.82100000', 1512428399999, '49.07706658', 1696, '638.73500000', '25.77387883', '278380.02135808'], [1512428400000, '0.04035200', '0.04038000', '0.04014900', '0.04035000', '1827.68300000', 1512430199999, '73.61889961', 2456, '914.63900000', '36.85262511', '278409.40064146'], [1512430200000, '0.04030700', '0.04038000', '0.04010000', '0.04018100', '1628.33700000', 1512431999999, '65.59838331', 2543, '815.33800000', '32.85071107', '278606.01147278'], [1512432000000, '0.04018200', '0.04029900', '0.04000300', '0.04015400', '2536.22300000', 1512433799999, '101.85565592', 2907, '1284.49500000', '51.61190524', '279185.13056218'], [1512433800000, '0.04009600', '0.04032800', '0.04000000', '0.04011100', '2168.78900000', 1512435599999, '87.13854519', 2691, '1090.86300000', '43.85484770', '279458.70644982'], [1512435600000, '0.04011100', '0.04030900', '0.03990000', '0.04003500', '3036.96200000', 1512437399999, '121.61453483', 2911, '1401.31000000', '56.12699823', '279662.34363628'], [1512437400000, '0.04001400', '0.04035000', '0.03995300', '0.04023300', '4192.40900000', 1512439199999, '168.33627974', 4309, '1699.94500000', '68.27704568', '278011.08940952'], [1512439200000, '0.04014500', '0.04035300', '0.03993800', '0.04002600', '2247.28100000', 1512440999999, '90.10168395', 3791, '1158.09300000', '46.45602077', '278548.96403265'], [1512441000000, '0.04002600', '0.04035700', '0.03984200', '0.04019400', '3766.44900000', 1512442799999, '151.03184413', 3823, '1474.33700000', '59.08843452', '277347.00217327'], [1512442800000, '0.04019400', '0.04036700', '0.04003200', '0.04014500', '2320.05300000', 1512444599999, '93.13268212', 4190, '1085.52500000', '43.60521873', '277831.16920991'], [1512444600000, '0.04015600', '0.04023300', '0.03992300', '0.04003800', '2522.11700000', 1512446399999, '101.10167512', 4361, '1211.21200000', '48.58343419', '277563.19136999'], [1512446400000, '0.04003100', '0.04021000', '0.04000900', '0.04020000', '2960.75800000', 1512448199999, '118.72470370', 3492, '1481.93800000', '59.44884676', '281826.25680563'], [1512448200000, '0.04020000', '0.04023400', '0.03999600', '0.04004500', '3412.06100000', 1512449999999, '136.82818448', 2914, '1889.38700000', '75.77771929', '280423.93447136'], [1512450000000, '0.04004500', '0.04016700', '0.03984200', '0.03985800', '2617.09700000', 1512451799999, '104.74921375', 2824, '1261.82000000', '50.52229377', '279849.99693037'], [1512451800000, '0.03998500', '0.03999600', '0.03980100', '0.03992200', '2445.15900000', 1512453599999, '97.57537355', 2488, '1240.78000000', '49.53694513', '280551.88941898'], [1512453600000, '0.03991800', '0.04004100', '0.03986200', '0.03998500', '2283.54300000', 1512455399999, '91.19679463', 2682, '985.06500000', '39.35746856', '280790.33075526'], [1512455400000, '0.03997500', '0.04010000', '0.03990600', '0.03992800', '1448.08500000', 1512457199999, '57.90941989', 1576, '669.39900000', '26.78374639', '280825.99880477'], [1512457200000, '0.03993300', '0.04005900', '0.03983800', '0.03999900', '2220.96500000', 1512458999999, '88.70815684', 2526, '983.91100000', '39.31460089', '280731.08885663'], [1512459000000, '0.03991700', '0.04001700', '0.03945100', '0.03953400', '2686.34900000', 1512460799999, '106.73777338', 2891, '1238.97000000', '49.25821585', '281839.07363256'], [1512460800000, '0.03953400', '0.03977500', '0.03935000', '0.03969100', '2378.44400000', 1512462599999, '94.13365948', 2827, '1243.20900000', '49.22407745', '281786.03675991'], [1512462600000, '0.03962200', '0.03974700', '0.03943400', '0.03961600', '2217.54900000', 1512464399999, '87.87688453', 2140, '1105.47300000', '43.81960623', '282223.17709129'], [1512464400000, '0.03961600', '0.03968700', '0.03940300', '0.03960000', '2598.49900000', 1512466199999, '102.86578918', 2306, '1257.22000000', '49.78609254', '282079.26129692'], [1512466200000, '0.03959500', '0.03970200', '0.03923100', '0.03961700', '3281.65100000', 1512467999999, '129.84654727', 2267, '1433.64700000', '56.76630900', '281966.73898816'], [1512468000000, '0.03954700', '0.03993400', '0.03934100', '0.03969800', '3303.70700000', 1512469799999, '131.05652821', 2994, '1621.54000000', '64.35560399', '285908.68922197'], [1512469800000, '0.03969800', '0.03977600', '0.03948000', '0.03957900', '3030.12600000', 1512471599999, '120.00677757', 2860, '1566.05200000', '62.06144847', '286865.54444735'], [1512471600000, '0.03957900', '0.03965500', '0.03939900', '0.03952600', '3150.32000000', 1512473399999, '124.57112162', 2728, '1732.39500000', '68.53188817', '288214.38879543'], [1512473400000, '0.03952600', '0.03965000', '0.03935100', '0.03941500', '2610.81800000', 1512475199999, '103.19298812', 2463, '1249.55700000', '49.42069313', '289823.30781981'], [1512475200000, '0.03941500', '0.03943800', '0.03921400', '0.03930100', '2894.06100000', 1512476999999, '113.85432800', 2430, '1427.41000000', '56.17176836', '291736.72196544'], [1512477000000, '0.03930700', '0.03935000', '0.03875200', '0.03879500', '3254.38700000', 1512478799999, '127.16264782', 3065, '1532.56100000', '59.90027022', '292547.03078930'], [1512478800000, '0.03884400', '0.03903100', '0.03855600', '0.03870600', '3591.11500000', 1512480599999, '139.36292905', 3513, '1715.01000000', '66.58808846', '293954.42804073'], [1512480600000, '0.03861300', '0.03878600', '0.03844800', '0.03863900', '4151.89700000', 1512482399999, '160.30528567', 3343, '2404.86500000', '92.89761229', '296525.29524806'], [1512482400000, '0.03870700', '0.03875100', '0.03851700', '0.03871600', '2700.30600000', 1512484199999, '104.36384119', 2685, '1511.63500000', '58.44591855', '298006.72589963'], [1512484200000, '0.03864600', '0.03890300', '0.03855100', '0.03880200', '3068.68200000', 1512485999999, '118.90503771', 2670, '1710.04500000', '66.30729183', '300459.44686708'], [1512486000000, '0.03880200', '0.03891900', '0.03857000', '0.03868800', '3965.33600000', 1512487799999, '153.85623878', 2942, '2778.34000000', '107.85381074', '301762.93341381'], [1512487800000, '0.03876500', '0.03888900', '0.03842000', '0.03868100', '4247.31600000', 1512489599999, '164.32765039', 3458, '1959.33500000', '75.88260859', '303588.00968678'], [1512489600000, '0.03854400', '0.03900000', '0.03850600', '0.03888800', '3836.01400000', 1512491399999, '148.62814866', 3764, '1986.64000000', '77.02761219', '305696.11052977'], [1512491400000, '0.03888700', '0.03889400', '0.03842100', '0.03868800', '4159.61900000', 1512493199999, '160.76927267', 4466, '2240.80100000', '86.63263178', '308935.61613196'], [1512493200000, '0.03868800', '0.03895000', '0.03830800', '0.03865600', '3149.40900000', 1512494999999, '121.75074918', 2867, '1529.39100000', '59.15719433', '310092.73759875'], [1512495000000, '0.03865000', '0.03900000', '0.03851500', '0.03893800', '2881.62200000', 1512496799999, '111.63434906', 2642, '1423.42000000', '55.16731925', '310903.56341236'], [1512496800000, '0.03893800', '0.03935700', '0.03893800', '0.03920300', '3262.89600000', 1512498599999, '127.68043711', 2409, '1686.82300000', '66.02007063', '309528.42573967'], [1512498600000, '0.03920300', '0.03935200', '0.03909200', '0.03921000', '2355.42600000', 1512500399999, '92.40141588', 1825, '1146.43600000', '44.98940185', '307416.13594424'], [1512500400000, '0.03922100', '0.03939700', '0.03882200', '0.03897600', '2874.43500000', 1512502199999, '112.51215427', 2069, '1520.04600000', '59.53023273', '305784.94473899'], [1512502200000, '0.03897600', '0.03919000', '0.03875300', '0.03883100', '3015.14600000', 1512503999999, '117.33424775', 2003, '1580.35300000', '61.51648009', '306279.14107467'], [1512504000000, '0.03887200', '0.03904600', '0.03860000', '0.03900000', '3394.01000000', 1512505799999, '131.92787905', 2456, '1616.91200000', '62.87830823', '306795.24445851'], [1512505800000, '0.03900000', '0.03917500', '0.03860900', '0.03907100', '3037.92700000', 1512507599999, '118.24846925', 2341, '1504.96000000', '58.61050058', '307222.57855183'], [1512507600000, '0.03907100', '0.03915400', '0.03880000', '0.03910200', '2900.79400000', 1512509399999, '113.22454676', 2409, '1322.00400000', '51.65145699', '306930.46536083'], [1512509400000, '0.03910700', '0.03949000', '0.03905900', '0.03938900', '2411.05100000', 1512511199999, '94.67539237', 2812, '1237.19500000', '48.60606227', '307621.57822477'], [1512511200000, '0.03931900', '0.03947300', '0.03899200', '0.03909800', '3083.40500000', 1512512999999, '120.84553454', 2999, '1516.52800000', '59.47007992', '308692.55642271'], [1512513000000, '0.03913700', '0.03929000', '0.03874100', '0.03880400', '2531.26100000', 1512514799999, '98.71551515', 2741, '1130.79000000', '44.13712223', '309162.62727243'], [1512514800000, '0.03880400', '0.03900000', '0.03871500', '0.03885900', '3402.86000000', 1512516599999, '132.20233952', 3125, '1734.84100000', '67.46098215', '308456.44369458'], [1512516600000, '0.03885900', '0.03892500', '0.03852500', '0.03875700', '4640.63200000', 1512518399999, '179.77542316', 4355, '2415.26800000', '93.65858530', '307810.37312273'], [1512518400000, '0.03871700', '0.03885900', '0.03845200', '0.03846500', '3368.38600000', 1512520199999, '130.22851595', 3372, '1637.64800000', '63.36207597', '309072.33752591'], [1512520200000, '0.03846700', '0.03861500', '0.03785300', '0.03800500', '3934.66600000', 1512521999999, '150.49985566', 3707, '1750.75000000', '67.02534451', '310683.00060894'], [1512522000000, '0.03805100', '0.03830400', '0.03770400', '0.03800200', '3587.97800000', 1512523799999, '136.23576054', 3322, '1813.58300000', '68.95363893', '312468.78094335'], [1512523800000, '0.03800100', '0.03830200', '0.03747100', '0.03802500', '6272.68600000', 1512525599999, '237.96627520', 5539, '3185.43400000', '121.00268918', '313160.49576078'], [1512525600000, '0.03792000', '0.03803000', '0.03720000', '0.03745000', '3318.61900000', 1512527399999, '125.36313534', 3387, '1652.58500000', '62.48235290', '313085.99075278'], [1512527400000, '0.03724500', '0.03745500', '0.03600800', '0.03619000', '5001.47800000', 1512529199999, '183.08013490', 4745, '2647.92800000', '97.04998868', '316993.64437148'], [1512529200000, '0.03615500', '0.03636300', '0.03538600', '0.03599500', '4997.09800000', 1512530999999, '179.84098778', 4530, '2495.49600000', '89.93283470', '318404.06130573'], [1512531000000, '0.03599900', '0.03651400', '0.03576000', '0.03624600', '2974.29900000', 1512532799999, '107.61339954', 2712, '1506.32100000', '54.57801668', '318917.06233492'], [1512532800000, '0.03624600', '0.03640000', '0.03610300', '0.03625200', '2151.67000000', 1512534599999, '78.08970529', 1558, '1139.38500000', '41.36790997', '319811.84954461'], [1512534600000, '0.03625200', '0.03628700', '0.03574700', '0.03603100', '5206.70900000', 1512536399999, '187.90494207', 4175, '2358.46300000', '85.17503469', '319217.38373010'], [1512536400000, '0.03605500', '0.03626700', '0.03561500', '0.03596800', '5114.77700000', 1512538199999, '184.10518865', 4080, '2644.24700000', '95.23669396', '318311.96399777'], [1512538200000, '0.03596800', '0.03606900', '0.03563700', '0.03595000', '4631.33800000', 1512539999999, '166.22247248', 2600, '2582.22200000', '92.71699623', '319565.36133858'], [1512540000000, '0.03588900', '0.03597500', '0.03511100', '0.03559700', '4280.24000000', 1512541799999, '152.79605133', 2989, '2080.88000000', '74.34693762', '325220.53052451'], [1512541800000, '0.03559700', '0.03594100', '0.03533100', '0.03580600', '3158.06700000', 1512543599999, '112.88690829', 2500, '1655.93400000', '59.18413591', '325329.51845455'], [1512543600000, '0.03585800', '0.03606900', '0.03540000', '0.03558000', '4624.62700000', 1512545399999, '165.11861486', 3441, '2166.55600000', '77.39229886', '325049.17850730'], [1512545400000, '0.03556900', '0.03590800', '0.03536500', '0.03566900', '2814.11900000', 1512547199999, '100.11115422', 2671, '1540.38100000', '54.80634738', '324733.88401636'], [1512547200000, '0.03571000', '0.03595900', '0.03547300', '0.03554200', '2943.43300000', 1512548999999, '104.98016423', 2208, '1395.95400000', '49.81009706', '325925.17011577'], [1512549000000, '0.03554200', '0.03562900', '0.03448100', '0.03518000', '5789.21400000', 1512550799999, '203.58417777', 5917, '3136.45300000', '110.37778109', '323979.13950922'], [1512550800000, '0.03518200', '0.03576000', '0.03500000', '0.03536000', '4214.51600000', 1512552599999, '149.21803646', 3602, '2192.72200000', '77.67279492', '321074.10363499'], [1512552600000, '0.03538100', '0.03538100', '0.03489200', '0.03515700', '3130.23100000', 1512554399999, '110.25324532', 2288, '1725.91600000', '60.80657666', '323262.13424598'], [1512554400000, '0.03512400', '0.03515700', '0.03349400', '0.03424600', '5734.21000000', 1512556199999, '199.06212389', 4385, '2806.84400000', '97.62611946', '322012.97100859'], [1512556200000, '0.03424600', '0.03459400', '0.03350300', '0.03395000', '5757.13100000', 1512557999999, '197.05941624', 5535, '3019.54100000', '103.56628229', '320441.55329499'], [1512558000000, '0.03405400', '0.03459400', '0.03326500', '0.03423900', '4522.52400000', 1512559799999, '154.18850215', 4047, '2668.57800000', '91.08125397', '320093.29562017'], [1512559800000, '0.03427000', '0.03463300', '0.03381600', '0.03447300', '2808.80900000', 1512561599999, '96.17893587', 2867, '1568.63600000', '53.74448358', '318319.42082780'], [1512561600000, '0.03461200', '0.03475600', '0.03400600', '0.03454600', '2718.68100000', 1512563399999, '93.90004206', 2938, '1462.21100000', '50.53500129', '317775.36613891'], [1512563400000, '0.03454600', '0.03465800', '0.03396600', '0.03424000', '4613.09800000', 1512565199999, '158.38729893', 4138, '2509.52500000', '86.20077711', '318294.19549364'], [1512565200000, '0.03427100', '0.03440500', '0.03300000', '0.03427800', '5167.28400000', 1512566999999, '175.78017556', 3854, '2204.50400000', '75.13809111', '316887.44149409'], [1512567000000, '0.03431600', '0.03468400', '0.03397500', '0.03468200', '3774.05500000', 1512568799999, '129.78415537', 3000, '1967.88400000', '67.69894934', '317330.83429584'], [1512568800000, '0.03454700', '0.03487500', '0.03425400', '0.03460000', '4589.93500000', 1512570599999, '159.06166141', 3521, '2173.35300000', '75.36026149', '317302.99881388'], [1512570600000, '0.03460000', '0.03479700', '0.03440000', '0.03450200', '3668.66500000', 1512572399999, '126.83968928', 3044, '1910.45000000', '66.09080468', '316517.60375608'], [1512572400000, '0.03449900', '0.03459700', '0.03414300', '0.03424700', '4800.27600000', 1512574199999, '165.14087193', 3489, '2209.16000000', '76.00198764', '315205.21659673'], [1512574200000, '0.03427600', '0.03433500', '0.03320000', '0.03400300', '7554.71600000', 1512575999999, '256.43179326', 5119, '3869.43400000', '131.49455516', '316135.61761760'], [1512576000000, '0.03399100', '0.03443000', '0.03300300', '0.03440800', '6573.04200000', 1512577799999, '222.81862609', 5303, '3445.89500000', '116.97636876', '315968.64641995'], [1512577800000, '0.03440800', '0.03445600', '0.03392200', '0.03425300', '3012.06400000', 1512579599999, '103.05750254', 3064, '1550.50000000', '53.06875366', '318111.05877111'], [1512579600000, '0.03425300', '0.03450000', '0.03391700', '0.03400100', '3152.53600000', 1512581399999, '107.77677963', 2719, '1625.04400000', '55.56666366', '319811.55750663'], [1512581400000, '0.03400000', '0.03414100', '0.03370200', '0.03390500', '2733.45600000', 1512583199999, '92.87870740', 2672, '1533.61800000', '52.13582934', '325878.23053601'], [1512583200000, '0.03389500', '0.03434500', '0.03385500', '0.03408100', '2923.43100000', 1512584999999, '99.84473234', 2073, '1544.94300000', '52.78353778', '326124.38510508'], [1512585000000, '0.03404800', '0.03418300', '0.03371800', '0.03388600', '2567.62700000', 1512586799999, '87.34089003', 1899, '1302.43900000', '44.32181243', '327362.50581302'], [1512586800000, '0.03387500', '0.03388100', '0.03305200', '0.03305200', '3596.17300000', 1512588599999, '120.50519675', 2496, '1824.42100000', '61.22343267', '327185.82625454'], [1512588600000, '0.03305200', '0.03320100', '0.03214900', '0.03214900', '4290.62400000', 1512590399999, '140.94823364', 3279, '1811.13600000', '59.54462782', '325841.24155614'], [1512590400000, '0.03214900', '0.03250000', '0.03157800', '0.03167000', '5781.38100000', 1512592199999, '184.76458854', 4278, '3157.41900000', '100.99832674', '324691.15530215'], [1512592200000, '0.03168600', '0.03218000', '0.03138700', '0.03200400', '4044.10700000', 1512593999999, '128.75743804', 3610, '2215.29800000', '70.57363044', '324381.70172991'], [1512594000000, '0.03199900', '0.03217200', '0.03160600', '0.03202300', '3060.93500000', 1512595799999, '97.91046159', 3327, '1479.71500000', '47.35914727', '324972.23482504'], [1512595800000, '0.03201300', '0.03240000', '0.03170900', '0.03180400', '3307.93300000', 1512597599999, '106.21858718', 3146, '1824.91300000', '58.62199218', '324909.59934920'], [1512597600000, '0.03181300', '0.03186000', '0.03107600', '0.03110700', '2875.18300000', 1512599399999, '90.26313557', 2605, '1326.26700000', '41.65143450', '324688.46899011'], [1512599400000, '0.03112800', '0.03121400', '0.02955500', '0.02959300', '4227.65600000', 1512601199999, '127.85640548', 3430, '1845.71400000', '55.89286594', '324966.17905045'], [1512601200000, '0.02959600', '0.03088100', '0.02940600', '0.03061100', '5092.19600000', 1512602999999, '155.19332168', 4090, '2514.28100000', '76.64363806', '324316.00845625'], [1512603000000, '0.03065000', '0.03083200', '0.03017300', '0.03039600', '2772.81400000', 1512604799999, '84.83306632', 2442, '1460.00500000', '44.68271848', '324290.08086243'], [1512604800000, '0.03039600', '0.03043500', '0.02901100', '0.02911800', '4983.47400000', 1512606599999, '147.73199714', 3941, '2476.87500000', '73.53221128', '322723.69163032'], [1512606600000, '0.02910100', '0.02958600', '0.02841600', '0.02922300', '7392.59600000', 1512608399999, '214.12354479', 5965, '3993.46200000', '115.81947485', '322680.65488234'], [1512608400000, '0.02937800', '0.02999500', '0.02880000', '0.02962900', '5444.69700000', 1512610199999, '161.49445948', 5897, '2519.91600000', '74.81424850', '321920.24360926'], [1512610200000, '0.02962800', '0.02973900', '0.02903300', '0.02948800', '5720.58600000', 1512611999999, '167.98081742', 5650, '2906.09500000', '85.39958877', '321704.33805007'], [1512612000000, '0.02948700', '0.03205900', '0.02941800', '0.03199600', '7046.33300000', 1512613799999, '215.11515997', 7046, '3617.11200000', '110.40171778', '323280.95178588'], [1512613800000, '0.03199600', '0.03203400', '0.03031500', '0.03090600', '5402.95600000', 1512615599999, '167.57184001', 4830, '2869.82200000', '89.05613875', '323069.89599180'], [1512615600000, '0.03090600', '0.03115000', '0.03043600', '0.03070600', '3810.87500000', 1512617399999, '117.10055852', 3188, '1962.49700000', '60.31907837', '322634.45813135'], [1512617400000, '0.03071800', '0.03100000', '0.03049900', '0.03097200', '3288.19400000', 1512619199999, '101.50425455', 2520, '1641.55700000', '50.69346025', '321791.68851375'], [1512619200000, '0.03097200', '0.03100000', '0.03047900', '0.03056900', '3014.72200000', 1512620999999, '92.76037615', 2567, '1290.24900000', '39.70827836', '322017.16913385'], [1512621000000, '0.03056900', '0.03060000', '0.03025700', '0.03042000', '5189.46600000', 1512622799999, '158.20581075', 3842, '1732.96400000', '52.88829057', '323151.33112580'], [1512622800000, '0.03039000', '0.03042100', '0.02962600', '0.02974300', '4381.20600000', 1512624599999, '131.30532616', 4106, '2275.71600000', '68.11901372', '323057.92266243'], [1512624600000, '0.02974300', '0.03005700', '0.02970000', '0.03001500', '2888.69400000', 1512626399999, '86.37515092', 2665, '1816.73500000', '54.33668170', '322510.61691865'], [1512626400000, '0.02995700', '0.03007700', '0.02950200', '0.02969900', '1257.60700000', 1512628199999, '37.56879184', 1500, '482.28100000', '14.40781873', '322511.90307468'], [1512628200000, '0.02967900', '0.02989800', '0.02950000', '0.02985000', '2620.73500000', 1512629999999, '77.97221430', 3618, '1751.49300000', '52.14166419', '321579.27198591'], [1512630000000, '0.02984100', '0.03000000', '0.02935400', '0.02955500', '3883.15500000', 1512631799999, '115.54234673', 3779, '2223.33500000', '66.17837370', '321628.48713226'], [1512631800000, '0.02955500', '0.02977800', '0.02944400', '0.02957900', '2960.08500000', 1512633599999, '87.57409791', 3350, '1498.33800000', '44.33910858', '320876.65718472'], [1512633600000, '0.02958800', '0.02960100', '0.02879200', '0.02896500', '4351.90000000', 1512635399999, '127.61085705', 3819, '2081.86900000', '61.04850500', '320593.90154688'], [1512635400000, '0.02899500', '0.02899500', '0.02800000', '0.02855200', '4621.33800000', 1512637199999, '132.43557671', 4130, '2667.51300000', '76.51462601', '318104.33938402'], [1512637200000, '0.02856400', '0.02869700', '0.02836700', '0.02850600', '3181.49000000', 1512638999999, '90.94068841', 2906, '1640.17300000', '46.89464605', '317058.15141450'], [1512639000000, '0.02850300', '0.02880200', '0.02805600', '0.02828100', '3041.77900000', 1512640799999, '86.41895558', 2792, '1495.26700000', '42.51968201', '317249.71749461'], [1512640800000, '0.02826400', '0.02827200', '0.02690300', '0.02715600', '4317.32100000', 1512642599999, '118.68037735', 3801, '2027.59500000', '55.79212795', '316295.67078937'], [1512642600000, '0.02715600', '0.02739600', '0.02680800', '0.02690500', '3855.07800000', 1512644399999, '104.41518574', 3933, '1602.55500000', '43.45913363', '315119.62531994'], [1512644400000, '0.02690500', '0.02780000', '0.02690300', '0.02730800', '6012.12200000', 1512646199999, '164.65548739', 3805, '2986.88700000', '81.87766066', '314609.81860012'], [1512646200000, '0.02729300', '0.02927000', '0.02726200', '0.02909600', '4479.29600000', 1512647999999, '124.74989532', 4460, '1904.21200000', '53.26537424', '313790.63880891'], [1512648000000, '0.02909600', '0.02930500', '0.02800000', '0.02828600', '4267.04100000', 1512649799999, '121.05006571', 3336, '1924.66300000', '54.65326437', '314672.19374023'], [1512649800000, '0.02819300', '0.02831400', '0.02770000', '0.02808300', '3985.11000000', 1512651599999, '111.42924099', 4029, '2305.70800000', '64.51018407', '313855.15924064'], [1512651600000, '0.02806100', '0.02826400', '0.02760300', '0.02787900', '3248.99900000', 1512653399999, '90.76970005', 2851, '1364.10900000', '38.11319122', '313285.05051341'], [1512653400000, '0.02787900', '0.02813800', '0.02750600', '0.02767900', '3029.26200000', 1512655199999, '84.67084195', 3522, '1562.95100000', '43.71172018', '311117.35232020'], [1512655200000, '0.02765000', '0.02772100', '0.02689000', '0.02702700', '4317.87900000', 1512656999999, '118.00389728', 3622, '1779.26200000', '48.65354385', '307170.97555087'], [1512657000000, '0.02700000', '0.02780000', '0.02697800', '0.02760000', '5001.22500000', 1512658799999, '137.07797259', 4727, '2401.67600000', '65.75064413', '308294.16756944'], [1512658800000, '0.02760000', '0.02761800', '0.02616300', '0.02620400', '5085.98400000', 1512660599999, '137.18198844', 4330, '1978.39100000', '53.19698125', '306724.74728239'], [1512660600000, '0.02623800', '0.02659900', '0.02597800', '0.02601400', '5752.56300000', 1512662399999, '150.60449291', 4706, '2806.71700000', '73.55723178', '306597.54515753'], [1512662400000, '0.02599900', '0.02601200', '0.02428500', '0.02467500', '5447.87900000', 1512664199999, '138.10240810', 5738, '3016.55800000', '76.40997900', '306747.71798782'], [1512664200000, '0.02467500', '0.02674200', '0.02458300', '0.02649900', '6542.47100000', 1512665999999, '167.81003629', 7231, '3494.35300000', '89.51315610', '306305.31061585'], [1512666000000, '0.02652300', '0.02740000', '0.02601100', '0.02724900', '3543.55600000', 1512667799999, '93.82908066', 4168, '2163.46000000', '57.21660443', '305824.80960357'], [1512667800000, '0.02724900', '0.02776500', '0.02618200', '0.02641000', '3162.03700000', 1512669599999, '85.04095582', 3288, '1688.57500000', '45.49571392', '306026.02595411'], [1512669600000, '0.02641000', '0.02643600', '0.02553800', '0.02586200', '3183.20700000', 1512671399999, '82.69706499', 3227, '1664.31600000', '43.29369581', '306186.29225424'], [1512671400000, '0.02596000', '0.02637900', '0.02569100', '0.02582800', '2116.40300000', 1512673199999, '55.08987847', 2723, '1369.06500000', '35.62470579', '306892.13213003'], [1512673200000, '0.02581600', '0.02675000', '0.02581500', '0.02665000', '2651.02700000', 1512674999999, '69.81860893', 3056, '1730.21000000', '45.59360703', '307427.60205969'], [1512675000000, '0.02665000', '0.02725100', '0.02629300', '0.02684000', '2448.02300000', 1512676799999, '65.51652387', 3238, '1364.29500000', '36.50119349', '308153.67106614'], [1512676800000, '0.02684100', '0.02742900', '0.02673100', '0.02723100', '2247.23600000', 1512678599999, '60.89095368', 2653, '1115.56600000', '30.24503841', '312026.86449307'], [1512678600000, '0.02723100', '0.02778800', '0.02650300', '0.02694300', '4080.98000000', 1512680399999, '110.64944186', 4029, '2105.57400000', '57.17017293', '310803.33775028'], [1512680400000, '0.02694300', '0.02720300', '0.02615600', '0.02616600', '2719.69800000', 1512682199999, '72.69151332', 2815, '1230.49100000', '32.89607156', '311031.74155401'], [1512682200000, '0.02616600', '0.02632600', '0.02581600', '0.02600900', '2245.70100000', 1512683999999, '58.52039957', 2294, '1318.41000000', '34.36965393', '310451.86130207'], [1512684000000, '0.02598700', '0.02613800', '0.02526300', '0.02531100', '2818.20100000', 1512685799999, '72.56416661', 2592, '1226.81100000', '31.60237937', '310841.20966656'], [1512685800000, '0.02531100', '0.02534800', '0.02435100', '0.02486100', '3017.45100000', 1512687599999, '75.27902699', 3251, '1592.02600000', '39.76793950', '310964.64382967'], [1512687600000, '0.02487000', '0.02542800', '0.02465200', '0.02507100', '1918.22300000', 1512689399999, '48.07501368', 2853, '1013.41700000', '25.41687205', '310023.20502896'], [1512689400000, '0.02498600', '0.02507000', '0.02425100', '0.02456500', '3653.30400000', 1512691199999, '90.13567255', 4451, '1733.99900000', '42.83404641', '310293.11559350'], [1512691200000, '0.02456200', '0.02470000', '0.02361600', '0.02381600', '3557.13600000', 1512692999999, '86.29517667', 3888, '1714.91600000', '41.69420367', '308571.96928312'], [1512693000000, '0.02382400', '0.02398400', '0.02320400', '0.02330500', '4158.30900000', 1512694799999, '97.38999355', 3445, '2723.60400000', '63.77982496', '307985.82672363'], [1512694800000, '0.02330500', '0.02387700', '0.02323000', '0.02343100', '4366.39200000', 1512696599999, '102.59111963', 6128, '2414.87300000', '56.79087542', '306078.04229043'], [1512696600000, '0.02343100', '0.02358200', '0.02312100', '0.02312400', '3310.77500000', 1512698399999, '77.23830986', 4600, '1714.02900000', '40.01003351', '305510.72855750'], [1512698400000, '0.02338700', '0.02433300', '0.02312300', '0.02380000', '3912.39500000', 1512700199999, '93.44389932', 4638, '1999.15300000', '47.83956314', '307802.40870331'], [1512700200000, '0.02380000', '0.02395100', '0.02350100', '0.02387000', '5241.73200000', 1512701999999, '124.73720265', 4874, '3972.82200000', '94.55832673', '306631.62798423'], [1512702000000, '0.02387000', '0.02580000', '0.02374700', '0.02579800', '4076.40700000', 1512703799999, '100.02348690', 5850, '2431.58100000', '59.73887996', '306752.94366046'], [1512703800000, '0.02579700', '0.02650000', '0.02541900', '0.02550900', '5150.81400000', 1512705599999, '133.51122689', 5298, '2445.97600000', '63.49777149', '306637.12750132'], [1512705600000, '0.02550900', '0.02562900', '0.02498200', '0.02538500', '3014.27300000', 1512707399999, '76.36007701', 3392, '1840.48700000', '46.62773558', '307300.16635620'], [1512707400000, '0.02537800', '0.02657100', '0.02530000', '0.02647900', '2827.64600000', 1512709199999, '73.39130895', 3566, '1582.60300000', '41.06478637', '306507.56367987'], [1512709200000, '0.02647900', '0.02848700', '0.02645300', '0.02830100', '6210.33500000', 1512710999999, '170.05039544', 6076, '3223.79900000', '88.25827364', '306321.01702937'], [1512711000000, '0.02830000', '0.02866500', '0.02634900', '0.02655600', '6520.80300000', 1512712799999, '180.10543178', 6690, '3195.19500000', '88.12315490', '307742.37322721'], [1512712800000, '0.02655600', '0.02747300', '0.02635300', '0.02658400', '3767.15000000', 1512714599999, '101.13163902', 3507, '2010.06600000', '53.96880260', '307121.85446839'], [1512714600000, '0.02656200', '0.02659200', '0.02542300', '0.02564300', '3091.08600000', 1512716399999, '80.40997528', 3650, '1620.63600000', '42.15798687', '307465.12909667'], [1512716400000, '0.02564300', '0.02596800', '0.02507600', '0.02549900', '2770.08900000', 1512718199999, '70.73067616', 3173, '1428.70900000', '36.45158507', '307602.14227088'], [1512718200000, '0.02550400', '0.02630500', '0.02541900', '0.02580600', '2263.19200000', 1512719999999, '58.52738553', 3036, '1317.19500000', '34.02449180', '308027.44305273'], [1512720000000, '0.02580600', '0.02628600', '0.02580500', '0.02618800', '2293.62700000', 1512721799999, '59.69443423', 3280, '1202.67000000', '31.30312808', '307597.38648576'], [1512721800000, '0.02618900', '0.02750000', '0.02615000', '0.02747300', '3267.34300000', 1512723599999, '87.03673650', 5150, '1393.12900000', '37.06501536', '307148.90720848'], [1512723600000, '0.02742800', '0.02788700', '0.02699300', '0.02779900', '4078.06600000', 1512725399999, '112.01881032', 4258, '2052.89800000', '56.32150439', '307097.24217078'], [1512725400000, '0.02780000', '0.02882600', '0.02756800', '0.02820200', '3963.64900000', 1512727199999, '112.24266563', 5686, '1857.17400000', '52.57175949', '306426.06373267'], [1512727200000, '0.02817600', '0.02848700', '0.02775300', '0.02825000', '3520.17100000', 1512728999999, '99.15367403', 5149, '1865.52500000', '52.56220344', '306153.67912118'], [1512729000000, '0.02825000', '0.02940000', '0.02823200', '0.02935000', '3825.01400000', 1512730799999, '110.38176625', 5032, '1763.18600000', '50.88420079', '306344.15471982'], [1512730800000, '0.02935000', '0.03140600', '0.02935000', '0.03108300', '5763.06000000', 1512732599999, '174.65522718', 6382, '2414.80600000', '73.05231753', '305590.06745300'], [1512732600000, '0.03109900', '0.03200000', '0.02920900', '0.02930100', '8137.44500000', 1512734399999, '248.19067404', 7224, '4017.80100000', '122.37452576', '303648.56293889'], [1512734400000, '0.02927900', '0.03031400', '0.02847900', '0.02914900', '3954.82600000', 1512736199999, '115.80667624', 6229, '2296.16300000', '67.22155504', '303349.29046597'], [1512736200000, '0.02914900', '0.02977400', '0.02900900', '0.02961600', '4128.21800000', 1512737999999, '121.29632480', 4006, '1253.57500000', '36.82896180', '302892.62875259'], [1512738000000, '0.02962000', '0.03043800', '0.02960000', '0.03003900', '4860.22100000', 1512739799999, '145.86927348', 4513, '2155.10800000', '64.60078448', '302821.37363989'], [1512739800000, '0.03004000', '0.03020000', '0.02956800', '0.02971300', '4757.87000000', 1512741599999, '142.04545063', 4962, '1711.28900000', '51.05426596', '304249.54183189'], [1512741600000, '0.02971300', '0.02979900', '0.02882400', '0.02894600', '3492.49900000', 1512743399999, '102.81334409', 4672, '1836.71800000', '54.12924197', '304121.79735444'], [1512743400000, '0.02894800', '0.02894800', '0.02700000', '0.02742800', '4795.14100000', 1512745199999, '132.96170274', 5690, '2390.61600000', '66.32595909', '313556.29201600'], [1512745200000, '0.02745200', '0.02807800', '0.02700000', '0.02802800', '3095.35400000', 1512746999999, '85.72200395', 4248, '1419.36200000', '39.34289016', '313598.24650533'], [1512747000000, '0.02800100', '0.02879900', '0.02789800', '0.02853900', '2504.93700000', 1512748799999, '71.07867732', 4822, '1149.85900000', '32.62971882', '314108.64150542'], [1512748800000, '0.02853900', '0.02861200', '0.02765800', '0.02815800', '2764.70900000', 1512750599999, '77.84200657', 6067, '1482.45300000', '41.76307509', '314107.78799274'], [1512750600000, '0.02815800', '0.02980000', '0.02804800', '0.02977900', '5722.94400000', 1512752399999, '166.11546588', 8741, '2687.29800000', '77.97990723', '313204.64800803'], [1512752400000, '0.02972700', '0.02990000', '0.02950600', '0.02966300', '4273.01000000', 1512754199999, '126.88598034', 4278, '2142.57800000', '63.62726099', '312971.99125643'], [1512754200000, '0.02966300', '0.03042600', '0.02962000', '0.03042600', '3461.09600000', 1512755999999, '104.08791174', 3347, '1870.86800000', '56.30805338', '312989.22834456'], [1512756000000, '0.03042400', '0.03053200', '0.03017800', '0.03027600', '3533.78400000', 1512757799999, '107.51229064', 3186, '1283.08200000', '39.01228575', '311898.40299090'], [1512757800000, '0.03030500', '0.03049800', '0.02965500', '0.02970300', '3216.41000000', 1512759599999, '96.87819512', 4228, '1558.86300000', '46.95105896', '312380.39725909'], [1512759600000, '0.02981800', '0.02982700', '0.02915600', '0.02926700', '2373.07000000', 1512761399999, '70.04036133', 3679, '1340.00100000', '39.58169485', '312715.89157698'], [1512761400000, '0.02926700', '0.03039000', '0.02903100', '0.02922700', '2158.06700000', 1512763199999, '63.07023587', 2914, '1204.88800000', '35.27059474', '312930.52807840'], [1512763200000, '0.02922900', '0.02929900', '0.02900200', '0.02919400', '1749.54400000', 1512764999999, '51.01143690', 3709, '988.96300000', '28.84413534', '313150.41803754'], [1512765000000, '0.02916900', '0.02950000', '0.02900200', '0.02926600', '2459.58400000', 1512766799999, '71.83455217', 4104, '1283.75400000', '37.50028371', '312932.73585029'], [1512766800000, '0.02925000', '0.02947600', '0.02895900', '0.02900000', '2264.71800000', 1512768599999, '66.30513939', 2649, '1165.07000000', '34.13173100', '316653.97967292'], [1512768600000, '0.02899500', '0.02908800', '0.02821900', '0.02827400', '3070.74700000', 1512770399999, '87.88323899', 3995, '1439.64500000', '41.26246790', '316859.41920894'], [1512770400000, '0.02825700', '0.02827100', '0.02798300', '0.02812000', '4535.19900000', 1512772199999, '127.36736204', 3989, '1524.95800000', '42.83181416', '317387.27466814'], [1512772200000, '0.02810700', '0.02836100', '0.02789900', '0.02815800', '3911.58700000', 1512773999999, '110.42716555', 5760, '2273.87300000', '64.24434436', '317418.09821925'], [1512774000000, '0.02815800', '0.02826800', '0.02784900', '0.02818800', '3301.84100000', 1512775799999, '92.69550646', 4830, '1892.37300000', '53.17998744', '317656.07259954'], [1512775800000, '0.02818800', '0.02823900', '0.02760000', '0.02785500', '2685.30300000', 1512777599999, '74.88888219', 3050, '1311.27000000', '36.56379531', '317685.38202946'], [1512777600000, '0.02786300', '0.02811400', '0.02725400', '0.02754500', '3673.66300000', 1512779399999, '101.80949720', 4723, '1878.71400000', '52.04112652', '318902.36754341'], [1512779400000, '0.02754000', '0.02827800', '0.02751100', '0.02820100', '3214.48300000', 1512781199999, '89.61185404', 4051, '1725.34400000', '48.11576644', '319824.94113594'], [1512781200000, '0.02820100', '0.02863900', '0.02795000', '0.02858700', '3501.79700000', 1512782999999, '99.14477558', 4225, '2223.84800000', '63.01765374', '319886.56975846'], [1512783000000, '0.02857900', '0.02936000', '0.02857300', '0.02925000', '4173.12600000', 1512784799999, '120.42413803', 3860, '2630.15000000', '75.85347655', '318285.85926951'], [1512784800000, '0.02928600', '0.02936100', '0.02897700', '0.02912800', '2661.35100000', 1512786599999, '77.55764000', 2732, '1212.40600000', '35.34032533', '319202.67526657'], [1512786600000, '0.02911700', '0.02995900', '0.02909100', '0.02931800', '2411.31100000', 1512788399999, '70.59201871', 2388, '1147.85600000', '33.60921860', '319917.25267372'], [1512788400000, '0.02931700', '0.02959200', '0.02931100', '0.02951800', '3079.19300000', 1512790199999, '90.78755270', 3227, '1592.66200000', '46.97033371', '322204.04186752'], [1512790200000, '0.02950100', '0.02965100', '0.02932700', '0.02953700', '3086.79300000', 1512791999999, '91.11987555', 2752, '1237.29800000', '36.53963811', '322690.66631680'], [1512792000000, '0.02954000', '0.02967800', '0.02929500', '0.02940000', '3037.14300000', 1512793799999, '89.47770035', 2715, '1829.93500000', '53.92454111', '323361.32215970'], [1512793800000, '0.02934500', '0.03025500', '0.02930000', '0.03006400', '4047.19400000', 1512795599999, '120.63828907', 3937, '2349.34900000', '70.06041894', '323231.96923602'], [1512795600000, '0.03006400', '0.03031900', '0.02970800', '0.03031900', '4047.14200000', 1512797399999, '121.80569209', 4313, '2153.18300000', '64.82947289', '323519.86169267'], [1512797400000, '0.03028300', '0.03200000', '0.03027100', '0.03134200', '9261.16100000', 1512799199999, '289.77885150', 7609, '4610.70600000', '144.10316741', '323437.11830309'], [1512799200000, '0.03132900', '0.03146800', '0.03039800', '0.03065000', '5293.02500000', 1512800999999, '163.25331566', 4454, '2272.43700000', '70.00530151', '323695.42586829'], [1512801000000, '0.03065000', '0.03132800', '0.03065000', '0.03110100', '3065.75900000', 1512802799999, '94.79595815', 2997, '1560.07500000', '48.20173947', '324202.62572096'], [1512802800000, '0.03110200', '0.03113200', '0.03023000', '0.03042700', '3555.89300000', 1512804599999, '108.58212670', 3812, '1877.21500000', '57.31883442', '324794.35673349'], [1512804600000, '0.03038800', '0.03111600', '0.03033900', '0.03079600', '3160.11600000', 1512806399999, '96.86831567', 3717, '1782.85400000', '54.70488988', '324585.39474002'], [1512806400000, '0.03079600', '0.03160000', '0.03079600', '0.03145000', '5231.59800000', 1512808199999, '163.15213655', 3583, '2154.18700000', '67.16003121', '326121.33712466'], [1512808200000, '0.03144900', '0.03188400', '0.03129200', '0.03182200', '3796.91900000', 1512809999999, '119.96112319', 3522, '1883.89000000', '59.53945158', '326595.46732225'], [1512810000000, '0.03182200', '0.03241600', '0.03180000', '0.03230600', '4591.82400000', 1512811799999, '147.48113272', 4182, '2273.08200000', '72.98841668', '326805.40358267'], [1512811800000, '0.03233400', '0.03290800', '0.03207700', '0.03226900', '6255.35300000', 1512813599999, '202.98221658', 5001, '2710.78200000', '88.01455934', '325240.31652173'], [1512813600000, '0.03226900', '0.03250000', '0.03201000', '0.03214000', '3957.59400000', 1512815399999, '127.93704562', 3239, '1610.82300000', '52.05029141', '325643.64688790'], [1512815400000, '0.03213500', '0.03225000', '0.03192300', '0.03213900', '3977.41900000', 1512817199999, '127.62409643', 4122, '1573.98500000', '50.52009579', '325389.32415110'], [1512817200000, '0.03211200', '0.03235500', '0.03147100', '0.03159900', '3284.63500000', 1512818999999, '104.90417288', 4880, '1713.03200000', '54.68635467', '325885.42969444'], [1512819000000, '0.03159100', '0.03167000', '0.03101900', '0.03124400', '3023.33500000', 1512820799999, '94.62721175', 3440, '1776.67800000', '55.61995446', '336027.75345148'], [1512820800000, '0.03128000', '0.03156000', '0.03109900', '0.03118900', '2832.13000000', 1512822599999, '88.48947111', 3375, '1465.82800000', '45.81035450', '335617.99922191'], [1512822600000, '0.03115300', '0.03186400', '0.03100100', '0.03183100', '2468.67300000', 1512824399999, '77.61590177', 3352, '1377.13700000', '43.28178318', '336358.80004921'], [1512824400000, '0.03183000', '0.03196200', '0.03142100', '0.03149700', '2598.43800000', 1512826199999, '82.17244357', 2891, '1350.68100000', '42.73034313', '336830.88435828'], [1512826200000, '0.03149500', '0.03155300', '0.03106800', '0.03108800', '2330.81600000', 1512827999999, '72.93550658', 3287, '1185.56400000', '37.08986330', '336426.29247099'], [1512828000000, '0.03109500', '0.03147100', '0.03105900', '0.03135900', '2690.91000000', 1512829799999, '84.22961022', 2626, '1285.98200000', '40.24922767', '337814.04822326'], [1512829800000, '0.03135700', '0.03156100', '0.03119500', '0.03151700', '2794.64900000', 1512831599999, '87.58971247', 2987, '1357.71200000', '42.57105504', '337937.11652345'], [1512831600000, '0.03151700', '0.03220000', '0.03148500', '0.03215700', '3183.38000000', 1512833399999, '101.23997403', 3833, '1569.76800000', '49.94328578', '338733.56677815'], [1512833400000, '0.03216300', '0.03300000', '0.03210000', '0.03291100', '4285.20600000', 1512835199999, '139.36756449', 4184, '2200.14400000', '71.55557132', '339292.15310424'], [1512835200000, '0.03291100', '0.03490000', '0.03287800', '0.03458200', '6237.65100000', 1512836999999, '210.80651269', 5773, '3291.49600000', '111.09974899', '338925.97703209'], [1512837000000, '0.03454700', '0.03460600', '0.03356400', '0.03376600', '5187.61000000', 1512838799999, '176.56251067', 5724, '2503.57200000', '85.18396023', '339149.50644964'], [1512838800000, '0.03376600', '0.03450000', '0.03362800', '0.03401300', '4143.31300000', 1512840599999, '141.25177390', 5341, '2030.52000000', '69.29410286', '340857.09893213'], [1512840600000, '0.03402000', '0.03487300', '0.03275000', '0.03292900', '5554.02400000', 1512842399999, '188.21816592', 5617, '2615.20900000', '88.81445028', '340209.97833382'], [1512842400000, '0.03293300', '0.03300000', '0.03177600', '0.03198900', '5340.07500000', 1512844199999, '172.67320984', 5512, '2663.20200000', '86.05791774', '341541.71508915'], [1512844200000, '0.03198900', '0.03251300', '0.03152800', '0.03172800', '2853.50400000', 1512845999999, '91.20476092', 3720, '1385.77400000', '44.25472861', '341764.60504930'], [1512846000000, '0.03173000', '0.03218300', '0.03140700', '0.03213000', '2282.69400000', 1512847799999, '72.68008307', 2785, '1144.79500000', '36.43338856', '343453.77061722'], [1512847800000, '0.03213000', '0.03280200', '0.03212900', '0.03260000', '3512.85300000', 1512849599999, '113.90802111', 3946, '1791.57500000', '58.12294635', '343750.79555644'], [1512849600000, '0.03260000', '0.03261500', '0.03196100', '0.03213400', '3308.01200000', 1512851399999, '106.76796416', 2685, '1535.52500000', '49.54760679', '343591.32765215'], [1512851400000, '0.03216300', '0.03216300', '0.03142800', '0.03171000', '1973.32500000', 1512853199999, '62.63151315', 2828, '1055.15800000', '33.48817951', '343493.82132493'], [1512853200000, '0.03173500', '0.03230200', '0.03169100', '0.03220400', '2175.03600000', 1512854999999, '69.56459670', 2282, '1055.92600000', '33.74441019', '343677.42064065'], [1512855000000, '0.03219600', '0.03247500', '0.03190900', '0.03194400', '1878.77900000', 1512856799999, '60.38847213', 1824, '960.43800000', '30.88878891', '344171.23269249'], [1512856800000, '0.03191700', '0.03217800', '0.03144900', '0.03164700', '2023.18100000', 1512858599999, '64.28004912', 2198, '1168.84600000', '37.09885189', '344626.75974052'], [1512858600000, '0.03162900', '0.03176200', '0.03092200', '0.03127500', '3204.18100000', 1512860399999, '100.16666092', 2653, '1988.93300000', '62.21480840', '344973.21605835'], [1512860400000, '0.03127500', '0.03192200', '0.03127500', '0.03158700', '2176.76100000', 1512862199999, '68.76915292', 2707, '1170.36200000', '36.97022788', '345073.15510322'], [1512862200000, '0.03159100', '0.03168000', '0.03127500', '0.03131100', '1631.63300000', 1512863999999, '51.39839515', 2204, '1001.99800000', '31.57831060', '344943.86873932'], [1512864000000, '0.03131700', '0.03191000', '0.03122000', '0.03170000', '2322.34800000', 1512865799999, '73.28034354', 3056, '1237.70000000', '39.07903728', '344565.77943723'], [1512865800000, '0.03170200', '0.03188400', '0.03156200', '0.03160800', '1737.77400000', 1512867599999, '55.17168771', 2310, '901.82700000', '28.63883542', '343546.24967086'], [1512867600000, '0.03160800', '0.03249000', '0.03157700', '0.03225000', '3745.45500000', 1512869399999, '120.20776475', 4160, '1854.28800000', '59.52014687', '343040.98232832'], [1512869400000, '0.03225000', '0.03269800', '0.03200000', '0.03218200', '3158.45800000', 1512871199999, '102.20397042', 4090, '1209.68700000', '39.16649438', '342220.53483356'], [1512871200000, '0.03218200', '0.03232200', '0.03181000', '0.03196300', '3441.78500000', 1512872999999, '110.20203354', 3696, '1916.73800000', '61.39599868', '342158.89972727'], [1512873000000, '0.03196300', '0.03269500', '0.03181000', '0.03252700', '3573.22300000', 1512874799999, '114.98177770', 5172, '1965.16000000', '63.17133876', '341348.97544564'], [1512874800000, '0.03252700', '0.03273300', '0.03201400', '0.03238800', '4231.42800000', 1512876599999, '137.20645425', 4471, '2141.78000000', '69.46784739', '340601.93766046'], [1512876600000, '0.03235400', '0.03289600', '0.03204500', '0.03259000', '3748.94800000', 1512878399999, '121.95193686', 7467, '1668.30200000', '54.32942130', '338795.53919035'], [1512878400000, '0.03252000', '0.03259100', '0.03185600', '0.03236000', '3979.47500000', 1512880199999, '128.52740739', 5670, '2212.53500000', '71.52258266', '343219.17580150'], [1512880200000, '0.03236000', '0.03262200', '0.03170000', '0.03190000', '3643.58500000', 1512881999999, '117.00878193', 4908, '1915.41500000', '61.52499847', '343236.57179779'], [1512882000000, '0.03187000', '0.03223900', '0.03170000', '0.03213400', '2914.13900000', 1512883799999, '93.51200536', 4946, '1673.67300000', '53.74803152', '342384.32087143'], [1512883800000, '0.03210600', '0.03258800', '0.03195500', '0.03250000', '3000.03600000', 1512885599999, '97.01513961', 3129, '1853.69900000', '59.90847774', '342227.88470769'], [1512885600000, '0.03245000', '0.03260000', '0.03210500', '0.03228400', '2945.22800000', 1512887399999, '95.42470884', 2514, '1474.66900000', '47.79007641', '341436.07701221'], [1512887400000, '0.03229000', '0.03249800', '0.03142700', '0.03162300', '4148.09400000', 1512889199999, '132.66880757', 2677, '1934.15400000', '61.73037816', '341283.90038579'], [1512889200000, '0.03156500', '0.03225000', '0.03145500', '0.03207400', '2962.53300000', 1512890999999, '94.22476397', 2260, '1531.00700000', '48.70712606', '341202.47721350'], [1512891000000, '0.03210600', '0.03248000', '0.03190600', '0.03191500', '2496.17200000', 1512892799999, '80.43336780', 2215, '1115.38200000', '35.95747359', '340994.38543792'], [1512892800000, '0.03191500', '0.03248000', '0.03190400', '0.03244300', '1945.00700000', 1512894599999, '62.73298713', 2051, '988.92700000', '31.89151589', '341954.59041784'], [1512894600000, '0.03244300', '0.03246800', '0.03205400', '0.03219300', '1907.03900000', 1512896399999, '61.58460764', 1415, '925.36800000', '29.84530841', '341759.99037356'], [1512896400000, '0.03219300', '0.03233700', '0.03204900', '0.03220000', '1917.65000000', 1512898199999, '61.71171072', 1525, '985.45800000', '31.72604657', '341503.75170339'], [1512898200000, '0.03223000', '0.03229800', '0.03192800', '0.03205100', '2760.78200000', 1512899999999, '88.78263670', 1882, '1563.93300000', '50.29652678', '340834.04759803'], [1512900000000, '0.03205200', '0.03221800', '0.03170000', '0.03175500', '3100.57900000', 1512901799999, '98.92617244', 1890, '1692.24300000', '53.98791834', '340746.01258931'], [1512901800000, '0.03174500', '0.03183100', '0.03100000', '0.03158600', '3513.90000000', 1512903599999, '110.65964609', 2572, '1634.40900000', '51.53552172', '340590.74607571'], [1512903600000, '0.03158600', '0.03175000', '0.03149400', '0.03156700', '1979.18200000', 1512905399999, '62.54327268', 1835, '1020.99500000', '32.27476266', '340041.07073117'], [1512905400000, '0.03159900', '0.03200000', '0.03154500', '0.03178100', '2179.02400000', 1512907199999, '69.23530847', 2121, '1266.42200000', '40.25286888', '339463.16416304'], [1512907200000, '0.03172600', '0.03200000', '0.03168000', '0.03184300', '2190.46400000', 1512908999999, '69.70251112', 1927, '1132.49800000', '36.03817472', '340552.61125623'], [1512909000000, '0.03184300', '0.03196500', '0.03131900', '0.03142100', '2737.49000000', 1512910799999, '86.53601979', 2609, '1418.31400000', '44.85776854', '340399.76527158'], [1512910800000, '0.03147900', '0.03148500', '0.03083600', '0.03089500', '3288.57300000', 1512912599999, '102.46115490', 3722, '1851.00900000', '57.72429906', '340808.45662828'], [1512912600000, '0.03083600', '0.03097400', '0.03015300', '0.03023800', '4093.94500000', 1512914399999, '124.93029819', 3979, '2265.80500000', '69.15370566', '341647.02085020'], [1512914400000, '0.03023300', '0.03026100', '0.02889900', '0.02902400', '4523.08300000', 1512916199999, '133.72508061', 4712, '2167.44600000', '64.11394067', '342485.40526419'], [1512916200000, '0.02902400', '0.02950700', '0.02861900', '0.02913900', '4675.24300000', 1512917999999, '135.66157694', 4431, '2511.67800000', '72.81589827', '343550.30386540'], [1512918000000, '0.02913900', '0.02973500', '0.02880000', '0.02884800', '6125.71300000', 1512919799999, '179.54827646', 5177, '3367.78600000', '98.76066084', '343896.36200400'], [1512919800000, '0.02884800', '0.02904800', '0.02840000', '0.02888600', '3358.44500000', 1512921599999, '96.54174310', 3599, '1669.55900000', '47.97434665', '344557.22882914'], [1512921600000, '0.02887100', '0.02913800', '0.02864300', '0.02875200', '2625.00900000', 1512923399999, '75.84848745', 2650, '1644.70100000', '47.52412115', '344919.30287306'], [1512923400000, '0.02871200', '0.02937900', '0.02866300', '0.02926700', '3392.77400000', 1512925199999, '98.36441512', 3879, '1769.98800000', '51.33633962', '345266.08113761'], [1512925200000, '0.02926900', '0.02945000', '0.02881700', '0.02927300', '2648.67800000', 1512926999999, '77.30599470', 3069, '1354.79700000', '39.53548281', '345909.35938887'], [1512927000000, '0.02930100', '0.02944100', '0.02923200', '0.02936200', '1814.74600000', 1512928799999, '53.21068801', 1957, '968.09900000', '28.39753275', '346743.10314363'], [1512928800000, '0.02937200', '0.02977400', '0.02934500', '0.02964000', '2876.20000000', 1512930599999, '84.96302802', 1984, '1484.92900000', '43.85278874', '346919.06285462'], [1512930600000, '0.02963600', '0.02982900', '0.02933700', '0.02953800', '2527.33700000', 1512932399999, '74.68643000', 2047, '1518.41000000', '44.87363418', '347012.29127867'], [1512932400000, '0.02955000', '0.02972800', '0.02923100', '0.02925800', '1493.80100000', 1512934199999, '44.05732694', 1919, '674.57700000', '19.90849160', '347741.64231915'], [1512934200000, '0.02923100', '0.02928900', '0.02860000', '0.02869400', '2055.64200000', 1512935999999, '59.53326672', 1936, '992.53700000', '28.76568200', '348001.56041082'], [1512936000000, '0.02869900', '0.02900600', '0.02860200', '0.02882600', '2773.39700000', 1512937799999, '79.84728049', 2345, '1346.74500000', '38.77333112', '347962.07416869'], [1512937800000, '0.02879700', '0.02919000', '0.02876000', '0.02899200', '2337.63700000', 1512939599999, '67.55968547', 2433, '1384.70500000', '40.03665182', '348466.32205997'], [1512939600000, '0.02894200', '0.02970000', '0.02884400', '0.02942600', '2963.34700000', 1512941399999, '86.52389662', 3184, '1564.93600000', '45.67481564', '348398.42576318'], [1512941400000, '0.02942600', '0.02993800', '0.02920100', '0.02988100', '2542.98000000', 1512943199999, '75.32572254', 2522, '1373.20400000', '40.67651855', '348051.48658872'], [1512943200000, '0.02987500', '0.02989000', '0.02895800', '0.02913800', '2314.28000000', 1512944999999, '68.28207630', 2854, '1277.05800000', '37.70055928', '348195.86331601'], [1512945000000, '0.02913500', '0.02987900', '0.02900000', '0.02960000', '2666.79600000', 1512946799999, '78.52977719', 2558, '1434.44600000', '42.21085165', '346773.03755216'], [1512946800000, '0.02960600', '0.02960800', '0.02791500', '0.02812400', '6770.28800000', 1512948599999, '192.27272691', 5325, '3409.39100000', '96.77467399', '346517.94162836'], [1512948600000, '0.02812400', '0.02899000', '0.02788700', '0.02869200', '3171.37100000', 1512950399999, '89.80547075', 3001, '1819.71300000', '51.54579041', '346691.14620742'], [1512950400000, '0.02869200', '0.02880900', '0.02843800', '0.02863100', '2225.22800000', 1512952199999, '63.67817155', 2744, '1347.92500000', '38.58964354', '346915.89053579'], [1512952200000, '0.02859900', '0.02939500', '0.02857800', '0.02904400', '3798.00500000', 1512953999999, '110.12886476', 4265, '2177.09600000', '63.06585372', '346545.47832251'], [1512954000000, '0.02909700', '0.02912700', '0.02811400', '0.02822200', '4773.63900000', 1512955799999, '136.78906220', 4378, '2257.69200000', '64.64337555', '346475.06769252'], [1512955800000, '0.02819600', '0.02846000', '0.02762600', '0.02780700', '4213.97100000', 1512957599999, '117.87855000', 3693, '2342.21300000', '65.52841447', '344932.07480586'], [1512957600000, '0.02778200', '0.02809500', '0.02765600', '0.02768800', '2737.75400000', 1512959399999, '76.39690543', 2572, '1327.42000000', '37.03635439', '344925.46218615'], [1512959400000, '0.02770000', '0.02775100', '0.02750000', '0.02762600', '4034.27800000', 1512961199999, '111.55000942', 3115, '2183.52500000', '60.38413904', '345837.31855094'], [1512961200000, '0.02762800', '0.02777000', '0.02755400', '0.02755500', '3806.12300000', 1512962999999, '105.29007295', 3678, '1996.39800000', '55.24539000', '345119.71607149'], [1512963000000, '0.02755500', '0.02788800', '0.02741100', '0.02766100', '4240.24700000', 1512964799999, '116.97563949', 4248, '2208.77100000', '60.95406820', '344765.47121223'], [1512964800000, '0.02765700', '0.02799800', '0.02725100', '0.02795400', '3224.32300000', 1512966599999, '89.19794538', 3501, '1655.12200000', '45.81520932', '344713.47718569'], [1512966600000, '0.02793100', '0.02844000', '0.02788400', '0.02794200', '3461.97300000', 1512968399999, '97.35946161', 4066, '1690.58300000', '47.55831903', '344390.63970045'], [1512968400000, '0.02797600', '0.02812700', '0.02774000', '0.02796700', '2023.14300000', 1512970199999, '56.51758958', 2378, '979.06800000', '27.34754901', '345167.33921376'], [1512970200000, '0.02795900', '0.02828400', '0.02788200', '0.02815600', '2925.81900000', 1512971999999, '82.00008198', 2856, '1477.81400000', '41.40725387', '344710.61125830'], [1512972000000, '0.02815600', '0.02840600', '0.02809100', '0.02809700', '3450.03100000', 1512973799999, '97.31338574', 3572, '1250.83100000', '35.29718462', '345468.60848214'], [1512973800000, '0.02810800', '0.02831300', '0.02759900', '0.02782800', '3408.77700000', 1512975599999, '95.33476908', 3285, '1758.23000000', '49.16903114', '344268.79463935'], [1512975600000, '0.02775800', '0.02806500', '0.02772300', '0.02802300', '2917.63600000', 1512977399999, '81.37152099', 2674, '1761.39300000', '49.10798555', '344651.16583084'], [1512977400000, '0.02802300', '0.02804000', '0.02756000', '0.02773000', '3186.34900000', 1512979199999, '88.70767077', 3025, '1601.91800000', '44.62158434', '344846.92400115'], [1512979200000, '0.02773000', '0.02788100', '0.02758100', '0.02774900', '3453.68100000', 1512980999999, '95.83100207', 2854, '1800.86400000', '49.97344827', '345271.54391168'], [1512981000000, '0.02774900', '0.02799000', '0.02768800', '0.02789000', '2848.93900000', 1512982799999, '79.35857680', 3298, '1348.63000000', '37.57576869', '345368.04279428'], [1512982800000, '0.02789000', '0.02804000', '0.02782000', '0.02799800', '2629.66700000', 1512984599999, '73.48245610', 2651, '1692.75900000', '47.31278554', '345701.61497108'], [1512984600000, '0.02799500', '0.02820000', '0.02797200', '0.02815500', '2271.70200000', 1512986399999, '63.67791528', 2392, '981.57200000', '27.52416973', '344279.18076994'], [1512986400000, '0.02809500', '0.02844100', '0.02800000', '0.02816200', '2726.57600000', 1512988199999, '76.60378834', 3287, '1326.29400000', '37.27815977', '344005.86592608'], [1512988200000, '0.02816200', '0.02818100', '0.02798400', '0.02801700', '2214.72800000', 1512989999999, '62.13621557', 2750, '1246.09000000', '34.96706171', '341933.27087869'], [1512990000000, '0.02800200', '0.02818200', '0.02777000', '0.02786300', '2621.41900000', 1512991799999, '73.44698192', 3472, '1311.98200000', '36.78296741', '343259.56888568'], [1512991800000, '0.02792100', '0.02814100', '0.02780600', '0.02814100', '2909.35400000', 1512993599999, '81.39884399', 3001, '1770.79000000', '49.55391694', '344027.96285300'], [1512993600000, '0.02811300', '0.02818200', '0.02800000', '0.02804100', '2740.85500000', 1512995399999, '76.97049796', 2960, '1244.84800000', '34.97344459', '342641.17954867'], [1512995400000, '0.02803600', '0.02820000', '0.02801800', '0.02815200', '1834.12700000', 1512997199999, '51.57359935', 1710, '1019.21300000', '28.65703885', '343508.92026914'], [1512997200000, '0.02815200', '0.02857400', '0.02815200', '0.02841000', '4207.60200000', 1512998999999, '119.06049736', 4023, '1824.98700000', '51.66313859', '343463.47095415'], [1512999000000, '0.02844000', '0.02883400', '0.02833400', '0.02868000', '3178.13300000', 1513000799999, '90.83474997', 3387, '1545.21300000', '44.16918621', '344421.97364696'], [1513000800000, '0.02868800', '0.02890000', '0.02859900', '0.02863800', '3537.78000000', 1513002599999, '101.69689753', 3396, '1727.32200000', '49.64226431', '344671.56258795'], [1513002600000, '0.02864400', '0.02889800', '0.02849300', '0.02853200', '3333.69300000', 1513004399999, '95.66248936', 3621, '1738.30800000', '49.89512651', '345337.82241777'], [1513004400000, '0.02853200', '0.02872700', '0.02846000', '0.02860000', '3029.90200000', 1513006199999, '86.54808481', 3108, '1344.95700000', '38.43327123', '346542.92197033'], [1513006200000, '0.02860000', '0.02866100', '0.02839800', '0.02849400', '3277.99800000', 1513007999999, '93.53620357', 2965, '1651.90800000', '47.13104590', '347571.37155205'], [1513008000000, '0.02850200', '0.02864700', '0.02841700', '0.02860100', '2283.50300000', 1513009799999, '65.07501676', 2496, '1386.96300000', '39.53984022', '347732.80973628'], [1513009800000, '0.02856800', '0.02876000', '0.02849300', '0.02858500', '2595.54000000', 1513011599999, '74.39784388', 2253, '1337.00000000', '38.33261726', '348266.99410748'], [1513011600000, '0.02858100', '0.02888700', '0.02855000', '0.02876900', '2853.73100000', 1513013399999, '81.98628553', 2747, '1650.42300000', '47.43097107', '348983.01046460'], [1513013400000, '0.02877400', '0.02907000', '0.02869800', '0.02895500', '3025.34700000', 1513015199999, '87.19616575', 2650, '1479.30500000', '42.65010637', '349119.73976603'], [1513015200000, '0.02895500', '0.02909900', '0.02869400', '0.02873500', '3323.95000000', 1513016999999, '96.17057075', 2427, '1499.07000000', '43.37968861', '349784.82526360'], [1513017000000, '0.02873300', '0.02879400', '0.02855200', '0.02860800', '2939.70300000', 1513018799999, '84.26827397', 2047, '1623.10500000', '46.52852182', '350803.55063898'], [1513018800000, '0.02860400', '0.02865900', '0.02842100', '0.02845500', '2734.31000000', 1513020599999, '78.00762177', 2412, '1484.81100000', '42.36257615', '350913.09655607'], [1513020600000, '0.02846900', '0.02854900', '0.02764500', '0.02767800', '3842.41400000', 1513022399999, '107.68436331', 3010, '1653.82800000', '46.32739666', '351509.42172394'], [1513022400000, '0.02767800', '0.02777000', '0.02678900', '0.02694500', '4062.33500000', 1513024199999, '110.85923376', 3115, '2077.75300000', '56.74909702', '352514.38704906'], [1513024200000, '0.02693900', '0.02750000', '0.02674600', '0.02738000', '3464.09100000', 1513025999999, '94.07378144', 2696, '1856.26100000', '50.44193742', '352649.15835341'], [1513026000000, '0.02738000', '0.02788000', '0.02728700', '0.02762700', '2401.50800000', 1513027799999, '66.21383691', 2052, '1247.90500000', '34.41900032', '352184.10668345'], [1513027800000, '0.02762700', '0.02770400', '0.02744000', '0.02754300', '2193.82100000', 1513029599999, '60.47432473', 1547, '1123.98400000', '30.99763495', '352230.84529322'], [1513029600000, '0.02748600', '0.02774600', '0.02746300', '0.02758800', '2796.33200000', 1513031399999, '77.14545000', 2040, '1673.09600000', '46.17376510', '352825.25722899'], [1513031400000, '0.02758800', '0.02808500', '0.02753200', '0.02805900', '3541.81600000', 1513033199999, '98.50682097', 2217, '1594.63600000', '44.34511065', '352942.02049992'], [1513033200000, '0.02805900', '0.02940800', '0.02800100', '0.02919300', '4911.75300000', 1513034999999, '139.99763023', 3917, '2117.15500000', '60.29480983', '352138.49490294'], [1513035000000, '0.02918800', '0.03120000', '0.02918200', '0.03070000', '13151.42900000', 1513036799999, '397.68429567', 7847, '6359.62800000', '192.28681419', '352449.85730046'], [1513036800000, '0.03070100', '0.03138400', '0.03006900', '0.03034900', '9789.93900000', 1513038599999, '300.39823619', 8160, '5299.31600000', '162.63742104', '352368.12377243'], [1513038600000, '0.03035000', '0.03060500', '0.02984300', '0.03055000', '6847.89500000', 1513040399999, '207.12509484', 6063, '3021.78400000', '91.38007884', '352653.80145033'], [1513040400000, '0.03055000', '0.03129900', '0.03032400', '0.03060900', '4971.76000000', 1513042199999, '153.19688469', 5736, '2581.27000000', '79.52527104', '352209.80747129'], [1513042200000, '0.03062000', '0.03094200', '0.02977300', '0.02989800', '5339.52000000', 1513043999999, '161.80273953', 4178, '2989.69900000', '90.56482687', '352069.70230294'], [1513044000000, '0.02989800', '0.03025000', '0.02983500', '0.02996400', '5152.89800000', 1513045799999, '154.60913530', 4024, '2943.99100000', '88.36510466', '351904.30950183'], [1513045800000, '0.02996400', '0.03230000', '0.02995300', '0.03215000', '12620.21100000', 1513047599999, '394.00780706', 7988, '5314.19700000', '165.66642399', '351357.95664775'], [1513047600000, '0.03219900', '0.03395000', '0.03212000', '0.03275100', '16031.80300000', 1513049399999, '529.55122160', 12497, '5628.95500000', '185.66333891', '353075.07008244'], [1513049400000, '0.03281500', '0.03298000', '0.03213300', '0.03260000', '6102.81600000', 1513051199999, '198.12792964', 5612, '2940.40000000', '95.48026582', '354913.92440411'], [1513051200000, '0.03260000', '0.03324500', '0.03258600', '0.03277800', '4736.37100000', 1513052999999, '156.17141990', 3984, '2528.34000000', '83.34082086', '354684.23998494'], [1513053000000, '0.03277900', '0.03285600', '0.03216800', '0.03254300', '4309.54500000', 1513054799999, '139.98350885', 3957, '2159.40700000', '70.12466741', '356744.58991674'], [1513054800000, '0.03252700', '0.03284600', '0.03200500', '0.03209100', '4726.77500000', 1513056599999, '153.79943471', 3996, '2488.18800000', '80.96927284', '359935.06859560'], [1513056600000, '0.03209400', '0.03238400', '0.03156000', '0.03163800', '4203.69000000', 1513058399999, '134.67224902', 3189, '2049.76100000', '65.64396770', '357849.85675829'], [1513058400000, '0.03163800', '0.03179000', '0.03125500', '0.03158100', '4040.89300000', 1513060199999, '127.38433318', 2924, '2348.19300000', '73.97630062', '358505.11966846'], [1513060200000, '0.03156600', '0.03159900', '0.03120000', '0.03129500', '2986.72200000', 1513061999999, '93.81350326', 2510, '1425.42100000', '44.78226020', '359628.45998738'], [1513062000000, '0.03129500', '0.03154800', '0.03122900', '0.03130600', '4160.74200000', 1513063799999, '130.41287237', 3679, '2036.88000000', '63.86390958', '360920.22392205'], [1513063800000, '0.03134000', '0.03159100', '0.03125000', '0.03157700', '5404.05000000', 1513065599999, '169.79482466', 4077, '3107.89700000', '97.67555520', '362342.58388903'], [1513065600000, '0.03157700', '0.03159100', '0.03121200', '0.03140500', '4189.26900000', 1513067399999, '131.64842144', 3487, '2101.75100000', '66.08842992', '362385.93137362'], [1513067400000, '0.03140100', '0.03143900', '0.03111300', '0.03121000', '3114.27900000', 1513069199999, '97.46477866', 2965, '1690.36500000', '52.90436226', '360718.44605463'], [1513069200000, '0.03121200', '0.03135000', '0.03070100', '0.03085500', '4201.77100000', 1513070999999, '130.70639095', 3507, '1707.66500000', '53.12922112', '360582.63809304'], [1513071000000, '0.03085500', '0.03109400', '0.03074800', '0.03080600', '2798.59900000', 1513072799999, '86.26703229', 3396, '1722.23700000', '53.10126390', '360731.86193447'], [1513072800000, '0.03080600', '0.03110000', '0.03075700', '0.03097400', '3768.02400000', 1513074599999, '116.53895519', 4282, '2201.31800000', '68.08909121', '363247.11408345'], [1513074600000, '0.03097400', '0.03267600', '0.03090900', '0.03230000', '7597.92200000', 1513076399999, '242.50041349', 6309, '2905.02100000', '92.68071455', '363978.74397489'], [1513076400000, '0.03230000', '0.03239800', '0.03198000', '0.03205300', '6098.58000000', 1513078199999, '196.34290057', 5168, '2328.26200000', '74.92135124', '365534.47247035'], [1513078200000, '0.03200700', '0.03218900', '0.03170000', '0.03172600', '4583.84000000', 1513079999999, '146.32802584', 3153, '2226.93100000', '71.09467302', '366506.82474677'], [1513080000000, '0.03173300', '0.03228200', '0.03139500', '0.03225200', '6400.28900000', 1513081799999, '203.20158566', 4353, '2737.60300000', '86.65007813', '359622.48113342'], [1513081800000, '0.03224800', '0.03425000', '0.03203700', '0.03388600', '9800.13300000', 1513083599999, '326.49440799', 5839, '3977.96200000', '132.40408912', '359861.19215026'], [1513083600000, '0.03392500', '0.03537500', '0.03320000', '0.03347400', '12750.96800000', 1513085399999, '437.70636667', 8785, '5839.86400000', '200.48179484', '360350.83093433'], [1513085400000, '0.03347300', '0.03368900', '0.03285200', '0.03344500', '7013.61300000', 1513087199999, '233.27355046', 5839, '2990.60100000', '99.43410859', '362844.61687716'], [1513087200000, '0.03347800', '0.03529000', '0.03340200', '0.03513900', '10639.98100000', 1513088999999, '364.57814309', 7052, '4342.91300000', '148.53616887', '365638.59000937'], [1513089000000, '0.03513900', '0.03655800', '0.03510300', '0.03583700', '12918.16100000', 1513090799999, '459.92248536', 7981, '5059.28400000', '180.27672850', '369164.18113506'], [1513090800000, '0.03583700', '0.04000000', '0.03581100', '0.03850400', '21909.76200000', 1513092599999, '828.67908623', 13858, '9326.01000000', '352.29778310', '372970.46474861'], [1513092600000, '0.03861000', '0.03929900', '0.03710000', '0.03740600', '16027.85900000', 1513094399999, '612.88631284', 10878, '6525.89200000', '249.31514561', '376434.62256108'], [1513094400000, '0.03740500', '0.03850000', '0.03711000', '0.03820500', '12020.83900000', 1513096199999, '454.67290217', 8741, '5877.41500000', '222.36689710', '378257.34805452'], [1513096200000, '0.03821100', '0.03850000', '0.03584400', '0.03644000', '11202.64700000', 1513097999999, '414.28294593', 9112, '5071.49200000', '187.25011074', '382820.69910083'], [1513098000000, '0.03644000', '0.03715900', '0.03590600', '0.03624800', '7696.17800000', 1513099799999, '281.32464191', 6602, '3524.53000000', '128.89870419', '385010.24220812'], [1513099800000, '0.03629000', '0.03630700', '0.03400000', '0.03488800', '7380.70400000', 1513101599999, '262.84946599', 5380, '3351.77100000', '119.56917057', '387619.95672861'], [1513101600000, '0.03488800', '0.03488800', '0.03334500', '0.03365000', '8858.41200000', 1513103399999, '302.63272697', 6497, '4773.08200000', '163.31084100', '388203.48949879'], [1513103400000, '0.03365000', '0.03540000', '0.03353600', '0.03489900', '5592.30600000', 1513105199999, '193.87327911', 4992, '2406.38000000', '83.35821441', '389846.87146283'], [1513105200000, '0.03489900', '0.03589700', '0.03449900', '0.03583200', '4913.54700000', 1513106999999, '172.34575504', 4913, '2365.28900000', '82.93267717', '391096.17262913'], [1513107000000, '0.03586700', '0.03606700', '0.03512700', '0.03550300', '5053.09400000', 1513108799999, '180.16532455', 3990, '2242.38300000', '79.88549340', '393120.65351438'], [1513108800000, '0.03550400', '0.03620500', '0.03535400', '0.03592900', '4513.62600000', 1513110599999, '161.40532488', 3232, '2186.45900000', '78.14848227', '394330.53861228'], [1513110600000, '0.03593600', '0.03674900', '0.03580000', '0.03596000', '5517.49300000', 1513112399999, '199.34784173', 4664, '3161.89300000', '114.36646021', '395378.99943652'], [1513112400000, '0.03596700', '0.03602000', '0.03502700', '0.03508200', '4341.26300000', 1513114199999, '153.87207514', 4023, '2321.68600000', '82.28511143', '395792.14369086'], [1513114200000, '0.03509400', '0.03567500', '0.03484500', '0.03545000', '3892.09500000', 1513115999999, '137.23885918', 3736, '2048.44800000', '72.28499917', '396382.48201601'], [1513116000000, '0.03546700', '0.03560300', '0.03435500', '0.03453300', '4132.36900000', 1513117799999, '144.23582573', 3854, '1932.92900000', '67.45789037', '396752.12519929'], [1513117800000, '0.03453300', '0.03527600', '0.03435600', '0.03523600', '4471.04600000', 1513119599999, '155.03332572', 3984, '2055.49300000', '71.31041197', '396907.69583799'], [1513119600000, '0.03521600', '0.03700000', '0.03521400', '0.03698200', '7838.93200000', 1513121399999, '284.60419608', 5619, '4377.56900000', '158.81376468', '397340.47658674'], [1513121400000, '0.03698100', '0.03900000', '0.03698100', '0.03800000', '10864.91400000', 1513123199999, '414.63076236', 7096, '4836.85000000', '184.69696151', '396813.55146361'], [1513123200000, '0.03800000', '0.03838500', '0.03690000', '0.03799300', '6995.53600000', 1513124999999, '263.82204432', 6331, '3221.00600000', '121.46529833', '398717.14693260'], [1513125000000, '0.03800900', '0.03858500', '0.03730000', '0.03733000', '5230.18600000', 1513126799999, '198.75750783', 4190, '2718.12100000', '103.22575626', '398379.93920804'], [1513126800000, '0.03733000', '0.03733100', '0.03630000', '0.03654400', '5721.98900000', 1513128599999, '211.12897768', 4612, '3632.46800000', '134.03538318', '398945.06171928'], [1513128600000, '0.03654400', '0.03725500', '0.03634000', '0.03715000', '4701.47600000', 1513130399999, '172.98002821', 4294, '2260.18100000', '83.07517247', '399325.76438745'], [1513130400000, '0.03713000', '0.03771300', '0.03686300', '0.03700000', '4673.59600000', 1513132199999, '174.10195249', 4267, '2263.25600000', '84.31778713', '398690.07287094'], [1513132200000, '0.03702200', '0.03722600', '0.03605200', '0.03642400', '5821.64400000', 1513133999999, '213.53449949', 5789, '2976.29700000', '109.21766685', '398735.72896302'], [1513134000000, '0.03642400', '0.03700000', '0.03630000', '0.03683600', '4442.61000000', 1513135799999, '163.21985122', 4860, '2087.45700000', '76.72103604', '399838.75153542'], [1513135800000, '0.03684000', '0.03735000', '0.03682900', '0.03716600', '2908.48600000', 1513137599999, '107.68496382', 3019, '1436.78500000', '53.21260430', '399570.45067602'], [1513137600000, '0.03716600', '0.03721900', '0.03676500', '0.03677300', '3176.50600000', 1513139399999, '117.58094852', 3042, '1408.57900000', '52.14695717', '401645.20382011'], [1513139400000, '0.03680600', '0.03689200', '0.03664300', '0.03686400', '2961.63900000', 1513141199999, '108.84219026', 2891, '1505.76400000', '55.34992795', '401847.57260786'], [1513141200000, '0.03682300', '0.03702200', '0.03667100', '0.03672700', '3451.16000000', 1513142999999, '127.26070498', 3568, '1514.54700000', '55.86531035', '401468.67211456'], [1513143000000, '0.03676700', '0.03708000', '0.03653200', '0.03697400', '3628.54100000', 1513144799999, '133.79450304', 3409, '1738.55500000', '64.12607328', '402712.84739370'], [1513144800000, '0.03706200', '0.03830700', '0.03676300', '0.03803800', '5390.67000000', 1513146599999, '201.45385343', 5844, '2478.41900000', '92.57873690', '400787.77524071'], [1513146600000, '0.03803800', '0.03896100', '0.03799100', '0.03802500', '6530.43000000', 1513148399999, '251.08120374', 5282, '2804.29800000', '107.86674671', '403852.92440479'], [1513148400000, '0.03802500', '0.03899100', '0.03800000', '0.03811300', '5663.30400000', 1513150199999, '217.95263262', 4013, '2716.12000000', '104.51517410', '403447.06643394'], [1513150200000, '0.03815100', '0.03838200', '0.03766900', '0.03828400', '4901.87300000', 1513151999999, '186.49792848', 3832, '2751.90500000', '104.81660060', '403931.35863001'], [1513152000000, '0.03828500', '0.03860000', '0.03797800', '0.03825700', '5152.34300000', 1513153799999, '196.66083113', 5254, '2654.07200000', '101.34961047', '401722.17212814'], [1513153800000, '0.03825700', '0.03903700', '0.03819000', '0.03850200', '7146.57400000', 1513155599999, '276.25038466', 6736, '4055.51800000', '156.84074625', '398814.45496069'], [1513155600000, '0.03852200', '0.03916300', '0.03850100', '0.03900000', '5213.60600000', 1513157399999, '202.35613341', 5073, '2851.47900000', '110.62721066', '400151.78547011'], [1513157400000, '0.03895000', '0.03920000', '0.03889900', '0.03912500', '4186.67300000', 1513159199999, '163.41243536', 4383, '1971.37800000', '76.96173281', '400690.41033889'], [1513159200000, '0.03918400', '0.04048900', '0.03895200', '0.04044300', '7787.25700000', 1513160999999, '308.54224279', 5269, '4370.29000000', '173.35962541', '401294.72134017'], [1513161000000, '0.04037000', '0.04087800', '0.04000000', '0.04013800', '8835.17800000', 1513162799999, '357.49487992', 6724, '4422.39600000', '179.06935028', '400693.76847726'], [1513162800000, '0.04018400', '0.04038700', '0.03920400', '0.03937000', '4687.83900000', 1513164599999, '187.05568007', 5347, '1778.18700000', '70.98625865', '401468.57397562'], [1513164600000, '0.03937000', '0.03981300', '0.03927900', '0.03955100', '3476.54500000', 1513166399999, '137.32481021', 4358, '1782.17600000', '70.42061804', '401740.19767554'], [1513166400000, '0.03955100', '0.04082100', '0.03950400', '0.04064800', '5714.51200000', 1513168199999, '229.49637631', 5362, '2688.68900000', '108.11755916', '401072.63050764'], [1513168200000, '0.04064800', '0.04066000', '0.03960200', '0.03983000', '4392.22700000', 1513169999999, '176.08758758', 5417, '2284.32200000', '91.61933492', '399908.14421945'], [1513170000000, '0.03976900', '0.04020000', '0.03924500', '0.04001000', '4699.50400000', 1513171799999, '186.55285897', 5603, '2072.91400000', '82.35544267', '400656.32461190'], [1513171800000, '0.04001000', '0.04039900', '0.03990000', '0.04030000', '3427.07700000', 1513173599999, '137.27371427', 3082, '1747.71500000', '70.00749635', '400519.25942754'], [1513173600000, '0.04030000', '0.04200000', '0.04030000', '0.04200000', '5445.08500000', 1513175399999, '223.62330589', 4176, '3010.36100000', '123.69536904', '399490.66638509'], [1513175400000, '0.04192700', '0.04424500', '0.04189000', '0.04321400', '14737.84200000', 1513177199999, '635.40596213', 8837, '6381.20300000', '274.77407297', '398662.74559846'], [1513177200000, '0.04321400', '0.04384000', '0.04246700', '0.04310200', '8558.10900000', 1513178999999, '368.55395346', 6380, '3495.82600000', '150.69674930', '399485.93993858'], [1513179000000, '0.04314800', '0.04328100', '0.04262200', '0.04297200', '5175.22700000', 1513180799999, '222.41950759', 4915, '2349.90700000', '100.97898479', '400405.50897919'], [1513180800000, '0.04297200', '0.04310000', '0.04230000', '0.04302800', '4536.87400000', 1513182599999, '193.82035901', 4507, '2259.03000000', '96.55018258', '401209.87036282'], [1513182600000, '0.04302400', '0.04375000', '0.04269800', '0.04302700', '5396.08600000', 1513184399999, '233.52911437', 5252, '2544.64200000', '110.13306554', '402367.65769888'], [1513184400000, '0.04302000', '0.04315800', '0.04219500', '0.04219500', '4552.17200000', 1513186199999, '193.82946483', 5000, '2222.46400000', '94.62768075', '402474.40728841'], [1513186200000, '0.04224500', '0.04230900', '0.04122300', '0.04221700', '5992.01800000', 1513187999999, '250.95409374', 6596, '2901.21500000', '121.54216572', '402682.88101934'], [1513188000000, '0.04221700', '0.04253900', '0.04150000', '0.04152100', '3906.53100000', 1513189799999, '164.24728702', 4580, '1767.61100000', '74.27109530', '403705.36047680'], [1513189800000, '0.04152100', '0.04198900', '0.04062500', '0.04183300', '4936.75100000', 1513191599999, '203.80991837', 4986, '2407.93700000', '99.42570044', '404233.12158053'], [1513191600000, '0.04183300', '0.04250000', '0.04147000', '0.04242800', '3894.66300000', 1513193399999, '163.48297664', 4390, '1708.57300000', '71.76362957', '405907.97187367'], [1513193400000, '0.04247400', '0.04296500', '0.04237500', '0.04252100', '4967.52000000', 1513195199999, '212.06134500', 4282, '2458.41500000', '104.97224137', '407614.25043381'], [1513195200000, '0.04252100', '0.04264500', '0.04150000', '0.04172000', '4058.81300000', 1513196999999, '170.94227833', 4578, '2034.23700000', '85.63732197', '408053.23581700'], [1513197000000, '0.04172300', '0.04230000', '0.04085900', '0.04209100', '5595.80100000', 1513198799999, '232.11766887', 6651, '2876.24000000', '119.46354019', '408706.15397622'], [1513198800000, '0.04205000', '0.04254200', '0.04127500', '0.04176700', '4480.60600000', 1513200599999, '188.16191915', 6094, '2382.37000000', '100.17028869', '410639.84130356'], [1513200600000, '0.04176700', '0.04183900', '0.04110000', '0.04151000', '2799.76400000', 1513202399999, '116.45115550', 2978, '1355.61500000', '56.40465465', '411020.75560228'], [1513202400000, '0.04151000', '0.04186400', '0.04150600', '0.04173800', '3110.55400000', 1513204199999, '129.72419584', 3206, '1497.57600000', '62.45606347', '411690.37879674'], [1513204200000, '0.04178000', '0.04198000', '0.04155100', '0.04176900', '4033.03000000', 1513205999999, '168.44674192', 3769, '2129.84700000', '88.98905637', '412385.45817491'], [1513206000000, '0.04176900', '0.04270000', '0.04167800', '0.04260400', '4864.51700000', 1513207799999, '204.97298609', 4301, '2808.30600000', '118.30212894', '412335.47250634'], [1513207800000, '0.04257700', '0.04289500', '0.04253600', '0.04281000', '3885.19800000', 1513209599999, '166.00638640', 3997, '2101.84500000', '89.84592214', '413062.23910461'], [1513209600000, '0.04281100', '0.04290000', '0.04245800', '0.04271300', '4171.27500000', 1513211399999, '177.97842404', 5128, '2102.79900000', '89.74729528', '414846.69535227'], [1513211400000, '0.04272900', '0.04436600', '0.04269100', '0.04425200', '6205.45100000', 1513213199999, '269.50629443', 5119, '3018.62900000', '131.19274485', '415847.93003104'], [1513213200000, '0.04425900', '0.04500000', '0.04378000', '0.04491500', '6850.23200000', 1513214999999, '304.06233111', 5886, '3599.13800000', '159.73724632', '416621.48383622'], [1513215000000, '0.04488000', '0.04522300', '0.04449000', '0.04500000', '5502.20700000', 1513216799999, '247.08792726', 4956, '2653.01400000', '119.15813033', '417700.67637111'], [1513216800000, '0.04503000', '0.04520000', '0.04441700', '0.04465700', '4971.16100000', 1513218599999, '223.07930204', 4847, '2293.20300000', '102.96438712', '419860.52951295'], [1513218600000, '0.04460000', '0.04500000', '0.04435800', '0.04492100', '3979.70400000', 1513220399999, '177.87270881', 4513, '1952.21300000', '87.29715230', '420265.86654719'], [1513220400000, '0.04489500', '0.04492000', '0.04454000', '0.04465000', '3560.56700000', 1513222199999, '159.16739632', 4255, '1817.32800000', '81.27414183', '421399.37535406'], [1513222200000, '0.04465000', '0.04499900', '0.04460500', '0.04496000', '4048.93300000', 1513223999999, '181.59448923', 4075, '1910.85700000', '85.72412252', '421171.25383851'], [1513224000000, '0.04490800', '0.04599800', '0.04489500', '0.04578600', '5174.21800000', 1513225799999, '234.91750886', 5266, '2491.90200000', '113.16461837', '422391.82412407'], [1513225800000, '0.04575900', '0.04594000', '0.04559500', '0.04572600', '4579.64300000', 1513227599999, '209.44535633', 4324, '2163.58400000', '98.97194633', '422850.78799508'], [1513227600000, '0.04572800', '0.04579500', '0.04525000', '0.04525000', '4794.91600000', 1513229399999, '218.05006092', 4638, '2334.64300000', '106.20665971', '427396.74264690'], [1513229400000, '0.04531000', '0.04531000', '0.04421100', '0.04460200', '5873.84500000', 1513231199999, '262.17956803', 5669, '2692.87900000', '120.15953681', '428278.66018839'], [1513231200000, '0.04460200', '0.04500000', '0.04455000', '0.04487100', '4873.49700000', 1513232999999, '218.31306925', 4283, '2344.33500000', '105.08121177', '427084.02643073'], [1513233000000, '0.04495000', '0.04527700', '0.04480100', '0.04488000', '5769.27000000', 1513234799999, '259.17293034', 5363, '2352.59300000', '105.73393303', '428245.96642095'], [1513234800000, '0.04488000', '0.04507000', '0.04450900', '0.04489500', '5011.33700000', 1513236599999, '224.44400734', 5554, '2330.86400000', '104.44327045', '427557.43810350'], [1513236600000, '0.04485500', '0.04530000', '0.04476000', '0.04476700', '5282.88700000', 1513238399999, '237.84501105', 5084, '2419.98400000', '109.00942249', '427865.56447771'], [1513238400000, '0.04484500', '0.04503000', '0.04100000', '0.04252800', '10687.19900000', 1513240199999, '460.05008015', 9334, '5039.22200000', '216.35030637', '429233.50277912'], [1513240200000, '0.04259900', '0.04486000', '0.04214700', '0.04470800', '9142.47200000', 1513241999999, '398.71482166', 8010, '3784.18500000', '164.38451663', '433026.25891288'], [1513242000000, '0.04474000', '0.04646800', '0.04340100', '0.04623800', '17286.83000000', 1513243799999, '789.29546920', 11593, '5949.01000000', '271.57535801', '450011.10950163'], [1513243800000, '0.04629100', '0.04650000', '0.04512200', '0.04576300', '16132.60000000', 1513245599999, '744.34005084', 12286, '6716.91000000', '309.94506401', '481442.92852691'], [1513245600000, '0.04576300', '0.04618900', '0.04520200', '0.04567600', '9581.60000000', 1513247399999, '438.13132652', 7800, '4372.44200000', '200.17512210', '505202.37000525'], [1513247400000, '0.04567600', '0.04570900', '0.04325100', '0.04352600', '14970.60100000', 1513249199999, '662.16387770', 10170, '9015.86700000', '398.09822275', '519390.41090083'], [1513249200000, '0.04352600', '0.04423500', '0.04269800', '0.04305700', '7694.43000000', 1513250999999, '335.87858804', 6443, '3795.50600000', '165.69253181', '520452.09268294'], [1513251000000, '0.04305700', '0.04319400', '0.04217000', '0.04227300', '9258.38400000', 1513252799999, '395.46058854', 6759, '4952.83100000', '211.38333121', '518326.48249642'], [1513252800000, '0.04227900', '0.04309100', '0.04142200', '0.04175200', '10130.26500000', 1513254599999, '424.72306294', 9680, '4880.37500000', '204.76182858', '516449.08369051'], [1513254600000, '0.04175200', '0.04229200', '0.04170000', '0.04172800', '6939.00400000', 1513256399999, '291.47830614', 9183, '3975.89300000', '167.08931273', '517420.40580799'], [1513256400000, '0.04172800', '0.04176900', '0.04058900', '0.04075200', '7756.81600000', 1513258199999, '318.63563361', 8178, '4318.09700000', '177.39269496', '515506.88491377'], [1513258200000, '0.04074300', '0.04167000', '0.04037500', '0.04145100', '6877.46500000', 1513259999999, '282.92586975', 8819, '3304.32600000', '135.97320431', '512503.67797793'], [1513260000000, '0.04145100', '0.04156000', '0.04001200', '0.04032900', '6657.06000000', 1513261799999, '272.49098465', 8262, '3670.89900000', '150.28489535', '504394.96132548'], [1513261800000, '0.04019200', '0.04091000', '0.04000800', '0.04055400', '8969.09100000', 1513263599999, '362.11338998', 8886, '3809.14800000', '153.88440951', '501574.26976754'], [1513263600000, '0.04052900', '0.04091000', '0.04000000', '0.04038200', '6846.32000000', 1513265399999, '276.14001206', 8475, '3549.53600000', '143.23521078', '498740.58565869'], [1513265400000, '0.04038200', '0.04182600', '0.04034000', '0.04155200', '6837.34100000', 1513267199999, '282.73234088', 5981, '3146.26900000', '130.15013785', '497011.21166136'], [1513267200000, '0.04156000', '0.04165900', '0.04093400', '0.04129700', '4498.87500000', 1513268999999, '185.98838818', 4874, '2320.93400000', '95.97950606', '494662.92262751'], [1513269000000, '0.04133500', '0.04137400', '0.04052000', '0.04110800', '5445.29500000', 1513270799999, '223.37021416', 6384, '2850.63200000', '116.94790203', '493967.12753748'], [1513270800000, '0.04111000', '0.04116100', '0.04064400', '0.04101400', '5549.55800000', 1513272599999, '226.78464995', 4997, '2567.83800000', '104.96309163', '496276.88013650'], [1513272600000, '0.04101500', '0.04109600', '0.04050000', '0.04060500', '5313.28400000', 1513274399999, '217.09501231', 4664, '2532.41300000', '103.52037898', '496981.56117622'], [1513274400000, '0.04069600', '0.04070000', '0.04010000', '0.04015600', '4293.91500000', 1513276199999, '173.36983262', 4703, '2206.24000000', '89.11254925', '498025.20843442'], [1513276200000, '0.04009900', '0.04024000', '0.03960000', '0.03974100', '5359.53800000', 1513277999999, '214.16374257', 6888, '2675.14200000', '106.94395335', '498086.60749486'], [1513278000000, '0.03974300', '0.04100200', '0.03964000', '0.04073100', '6170.24400000', 1513279799999, '248.94643553', 6851, '2649.30500000', '106.57529107', '497475.67609005'], [1513279800000, '0.04073000', '0.04100000', '0.04060000', '0.04061000', '4298.88600000', 1513281599999, '175.36751517', 5242, '1880.95400000', '76.76685985', '497611.74800848'], [1513281600000, '0.04061000', '0.04135100', '0.04052000', '0.04118300', '4240.01100000', 1513283399999, '173.74562064', 4963, '1992.27000000', '81.66894558', '500802.62316952'], [1513283400000, '0.04120300', '0.04190000', '0.04111500', '0.04143800', '6100.87800000', 1513285199999, '252.47889847', 6345, '3051.52500000', '126.21324047', '499474.64539503'], [1513285200000, '0.04143800', '0.04175000', '0.04111100', '0.04130700', '4069.33400000', 1513286999999, '168.22958774', 4781, '1893.02600000', '78.31736177', '500247.54753106'], [1513287000000, '0.04131400', '0.04179900', '0.04109600', '0.04149600', '4696.50600000', 1513288799999, '194.42953272', 4890, '2127.29100000', '88.08410388', '500881.44110492'], [1513288800000, '0.04148500', '0.04188800', '0.04134200', '0.04152500', '4572.88200000', 1513290599999, '189.90819534', 6010, '2378.37300000', '98.79246107', '499508.38901474'], [1513290600000, '0.04152600', '0.04158400', '0.04092700', '0.04139800', '4345.29400000', 1513292399999, '179.37097031', 5044, '1840.31100000', '75.97779736', '499152.83879865'], [1513292400000, '0.04138400', '0.04162100', '0.04120100', '0.04130400', '3456.31300000', 1513294199999, '143.03951467', 4702, '1727.90500000', '71.51489600', '498226.72776506'], [1513294200000, '0.04130400', '0.04190700', '0.04123600', '0.04154900', '4293.08300000', 1513295999999, '177.68772238', 4997, '2494.19900000', '103.24486912', '498596.72595260'], [1513296000000, '0.04155000', '0.04166000', '0.04000000', '0.04014700', '5752.01000000', 1513297799999, '235.64916427', 6937, '2914.60600000', '119.52132916', '498276.38544297'], [1513297800000, '0.04010600', '0.04019900', '0.03800900', '0.03854200', '8258.58500000', 1513299599999, '323.38217826', 8964, '4360.21400000', '170.58251118', '495716.42010416'], [1513299600000, '0.03830000', '0.03970000', '0.03830000', '0.03880000', '6576.86600000', 1513301399999, '256.74442774', 6917, '3408.91600000', '133.19129721', '494232.79936763'], [1513301400000, '0.03876400', '0.03880000', '0.03633700', '0.03677800', '8066.68600000', 1513303199999, '300.53205736', 8808, '4564.86400000', '170.04992032', '494156.85304774'], [1513303200000, '0.03677800', '0.03798900', '0.03556700', '0.03568500', '9227.80000000', 1513304999999, '338.27200258', 8353, '4625.80800000', '169.71085855', '489172.81426958'], [1513305000000, '0.03569200', '0.03575200', '0.03350100', '0.03530300', '12307.93300000', 1513306799999, '423.34667662', 8962, '6697.92900000', '230.44034331', '488280.80379309'], [1513306800000, '0.03530700', '0.03790900', '0.03432500', '0.03758700', '11846.12400000', 1513308599999, '427.73548991', 8240, '6531.93200000', '234.42116184', '486734.72638626'], [1513308600000, '0.03758600', '0.03759500', '0.03640000', '0.03747900', '6972.23700000', 1513310399999, '258.06849388', 6026, '3103.13700000', '114.89983261', '484791.17602836'], [1513310400000, '0.03747700', '0.03897200', '0.03747700', '0.03830400', '4740.15500000', 1513312199999, '181.29403754', 5503, '2136.09900000', '81.68708467', '484406.65692094'], [1513312200000, '0.03830400', '0.03863100', '0.03724400', '0.03738700', '4661.57300000', 1513313999999, '177.61298551', 4561, '2445.08500000', '92.96189362', '482856.50686377'], [1513314000000, '0.03738700', '0.03767300', '0.03720000', '0.03725300', '4832.52000000', 1513315799999, '180.66124535', 4319, '2536.63300000', '94.84644016', '482979.61580230'], [1513315800000, '0.03729000', '0.03779900', '0.03720000', '0.03774200', '4146.07600000', 1513317599999, '155.51055452', 3712, '2369.63400000', '88.85482132', '481617.16257418'], [1513317600000, '0.03774300', '0.03886000', '0.03771600', '0.03872600', '4525.26500000', 1513319399999, '172.77584186', 4190, '2030.28500000', '77.49062164', '479091.62586439'], [1513319400000, '0.03872200', '0.03901900', '0.03820400', '0.03831800', '4331.28800000', 1513321199999, '167.50647386', 4710, '1889.31600000', '73.07855133', '478537.85416053'], [1513321200000, '0.03830300', '0.03855000', '0.03803200', '0.03846900', '4286.82000000', 1513322999999, '164.22781818', 4416, '1913.44500000', '73.32011831', '477827.02279787'], [1513323000000, '0.03846900', '0.03870000', '0.03805600', '0.03842900', '4366.03800000', 1513324799999, '167.47346420', 4055, '1826.65800000', '70.10063455', '478875.62360061'], [1513324800000, '0.03842800', '0.03900000', '0.03830900', '0.03887100', '4571.55600000', 1513326599999, '176.55538836', 4896, '2114.21800000', '81.71928086', '476597.69015741'], [1513326600000, '0.03888600', '0.03908900', '0.03794300', '0.03803500', '3871.60600000', 1513328399999, '149.19749256', 4285, '2151.84800000', '82.94442534', '476827.35411526'], [1513328400000, '0.03803600', '0.03807900', '0.03692300', '0.03740000', '6069.19400000', 1513330199999, '227.25195714', 5625, '2548.00200000', '95.42116630', '476702.67403713'], [1513330200000, '0.03740000', '0.03760000', '0.03585100', '0.03599200', '6550.31000000', 1513331999999, '241.56875089', 5139, '4330.70600000', '159.53374791', '475862.69845078'], [1513332000000, '0.03598700', '0.03600000', '0.03500000', '0.03541000', '6895.90400000', 1513333799999, '244.71195701', 6077, '3384.06100000', '120.20091966', '475258.86906032'], [1513333800000, '0.03544200', '0.03680400', '0.03513600', '0.03639000', '6239.84700000', 1513335599999, '224.59444703', 5665, '3785.84300000', '136.39918006', '472318.51694734'], [1513335600000, '0.03639000', '0.03658000', '0.03615400', '0.03637400', '4234.10000000', 1513337399999, '153.95235974', 3699, '2164.44600000', '78.73431491', '470097.05211449'], [1513337400000, '0.03641000', '0.03641000', '0.03568000', '0.03595300', '4249.11400000', 1513339199999, '153.18567241', 3524, '2206.85700000', '79.56141865', '468592.01454597'], [1513339200000, '0.03595400', '0.03619900', '0.03580500', '0.03611100', '3372.61900000', 1513340999999, '121.26903772', 3071, '1551.51800000', '55.80441499', '469119.21509598'], [1513341000000, '0.03611000', '0.03665600', '0.03603000', '0.03653500', '4161.19700000', 1513342799999, '151.40619688', 3830, '1993.83900000', '72.60579288', '468557.75673631'], [1513342800000, '0.03653500', '0.03778900', '0.03652300', '0.03776300', '5127.07400000', 1513344599999, '189.58640313', 4308, '2404.94800000', '88.88737279', '469374.40530748'], [1513344600000, '0.03776600', '0.03920000', '0.03758600', '0.03780900', '8518.74300000', 1513346399999, '324.89186326', 5992, '3772.20000000', '144.04161653', '469611.52218349'], [1513346400000, '0.03780900', '0.03807500', '0.03730800', '0.03785700', '5541.80700000', 1513348199999, '209.17181476', 5288, '2864.93200000', '108.13824516', '469674.03587751'], [1513348200000, '0.03785700', '0.03813500', '0.03631400', '0.03807900', '4639.44200000', 1513349999999, '175.65289289', 5121, '2320.26500000', '88.06844590', '468769.17259083'], [1513350000000, '0.03803800', '0.04000000', '0.03800000', '0.03939900', '7741.12000000', 1513351799999, '300.09993496', 6197, '3880.87200000', '150.38267411', '468283.22515762'], [1513351800000, '0.03942600', '0.03948000', '0.03895000', '0.03903400', '5077.43100000', 1513353599999, '198.75536649', 3866, '2446.37000000', '95.79943572', '466174.34449851'], [1513353600000, '0.03903400', '0.03906800', '0.03825100', '0.03842900', '3732.33000000', 1513355399999, '144.22192220', 4241, '1866.49700000', '72.16292459', '465934.77878489'], [1513355400000, '0.03843100', '0.03915200', '0.03830100', '0.03885900', '3521.21800000', 1513357199999, '136.17116126', 5371, '1794.48600000', '69.37182919', '465442.29505914'], [1513357200000, '0.03887300', '0.03909900', '0.03873800', '0.03882100', '3699.79600000', 1513358999999, '143.80211832', 4671, '1867.19800000', '72.59877302', '465546.81243670'], [1513359000000, '0.03882100', '0.03903800', '0.03854400', '0.03892800', '3326.63200000', 1513360799999, '129.14701820', 5242, '1832.45200000', '71.17469350', '465727.22894148'], [1513360800000, '0.03890000', '0.03914800', '0.03870100', '0.03870500', '3080.65000000', 1513362599999, '119.78755389', 4462, '1602.47600000', '62.33511512', '466033.89701969'], [1513362600000, '0.03874300', '0.03889900', '0.03803300', '0.03819100', '3395.71900000', 1513364399999, '130.87285188', 3474, '1684.85900000', '64.92612876', '466238.66298137'], [1513364400000, '0.03815000', '0.03855000', '0.03750400', '0.03835800', '3725.05400000', 1513366199999, '141.70415315', 4452, '1743.64000000', '66.38839855', '466505.96572959'], [1513366200000, '0.03839800', '0.03850000', '0.03811400', '0.03839200', '2227.38700000', 1513367999999, '85.36364700', 3344, '1201.47100000', '46.05547523', '466726.77307036'], [1513368000000, '0.03839800', '0.03854900', '0.03816000', '0.03827300', '2791.16500000', 1513369799999, '107.01117939', 2859, '1207.27700000', '46.30144224', '467203.39871813'], [1513369800000, '0.03829600', '0.03851100', '0.03805100', '0.03843300', '2578.37200000', 1513371599999, '98.81832598', 2973, '1164.41100000', '44.64088100', '467227.24524312'], [1513371600000, '0.03841300', '0.03899900', '0.03831500', '0.03891700', '3099.18100000', 1513373399999, '119.53866548', 4177, '1595.40400000', '61.55758005', '467186.72043843'], [1513373400000, '0.03891800', '0.03910000', '0.03875000', '0.03880600', '3107.45800000', 1513375199999, '120.96513625', 3458, '1559.64600000', '60.71728059', '467666.71153209'], [1513375200000, '0.03880600', '0.03901900', '0.03841900', '0.03878600', '2536.26600000', 1513376999999, '98.37070657', 3495, '1187.03600000', '46.02819268', '469138.76046432'], [1513377000000, '0.03878600', '0.03888500', '0.03859100', '0.03868400', '2828.27900000', 1513378799999, '109.70091647', 3010, '1606.55600000', '62.32477554', '469128.09838725'], [1513378800000, '0.03868000', '0.03873700', '0.03840500', '0.03844300', '2990.95200000', 1513380599999, '115.34507012', 3365, '1382.98500000', '53.36076800', '469219.94421198'], [1513380600000, '0.03848400', '0.03860100', '0.03833000', '0.03857900', '3765.41400000', 1513382399999, '144.94558934', 3973, '1767.62000000', '68.06346352', '469087.52809448'], [1513382400000, '0.03857900', '0.03887000', '0.03852100', '0.03881100', '4173.74500000', 1513384199999, '161.40841916', 4823, '2082.60700000', '80.56499456', '468088.61407618'], [1513384200000, '0.03877100', '0.03941600', '0.03874000', '0.03924000', '5154.12400000', 1513385999999, '201.26069935', 4831, '2234.50900000', '87.31290489', '467259.57386247'], [1513386000000, '0.03924000', '0.03994000', '0.03924000', '0.03987200', '6210.28800000', 1513387799999, '245.92295024', 5270, '2416.02500000', '95.77127904', '465972.16638191'], [1513387800000, '0.03987200', '0.04089800', '0.03987100', '0.04015800', '7026.88400000', 1513389599999, '283.11820739', 6009, '3106.62500000', '125.16740741', '465796.48131731'], [1513389600000, '0.04015700', '0.04060400', '0.04005600', '0.04054200', '4564.16700000', 1513391399999, '184.20671122', 4017, '2196.19300000', '88.62061644', '465376.84567615'], [1513391400000, '0.04054200', '0.04061100', '0.03989300', '0.04019700', '5229.77900000', 1513393199999, '210.54859587', 4966, '2769.29000000', '111.50238953', '463321.11539433'], [1513393200000, '0.04019200', '0.04036700', '0.04013900', '0.04024500', '4603.69000000', 1513394999999, '185.20703846', 4422, '2147.01500000', '86.40545617', '464103.93901771'], [1513395000000, '0.04020700', '0.04027900', '0.03983000', '0.03999600', '4677.77200000', 1513396799999, '187.60760772', 3371, '1720.83500000', '69.03558934', '463982.26701003'], [1513396800000, '0.03995600', '0.04003900', '0.03935000', '0.03947600', '3987.03700000', 1513398599999, '158.52040482', 3419, '1617.27900000', '64.31613877', '461446.04862297'], [1513398600000, '0.03947600', '0.03982400', '0.03938200', '0.03960600', '3929.60900000', 1513400399999, '155.58662430', 3168, '1449.30800000', '57.39123663', '459821.27093016'], [1513400400000, '0.03960700', '0.04000000', '0.03950100', '0.03976500', '2991.00300000', 1513402199999, '118.72322517', 2838, '1359.32800000', '53.97985168', '457898.87877220'], [1513402200000, '0.03972400', '0.03994900', '0.03962100', '0.03968800', '3887.43200000', 1513403999999, '154.63146634', 2791, '1675.87100000', '66.68306345', '456608.84132169'], [1513404000000, '0.03968200', '0.03976500', '0.03884000', '0.03887500', '4614.40200000', 1513405799999, '181.97020968', 3166, '1982.80500000', '78.14294830', '454057.67824256'], [1513405800000, '0.03887000', '0.03896900', '0.03800000', '0.03854500', '6346.86100000', 1513407599999, '244.28905379', 4453, '2943.97600000', '113.40939755', '454011.11308183'], [1513407600000, '0.03854100', '0.03854100', '0.03790900', '0.03791600', '5384.33500000', 1513409399999, '206.00815638', 3359, '2335.44800000', '89.49757701', '454658.24760348'], [1513409400000, '0.03791600', '0.03850000', '0.03760400', '0.03845000', '5917.88300000', 1513411199999, '224.93186024', 4333, '3445.35100000', '130.93762597', '454450.45965635'], [1513411200000, '0.03848800', '0.03926000', '0.03811300', '0.03917600', '4089.75400000', 1513412999999, '157.96087180', 3046, '1825.51400000', '70.49554451', '452827.56883607'], [1513413000000, '0.03920000', '0.03945500', '0.03860200', '0.03860300', '4333.40400000', 1513414799999, '169.31933381', 3308, '1804.49300000', '70.53287874', '452942.86859056'], [1513414800000, '0.03863900', '0.03889100', '0.03851000', '0.03864200', '4536.83900000', 1513416599999, '175.52502592', 3496, '2423.80500000', '93.79098681', '452583.49492818'], [1513416600000, '0.03864100', '0.03877100', '0.03850000', '0.03865800', '3919.55300000', 1513418399999, '151.56005088', 3343, '1703.46400000', '65.90709747', '453559.42486029'], [1513418400000, '0.03866000', '0.03900000', '0.03840000', '0.03843100', '3363.24800000', 1513420199999, '129.91602920', 3678, '1479.91700000', '57.18076762', '453852.93854878'], [1513420200000, '0.03850000', '0.03870000', '0.03840600', '0.03859000', '3824.03600000', 1513421999999, '147.52825466', 4042, '1786.04800000', '68.95165531', '454628.56800797'], [1513422000000, '0.03859100', '0.03916400', '0.03859100', '0.03896100', '4215.06200000', 1513423799999, '163.90959960', 4435, '2074.81500000', '80.69916147', '453285.99700884'], [1513423800000, '0.03896000', '0.03906400', '0.03857300', '0.03866600', '5225.09500000', 1513425599999, '203.01504665', 4510, '2094.94100000', '81.41976503', '453466.32224733'], [1513425600000, '0.03886800', '0.03900000', '0.03863100', '0.03877500', '2981.45100000', 1513427399999, '115.57734875', 3123, '1523.23000000', '59.07051793', '453934.95921041'], [1513427400000, '0.03884400', '0.03900000', '0.03861300', '0.03872500', '3464.04300000', 1513429199999, '134.62929225', 3389, '1671.82400000', '64.99668983', '454441.66576004'], [1513429200000, '0.03872600', '0.03879900', '0.03740000', '0.03746400', '5865.55900000', 1513430999999, '223.83845958', 4976, '2623.89500000', '100.16749576', '454539.26459702'], [1513431000000, '0.03754800', '0.03782600', '0.03700000', '0.03741700', '6216.22200000', 1513432799999, '232.54814803', 5813, '3145.41900000', '117.72824128', '453939.33395233'], [1513432800000, '0.03741700', '0.03761200', '0.03721700', '0.03722000', '4025.77900000', 1513434599999, '150.69719192', 3305, '1896.98500000', '71.05211190', '455112.14909951'], [1513434600000, '0.03722100', '0.03736800', '0.03669300', '0.03670100', '5071.88100000', 1513436399999, '187.79208278', 4365, '2469.72900000', '91.50920165', '456117.07878043'], [1513436400000, '0.03670200', '0.03702700', '0.03643600', '0.03672800', '5455.86400000', 1513438199999, '200.25862092', 4430, '2739.39600000', '100.62285313', '454051.85205468'], [1513438200000, '0.03672800', '0.03694300', '0.03568000', '0.03587700', '6771.52000000', 1513439999999, '245.19164390', 5302, '3283.60000000', '118.99534455', '455459.46445628'], [1513440000000, '0.03587600', '0.03710000', '0.03579800', '0.03691000', '7140.82400000', 1513441799999, '259.10775324', 5867, '3755.13900000', '136.31980321', '456737.52275516'], [1513441800000, '0.03694600', '0.03733100', '0.03599900', '0.03659600', '5422.71700000', 1513443599999, '199.73159659', 4768, '2746.17100000', '101.18547149', '457574.58446172'], [1513443600000, '0.03661900', '0.03682200', '0.03632100', '0.03654000', '4004.88500000', 1513445399999, '146.53002435', 3810, '2061.96000000', '75.46545325', '458780.04225626'], [1513445400000, '0.03654000', '0.03695000', '0.03645400', '0.03662500', '3437.85100000', 1513447199999, '125.96063624', 4395, '1842.77500000', '67.56175832', '463152.08794591'], [1513447200000, '0.03662800', '0.03674100', '0.03568000', '0.03660900', '7335.28600000', 1513448999999, '267.64867789', 5789, '3421.31500000', '125.01624118', '462416.13691230'], [1513449000000, '0.03666900', '0.03669700', '0.03623700', '0.03627200', '3340.91600000', 1513450799999, '121.73933409', 3002, '1477.77300000', '53.83561849', '463742.60963864'], [1513450800000, '0.03626500', '0.03627500', '0.03549600', '0.03558400', '5310.44300000', 1513452599999, '190.70172522', 4585, '2709.97300000', '97.39414768', '464757.49142404'], [1513452600000, '0.03554800', '0.03575200', '0.03489200', '0.03489400', '5403.38700000', 1513454399999, '190.90916723', 5027, '2787.49900000', '98.58540753', '464638.77316742'], [1513454400000, '0.03489500', '0.03563100', '0.03480000', '0.03518500', '5780.14200000', 1513456199999, '203.22898291', 5572, '2692.89900000', '94.74699468', '467893.54574169'], [1513456200000, '0.03518400', '0.03557900', '0.03510200', '0.03549300', '3154.51500000', 1513457999999, '111.65968327', 3990, '1722.75900000', '61.00443145', '469585.31023654'], [1513458000000, '0.03542500', '0.03605400', '0.03542000', '0.03589700', '4521.72000000', 1513459799999, '161.97660727', 4854, '2388.76100000', '85.58989157', '469565.21978386'], [1513459800000, '0.03589700', '0.03597700', '0.03539900', '0.03557600', '4120.15600000', 1513461599999, '147.00665269', 3456, '1842.79900000', '65.79845074', '470945.42147399'], [1513461600000, '0.03550100', '0.03566600', '0.03513300', '0.03530100', '3739.17900000', 1513463399999, '132.58296921', 3514, '1834.63700000', '65.08476077', '471772.67016167'], [1513463400000, '0.03526100', '0.03535800', '0.03493500', '0.03518500', '4982.06800000', 1513465199999, '174.98305974', 4067, '2367.82500000', '83.20978534', '472709.28986270'], [1513465200000, '0.03515300', '0.03542100', '0.03500000', '0.03505900', '4720.96700000', 1513466999999, '165.51650053', 4123, '1942.93600000', '68.17144344', '473891.65661472'], [1513467000000, '0.03505400', '0.03579100', '0.03500000', '0.03556100', '6533.71500000', 1513468799999, '231.10589212', 4843, '2723.06100000', '96.37366095', '474585.69465775'], [1513468800000, '0.03556000', '0.03660000', '0.03553200', '0.03641500', '7367.39600000', 1513470599999, '266.31894682', 6989, '3447.08500000', '124.67334683', '475162.78533581'], [1513470600000, '0.03641500', '0.03700000', '0.03630000', '0.03674100', '6247.25800000', 1513472399999, '228.90214527', 5224, '3177.70900000', '116.43666346', '475548.83676378'], [1513472400000, '0.03677000', '0.03726800', '0.03666600', '0.03692600', '5583.46300000', 1513474199999, '205.95198268', 5628, '2730.31500000', '100.80216936', '476451.27061774'], [1513474200000, '0.03692900', '0.03750000', '0.03691100', '0.03706800', '6526.14300000', 1513475999999, '243.08334208', 5905, '3451.62300000', '128.63530712', '477486.49047697'], [1513476000000, '0.03706800', '0.03744500', '0.03655000', '0.03662500', '5548.55300000', 1513477799999, '205.21378301', 6486, '2911.10800000', '107.76502963', '476430.07821744'], [1513477800000, '0.03662500', '0.03721500', '0.03655800', '0.03700000', '6519.87800000', 1513479599999, '240.67882466', 7629, '3308.20200000', '122.22518122', '474488.64436864'], [1513479600000, '0.03700000', '0.03714600', '0.03632600', '0.03681900', '7356.00700000', 1513481399999, '270.43444758', 6929, '4213.83100000', '155.00727764', '478789.19263105'], [1513481400000, '0.03681900', '0.03751000', '0.03671000', '0.03740100', '6266.87000000', 1513483199999, '232.08330683', 6116, '3204.42300000', '118.65847181', '478451.85806680'], [1513483200000, '0.03737900', '0.03779900', '0.03725000', '0.03764500', '7219.40100000', 1513484999999, '271.06423011', 7003, '3412.72300000', '128.19506405', '478058.61548906'], [1513485000000, '0.03767900', '0.03799000', '0.03742500', '0.03757500', '4982.36200000', 1513486799999, '188.09220328', 5626, '2253.30200000', '85.07758214', '479417.61441394'], [1513486800000, '0.03763600', '0.03785200', '0.03743600', '0.03765300', '5398.70300000', 1513488599999, '203.28059414', 6560, '2833.41800000', '106.74341749', '480460.21716944'], [1513488600000, '0.03765300', '0.03777000', '0.03703300', '0.03720200', '6289.46700000', 1513490399999, '235.60034621', 6852, '2957.79500000', '110.77367525', '481410.68301861'], [1513490400000, '0.03720200', '0.03773300', '0.03706600', '0.03731000', '6469.96700000', 1513492199999, '241.90069120', 7767, '3130.72500000', '117.14405079', '481878.27762444'], [1513492200000, '0.03731600', '0.03740000', '0.03689500', '0.03703300', '4859.98700000', 1513493999999, '180.54326846', 6040, '2454.43200000', '91.23758036', '482900.95568347'], [1513494000000, '0.03703300', '0.03722000', '0.03628300', '0.03633800', '5132.42000000', 1513495799999, '188.16726928', 5156, '2728.39500000', '100.08726943', '483948.39319904'], [1513495800000, '0.03641500', '0.03687800', '0.03625000', '0.03658900', '5955.37600000', 1513497599999, '217.58210833', 5740, '3257.93800000', '119.08801390', '483800.22108379'], [1513497600000, '0.03661000', '0.03685300', '0.03644600', '0.03661900', '4063.34300000', 1513499399999, '148.58743706', 4507, '1850.59200000', '67.69731042', '485723.35457661'], [1513499400000, '0.03661900', '0.03690100', '0.03657200', '0.03683500', '3999.07900000', 1513501199999, '146.97537353', 4476, '1869.51300000', '68.73552161', '486425.26765584'], [1513501200000, '0.03683500', '0.03690000', '0.03640000', '0.03645100', '4472.22400000', 1513502999999, '164.10035124', 4732, '2188.10000000', '80.30334640', '485882.77018633'], [1513503000000, '0.03645100', '0.03669500', '0.03637300', '0.03650100', '3724.39600000', 1513504799999, '136.11546685', 4286, '1689.15600000', '61.76362757', '485524.72180691'], [1513504800000, '0.03638500', '0.03679200', '0.03636100', '0.03661000', '3913.21800000', 1513506599999, '143.09965739', 5517, '1896.49100000', '69.38766641', '485983.05295914'], [1513506600000, '0.03660400', '0.03673000', '0.03631100', '0.03640600', '4646.33100000', 1513508399999, '169.61208498', 4858, '2271.05300000', '82.93294624', '486302.81619189'], [1513508400000, '0.03640600', '0.03653700', '0.03614500', '0.03620600', '4792.03900000', 1513510199999, '174.00638076', 4678, '2233.82300000', '81.14498947', '486473.77758216'], [1513510200000, '0.03620700', '0.03647000', '0.03600300', '0.03606400', '5019.92400000', 1513511999999, '181.80121753', 5111, '2332.66200000', '84.49895799', '485679.73404510'], [1513512000000, '0.03610000', '0.03612800', '0.03569900', '0.03596600', '5249.75200000', 1513513799999, '188.65543543', 5585, '2297.19700000', '82.58267932', '486050.17232568'], [1513513800000, '0.03596600', '0.03639100', '0.03583300', '0.03623700', '4911.15200000', 1513515599999, '177.02948386', 5585, '2272.24400000', '81.93493311', '484856.64188267'], [1513515600000, '0.03623600', '0.03648600', '0.03590000', '0.03599600', '4822.74900000', 1513517399999, '174.63720877', 5593, '2226.12800000', '80.65230811', '484779.64753560'], [1513517400000, '0.03596000', '0.03610000', '0.03589400', '0.03607000', '4160.67500000', 1513519199999, '149.67852315', 5120, '1955.63200000', '70.38620880', '485644.59363781'], [1513519200000, '0.03607200', '0.03633900', '0.03604500', '0.03620400', '4587.60000000', 1513520999999, '165.94230658', 4911, '2115.67600000', '76.55709513', '485160.60923641'], [1513521000000, '0.03620400', '0.03664400', '0.03616600', '0.03660900', '5403.91800000', 1513522799999, '196.34136290', 5271, '2380.53600000', '86.53038482', '484924.80491739'], [1513522800000, '0.03660900', '0.03700000', '0.03631200', '0.03699900', '4205.26300000', 1513524599999, '153.99238090', 4981, '1975.25400000', '72.36609024', '484323.08969009'], [1513524600000, '0.03699900', '0.03703300', '0.03664100', '0.03664100', '4140.69900000', 1513526399999, '152.41172246', 4636, '2256.22900000', '83.08261350', '485668.70118741'], [1513526400000, '0.03664100', '0.03692400', '0.03652800', '0.03691200', '4560.35000000', 1513528199999, '167.37278421', 5609, '2259.10200000', '82.92735545', '485927.08718653'], [1513528200000, '0.03683800', '0.03694800', '0.03670000', '0.03683000', '4743.35200000', 1513529999999, '174.79211996', 5139, '2559.15900000', '94.33265215', '486769.90661575'], [1513530000000, '0.03683100', '0.03699900', '0.03660200', '0.03682700', '4183.39800000', 1513531799999, '153.99471807', 4344, '2048.54500000', '75.40103621', '487224.09243211'], [1513531800000, '0.03682700', '0.03690200', '0.03662200', '0.03689000', '3703.58600000', 1513533599999, '136.28030358', 4894, '2212.21100000', '81.43996087', '487770.47961989'], [1513533600000, '0.03689000', '0.03732600', '0.03685500', '0.03729900', '4410.29300000', 1513535399999, '163.99067739', 5508, '1983.26500000', '73.78936759', '489843.54705734'], [1513535400000, '0.03730000', '0.03842100', '0.03725500', '0.03833200', '5912.13100000', 1513537199999, '222.13424481', 6959, '3211.07900000', '120.58369183', '489366.21967643'], [1513537200000, '0.03833300', '0.03860500', '0.03766500', '0.03839500', '6387.56200000', 1513538999999, '244.11166471', 5595, '2812.53300000', '107.42703322', '489446.85502782'], [1513539000000, '0.03839400', '0.03847600', '0.03775800', '0.03783600', '4686.24900000', 1513540799999, '178.90420305', 5486, '2358.25900000', '90.01722680', '487550.35204930'], [1513540800000, '0.03783600', '0.03795000', '0.03710100', '0.03746600', '5033.78100000', 1513542599999, '188.69837059', 5535, '2485.93400000', '93.22596809', '488615.11644702'], [1513542600000, '0.03746600', '0.03777700', '0.03737800', '0.03777500', '3723.04600000', 1513544399999, '139.99269611', 4358, '1809.18600000', '68.03900540', '490289.25005455'], [1513544400000, '0.03770000', '0.03799500', '0.03768800', '0.03795200', '4201.15500000', 1513546199999, '159.05855256', 4309, '2006.56000000', '76.00247104', '491048.57441230'], [1513546200000, '0.03795200', '0.03838100', '0.03794300', '0.03825900', '4253.52400000', 1513547999999, '162.20273137', 5364, '2035.04400000', '77.64020672', '490180.87930352'], [1513548000000, '0.03829000', '0.03839900', '0.03747700', '0.03762700', '4633.41200000', 1513549799999, '176.34796460', 4741, '1951.29100000', '74.23166865', '490891.47879105'], [1513549800000, '0.03762700', '0.03774800', '0.03680100', '0.03702500', '5009.07300000', 1513551599999, '186.03884789', 5177, '2265.45500000', '84.21309626', '491341.43038089'], [1513551600000, '0.03702300', '0.03780900', '0.03679600', '0.03744100', '5721.06600000', 1513553399999, '214.00710714', 5661, '2800.15100000', '104.77895623', '491784.38828225'], [1513553400000, '0.03740300', '0.03761700', '0.03728600', '0.03744800', '2295.67200000', 1513555199999, '85.94828056', 3414, '1157.71600000', '43.36107774', '492287.64610709'], [1513555200000, '0.03734300', '0.03800000', '0.03734300', '0.03793500', '4183.24000000', 1513556999999, '157.75638306', 4677, '2090.52800000', '78.88514814', '492555.11520947'], [1513557000000, '0.03793500', '0.03831400', '0.03770200', '0.03809200', '6182.06600000', 1513558799999, '235.20570742', 6470, '3246.51000000', '123.55813092', '491980.38584634'], [1513558800000, '0.03811500', '0.03819800', '0.03717600', '0.03761300', '8904.46100000', 1513560599999, '335.60677952', 9050, '3909.79200000', '147.42600071', '491160.82184864'], [1513560600000, '0.03761300', '0.03800000', '0.03750000', '0.03762600', '6010.16800000', 1513562399999, '226.48191907', 6470, '3040.33900000', '114.65032522', '491429.18121522'], [1513562400000, '0.03764900', '0.03772700', '0.03750000', '0.03771500', '3449.63200000', 1513564199999, '129.70530156', 4244, '1873.45400000', '70.46375597', '490209.59716529'], [1513564200000, '0.03771500', '0.03800000', '0.03760200', '0.03793500', '4579.65300000', 1513565999999, '173.28183797', 5435, '2041.85200000', '77.29986352', '491324.81618290'], [1513566000000, '0.03793500', '0.03820900', '0.03777700', '0.03802100', '5080.82500000', 1513567799999, '193.15504216', 4760, '2162.79900000', '82.22142709', '490752.04254304'], [1513567800000, '0.03809500', '0.03820000', '0.03794200', '0.03802700', '4975.57500000', 1513569599999, '189.33503345', 3975, '2222.68000000', '84.60829783', '489948.44987585'], [1513569600000, '0.03802600', '0.03809900', '0.03769200', '0.03770700', '4633.86100000', 1513571399999, '175.54334966', 4655, '2354.90600000', '89.25388916', '492384.73326415'], [1513571400000, '0.03775100', '0.03779700', '0.03730000', '0.03759800', '4642.48900000', 1513573199999, '174.68381174', 4318, '2090.86200000', '78.72377515', '496928.21011923'], [1513573200000, '0.03758100', '0.03787400', '0.03726200', '0.03766900', '7661.99000000', 1513574999999, '288.73072549', 7776, '3645.59600000', '137.46457960', '500877.31396664'], [1513575000000, '0.03769000', '0.03774500', '0.03707400', '0.03753300', '7792.76500000', 1513576799999, '292.45706604', 7645, '4203.62800000', '157.93194346', '502060.20147455'], [1513576800000, '0.03753300', '0.03781000', '0.03699500', '0.03733100', '7311.19700000', 1513578599999, '273.80756237', 6242, '3582.06200000', '134.22783568', '503772.13245657'], [1513578600000, '0.03736600', '0.03770800', '0.03723400', '0.03753000', '5445.98500000', 1513580399999, '204.02307801', 6318, '2321.66700000', '86.99334768', '505596.13681907'], [1513580400000, '0.03753100', '0.03776000', '0.03738700', '0.03758500', '6110.24300000', 1513582199999, '229.34033816', 6296, '3042.42100000', '114.24490650', '508310.32533552'], [1513582200000, '0.03758500', '0.03786000', '0.03749900', '0.03772400', '5506.55700000', 1513583999999, '207.20379114', 5074, '2938.72800000', '110.62619955', '509770.84322182'], [1513584000000, '0.03769100', '0.03798000', '0.03756100', '0.03787700', '6186.45000000', 1513585799999, '233.74070102', 7074, '3181.91500000', '120.28742876', '510551.54569678'], [1513585800000, '0.03791500', '0.03819900', '0.03776900', '0.03796400', '9346.85400000', 1513587599999, '354.72261150', 10223, '4906.11700000', '186.30443174', '511653.86100811'], [1513587600000, '0.03793600', '0.03859900', '0.03752100', '0.03812600', '9047.80300000', 1513589399999, '344.78202701', 9469, '4687.78800000', '178.78410116', '514800.17151086'], [1513589400000, '0.03806500', '0.03844900', '0.03801300', '0.03819000', '4841.24700000', 1513591199999, '184.54635058', 4880, '2714.53300000', '103.50838947', '516190.83332280'], [1513591200000, '0.03819300', '0.03859700', '0.03815400', '0.03845200', '4131.99900000', 1513592999999, '158.53061291', 3879, '2167.00000000', '83.18134448', '518214.65324042'], [1513593000000, '0.03845200', '0.03888800', '0.03840100', '0.03880400', '10829.36900000', 1513594799999, '417.90649473', 7938, '5055.19900000', '195.01026033', '534895.72151026'], [1513594800000, '0.03880400', '0.03920000', '0.03860100', '0.03888500', '12346.75600000', 1513596599999, '479.98031275', 8424, '5807.03300000', '225.79412770', '538166.43206380'], [1513596600000, '0.03888500', '0.03940000', '0.03850000', '0.03855300', '10311.65600000', 1513598399999, '402.66191645', 8446, '5230.26400000', '204.36250013', '544546.73283808'], [1513598400000, '0.03858600', '0.03980000', '0.03803000', '0.03839100', '10603.53700000', 1513600153231, '407.39974539', 7521, '5074.80500000', '195.34579578', '545054.38538438'], [1513603800000, '0.03839100', '0.04000000', '0.03780000', '0.03858600', '12391.33100000', 1513605599999, '476.91779802', 11575, '6549.00300000', '252.81911317', '0'], [1513605600000, '0.03858600', '0.03898000', '0.03836200', '0.03883400', '9011.66600000', 1513607399999, '348.58683863', 9330, '3984.58900000', '154.18203786', '0'], [1513607400000, '0.03879900', '0.03888800', '0.03865200', '0.03880100', '7196.85700000', 1513609199999, '279.09177090', 6675, '3496.71500000', '135.65314083', '0'], [1513609200000, '0.03882500', '0.03890200', '0.03853100', '0.03858500', '6520.53600000', 1513610999999, '252.69228636', 6756, '3214.03500000', '124.61315214', '0'], [1513611000000, '0.03858700', '0.03890000', '0.03857300', '0.03870300', '6135.25000000', 1513612799999, '237.63537060', 6360, '2884.46900000', '111.78051519', '0'], [1513612800000, '0.03873700', '0.03927400', '0.03865500', '0.03919500', '6683.24400000', 1513614599999, '260.50659645', 6791, '3184.28100000', '124.15358646', '0'], [1513614600000, '0.03919500', '0.03970000', '0.03913100', '0.03960700', '6330.04600000', 1513616399999, '249.36950735', 5731, '2708.03200000', '106.68175686', '0'], [1513616400000, '0.03960700', '0.03980000', '0.03934500', '0.03955100', '6268.95700000', 1513618199999, '248.03881502', 5353, '3514.14000000', '139.06903820', '0'], [1513618200000, '0.03955100', '0.03980000', '0.03940100', '0.03960100', '5126.77300000', 1513619999999, '203.15643943', 4890, '2376.12400000', '94.18886129', '0'], [1513620000000, '0.03964200', '0.04015900', '0.03939200', '0.04015400', '6039.18000000', 1513621799999, '240.90660340', 6086, '2717.06700000', '108.45091980', '0'], [1513621800000, '0.04012400', '0.04150000', '0.04004600', '0.04099900', '10270.38300000', 1513623599999, '420.76517783', 8104, '3870.84100000', '158.57233299', '0'], [1513623600000, '0.04099800', '0.04136300', '0.04084400', '0.04116700', '7237.29600000', 1513625399999, '297.42867863', 6352, '3243.19700000', '133.32626328', '0'], [1513625400000, '0.04116700', '0.04130700', '0.04100200', '0.04116100', '4789.54500000', 1513627199999, '197.08669139', 5413, '2317.92200000', '95.41142896', '0'], [1513627200000, '0.04116100', '0.04249800', '0.04104600', '0.04203300', '9565.36800000', 1513628999999, '400.96974992', 9968, '4077.62900000', '170.74375909', '0'], [1513629000000, '0.04206000', '0.04218800', '0.04120000', '0.04133500', '7247.26900000', 1513630799999, '302.47818213', 8294, '3365.25000000', '140.49222825', '0'], [1513630800000, '0.04132500', '0.04193600', '0.04122500', '0.04186400', '4428.52600000', 1513632599999, '183.89483731', 7084, '1916.41700000', '79.61490825', '0'], [1513632600000, '0.04180800', '0.04280000', '0.04170000', '0.04263800', '7166.63200000', 1513634399999, '302.57558210', 7601, '3318.76800000', '140.16073121', '0'], [1513634400000, '0.04260900', '0.04279300', '0.04230000', '0.04259200', '5661.81400000', 1513636199999, '240.89389379', 6379, '2556.77400000', '108.78422184', '0'], [1513636200000, '0.04253400', '0.04311200', '0.04210000', '0.04213100', '6849.24700000', 1513637999999, '293.04425144', 7048, '3079.38700000', '131.74884903', '0'], [1513638000000, '0.04213000', '0.04216200', '0.04079800', '0.04177700', '8116.40500000', 1513639799999, '336.47716894', 8018, '4036.81500000', '167.31999008', '0'], [1513639800000, '0.04177700', '0.04192400', '0.04147300', '0.04156900', '4735.96900000', 1513641599999, '197.40852929', 5311, '2520.88700000', '105.10141542', '0'], [1513641600000, '0.04153000', '0.04161000', '0.04095700', '0.04127300', '5713.83700000', 1513643399999, '235.69101482', 7235, '2820.91000000', '116.42575649', '0'], [1513643400000, '0.04128800', '0.04170000', '0.04127300', '0.04161800', '5165.82700000', 1513645199999, '213.97985122', 7348, '2713.70400000', '112.43867359', '0'], [1513645200000, '0.04151500', '0.04232000', '0.04150500', '0.04219100', '7295.36800000', 1513646999999, '305.44055036', 8909, '3544.47900000', '148.49430910', '0'], [1513647000000, '0.04225100', '0.04289600', '0.04218000', '0.04289300', '7212.37700000', 1513648799999, '306.35887536', 8031, '3113.95300000', '132.34926928', '0'], [1513648800000, '0.04276200', '0.04366600', '0.04272100', '0.04350600', '9533.02200000', 1513650599999, '410.24432241', 10216, '3821.18600000', '164.46846324', '0'], [1513650600000, '0.04350600', '0.04390000', '0.04300900', '0.04369900', '9555.47200000', 1513652399999, '415.53725350', 9330, '4143.68100000', '180.14678571', '0'], [1513652400000, '0.04358300', '0.04377500', '0.04318100', '0.04335800', '8205.57100000', 1513654199999, '356.45836766', 9621, '4106.00900000', '178.48393576', '0'], [1513654200000, '0.04337100', '0.04400000', '0.04290000', '0.04322400', '6873.90000000', 1513655999999, '296.73581205', 8245, '3209.53100000', '138.73006833', '0'], [1513656000000, '0.04324900', '0.04400000', '0.04315100', '0.04386000', '7064.96800000', 1513657799999, '307.67832723', 7625, '3131.83100000', '136.44265360', '0'], [1513657800000, '0.04386000', '0.04390000', '0.04340000', '0.04365000', '6638.79900000', 1513659599999, '289.50276158', 7769, '3047.36200000', '132.93752984', '0'], [1513659600000, '0.04354600', '0.04372100', '0.04340500', '0.04352600', '5331.73000000', 1513661399999, '232.43217825', 6638, '2125.44900000', '92.68717742', '0'], [1513661400000, '0.04352500', '0.04422500', '0.04342100', '0.04412300', '7255.69200000', 1513663199999, '317.36158044', 8104, '3314.43900000', '145.01014941', '0'], [1513663200000, '0.04413100', '0.04495600', '0.04413100', '0.04461000', '8438.33300000', 1513664999999, '375.11172267', 10518, '3852.75000000', '171.38530893', '0'], [1513665000000, '0.04456000', '0.04529800', '0.04449000', '0.04520000', '9318.85700000', 1513666799999, '418.16937185', 10629, '4441.64300000', '199.41365323', '0'], [1513666800000, '0.04520000', '0.04544900', '0.04478300', '0.04491500', '8453.04000000', 1513668599999, '381.79869994', 9362, '4132.06500000', '186.64296527', '0'], [1513668600000, '0.04501200', '0.04532600', '0.04438000', '0.04493800', '7822.59600000', 1513670399999, '351.36447495', 8369, '3763.32800000', '169.14971661', '0'], [1513670400000, '0.04492100', '0.04518000', '0.04480700', '0.04505400', '5212.18900000', 1513672199999, '234.38566742', 6612, '2307.52000000', '103.80603428', '0'], [1513672200000, '0.04504200', '0.04590000', '0.04502200', '0.04582500', '6336.06700000', 1513673999999, '288.62248384', 6630, '2695.49200000', '122.84594149', '0'], [1513674000000, '0.04582300', '0.04622000', '0.04563400', '0.04613500', '6214.29100000', 1513675799999, '285.09553529', 6812, '2583.93100000', '118.63879898', '0'], [1513675800000, '0.04613500', '0.04699500', '0.04550100', '0.04620200', '8275.26100000', 1513677599999, '383.52695124', 9969, '3397.51300000', '157.53791751', '0'], [1513677600000, '0.04622800', '0.04630000', '0.04404400', '0.04503700', '13239.73700000', 1513679399999, '595.88378880', 13909, '5604.26800000', '252.37534222', '0'], [1513679400000, '0.04522900', '0.04588000', '0.04417500', '0.04488600', '10438.45100000', 1513681199999, '468.13735112', 10521, '4511.18000000', '202.40855841', '0'], [1513681200000, '0.04491400', '0.04559800', '0.04480700', '0.04532600', '7816.85500000', 1513682999999, '352.86129031', 8698, '3364.82400000', '151.90166684', '0'], [1513683000000, '0.04533100', '0.04618100', '0.04531000', '0.04598200', '9580.72800000', 1513684799999, '439.04415038', 10545, '4308.55400000', '197.64240152', '0'], [1513684800000, '0.04598200', '0.04650000', '0.04500100', '0.04502000', '7356.51300000', 1513686599999, '335.03442532', 7871, '3851.06700000', '175.27759191', '0'], [1513686600000, '0.04502000', '0.04580000', '0.04499300', '0.04540000', '4715.31600000', 1513688399999, '213.27516199', 5802, '2308.32100000', '104.48760305', '0'], [1513688400000, '0.04539400', '0.04593300', '0.04526400', '0.04581700', '5947.35400000', 1513690199999, '271.01557322', 6251, '2870.78300000', '130.89471499', '0'], [1513690200000, '0.04593000', '0.04662000', '0.04581100', '0.04659700', '6573.48100000', 1513691999999, '303.71776776', 6586, '2742.59100000', '126.74712956', '0'], [1513692000000, '0.04659700', '0.04699000', '0.04652200', '0.04671500', '7218.65100000', 1513693799999, '337.42502613', 6757, '3458.73800000', '161.71094450', '0'], [1513693800000, '0.04671600', '0.04682400', '0.04602900', '0.04625200', '7478.21900000', 1513695599999, '347.41929804', 9257, '3273.41800000', '152.17674541', '0'], [1513695600000, '0.04628400', '0.04628400', '0.04500000', '0.04564100', '8981.79200000', 1513697399999, '409.30232956', 9160, '4122.40400000', '187.88178798', '0'], [1513697400000, '0.04564500', '0.04630000', '0.04563000', '0.04590000', '5041.79800000', 1513699199999, '231.52207933', 6997, '2460.29900000', '112.99068572', '0'], [1513699200000, '0.04593900', '0.04599900', '0.04557500', '0.04565600', '5538.58900000', 1513700999999, '253.75384001', 7271, '2818.92100000', '129.20413762', '0'], [1513701000000, '0.04566700', '0.04581500', '0.04544000', '0.04544600', '6115.82100000', 1513702799999, '278.98843910', 7124, '3085.26900000', '140.79897398', '0'], [1513702800000, '0.04544700', '0.04584200', '0.04485400', '0.04579600', '6196.31300000', 1513704599999, '282.07918949', 6875, '2578.80400000', '117.55717079', '0'], [1513704600000, '0.04579600', '0.04600000', '0.04551400', '0.04562900', '5536.52400000', 1513706399999, '253.17202655', 8089, '2746.78100000', '125.66487689', '0'], [1513706400000, '0.04562900', '0.04584500', '0.04546800', '0.04573000', '4842.39500000', 1513708199999, '221.23003269', 7114, '2208.16500000', '100.91479508', '0'], [1513708200000, '0.04573000', '0.04600600', '0.04560000', '0.04587500', '5582.93800000', 1513709999999, '256.02794645', 6873, '2555.13200000', '117.21488174', '0'], [1513710000000, '0.04587500', '0.04642000', '0.04578500', '0.04632900', '4396.22700000', 1513711799999, '202.73275152', 6872, '2203.95500000', '101.63452572', '0'], [1513711800000, '0.04631600', '0.04657500', '0.04610000', '0.04650000', '5452.63900000', 1513713599999, '252.82203347', 6104, '2404.65800000', '111.52894798', '0'], [1513713600000, '0.04645900', '0.04675000', '0.04610000', '0.04644400', '5740.97100000', 1513715399999, '266.63499021', 7689, '2840.97100000', '131.96285740', '0'], [1513715400000, '0.04644400', '0.04664900', '0.04641000', '0.04646000', '3594.15700000', 1513717199999, '167.28611145', 5207, '1795.43800000', '83.60503892', '0'], [1513717200000, '0.04645700', '0.04660000', '0.04570000', '0.04603300', '4296.57300000', 1513718999999, '198.70905036', 6228, '2308.07800000', '106.83753863', '0'], [1513719000000, '0.04603300', '0.04618300', '0.04547000', '0.04573400', '4676.12500000', 1513720799999, '214.19004051', 6952, '2070.37100000', '94.89682742', '0'], [1513720800000, '0.04565600', '0.04700000', '0.04547000', '0.04609500', '4789.34700000', 1513722599999, '219.98688009', 6314, '2296.41600000', '105.66846990', '0'], [1513722600000, '0.04611900', '0.04640000', '0.04573200', '0.04622500', '3188.52600000', 1513724399999, '147.04754701', 4769, '1608.55400000', '74.22195201', '0'], [1513724400000, '0.04622500', '0.04648100', '0.04604400', '0.04628600', '2795.77700000', 1513726199999, '129.20555380', 4844, '1557.26500000', '71.99193894', '0'], [1513726200000, '0.04624500', '0.04650000', '0.04616000', '0.04621200', '4589.74400000', 1513727999999, '212.68030519', 6067, '2290.72700000', '106.19134393', '0'], [1513728000000, '0.04622900', '0.04649900', '0.04501000', '0.04560900', '9781.11700000', 1513729799999, '447.23818913', 11829, '4584.64300000', '209.63981890', '0'], [1513729800000, '0.04549000', '0.04578000', '0.04400000', '0.04508300', '19069.50700000', 1513731599999, '859.27344278', 19218, '7962.20600000', '359.25499728', '0'], [1513731600000, '0.04510900', '0.04650000', '0.04500000', '0.04592700', '14539.62900000', 1513733399999, '663.86898623', 13703, '6996.24100000', '319.50972884', '0'], [1513733400000, '0.04592700', '0.04696500', '0.04529700', '0.04641400', '11882.79500000', 1513735199999, '549.03857062', 13277, '6561.94100000', '303.53000467', '0'], [1513735200000, '0.04641400', '0.04685600', '0.04610400', '0.04666000', '13357.05400000', 1513736999999, '621.54828547', 14334, '5749.63800000', '267.71321696', '0'], [1513737000000, '0.04665900', '0.04700800', '0.04600000', '0.04615600', '8446.68000000', 1513738799999, '394.24698190', 10692, '3906.14200000', '182.40269128', '0'], [1513738800000, '0.04610600', '0.04654400', '0.04603500', '0.04630000', '7657.46600000', 1513740599999, '354.42656110', 9827, '3657.13200000', '169.35671620', '0'], [1513740600000, '0.04630100', '0.04668000', '0.04622300', '0.04660700', '5817.09700000', 1513742399999, '270.45202875', 7400, '2648.49400000', '123.18144384', '0'], [1513742400000, '0.04660700', '0.04680000', '0.04602700', '0.04627000', '6612.00200000', 1513744199999, '307.01450959', 7731, '2788.65900000', '129.55769957', '0'], [1513744200000, '0.04627000', '0.04650000', '0.04615200', '0.04645300', '4240.14500000', 1513745999999, '196.46627310', 6441, '2199.87700000', '101.96099298', '0'], [1513746000000, '0.04645300', '0.04702000', '0.04640000', '0.04684300', '4702.77600000', 1513747799999, '219.37507385', 5968, '2260.21800000', '105.47811560', '0'], [1513747800000, '0.04684300', '0.04700000', '0.04660500', '0.04691600', '5673.86800000', 1513749599999, '265.62591102', 6346, '2736.63000000', '128.17361741', '0'], [1513749600000, '0.04691600', '0.04695800', '0.04650000', '0.04675900', '7298.08400000', 1513751399999, '340.99416287', 8324, '3701.97700000', '173.03607815', '0'], [1513751400000, '0.04675900', '0.04699200', '0.04639500', '0.04669500', '7449.02900000', 1513753199999, '348.09723464', 8526, '3700.06800000', '173.03953391', '0'], [1513753200000, '0.04675800', '0.04698900', '0.04620800', '0.04640600', '5998.79300000', 1513754999999, '280.26602132', 6415, '2234.31700000', '104.40047179', '0'], [1513755000000, '0.04639600', '0.04679900', '0.04625200', '0.04673600', '4404.82600000', 1513756799999, '204.75606957', 5027, '2048.43300000', '95.24162708', '0'], [1513756800000, '0.04678000', '0.04710100', '0.04669400', '0.04704100', '5017.70800000', 1513758599999, '235.19768474', 5351, '2390.35200000', '112.09141349', '0'], [1513758600000, '0.04704100', '0.04722000', '0.04685900', '0.04709700', '5370.45300000', 1513760399999, '252.98027620', 5313, '2267.35600000', '106.83743137', '0'], [1513760400000, '0.04700600', '0.04719400', '0.04700000', '0.04716000', '5033.41900000', 1513762199999, '237.18265616', 5574, '2451.06900000', '115.54263696', '0'], [1513762200000, '0.04719100', '0.04740000', '0.04700100', '0.04706100', '4314.64300000', 1513763999999, '203.28944555', 5582, '2147.99800000', '101.24354112', '0'], [1513764000000, '0.04711600', '0.04715600', '0.04665000', '0.04671000', '5360.76300000', 1513765799999, '251.47657865', 6143, '2208.16700000', '103.65612579', '0'], [1513765800000, '0.04671100', '0.04683900', '0.04635400', '0.04655200', '5908.83600000', 1513767599999, '275.45710011', 8211, '3244.23000000', '151.26915802', '0'], [1513767600000, '0.04655200', '0.04700000', '0.04645100', '0.04674200', '6116.17700000', 1513769399999, '286.04582073', 7123, '2621.71600000', '122.67116130', '0'], [1513769400000, '0.04678000', '0.04690700', '0.04641200', '0.04669000', '5454.82500000', 1513771199999, '254.42531432', 6821, '2406.13100000', '112.28030090', '0'], [1513771200000, '0.04669000', '0.04700000', '0.04661300', '0.04694100', '6800.05100000', 1513772999999, '318.55272648', 7867, '2747.62800000', '128.78518428', '0'], [1513773000000, '0.04698100', '0.04699700', '0.04641400', '0.04652000', '6742.70600000', 1513774799999, '315.24558265', 7359, '3093.17400000', '144.67272994', '0'], [1513774800000, '0.04652000', '0.04690000', '0.04651400', '0.04656000', '5659.37500000', 1513776599999, '264.17970179', 6698, '2638.20300000', '123.21759150', '0'], [1513776600000, '0.04656000', '0.04687000', '0.04627400', '0.04681600', '6796.13900000', 1513778399999, '316.92903788', 7895, '3382.46900000', '157.86491529', '0'], [1513778400000, '0.04681600', '0.04690000', '0.04642000', '0.04647800', '5575.97500000', 1513780199999, '260.29950061', 6517, '2640.69100000', '123.35612197', '0'], [1513780200000, '0.04660000', '0.04690000', '0.04636800', '0.04689800', '5197.16300000', 1513781999999, '242.27349961', 5931, '2844.56700000', '132.60759575', '0'], [1513782000000, '0.04685200', '0.04820800', '0.04683900', '0.04794900', '8600.88000000', 1513783799999, '407.84847236', 8236, '4902.43000000', '232.14276298', '0'], [1513783800000, '0.04795000', '0.04845200', '0.04794900', '0.04811700', '6639.91900000', 1513785599999, '320.40665337', 6922, '2936.47500000', '141.77702558', '0'], [1513785600000, '0.04800100', '0.04811600', '0.04710000', '0.04766200', '6202.20600000', 1513787399999, '295.73187199', 6301, '2720.42200000', '129.82662264', '0'], [1513787400000, '0.04766200', '0.04797700', '0.04740000', '0.04741000', '6971.08000000', 1513789199999, '332.41791716', 7082, '3393.31000000', '161.94519983', '0'], [1513789200000, '0.04766800', '0.04806100', '0.04741000', '0.04775200', '5380.94900000', 1513790999999, '256.76288576', 5745, '2731.62500000', '130.42606447', '0'], [1513791000000, '0.04773200', '0.04781600', '0.04677300', '0.04738500', '4855.70400000', 1513792799999, '230.63768406', 4975, '1713.89000000', '81.53212251', '0'], [1513792800000, '0.04738500', '0.04783500', '0.04725500', '0.04771100', '3935.98600000', 1513794599999, '187.25025389', 4778, '1940.54100000', '92.39289965', '0'], [1513794600000, '0.04771600', '0.04840000', '0.04771600', '0.04786300', '3787.42300000', 1513796399999, '181.76948407', 4557, '1590.89100000', '76.41769394', '0'], [1513796400000, '0.04790500', '0.04825700', '0.04752500', '0.04788000', '4100.70300000', 1513798199999, '196.59797602', 5088, '1627.46500000', '78.08707685', '0'], [1513798200000, '0.04788000', '0.04845000', '0.04767000', '0.04793300', '5055.64400000', 1513799999999, '242.50173434', 6048, '2274.79300000', '109.18801435', '0'], [1513800000000, '0.04817700', '0.04900000', '0.04791000', '0.04834900', '5454.34900000', 1513801799999, '263.57697742', 6736, '2507.68300000', '121.29399048', '0'], [1513801800000, '0.04832200', '0.04890000', '0.04815100', '0.04843400', '5810.50600000', 1513803599999, '281.27343789', 7211, '2365.29600000', '114.59697163', '0'], [1513803600000, '0.04843400', '0.04900000', '0.04788200', '0.04806600', '5283.50900000', 1513805399999, '254.29928645', 6282, '2386.68400000', '114.91167061', '0'], [1513805400000, '0.04811300', '0.04853000', '0.04784700', '0.04831500', '5736.03500000', 1513807199999, '276.71059276', 6345, '2470.85900000', '119.26964887', '0'], [1513807200000, '0.04831600', '0.04898900', '0.04814000', '0.04872400', '5328.73200000', 1513808999999, '258.81190160', 6029, '2457.98000000', '119.43365367', '0'], [1513809000000, '0.04872800', '0.04891500', '0.04778900', '0.04809000', '4856.97600000', 1513810799999, '234.95685689', 5716, '2003.87500000', '96.96648298', '0'], [1513810800000, '0.04805200', '0.04850000', '0.04772900', '0.04807800', '4930.03600000', 1513812599999, '236.99381836', 6523, '2255.65700000', '108.48222467', '0'], [1513812600000, '0.04802700', '0.04838500', '0.04782400', '0.04826800', '4704.95200000', 1513814399999, '226.42105714', 6027, '2376.89800000', '114.40680337', '0'], [1513814400000, '0.04826600', '0.04844100', '0.04789400', '0.04789400', '5685.69300000', 1513816199999, '273.56880443', 7400, '2704.90900000', '130.20987771', '0'], [1513816200000, '0.04791400', '0.04815000', '0.04760100', '0.04805200', '6124.34700000', 1513817999999, '293.33044898', 7101, '2771.06400000', '132.78708089', '0'], [1513818000000, '0.04799600', '0.04839900', '0.04790400', '0.04827600', '6273.81900000', 1513819799999, '302.28368900', 7333, '2874.92600000', '138.57749511', '0'], [1513819800000, '0.04822500', '0.04844800', '0.04810400', '0.04829700', '6037.78700000', 1513821599999, '291.35259879', 7100, '2775.41400000', '133.98168206', '0'], [1513821600000, '0.04829700', '0.04839000', '0.04800100', '0.04809500', '6297.05000000', 1513823399999, '303.23905503', 7221, '2888.32600000', '139.14909657', '0'], [1513823400000, '0.04814300', '0.04864300', '0.04809700', '0.04851700', '6507.56000000', 1513825199999, '314.87304175', 7084, '2859.06800000', '138.38731767', '0'], [1513825200000, '0.04852600', '0.04900100', '0.04850000', '0.04895500', '6495.38000000', 1513826999999, '316.56707382', 7890, '3273.68800000', '159.55351115', '0'], [1513827000000, '0.04895500', '0.04900400', '0.04818800', '0.04827700', '8256.56600000', 1513828799999, '400.95370752', 9863, '3616.13100000', '175.68807195', '0'], [1513828800000, '0.04820200', '0.04880900', '0.04800100', '0.04864400', '8819.34400000', 1513830599999, '426.46244534', 10587, '4387.72300000', '212.27186831', '0'], [1513830600000, '0.04864400', '0.04938700', '0.04862500', '0.04923100', '8676.04200000', 1513832399999, '425.07675191', 8953, '3947.78200000', '193.48466775', '0'], [1513832400000, '0.04923100', '0.05000200', '0.04911000', '0.04991600', '8076.59200000', 1513834199999, '402.24423122', 7498, '4372.41800000', '217.87894206', '0'], [1513834200000, '0.04991800', '0.05029500', '0.04930200', '0.04943900', '6680.64200000', 1513835999999, '333.33072271', 7526, '3220.68600000', '160.71867961', '0'], [1513836000000, '0.04953300', '0.04967000', '0.04931800', '0.04950200', '5403.51000000', 1513837799999, '267.18505821', 6103, '2393.19300000', '118.38424405', '0'], [1513837800000, '0.04950200', '0.04972700', '0.04880800', '0.04921300', '7741.56400000', 1513839599999, '382.40845816', 8120, '3499.73600000', '172.94006667', '0'], [1513839600000, '0.04916300', '0.04921300', '0.04830000', '0.04884600', '7313.83400000', 1513841399999, '356.47390782', 8328, '3544.78900000', '172.84610869', '0'], [1513841400000, '0.04884100', '0.04990000', '0.04862900', '0.04876600', '8635.50000000', 1513843199999, '421.71556329', 8813, '3948.55500000', '193.08579347', '0'], [1513843200000, '0.04874000', '0.05002900', '0.04869100', '0.04932000', '8379.39400000', 1513844999999, '411.73888246', 8098, '3821.37400000', '187.98176400', '0'], [1513845000000, '0.04935400', '0.05029500', '0.04900000', '0.04943900', '6718.95800000', 1513846799999, '331.37525966', 6726, '3178.82300000', '156.91923339', '0'], [1513846800000, '0.04943900', '0.04979900', '0.04920700', '0.04953700', '6260.67300000', 1513848599999, '309.58917056', 6679, '3383.53900000', '167.40324377', '0'], [1513848600000, '0.04953700', '0.04990000', '0.04947500', '0.04961100', '5310.82800000', 1513850399999, '263.50089513', 6782, '2281.15900000', '113.22588346', '0'], [1513850400000, '0.04965900', '0.05032000', '0.04959600', '0.05012700', '6351.47700000', 1513852199999, '317.18847950', 6829, '3311.11100000', '165.42337909', '0'], [1513852200000, '0.05012600', '0.05040000', '0.05000000', '0.05005400', '5977.91500000', 1513853999999, '299.64025306', 6929, '2725.63000000', '136.66829483', '0'], [1513854000000, '0.05009700', '0.05026700', '0.04984400', '0.05010600', '6374.48000000', 1513855799999, '319.04562787', 6669, '2998.39800000', '150.11286634', '0'], [1513855800000, '0.05010600', '0.05038300', '0.05002300', '0.05020900', '5554.04300000', 1513857599999, '278.59194150', 6568, '2779.69100000', '139.48372201', '0'], [1513857600000, '0.05017500', '0.05039000', '0.05000000', '0.05009100', '6946.92500000', 1513859399999, '348.23765455', 7172, '3092.92000000', '155.14206635', '0'], [1513859400000, '0.05009100', '0.05041500', '0.05008200', '0.05024000', '5873.56400000', 1513861199999, '295.02031580', 6874, '2785.18400000', '139.94717318', '0'], [1513861200000, '0.05024000', '0.05037500', '0.05000000', '0.05035900', '6604.41900000', 1513862999999, '331.33250471', 7286, '3124.67600000', '156.85256974', '0'], [1513863000000, '0.05031300', '0.05040000', '0.05004100', '0.05027300', '6819.28900000', 1513864799999, '342.78469461', 8075, '3357.34300000', '168.83846340', '0'], [1513864800000, '0.05027500', '0.05031900', '0.05000000', '0.05024800', '7760.75600000', 1513866599999, '389.12269875', 8813, '3300.54000000', '165.54795671', '0'], [1513866600000, '0.05019500', '0.05042900', '0.04999700', '0.05016400', '9198.00800000', 1513868399999, '461.86920455', 9852, '4139.00400000', '207.95577483', '0'], [1513868400000, '0.05016400', '0.05048600', '0.04954100', '0.05001100', '11844.73300000', 1513870199999, '592.68709980', 12714, '5689.50000000', '284.85115220', '0'], [1513870200000, '0.05000000', '0.05051300', '0.04994000', '0.05031400', '12688.95000000', 1513871999999, '637.23545672', 11847, '5641.42900000', '283.47739726', '0'], [1513872000000, '0.05031400', '0.05031900', '0.04970000', '0.05009800', '9970.76500000', 1513873799999, '497.71814944', 10403, '5093.74800000', '254.35608266', '0'], [1513873800000, '0.05009800', '0.05034000', '0.04989400', '0.05010600', '6529.40600000', 1513875599999, '327.00420152', 7327, '3233.31200000', '162.00592335', '0'], [1513875600000, '0.05007200', '0.05075000', '0.05002400', '0.05064700', '6116.26600000', 1513877399999, '307.59784587', 7623, '3142.60100000', '158.13812062', '0'], [1513877400000, '0.05064800', '0.05157400', '0.05050300', '0.05064500', '7462.88100000', 1513879199999, '379.91242033', 7300, '3605.69100000', '183.63522981', '0'], [1513879200000, '0.05064500', '0.05140900', '0.05064000', '0.05122800', '6580.77600000', 1513880999999, '335.83528853', 6426, '2740.76200000', '139.89037775', '0'], [1513881000000, '0.05122700', '0.05151800', '0.05100100', '0.05142100', '5777.21600000', 1513882799999, '296.14819146', 6682, '2444.00300000', '125.33232635', '0'], [1513882800000, '0.05142100', '0.05170000', '0.05130000', '0.05143000', '6799.49100000', 1513884599999, '350.38585333', 6562, '2997.26500000', '154.49945846', '0'], [1513884600000, '0.05140000', '0.05162800', '0.05035500', '0.05069800', '5736.64300000', 1513886399999, '292.88327636', 5723, '2664.68100000', '136.14083066', '0'], [1513886400000, '0.05064600', '0.05073600', '0.05010000', '0.05018900', '5901.95900000', 1513888199999, '297.33709279', 5906, '3198.45400000', '161.21020060', '0'], [1513888200000, '0.05018800', '0.05032200', '0.05002800', '0.05019200', '4809.33000000', 1513889999999, '241.31179093', 5746, '2458.79500000', '123.41360853', '0'], [1513890000000, '0.05019100', '0.05023200', '0.05000000', '0.05000100', '5034.51000000', 1513891799999, '252.09406485', 5583, '2373.61000000', '118.90590663', '0'], [1513891800000, '0.05000100', '0.05012500', '0.04970000', '0.04982400', '6067.16000000', 1513893599999, '302.92527760', 6431, '3021.01600000', '150.85462318', '0'], [1513893600000, '0.04976700', '0.04999400', '0.04970000', '0.04987800', '5003.92600000', 1513895399999, '249.36720213', 6260, '2678.54100000', '133.52618154', '0'], [1513895400000, '0.04985000', '0.05060100', '0.04979400', '0.05050800', '5498.67800000', 1513897199999, '275.60297702', 6451, '2605.48300000', '130.61312045', '0'], [1513897200000, '0.05050900', '0.05085100', '0.05047400', '0.05076300', '5226.50000000', 1513898999999, '264.66409771', 5627, '2504.46700000', '126.88312849', '0'], [1513899000000, '0.05076300', '0.05085000', '0.05056000', '0.05063000', '6693.22400000', 1513900799999, '339.48159272', 5712, '2639.25100000', '133.91047846', '0'], [1513900800000, '0.05058000', '0.05084000', '0.05020500', '0.05075700', '7325.42200000', 1513902599999, '369.68205298', 7944, '3354.50300000', '169.37559790', '0'], [1513902600000, '0.05080000', '0.05087000', '0.05035600', '0.05081900', '6663.43200000', 1513904399999, '337.51930012', 7839, '2927.02900000', '148.32594553', '0'], [1513904400000, '0.05081900', '0.05149100', '0.05069000', '0.05127900', '7913.56500000', 1513906199999, '403.59745332', 8013, '3923.33700000', '200.11664942', '0'], [1513906200000, '0.05122000', '0.05148700', '0.05070000', '0.05085000', '7759.70800000', 1513907999999, '397.26870590', 8136, '3710.33800000', '190.03703298', '0'], [1513908000000, '0.05085000', '0.05140300', '0.05064400', '0.05071000', '8840.82000000', 1513909799999, '449.68513909', 9672, '4033.50900000', '205.27228823', '0'], [1513909800000, '0.05071000', '0.05125000', '0.05020700', '0.05078800', '8654.34600000', 1513911599999, '438.55709624', 10246, '3940.34000000', '199.84965556', '0'], [1513911600000, '0.05063700', '0.05099200', '0.04910900', '0.04926000', '12721.36900000', 1513913399999, '637.58226568', 13863, '5763.13400000', '289.02733197', '0'], [1513913400000, '0.04926000', '0.04973700', '0.04812500', '0.04837200', '10782.88400000', 1513915199999, '526.94841983', 12087, '4791.98600000', '234.34630727', '0'], [1513915200000, '0.04820800', '0.04947400', '0.04820300', '0.04920200', '9674.78500000', 1513916999999, '471.50445168', 11023, '4833.21100000', '235.73557944', '0'], [1513917000000, '0.04917400', '0.04968700', '0.04860000', '0.04900500', '8304.35700000', 1513918799999, '408.24287939', 9465, '3699.99000000', '181.90838064', '0'], [1513918800000, '0.04896500', '0.04960000', '0.04881500', '0.04933500', '6495.66100000', 1513920599999, '319.78370387', 7707, '2739.36200000', '134.94230692', '0'], [1513920600000, '0.04933600', '0.04980000', '0.04930200', '0.04939900', '7557.62600000', 1513922399999, '374.17486333', 7194, '3529.99500000', '174.82670544', '0'], [1513922400000, '0.04939900', '0.04956400', '0.04900200', '0.04915700', '5541.59600000', 1513924199999, '273.09827262', 5897, '2521.68200000', '124.37031200', '0'], [1513924200000, '0.04915600', '0.04979700', '0.04898200', '0.04914700', '5977.78500000', 1513925999999, '293.80092841', 6220, '2658.81500000', '130.76334960', '0'], [1513926000000, '0.04914700', '0.04925100', '0.04800000', '0.04818800', '13355.79100000', 1513927799999, '648.25218115', 12971, '5489.30600000', '266.78738835', '0'], [1513927800000, '0.04815900', '0.04871200', '0.04710000', '0.04760000', '11295.92800000', 1513929599999, '537.99406096', 11869, '5495.36000000', '261.89892013', '0'], [1513929600000, '0.04745500', '0.04836700', '0.04666000', '0.04761700', '8044.43600000', 1513931399999, '383.22560717', 8765, '3846.61700000', '183.51470566', '0'], [1513931400000, '0.04765300', '0.04842400', '0.04732800', '0.04807600', '7070.55900000', 1513933199999, '338.77714982', 7338, '3323.11300000', '159.29950879', '0'], [1513933200000, '0.04808700', '0.04862500', '0.04807600', '0.04849700', '7099.19400000', 1513934999999, '343.49041652', 7725, '3465.65500000', '167.78376616', '0'], [1513935000000, '0.04848800', '0.04963900', '0.04837000', '0.04889900', '6458.43900000', 1513936799999, '316.01878788', 7729, '3007.82600000', '147.27404674', '0'], [1513936800000, '0.04890000', '0.04963800', '0.04875000', '0.04918000', '5653.53200000', 1513938599999, '277.46581713', 6956, '2692.99100000', '132.26999244', '0'], [1513938600000, '0.04918100', '0.04918100', '0.04823600', '0.04824600', '6715.52400000', 1513940399999, '326.87401049', 7403, '3247.29100000', '158.14187007', '0'], [1513940400000, '0.04824600', '0.04841500', '0.04777700', '0.04800200', '5379.47500000', 1513942199999, '258.32635759', 5033, '2603.72900000', '125.06979233', '0'], [1513942200000, '0.04800200', '0.04862100', '0.04780400', '0.04816100', '5395.93600000', 1513943999999, '260.03884044', 6021, '2518.47900000', '121.43385720', '0'], [1513944000000, '0.04816500', '0.04900000', '0.04812000', '0.04840800', '4521.13600000', 1513945799999, '218.46100838', 5221, '2391.02800000', '115.61765578', '0'], [1513945800000, '0.04833600', '0.04853300', '0.04756900', '0.04772400', '5221.19200000', 1513947599999, '250.86001135', 5668, '2655.11600000', '127.62148449', '0'], [1513947600000, '0.04776100', '0.04877600', '0.04711700', '0.04738200', '8687.43300000', 1513949399999, '414.24772566', 9943, '3924.51100000', '187.22887858', '0'], [1513949400000, '0.04737700', '0.04757100', '0.04666000', '0.04739100', '9185.55900000', 1513951199999, '432.72508275', 8955, '4303.70500000', '202.87742960', '0'], [1513951200000, '0.04740700', '0.04760900', '0.04534000', '0.04632700', '14544.48400000', 1513952999999, '677.32159983', 15756, '6775.65700000', '316.00633516', '0'], [1513953000000, '0.04636500', '0.04719600', '0.04583400', '0.04639500', '11621.19200000', 1513954799999, '540.43116859', 12933, '5815.29200000', '270.68087868', '0'], [1513954800000, '0.04644100', '0.04870500', '0.04637000', '0.04799500', '11651.71800000', 1513956599999, '552.64471333', 13038, '5831.82800000', '276.87687143', '0'], [1513956600000, '0.04803100', '0.04900000', '0.04798300', '0.04827000', '10692.57900000', 1513958399999, '517.43465300', 13612, '5339.72400000', '258.65792183', '0'], [1513958400000, '0.04827000', '0.04855700', '0.04718700', '0.04797200', '10893.02800000', 1513960199999, '521.96042070', 12879, '5291.91600000', '253.70608041', '0'], [1513960200000, '0.04795600', '0.04887700', '0.04767000', '0.04841000', '8847.60900000', 1513961999999, '426.87948102', 9913, '4104.89200000', '198.18469916', '0'], [1513962000000, '0.04841000', '0.04889800', '0.04790900', '0.04816600', '6855.99000000', 1513963799999, '331.78839360', 8240, '3527.23900000', '170.75794808', '0'], [1513963800000, '0.04816700', '0.04848000', '0.04800000', '0.04820000', '6132.25200000', 1513965599999, '295.80063079', 8148, '3136.13500000', '151.35499562', '0'], [1513965600000, '0.04811000', '0.04860800', '0.04800000', '0.04812100', '5751.47800000', 1513967399999, '277.40845020', 6843, '2927.44000000', '141.25047798', '0'], [1513967400000, '0.04812100', '0.04839500', '0.04751500', '0.04810200', '5107.24700000', 1513969199999, '245.17060295', 7212, '2605.18400000', '125.13873626', '0'], [1513969200000, '0.04810200', '0.04836800', '0.04782100', '0.04810000', '6681.73200000', 1513970999999, '321.08595045', 7965, '3379.39000000', '162.47694287', '0'], [1513971000000, '0.04808300', '0.04816000', '0.04758400', '0.04769500', '5942.97400000', 1513972799999, '284.58139385', 7389, '2868.39300000', '137.41432202', '0'], [1513972800000, '0.04774100', '0.04800000', '0.04736100', '0.04759300', '5099.71800000', 1513974599999, '243.03845906', 5925, '2692.74600000', '128.41099841', '0'], [1513974600000, '0.04768100', '0.04775800', '0.04700000', '0.04724000', '5437.73200000', 1513976399999, '257.65229529', 6878, '2841.47400000', '134.73389895', '0'], [1513976400000, '0.04715000', '0.04766800', '0.04700700', '0.04745100', '5446.48000000', 1513978199999, '258.18483661', 6868, '2786.91800000', '132.16268312', '0'], [1513978200000, '0.04742600', '0.04799700', '0.04731800', '0.04769800', '5412.94300000', 1513979999999, '257.28090998', 7035, '2595.90300000', '123.46434185', '0'], [1513980000000, '0.04760600', '0.04788900', '0.04731600', '0.04751000', '4943.89800000', 1513981799999, '235.24110034', 6306, '2360.10100000', '112.38150132', '0'], [1513981800000, '0.04761300', '0.04790200', '0.04710000', '0.04730200', '6003.72500000', 1513983599999, '285.04461120', 7215, '3333.39800000', '158.34978421', '0'], [1513983600000, '0.04725600', '0.04785400', '0.04719900', '0.04760200', '6848.01200000', 1513985399999, '325.62613638', 8063, '3581.52400000', '170.37251795', '0'], [1513985400000, '0.04760200', '0.04790200', '0.04715200', '0.04760600', '7356.79600000', 1513987199999, '349.48648320', 7451, '3458.35400000', '164.38085086', '0'], [1513987200000, '0.04760100', '0.04799800', '0.04749800', '0.04784600', '4685.45700000', 1513988999999, '223.36336932', 5883, '2215.41200000', '105.67208936', '0'], [1513989000000, '0.04784100', '0.04830000', '0.04761500', '0.04803400', '4986.67600000', 1513990799999, '238.87037777', 6047, '2554.04100000', '122.39560665', '0'], [1513990800000, '0.04801500', '0.04865300', '0.04798100', '0.04861400', '5143.43400000', 1513992599999, '248.57222070', 5391, '2794.11300000', '135.02036123', '0'], [1513992600000, '0.04849100', '0.04895000', '0.04836000', '0.04882800', '5057.22500000', 1513994399999, '246.20186311', 5438, '2254.42700000', '109.78526221', '0'], [1513994400000, '0.04882200', '0.04890700', '0.04860000', '0.04879000', '5317.69800000', 1513996199999, '259.36887611', 5234, '2505.89800000', '122.27034668', '0'], [1513996200000, '0.04883000', '0.04895000', '0.04850200', '0.04865200', '5681.79700000', 1513997999999, '276.93906218', 5942, '2585.12700000', '126.07551535', '0'], [1513998000000, '0.04866600', '0.04894900', '0.04839100', '0.04879500', '5967.26000000', 1513999799999, '290.68682732', 6712, '2938.38900000', '143.16993964', '0'], [1513999800000, '0.04883600', '0.04900000', '0.04869600', '0.04878000', '5925.61100000', 1514001599999, '289.47419359', 6091, '3020.07600000', '147.62288093', '0'], [1514001600000, '0.04878900', '0.04901900', '0.04850100', '0.04867600', '6271.16500000', 1514003399999, '305.84425071', 7177, '3094.11200000', '150.96753912', '0'], [1514003400000, '0.04867600', '0.04883900', '0.04850000', '0.04875000', '4816.70100000', 1514005199999, '234.50601333', 5470, '2613.37100000', '127.27066653', '0'], [1514005200000, '0.04865800', '0.04881200', '0.04798900', '0.04843500', '5188.80700000', 1514006999999, '251.85401042', 5514, '2774.89700000', '134.64688154', '0'], [1514007000000, '0.04843500', '0.04875000', '0.04838900', '0.04853800', '4403.92900000', 1514008799999, '214.01251144', 4992, '1998.67200000', '97.14720874', '0'], [1514008800000, '0.04859000', '0.04881500', '0.04804900', '0.04845200', '5591.57700000', 1514010599999, '271.02360525', 6699, '2668.56200000', '129.38499163', '0'], [1514010600000, '0.04846700', '0.04888000', '0.04839100', '0.04881100', '4777.94600000', 1514012399999, '232.36656434', 5389, '2443.12600000', '118.84886309', '0'], [1514012400000, '0.04886300', '0.04899400', '0.04852200', '0.04870900', '5610.07000000', 1514014199999, '273.73321344', 5397, '2836.22100000', '138.47784927', '0'], [1514014200000, '0.04870900', '0.04891200', '0.04850300', '0.04890700', '4581.60900000', 1514015999999, '223.48913382', 5013, '2296.18400000', '112.06058229', '0'], [1514016000000, '0.04890600', '0.04895300', '0.04854500', '0.04879900', '4770.68700000', 1514017799999, '232.75426458', 5285, '2472.19400000', '120.69607146', '0'], [1514017800000, '0.04871100', '0.04895300', '0.04870500', '0.04891000', '3804.80400000', 1514019599999, '185.79845737', 5031, '2000.62500000', '97.73727146', '0'], [1514019600000, '0.04891000', '0.04900000', '0.04855000', '0.04882200', '4429.24000000', 1514021399999, '216.29233742', 5718, '2087.15700000', '101.98464066', '0'], [1514021400000, '0.04877500', '0.04887700', '0.04855100', '0.04879300', '6002.10700000', 1514023199999, '292.76439160', 6087, '3093.35600000', '150.96397738', '0'], [1514023200000, '0.04879200', '0.04900000', '0.04868100', '0.04890600', '4847.17800000', 1514024999999, '236.63056969', 6044, '2521.84200000', '123.18368973', '0'], [1514025000000, '0.04899300', '0.04900000', '0.04820000', '0.04852000', '5875.07200000', 1514026799999, '285.93170715', 7322, '2753.10900000', '134.07572189', '0'], [1514026800000, '0.04852000', '0.04869000', '0.04822700', '0.04847000', '6006.51100000', 1514028599999, '290.86233660', 6896, '3054.26000000', '147.92976946', '0'], [1514028600000, '0.04845700', '0.04870900', '0.04827400', '0.04830100', '5623.72300000', 1514030399999, '272.56910948', 6444, '2596.04700000', '125.85733950', '0'], [1514030400000, '0.04830000', '0.04859000', '0.04786500', '0.04797200', '5967.69200000', 1514032199999, '287.75578750', 6683, '2943.60100000', '141.93696180', '0'], [1514032200000, '0.04797200', '0.04827300', '0.04783300', '0.04809400', '5405.66400000', 1514033999999, '259.93005197', 5906, '2711.07000000', '130.39777036', '0'], [1514034000000, '0.04809400', '0.04850000', '0.04795300', '0.04801100', '5917.00200000', 1514035799999, '284.65859470', 7072, '3004.88500000', '144.61160413', '0'], [1514035800000, '0.04801700', '0.04860000', '0.04784900', '0.04816200', '5247.37300000', 1514037599999, '252.23598037', 6674, '2532.63600000', '121.83318089', '0'], [1514037600000, '0.04816300', '0.04860000', '0.04806300', '0.04832200', '7121.17100000', 1514039399999, '343.72726697', 8514, '3063.78300000', '147.99236639', '0'], [1514039400000, '0.04836300', '0.04856900', '0.04789800', '0.04808900', '8129.78900000', 1514041199999, '392.40093287', 8886, '3474.74200000', '167.79143491', '0'], [1514041200000, '0.04808900', '0.04823300', '0.04776700', '0.04795800', '7448.36200000', 1514042999999, '357.37054354', 9711, '3846.23800000', '184.63494304', '0'], [1514043000000, '0.04795900', '0.04822200', '0.04770000', '0.04807300', '9183.47800000', 1514044799999, '440.50067885', 11080, '4483.98300000', '215.17489485', '0'], [1514044800000, '0.04807900', '0.04833000', '0.04780200', '0.04794500', '7508.37400000', 1514046599999, '361.45292329', 8847, '3942.77100000', '189.90941861', '0'], [1514046600000, '0.04790100', '0.04829900', '0.04780000', '0.04806700', '6323.19500000', 1514048399999, '303.77206353', 8748, '2895.61000000', '139.18409079', '0'], [1514048400000, '0.04806700', '0.04839700', '0.04777200', '0.04825200', '6289.43500000', 1514050199999, '302.42018088', 9203, '3144.84700000', '151.32117411', '0'], [1514050200000, '0.04816100', '0.04838700', '0.04783500', '0.04794900', '6798.78000000', 1514051999999, '327.19494769', 8452, '3332.26300000', '160.44943996', '0'], [1514052000000, '0.04794900', '0.04814200', '0.04777900', '0.04790000', '5688.32900000', 1514053799999, '272.54119585', 6957, '2928.17300000', '140.35152537', '0'], [1514053800000, '0.04783300', '0.04810000', '0.04780000', '0.04798500', '5060.73300000', 1514055599999, '242.71677270', 6530, '2459.04500000', '117.97727035', '0'], [1514055600000, '0.04801600', '0.04829400', '0.04798300', '0.04818100', '4940.79200000', 1514057399999, '237.77601914', 5767, '1854.72500000', '89.31022746', '0'], [1514057400000, '0.04811500', '0.04822100', '0.04801800', '0.04815900', '5376.67500000', 1514059199999, '258.69288741', 6152, '2393.84900000', '115.24447367', '0'], [1514059200000, '0.04814800', '0.04829000', '0.04790000', '0.04800200', '5401.22900000', 1514060999999, '259.75007596', 6380, '2616.42000000', '125.90457425', '0'], [1514061000000, '0.04800000', '0.04835000', '0.04790000', '0.04819300', '6254.70000000', 1514062799999, '300.94662377', 7543, '2814.51000000', '135.49328225', '0'], [1514062800000, '0.04819800', '0.04839000', '0.04798500', '0.04813900', '6785.64500000', 1514064599999, '326.98576326', 8551, '3062.17900000', '147.63622570', '0'], [1514064600000, '0.04809600', '0.04866600', '0.04770000', '0.04790300', '7701.04700000', 1514066399999, '370.55068911', 9012, '3905.69500000', '188.19306873', '0'], [1514066400000, '0.04790300', '0.04810200', '0.04770500', '0.04787300', '5124.72600000', 1514068199999, '245.58708196', 7335, '2599.76400000', '124.64258364', '0'], [1514068200000, '0.04787500', '0.04813400', '0.04781100', '0.04786400', '6164.48600000', 1514069999999, '295.52229555', 7109, '2966.10800000', '142.25111982', '0'], [1514070000000, '0.04786400', '0.04850000', '0.04773500', '0.04813400', '7331.49300000', 1514071799999, '352.55740064', 7624, '3753.93300000', '180.58624186', '0'], [1514071800000, '0.04819500', '0.04863800', '0.04799800', '0.04814000', '10633.16500000', 1514073599999, '513.03413229', 10978, '4992.04700000', '240.95320981', '0'], [1514073600000, '0.04814000', '0.04869300', '0.04810100', '0.04819200', '7877.53200000', 1514075399999, '380.50810650', 9597, '3948.91600000', '190.89693711', '0'], [1514075400000, '0.04819200', '0.04850000', '0.04774400', '0.04820500', '6543.72700000', 1514077199999, '315.37765090', 8218, '2728.98900000', '131.57157700', '0'], [1514077200000, '0.04811500', '0.04860000', '0.04810300', '0.04832000', '6254.81500000', 1514078999999, '302.22526795', 7447, '2743.71400000', '132.65899543', '0'], [1514079000000, '0.04831900', '0.04847800', '0.04805700', '0.04813700', '6299.46200000', 1514080799999, '303.90823635', 6873, '2987.63200000', '144.26465332', '0'], [1514080800000, '0.04813700', '0.04830000', '0.04780700', '0.04809100', '5655.83700000', 1514082599999, '272.08306484', 6993, '2692.09100000', '129.60888640', '0'], [1514082600000, '0.04809700', '0.04869400', '0.04780000', '0.04800200', '6625.30300000', 1514084399999, '318.90207130', 7876, '3126.50800000', '150.63120243', '0'], [1514084400000, '0.04798300', '0.04880000', '0.04770000', '0.04815700', '5890.77900000', 1514086199999, '284.16416604', 7471, '2931.35500000', '141.52124702', '0'], [1514086200000, '0.04820000', '0.04840000', '0.04788000', '0.04809200', '5439.44900000', 1514087999999, '262.16178589', 6212, '2693.11900000', '129.87117983', '0'], [1514088000000, '0.04809200', '0.04850000', '0.04801100', '0.04821600', '4945.12200000', 1514089799999, '238.38297113', 5587, '2466.33500000', '118.96475826', '0'], [1514089800000, '0.04821900', '0.04890000', '0.04798200', '0.04840600', '6661.45900000', 1514091599999, '322.59129955', 8184, '3429.37100000', '166.26794843', '0'], [1514091600000, '0.04840600', '0.04890000', '0.04829500', '0.04851400', '7210.21700000', 1514093399999, '349.67055456', 6753, '3386.09700000', '164.33124348', '0'], [1514093400000, '0.04851400', '0.04900000', '0.04836400', '0.04838300', '7319.77900000', 1514095199999, '355.01663201', 6164, '3786.08800000', '183.73082363', '0'], [1514095200000, '0.04838300', '0.04849900', '0.04815800', '0.04823400', '4852.50500000', 1514096999999, '234.28670293', 5236, '2431.16100000', '117.41084130', '0'], [1514097000000, '0.04823400', '0.04900000', '0.04820100', '0.04831600', '6581.39000000', 1514098799999, '318.42591140', 6299, '3342.19900000', '161.83282486', '0'], [1514098800000, '0.04844600', '0.04864900', '0.04811200', '0.04832200', '5051.91100000', 1514100599999, '243.88078022', 6415, '2174.03000000', '105.00944431', '0'], [1514100600000, '0.04836400', '0.04842500', '0.04810000', '0.04823100', '5093.95200000', 1514102399999, '245.98424023', 5822, '2283.40800000', '110.33335462', '0'], [1514102400000, '0.04823500', '0.04833000', '0.04794100', '0.04811600', '5419.95400000', 1514104199999, '261.00003244', 5632, '2361.93000000', '113.78969353', '0'], [1514104200000, '0.04813300', '0.04840000', '0.04810000', '0.04832300', '6142.79600000', 1514105999999, '296.33836741', 6411, '2565.83300000', '123.84877357', '0'], [1514106000000, '0.04831500', '0.04840000', '0.04808600', '0.04832800', '4949.47400000', 1514107799999, '239.04195104', 5638, '2912.40100000', '140.71928323', '0'], [1514107800000, '0.04825700', '0.04844400', '0.04821100', '0.04828600', '5294.37400000', 1514109599999, '255.88746781', 5144, '2884.41600000', '139.45790034', '0'], [1514109600000, '0.04828600', '0.04866600', '0.04810000', '0.04846800', '6070.09400000', 1514111399999, '293.72366336', 6484, '2813.41600000', '136.17119601', '0'], [1514111400000, '0.04846700', '0.04859600', '0.04810300', '0.04824200', '4722.15100000', 1514113199999, '228.12765660', 6130, '2083.11900000', '100.69895914', '0'], [1514113200000, '0.04824200', '0.04870000', '0.04810000', '0.04813000', '5917.75300000', 1514114999999, '285.66071327', 6794, '3065.45400000', '148.06950117', '0'], [1514115000000, '0.04813000', '0.04840000', '0.04781300', '0.04797000', '6538.45600000', 1514116799999, '314.77521757', 7890, '2917.08800000', '140.53647394', '0'], [1514116800000, '0.04797000', '0.04830300', '0.04780100', '0.04815000', '6380.73000000', 1514118599999, '306.95294769', 7352, '3198.67400000', '153.92049779', '0'], [1514118600000, '0.04819700', '0.04850000', '0.04800000', '0.04836600', '6904.63300000', 1514120399999, '333.04718971', 7205, '3734.18500000', '180.18753262', '0'], [1514120400000, '0.04836600', '0.04870000', '0.04835400', '0.04859200', '5741.39500000', 1514122199999, '278.77644055', 6051, '2880.22900000', '139.91493439', '0'], [1514122200000, '0.04859900', '0.04868300', '0.04810000', '0.04825700', '5603.98100000', 1514123999999, '271.76281585', 5883, '2870.55400000', '139.29066056', '0'], [1514124000000, '0.04822900', '0.04849800', '0.04811100', '0.04849200', '4439.80500000', 1514125799999, '214.45066937', 5805, '2252.58800000', '108.84767344', '0'], [1514125800000, '0.04849200', '0.04854800', '0.04790000', '0.04802500', '5911.48000000', 1514127599999, '285.00016329', 6891, '2823.38800000', '136.22844445', '0'], [1514127600000, '0.04805400', '0.04829900', '0.04795200', '0.04818800', '4548.52700000', 1514129399999, '219.15285026', 5373, '2269.16300000', '109.36691641', '0'], [1514129400000, '0.04818800', '0.04865000', '0.04802000', '0.04853300', '6378.39000000', 1514131199999, '308.54303887', 6437, '3440.75900000', '166.50638626', '0'], [1514131200000, '0.04853200', '0.04860000', '0.04844000', '0.04854200', '4626.53800000', 1514132999999, '224.53457907', 4814, '2196.05700000', '106.61397077', '0'], [1514133000000, '0.04854100', '0.04868400', '0.04835000', '0.04860400', '4392.60300000', 1514134799999, '213.16399680', 4673, '2055.49500000', '99.78997943', '0'], [1514134800000, '0.04865600', '0.04879900', '0.04852900', '0.04872900', '3980.26200000', 1514136599999, '193.54051668', 4548, '2426.14400000', '117.98903350', '0'], [1514136600000, '0.04872900', '0.04880000', '0.04860900', '0.04869800', '4187.27500000', 1514138399999, '203.86329130', 4311, '2033.69700000', '99.04633751', '0'], [1514138400000, '0.04866500', '0.04889400', '0.04863500', '0.04873900', '4660.69000000', 1514140199999, '227.15238321', 4822, '2637.13300000', '128.55126311', '0'], [1514140200000, '0.04873900', '0.04882500', '0.04866500', '0.04876000', '2913.59500000', 1514141999999, '142.03319823', 3755, '1505.23100000', '73.39770594', '0'], [1514142000000, '0.04879700', '0.04924600', '0.04844700', '0.04864500', '3787.74000000', 1514143799999, '184.97095202', 4558, '2068.54900000', '101.04544653', '0'], [1514143800000, '0.04860400', '0.04900000', '0.04850100', '0.04873000', '3471.90500000', 1514145599999, '169.26483459', 4116, '1718.93800000', '83.82744157', '0'], [1514145600000, '0.04872900', '0.04902900', '0.04872200', '0.04886900', '3665.52100000', 1514147399999, '179.23522749', 3990, '2021.29800000', '98.86319503', '0'], [1514147400000, '0.04887300', '0.04905500', '0.04850100', '0.04859000', '4407.41700000', 1514149199999, '215.22387780', 4594, '2519.16000000', '123.06293092', '0'], [1514149200000, '0.04859000', '0.04895200', '0.04856200', '0.04879100', '3616.82400000', 1514150999999, '176.24440676', 3894, '2066.82900000', '100.74209315', '0'], [1514151000000, '0.04879100', '0.04920000', '0.04866700', '0.04896200', '3428.10000000', 1514152799999, '167.56875312', 3892, '1698.43100000', '83.08521244', '0'], [1514152800000, '0.04896300', '0.04902400', '0.04859000', '0.04878500', '3862.56800000', 1514154599999, '188.82190058', 3894, '2132.58800000', '104.29150173', '0'], [1514154600000, '0.04878600', '0.04892400', '0.04855500', '0.04873100', '4092.71400000', 1514156399999, '199.49892606', 4717, '2194.44100000', '107.00490567', '0'], [1514156400000, '0.04873100', '0.04900000', '0.04855100', '0.04874500', '4653.48300000', 1514158199999, '226.81451905', 4975, '2488.35100000', '121.35297156', '0'], [1514158200000, '0.04874500', '0.04916900', '0.04857000', '0.04879500', '3953.51700000', 1514159999999, '193.02785740', 4626, '1952.22900000', '95.34592944', '0'], [1514160000000, '0.04876500', '0.04960000', '0.04870000', '0.04953500', '6309.33900000', 1514161799999, '309.79997778', 7044, '3046.85000000', '149.74571093', '0'], [1514161800000, '0.04953500', '0.05032200', '0.04952500', '0.05018100', '6671.47000000', 1514163599999, '333.01288808', 6750, '2990.35400000', '149.36492190', '0'], [1514163600000, '0.05018800', '0.05046200', '0.04992300', '0.05046200', '5699.37300000', 1514165399999, '286.06090785', 5162, '1840.51500000', '92.45687297', '0'], [1514165400000, '0.05041100', '0.05149900', '0.05018200', '0.05141400', '6322.81000000', 1514167199999, '320.70422922', 6621, '3284.83200000', '166.64400741', '0'], [1514167200000, '0.05141400', '0.05237200', '0.05125200', '0.05199000', '8227.99900000', 1514168999999, '426.80361836', 8870, '3625.85500000', '188.10056584', '0'], [1514169000000, '0.05199500', '0.05218500', '0.05189200', '0.05189200', '5231.83600000', 1514170799999, '272.13664701', 5412, '2465.09800000', '128.27557164', '0'], [1514170800000, '0.05189300', '0.05250100', '0.05189200', '0.05223600', '5190.58100000', 1514172599999, '270.99105819', 5320, '2774.36300000', '144.85526040', '0'], [1514172600000, '0.05223600', '0.05277000', '0.05189200', '0.05256100', '5725.64500000', 1514174399999, '299.38622610', 6431, '2926.58300000', '153.08068674', '0'], [1514174400000, '0.05251100', '0.05266700', '0.05210000', '0.05218600', '6728.30500000', 1514176199999, '352.24522463', 7696, '3326.86400000', '174.25095730', '0'], [1514176200000, '0.05218800', '0.05247800', '0.05113400', '0.05173200', '6539.13100000', 1514177999999, '339.48788785', 7682, '3137.63400000', '162.97728274', '0'], [1514178000000, '0.05178500', '0.05240000', '0.05152100', '0.05192800', '4722.19200000', 1514179799999, '245.14843400', 5312, '2415.82400000', '125.56473089', '0'], [1514179800000, '0.05192800', '0.05230500', '0.05142500', '0.05189400', '4926.47300000', 1514181599999, '255.65645999', 5718, '2178.59900000', '113.10917775', '0'], [1514181600000, '0.05184500', '0.05194800', '0.05139000', '0.05174200', '5753.37400000', 1514183399999, '297.54908549', 5741, '2571.73000000', '133.06721940', '0'], [1514183400000, '0.05174500', '0.05199000', '0.05166100', '0.05171800', '5005.68700000', 1514185199999, '259.46973632', 4519, '2357.36800000', '122.21328677', '0'], [1514185200000, '0.05166400', '0.05180000', '0.05152000', '0.05166900', '4434.83300000', 1514186999999, '229.03868896', 4790, '1936.43100000', '100.03552654', '0'], [1514187000000, '0.05166900', '0.05180000', '0.05149900', '0.05156400', '4958.44100000', 1514188799999, '256.03319920', 5133, '2224.68400000', '114.91953953', '0'], [1514188800000, '0.05159000', '0.05190000', '0.05130900', '0.05160000', '5342.88400000', 1514190599999, '275.76015107', 5471, '2447.87300000', '126.37422679', '0'], [1514190600000, '0.05160000', '0.05178800', '0.05125500', '0.05154200', '6853.04200000', 1514192399999, '353.01806994', 5978, '2778.83100000', '143.17151640', '0'], [1514192400000, '0.05154200', '0.05179900', '0.05144800', '0.05169800', '5752.81400000', 1514194199999, '296.70439676', 5957, '2856.22900000', '147.36595668', '0'], [1514194200000, '0.05169900', '0.05222800', '0.05163800', '0.05203800', '6025.96000000', 1514195999999, '312.84731136', 6042, '2817.40800000', '146.32076794', '0'], [1514196000000, '0.05203800', '0.05242100', '0.05195200', '0.05215000', '6642.79100000', 1514197799999, '346.33787921', 6366, '2818.10100000', '146.94204620', '0'], [1514197800000, '0.05210100', '0.05235100', '0.05210000', '0.05212800', '5148.74300000', 1514199599999, '268.54305427', 5954, '2322.06200000', '121.16756352', '0'], [1514199600000, '0.05212800', '0.05230000', '0.05210000', '0.05215000', '5269.65000000', 1514201399999, '274.82206408', 5388, '2440.97500000', '127.35441712', '0'], [1514201400000, '0.05219800', '0.05227500', '0.05206300', '0.05217600', '6765.90300000', 1514203199999, '352.75695032', 6587, '3021.52900000', '157.58364667', '0'], [1514203200000, '0.05212600', '0.05240000', '0.05200000', '0.05222700', '5629.68800000', 1514204999999, '293.97517847', 6179, '2598.31700000', '135.76942088', '0'], [1514205000000, '0.05220100', '0.05234100', '0.05200000', '0.05200800', '6324.18000000', 1514206799999, '329.46798133', 7211, '2472.06600000', '128.86642821', '0'], [1514206800000, '0.05200900', '0.05210000', '0.05150000', '0.05159700', '7734.84100000', 1514208599999, '401.85675928', 7414, '2715.40000000', '141.08593628', '0'], [1514208600000, '0.05159600', '0.05200000', '0.05143600', '0.05188700', '5934.62000000', 1514210399999, '306.92937671', 6149, '2808.28100000', '145.29192503', '0'], [1514210400000, '0.05193100', '0.05220000', '0.05161100', '0.05207800', '5946.67300000', 1514212199999, '308.42395246', 7083, '2915.47800000', '151.26607203', '0'], [1514212200000, '0.05203300', '0.05244900', '0.05200000', '0.05221000', '5668.65000000', 1514213999999, '295.97900250', 6645, '2887.12900000', '150.78537937', '0'], [1514214000000, '0.05216300', '0.05238600', '0.05207100', '0.05230000', '4567.08800000', 1514215799999, '238.50358065', 5798, '2101.77900000', '109.79890767', '0'], [1514215800000, '0.05230000', '0.05245000', '0.05095000', '0.05227600', '6572.61900000', 1514217599999, '343.51947291', 6380, '2820.88400000', '147.68350142', '0'], [1514217600000, '0.05224600', '0.05245000', '0.05208700', '0.05218200', '5337.79900000', 1514219399999, '278.98289127', 6168, '2529.07000000', '132.24922714', '0'], [1514219400000, '0.05211800', '0.05219900', '0.05172600', '0.05193300', '5861.58900000', 1514221199999, '304.76661567', 6542, '3231.61300000', '168.07082843', '0'], [1514221200000, '0.05198800', '0.05219900', '0.05175800', '0.05189800', '5119.97000000', 1514222999999, '265.59313243', 5710, '2810.60000000', '145.84540973', '0'], [1514223000000, '0.05189800', '0.05245000', '0.05180000', '0.05224900', '5974.09800000', 1514224799999, '311.23079669', 7409, '3169.84200000', '165.19435948', '0'], [1514224800000, '0.05220700', '0.05244100', '0.05200000', '0.05229900', '4528.05000000', 1514226599999, '236.62491741', 5197, '2410.46300000', '126.01431701', '0'], [1514226600000, '0.05220100', '0.05249800', '0.05185500', '0.05196300', '4878.99100000', 1514228399999, '254.30333033', 5584, '2386.80000000', '124.49107594', '0'], [1514228400000, '0.05191200', '0.05223200', '0.05186600', '0.05201300', '4742.61000000', 1514230199999, '246.83508289', 5145, '2508.74200000', '130.61595563', '0'], [1514230200000, '0.05206600', '0.05265000', '0.05197000', '0.05237200', '5576.84000000', 1514231999999, '291.29518250', 6196, '2669.35900000', '139.53390022', '0'], [1514232000000, '0.05237100', '0.05283800', '0.05219700', '0.05282500', '6476.02600000', 1514233799999, '340.84373539', 7129, '3170.43900000', '166.97477832', '0'], [1514233800000, '0.05280000', '0.05300000', '0.05270400', '0.05291000', '4918.55900000', 1514235599999, '259.94113912', 5134, '2382.38800000', '125.95259634', '0'], [1514235600000, '0.05294100', '0.05300000', '0.05261000', '0.05277700', '4074.56800000', 1514237399999, '215.15324442', 5196, '2102.28400000', '111.05315327', '0'], [1514237400000, '0.05277900', '0.05300000', '0.05263100', '0.05281300', '3271.18500000', 1514239199999, '172.67937547', 4091, '1673.74300000', '88.38029579', '0'], [1514239200000, '0.05281300', '0.05307300', '0.05269300', '0.05296300', '4494.08600000', 1514240999999, '237.45380184', 5003, '2192.88900000', '115.90561638', '0'], [1514241000000, '0.05296300', '0.05499900', '0.05245500', '0.05268900', '7029.59200000', 1514242799999, '371.57674642', 7506, '3825.07200000', '202.56963139', '0'], [1514242800000, '0.05260100', '0.05288900', '0.05231300', '0.05253500', '6056.09800000', 1514244599999, '318.34065001', 7054, '3184.33900000', '167.45695151', '0'], [1514244600000, '0.05253500', '0.05258800', '0.05202000', '0.05215300', '5895.60500000', 1514246399999, '308.28360600', 7315, '2980.27900000', '155.89801259', '0'], [1514246400000, '0.05205900', '0.05237000', '0.05200000', '0.05236700', '5584.75400000', 1514248199999, '291.50600833', 7103, '2784.50400000', '145.41139181', '0'], [1514248200000, '0.05231500', '0.05260000', '0.05217200', '0.05236800', '5327.00500000', 1514249999999, '278.86884590', 6998, '2495.18400000', '130.67464131', '0'], [1514250000000, '0.05231700', '0.05267300', '0.05225000', '0.05259100', '4642.95900000', 1514251799999, '243.34194757', 5429, '2735.05100000', '143.38423371', '0'], [1514251800000, '0.05264200', '0.05276000', '0.05238000', '0.05266600', '5301.05300000', 1514253599999, '279.05065538', 5263, '2701.17600000', '142.24062605', '0'], [1514253600000, '0.05267100', '0.05322700', '0.05263100', '0.05313200', '5875.59300000', 1514255399999, '311.30033489', 6254, '3050.91000000', '161.69567912', '0'], [1514255400000, '0.05313200', '0.05363100', '0.05299900', '0.05327300', '5188.36200000', 1514257199999, '275.99384981', 6455, '2797.01000000', '148.86120939', '0'], [1514257200000, '0.05333000', '0.05350000', '0.05307800', '0.05336000', '5343.57800000', 1514258999999, '284.57872888', 6190, '2215.79300000', '118.04457563', '0'], [1514259000000, '0.05336000', '0.05341300', '0.05186200', '0.05197500', '8877.84300000', 1514260799999, '468.81408504', 9992, '3877.03400000', '204.89289732', '0'], [1514260800000, '0.05197500', '0.05226400', '0.05017000', '0.05039800', '8984.26400000', 1514262599999, '460.07658055', 10447, '4353.04300000', '222.81016916', '0'], [1514262600000, '0.05035800', '0.05049000', '0.04959100', '0.04974200', '8795.23100000', 1514264399999, '439.56594495', 9437, '4101.72700000', '205.09807019', '0'], [1514264400000, '0.04969800', '0.04974800', '0.04720000', '0.04871900', '12299.57000000', 1514266199999, '595.82466374', 12477, '5993.23700000', '290.43083366', '0'], [1514266200000, '0.04871900', '0.04970000', '0.04814000', '0.04901900', '8746.97900000', 1514267999999, '427.98782401', 9683, '4166.79200000', '203.77940025', '0'], [1514268000000, '0.04902300', '0.04957800', '0.04900100', '0.04931100', '5183.51500000', 1514269799999, '255.39271714', 6684, '2568.15100000', '126.56123815', '0'], [1514269800000, '0.04931000', '0.04940200', '0.04830000', '0.04837800', '6652.16100000', 1514271599999, '323.83842177', 7109, '3130.42500000', '152.40962711', '0'], [1514271600000, '0.04837700', '0.04974800', '0.04834500', '0.04945000', '6438.44000000', 1514273399999, '316.08065228', 6635, '2840.60400000', '139.41020829', '0'], [1514273400000, '0.04945000', '0.04963200', '0.04910000', '0.04930300', '4809.40700000', 1514275199999, '237.15438229', 5047, '2577.93300000', '127.17428155', '0'], [1514275200000, '0.04930000', '0.04993600', '0.04916700', '0.04973300', '5343.86300000', 1514276999999, '264.53782822', 5820, '2359.91700000', '116.86903414', '0'], [1514277000000, '0.04973300', '0.05020100', '0.04971000', '0.05013000', '5652.46300000', 1514278799999, '281.72104937', 5752, '2367.76100000', '118.07880995', '0'], [1514278800000, '0.05012700', '0.05025000', '0.04980000', '0.04995200', '6326.15600000', 1514280599999, '316.56274110', 5734, '2337.60500000', '117.04284839', '0'], [1514280600000, '0.04995400', '0.05005100', '0.04934100', '0.04948300', '4034.26600000', 1514282399999, '201.09663606', 4993, '1556.86300000', '77.61708550', '0'], [1514282400000, '0.04952900', '0.04975000', '0.04918900', '0.04971000', '2787.09300000', 1514284199999, '137.85401361', 4149, '944.87000000', '46.73382638', '0'], [1514284200000, '0.04971200', '0.04984400', '0.04925600', '0.04960600', '5660.00800000', 1514285999999, '280.74836193', 6031, '2181.53600000', '108.22268365', '0'], [1514286000000, '0.04960600', '0.04978600', '0.04940600', '0.04964000', '4532.90300000', 1514287799999, '224.86245594', 5018, '2326.14800000', '115.43554595', '0'], [1514287800000, '0.04964100', '0.04975000', '0.04956400', '0.04965100', '3870.79700000', 1514289599999, '192.16323277', 4610, '1729.17600000', '85.86930547', '0'], [1514289600000, '0.04965100', '0.04973300', '0.04939200', '0.04948500', '3447.88600000', 1514291399999, '171.01922783', 4602, '1357.18500000', '67.32754460', '0'], [1514291400000, '0.04948600', '0.04956900', '0.04875000', '0.04900200', '5456.00800000', 1514293199999, '268.30558062', 6525, '2352.67300000', '115.67745921', '0'], [1514293200000, '0.04900200', '0.04905200', '0.04842500', '0.04872800', '4489.92400000', 1514294999999, '218.41578285', 6238, '2070.45800000', '100.73383154', '0'], [1514295000000, '0.04872800', '0.04881900', '0.04841600', '0.04856700', '4743.04500000', 1514296799999, '230.53404248', 5536, '2498.12600000', '121.45311190', '0'], [1514296800000, '0.04860800', '0.04900000', '0.04786000', '0.04814400', '9456.69900000', 1514298599999, '458.27618811', 11669, '4767.04100000', '231.14856452', '0'], [1514298600000, '0.04823800', '0.04830400', '0.04640400', '0.04654700', '10085.18000000', 1514300399999, '477.13108278', 10614, '4627.88300000', '219.08157732', '0'], [1514300400000, '0.04645200', '0.04702000', '0.04630500', '0.04657800', '7602.08200000', 1514302199999, '355.50622755', 9306, '3759.53600000', '175.88159848', '0'], [1514302200000, '0.04661000', '0.04767200', '0.04655200', '0.04726000', '6180.49600000', 1514303999999, '291.08434309', 6901, '2300.02800000', '108.13266713', '0'], [1514304000000, '0.04720700', '0.04731000', '0.04645400', '0.04651100', '7278.89900000', 1514305799999, '340.18391375', 7783, '3710.75700000', '173.53631397', '0'], [1514305800000, '0.04651100', '0.04702400', '0.04643000', '0.04661000', '6455.58900000', 1514307599999, '301.11696842', 7606, '3339.47700000', '155.82415731', '0'], [1514307600000, '0.04661000', '0.04700000', '0.04650300', '0.04669000', '5087.02700000', 1514309399999, '237.45329507', 6270, '2485.32400000', '116.05248594', '0'], [1514309400000, '0.04669000', '0.04746500', '0.04665000', '0.04709500', '5288.84500000', 1514311199999, '249.35993570', 6360, '2516.36700000', '118.66426030', '0'], [1514311200000, '0.04709500', '0.05380000', '0.04701800', '0.04745000', '6058.78500000', 1514312999999, '291.30300082', 6711, '3692.40400000', '179.53838883', '0'], [1514313000000, '0.04734700', '0.04820000', '0.04720000', '0.04750000', '4125.51400000', 1514314799999, '195.88867343', 5786, '1926.66000000', '91.53474752', '0'], [1514314800000, '0.04750000', '0.04761000', '0.04713000', '0.04713100', '3950.24500000', 1514316599999, '187.25275120', 5096, '1876.47600000', '88.98862061', '0'], [1514316600000, '0.04712900', '0.04743400', '0.04700000', '0.04711300', '3301.79200000', 1514318399999, '155.52289356', 4786, '1539.98500000', '72.56865261', '0'], [1514318400000, '0.04716000', '0.04716500', '0.04628200', '0.04649200', '4791.16000000', 1514320199999, '223.24663440', 5879, '2447.27000000', '114.07964163', '0'], [1514320200000, '0.04649100', '0.04704700', '0.04643700', '0.04693000', '3542.33100000', 1514321999999, '165.05894091', 4946, '1845.98200000', '86.06303559', '0'], [1514322000000, '0.04690700', '0.04705900', '0.04672600', '0.04681800', '2933.90400000', 1514323799999, '137.50578973', 4649, '1516.59600000', '71.10522287', '0'], [1514323800000, '0.04687800', '0.04693600', '0.04660100', '0.04675300', '3448.07300000', 1514325599999, '161.25483291', 5167, '1894.71300000', '88.65594919', '0'], [1514325600000, '0.04670700', '0.04703800', '0.04649200', '0.04695600', '4474.91500000', 1514327399999, '209.07275098', 6003, '2163.42600000', '101.08155211', '0'], [1514327400000, '0.04695500', '0.04719200', '0.04678600', '0.04713600', '3793.46400000', 1514329199999, '178.24231812', 5474, '1834.08900000', '86.20856751', '0'], [1514329200000, '0.04714100', '0.04783500', '0.04708000', '0.04778500', '4345.53600000', 1514330999999, '205.82701897', 5498, '1903.47000000', '90.12830038', '0'], [1514331000000, '0.04778500', '0.04788800', '0.04752700', '0.04780500', '5261.98000000', 1514332799999, '251.22137619', 6073, '2888.19600000', '137.91909563', '0'], [1514332800000, '0.04780600', '0.04819300', '0.04760300', '0.04774000', '4211.91800000', 1514334599999, '201.72429414', 6023, '2103.24800000', '100.75260170', '0'], [1514334600000, '0.04774100', '0.04858500', '0.04750200', '0.04809600', '5236.34700000', 1514336399999, '251.27910703', 6085, '2442.03000000', '117.28462851', '0'], [1514336400000, '0.04803700', '0.04821100', '0.04750100', '0.04780600', '4543.79500000', 1514338199999, '217.31759931', 6144, '2186.72900000', '104.63212814', '0'], [1514338200000, '0.04780700', '0.04787900', '0.04750100', '0.04768700', '4345.80300000', 1514339999999, '207.10034326', 4917, '1804.93700000', '86.05041768', '0'], [1514340000000, '0.04768800', '0.04787700', '0.04764200', '0.04769600', '4043.10200000', 1514341799999, '193.06337412', 4661, '1802.71100000', '86.09807878', '0'], [1514341800000, '0.04773900', '0.04788100', '0.04762300', '0.04772500', '3134.99900000', 1514343599999, '149.61900301', 4717, '1464.87700000', '69.94162956', '0'], [1514343600000, '0.04772700', '0.04803500', '0.04766700', '0.04797800', '4368.99500000', 1514345399999, '208.92747349', 5002, '2044.35500000', '97.76689665', '0'], [1514345400000, '0.04797900', '0.04817800', '0.04790200', '0.04801500', '4371.21700000', 1514347199999, '209.88567851', 5479, '1898.56400000', '91.19888003', '0'], [1514347200000, '0.04801500', '0.04801900', '0.04651300', '0.04666100', '5959.22700000', 1514348999999, '281.56689980', 6969, '3021.92700000', '142.88289486', '0'], [1514349000000, '0.04661500', '0.04674000', '0.04630000', '0.04645100', '6352.34900000', 1514350799999, '295.66297590', 6817, '2861.10000000', '133.20131251', '0'], [1514350800000, '0.04645100', '0.04716000', '0.04633900', '0.04681600', '5178.21400000', 1514352599999, '241.64790445', 6121, '2787.96600000', '130.18563898', '0'], [1514352600000, '0.04686200', '0.04686300', '0.04655000', '0.04661700', '4458.21600000', 1514354399999, '208.25895425', 5774, '2449.46000000', '114.44959777', '0'], [1514354400000, '0.04661800', '0.04670000', '0.04637600', '0.04642800', '5258.21400000', 1514356199999, '244.44843885', 6676, '2605.41800000', '121.18086499', '0'], [1514356200000, '0.04641100', '0.04659200', '0.04640400', '0.04652400', '5178.66400000', 1514357999999, '240.73822634', 5666, '2733.92100000', '127.09744454', '0'], [1514358000000, '0.04659100', '0.04766900', '0.04645400', '0.04739400', '6758.11500000', 1514359799999, '317.36899176', 8190, '3570.70500000', '167.71531755', '0'], [1514359800000, '0.04739400', '0.04782000', '0.04733600', '0.04743800', '5699.88200000', 1514361599999, '271.16583837', 6906, '2364.45500000', '112.49612354', '0'], [1514361600000, '0.04739400', '0.04760500', '0.04714200', '0.04724000', '4660.03600000', 1514363399999, '220.44460338', 5643, '2567.63400000', '121.50831710', '0'], [1514363400000, '0.04720300', '0.04747300', '0.04710800', '0.04740100', '4081.54400000', 1514365199999, '192.97814129', 5381, '2010.33800000', '95.08821288', '0'], [1514365200000, '0.04742500', '0.04793400', '0.04739600', '0.04781000', '3744.52400000', 1514366999999, '177.95561195', 4678, '1925.43500000', '91.51361775', '0'], [1514367000000, '0.04780900', '0.04800000', '0.04742700', '0.04759400', '4131.85900000', 1514368799999, '197.03012753', 4765, '2503.28800000', '119.35050270', '0'], [1514368800000, '0.04755800', '0.04762200', '0.04741300', '0.04757400', '3854.41200000', 1514370599999, '183.31139314', 4236, '2330.06200000', '110.85980894', '0'], [1514370600000, '0.04762200', '0.04775000', '0.04727100', '0.04772800', '4698.32800000', 1514372399999, '223.65283467', 5451, '2864.63500000', '136.40600181', '0'], [1514372400000, '0.04769000', '0.04800000', '0.04763000', '0.04781600', '4422.57400000', 1514374199999, '211.41107081', 5792, '1598.31700000', '76.42471321', '0'], [1514374200000, '0.04781600', '0.04810000', '0.04779700', '0.04805300', '3917.70800000', 1514375999999, '187.76900237', 4807, '1732.73200000', '83.08329110', '0'], [1514376000000, '0.04805300', '0.04809900', '0.04742800', '0.04760600', '4125.01000000', 1514377799999, '197.21131343', 5478, '1720.38500000', '82.24953995', '0'], [1514377800000, '0.04760600', '0.04791000', '0.04735800', '0.04769200', '4396.50800000', 1514379599999, '209.45065003', 5833, '2191.53600000', '104.45327700', '0'], [1514379600000, '0.04775400', '0.04810700', '0.04769000', '0.04797700', '4319.26300000', 1514381399999, '206.87284088', 5892, '2147.46900000', '102.90071109', '0'], [1514381400000, '0.04790600', '0.04805000', '0.04777200', '0.04797700', '4632.73200000', 1514383199999, '222.00089377', 6017, '2308.56000000', '110.66996932', '0'], [1514383200000, '0.04797600', '0.04813700', '0.04790200', '0.04806600', '3739.11300000', 1514384999999, '179.54506123', 5415, '1750.09200000', '84.06496687', '0'], [1514385000000, '0.04806600', '0.04846200', '0.04800000', '0.04819900', '5748.86700000', 1514386799999, '277.19009295', 7671, '2698.77900000', '130.19801045', '0'], [1514386800000, '0.04811300', '0.04850000', '0.04810000', '0.04822900', '5405.69700000', 1514388599999, '261.06366265', 6964, '2735.32600000', '132.15060815', '0'], [1514388600000, '0.04822900', '0.04852400', '0.04820500', '0.04832200', '6271.34700000', 1514390399999, '303.34663464', 7983, '2818.18800000', '136.36765022', '0'], [1514390400000, '0.04832200', '0.04840100', '0.04811900', '0.04828000', '6665.88500000', 1514392199999, '321.79997341', 8838, '3567.52700000', '172.29859628', '0'], [1514392200000, '0.04829700', '0.04863700', '0.04820000', '0.04846000', '7744.70600000', 1514393999999, '374.89334054', 9701, '4195.69700000', '203.14737448', '0'], [1514394000000, '0.04846000', '0.04900000', '0.04841300', '0.04845400', '5735.73300000', 1514395799999, '278.67989483', 7453, '2850.18200000', '138.52295695', '0'], [1514395800000, '0.04850000', '0.04866200', '0.04841000', '0.04860500', '3913.03500000', 1514397599999, '189.81268268', 5687, '2075.57600000', '100.71861105', '0'], [1514397600000, '0.04860200', '0.04880000', '0.04840600', '0.04840800', '5485.90700000', 1514399399999, '266.47529579', 6995, '2661.50400000', '129.32694218', '0'], [1514399400000, '0.04840800', '0.04887500', '0.04827600', '0.04864400', '4626.29500000', 1514401199999, '224.62966508', 6001, '2389.66900000', '116.07862204', '0'], [1514401200000, '0.04864400', '0.04873700', '0.04859500', '0.04867200', '5118.23700000', 1514402999999, '249.00930832', 6025, '2048.64800000', '99.71090204', '0'], [1514403000000, '0.04867200', '0.04887500', '0.04859500', '0.04869000', '5109.50800000', 1514404799999, '248.73284738', 6502, '2499.39400000', '121.71207793', '0'], [1514404800000, '0.04869000', '0.04880100', '0.04858300', '0.04880100', '5657.69200000', 1514406599999, '275.33803205', 7181, '2267.31700000', '110.38724121', '0'], [1514406600000, '0.04872200', '0.04899100', '0.04866200', '0.04885800', '4559.40900000', 1514408399999, '222.68962825', 6179, '2012.09600000', '98.29675754', '0'], [1514408400000, '0.04885900', '0.04886100', '0.04826300', '0.04829100', '4385.17900000', 1514410199999, '213.19269720', 5833, '1968.82700000', '95.73722971', '0'], [1514410200000, '0.04829100', '0.04849900', '0.04811000', '0.04818000', '3309.14400000', 1514411999999, '159.82166864', 5531, '1445.54000000', '69.84992694', '0'], [1514412000000, '0.04818000', '0.04819900', '0.04770000', '0.04775100', '4141.78400000', 1514413799999, '198.45073641', 6149, '1979.93600000', '94.90655182', '0'], [1514413800000, '0.04775200', '0.04816500', '0.04750000', '0.04801900', '5653.15700000', 1514415599999, '270.27625371', 7593, '2591.32200000', '123.92247106', '0'], [1514415600000, '0.04797100', '0.04828500', '0.04770000', '0.04788100', '4637.26200000', 1514417399999, '222.52847205', 6628, '2433.29200000', '116.81345262', '0'], [1514417400000, '0.04786900', '0.04797800', '0.04770100', '0.04780400', '3764.12400000', 1514419199999, '179.93738819', 5766, '1791.89700000', '85.69460752', '0'], [1514419200000, '0.04780400', '0.04798500', '0.04758400', '0.04780700', '4876.65200000', 1514420999999, '233.05868781', 6978, '2530.99500000', '121.00879300', '0'], [1514421000000, '0.04781000', '0.04840100', '0.04772700', '0.04825200', '4985.08100000', 1514422799999, '239.82856475', 6641, '2247.82500000', '108.15721110', '0'], [1514422800000, '0.04830000', '0.04840000', '0.04780000', '0.04780600', '5263.69500000', 1514424599999, '253.03650563', 6878, '2579.81100000', '124.09218337', '0'], [1514424600000, '0.04780600', '0.04806700', '0.04776000', '0.04802000', '5049.86500000', 1514426399999, '242.10393398', 6142, '2319.55400000', '111.24739045', '0'], [1514426400000, '0.04795600', '0.04807900', '0.04780000', '0.04799900', '6424.86600000', 1514428199999, '307.82931558', 7709, '3190.26200000', '152.91009680', '0'], [1514428200000, '0.04795900', '0.04849900', '0.04786900', '0.04836000', '12910.59800000', 1514429999999, '620.85964449', 13794, '6624.55300000', '318.67455143', '0'], [1514430000000, '0.04841100', '0.04873400', '0.04805400', '0.04865600', '9145.29200000', 1514431799999, '442.53661244', 10391, '4308.80400000', '208.61354620', '0'], [1514431800000, '0.04870500', '0.04942800', '0.04862700', '0.04891000', '8046.32600000', 1514433599999, '394.13295866', 9335, '3837.75200000', '188.02464819', '0'], [1514433600000, '0.04891100', '0.04930000', '0.04886300', '0.04894700', '5307.61500000', 1514435399999, '260.53803512', 6456, '2380.36300000', '116.89072391', '0'], [1514435400000, '0.04894500', '0.04924900', '0.04871200', '0.04889300', '4313.61300000', 1514437199999, '211.08571792', 5576, '1909.79600000', '93.49600816', '0'], [1514437200000, '0.04889200', '0.04937000', '0.04887600', '0.04926200', '5409.37900000', 1514438999999, '265.67090980', 6363, '2293.31500000', '112.63774825', '0'], [1514439000000, '0.04926200', '0.04985500', '0.04926200', '0.04966900', '5343.54200000', 1514440799999, '264.31526675', 7036, '2932.27600000', '145.10416194', '0'], [1514440800000, '0.04963500', '0.04971000', '0.04939800', '0.04950400', '4042.89500000', 1514442599999, '200.34568351', 4830, '1825.58500000', '90.50264564', '0'], [1514442600000, '0.04955400', '0.04976500', '0.04929600', '0.04953400', '4606.73000000', 1514444399999, '228.11675858', 5336, '2267.59100000', '112.32103279', '0'], [1514444400000, '0.04953700', '0.04961600', '0.04900000', '0.04932700', '4704.77600000', 1514446199999, '231.96513287', 5195, '2031.14700000', '100.15352782', '0'], [1514446200000, '0.04930200', '0.04937300', '0.04900000', '0.04910200', '3410.42500000', 1514447999999, '167.75517394', 4342, '1685.01300000', '82.89950543', '0'], [1514448000000, '0.04915000', '0.04940500', '0.04900000', '0.04934800', '4344.07700000', 1514449799999, '213.67378334', 5145, '2060.95500000', '101.39895022', '0'], [1514449800000, '0.04934800', '0.04940400', '0.04918100', '0.04923400', '4216.51700000', 1514451599999, '207.70860598', 5098, '2010.01400000', '99.04670944', '0'], [1514451600000, '0.04923500', '0.04928300', '0.04884300', '0.04896900', '5319.65900000', 1514453399999, '261.34115494', 6252, '1814.24600000', '89.11047542', '0'], [1514453400000, '0.04896900', '0.04900000', '0.04862100', '0.04874800', '4938.92300000', 1514455199999, '240.85817183', 5766, '2283.01900000', '111.38188961', '0'], [1514455200000, '0.04874700', '0.04911800', '0.04861000', '0.04904100', '5827.00700000', 1514456999999, '284.90725852', 6505, '2737.53500000', '133.85819553', '0'], [1514457000000, '0.04905000', '0.04940000', '0.04891300', '0.04931700', '5642.83200000', 1514458799999, '277.21444387', 6823, '2735.36500000', '134.42291593', '0'], [1514458800000, '0.04931600', '0.04949600', '0.04909100', '0.04933300', '4640.63700000', 1514460599999, '229.01066582', 6004, '2630.30700000', '129.82749683', '0'], [1514460600000, '0.04933300', '0.05170000', '0.04913600', '0.04925100', '5399.18500000', 1514462399999, '267.30586623', 5413, '3191.00900000', '158.38344377', '0'], [1514462400000, '0.04925100', '0.04980600', '0.04920600', '0.04950000', '4107.77000000', 1514464199999, '202.86431743', 5364, '1782.28800000', '88.05410217', '0'], [1514464200000, '0.04950000', '0.04976000', '0.04930500', '0.04954600', '3688.19800000', 1514465999999, '182.30315177', 4711, '1730.46900000', '85.56248911', '0'], [1514466000000, '0.04950400', '0.04980100', '0.04927400', '0.04952800', '4903.65200000', 1514467799999, '242.65321194', 5440, '2369.28200000', '117.24522511', '0'], [1514467800000, '0.04952800', '0.04967100', '0.04951900', '0.04966900', '3915.61300000', 1514469599999, '194.21809834', 4628, '2094.87000000', '103.93307469', '0'], [1514469600000, '0.04966900', '0.04996800', '0.04955900', '0.04987400', '4855.25100000', 1514471399999, '241.80232215', 5644, '2205.23800000', '109.85171857', '0'], [1514471400000, '0.04987400', '0.04988700', '0.04960000', '0.04970500', '6616.79800000', 1514473199999, '328.95913082', 7025, '3095.74000000', '153.97580335', '0'], [1514473200000, '0.04976000', '0.04999900', '0.04962100', '0.04987900', '6294.97300000', 1514474999999, '313.35497363', 7685, '2630.34600000', '131.00556237', '0'], [1514475000000, '0.04984000', '0.05000000', '0.04980800', '0.04992000', '4760.04100000', 1514476799999, '237.71308081', 5829, '2319.57200000', '115.86729656', '0'], [1514476800000, '0.04997000', '0.05016400', '0.04990600', '0.05008000', '4968.57000000', 1514478599999, '248.56798435', 6185, '2212.36400000', '110.72028762', '0'], [1514478600000, '0.05009400', '0.05049900', '0.04979700', '0.04984300', '7000.22300000', 1514480399999, '351.10481558', 9796, '2645.15200000', '132.74207802', '0'], [1514480400000, '0.04985500', '0.05028900', '0.04979800', '0.05000000', '4932.64200000', 1514482199999, '246.76424620', 7403, '2532.19500000', '126.72792160', '0'], [1514482200000, '0.05003800', '0.05025100', '0.04970000', '0.04970700', '4429.50800000', 1514483999999, '221.13733230', 7259, '2053.29100000', '102.57710875', '0'], [1514484000000, '0.04970700', '0.05043300', '0.04962500', '0.05039100', '6732.93900000', 1514485799999, '337.55381116', 8860, '3494.87800000', '175.31846622', '0'], [1514485800000, '0.05039100', '0.05100000', '0.05027000', '0.05055900', '5837.94000000', 1514487599999, '294.99166985', 7748, '2717.59400000', '137.40183412', '0'], [1514487600000, '0.05050100', '0.05070500', '0.05021000', '0.05026600', '5183.27300000', 1514489399999, '261.24694125', 6990, '2198.15900000', '110.87360828', '0'], [1514489400000, '0.05021100', '0.05046900', '0.05007600', '0.05014100', '4982.90200000', 1514491199999, '250.04681676', 6464, '2466.58000000', '123.82596919', '0'], [1514491200000, '0.05014000', '0.05030000', '0.04973000', '0.05007000', '5719.56600000', 1514492999999, '286.32816356', 8390, '2708.20100000', '135.64176139', '0'], [1514493000000, '0.05007000', '0.05044000', '0.04999100', '0.05027000', '4743.70200000', 1514494799999, '238.02683433', 6841, '2229.96400000', '111.94655692', '0'], [1514494800000, '0.05025700', '0.05071000', '0.05015500', '0.05039500', '7377.90300000', 1514496599999, '371.70204102', 10100, '3461.72900000', '174.52913219', '0'], [1514496600000, '0.05036700', '0.05059800', '0.05015600', '0.05021500', '4262.59400000', 1514498399999, '214.45755871', 5845, '2222.69900000', '111.86382931', '0'], [1514498400000, '0.05021500', '0.05045000', '0.05013600', '0.05035200', '4265.07400000', 1514500199999, '214.43292412', 6450, '1855.63900000', '93.32121136', '0'], [1514500200000, '0.05039200', '0.05046000', '0.05030000', '0.05039700', '4861.72900000', 1514501999999, '244.83699160', 5602, '2599.12900000', '130.93757083', '0'], [1514502000000, '0.05037200', '0.05099900', '0.05030500', '0.05035100', '4231.06000000', 1514503799999, '213.47087726', 6148, '1977.75400000', '99.82674086', '0'], [1514503800000, '0.05035000', '0.05050600', '0.04978000', '0.04985300', '5127.87800000', 1514505599999, '257.10061604', 7125, '2222.54800000', '111.46550281', '0'], [1514505600000, '0.04988300', '0.05028300', '0.04977500', '0.05024900', '4169.63000000', 1514507399999, '208.70473913', 6668, '2019.45500000', '101.11339755', '0'], [1514507400000, '0.05020100', '0.05039500', '0.05015000', '0.05021300', '4306.50800000', 1514509199999, '216.24388194', 5808, '1933.11900000', '97.10503399', '0'], [1514509200000, '0.05021400', '0.05044900', '0.05015000', '0.05021800', '4696.19100000', 1514510999999, '236.01130256', 6040, '2110.64200000', '106.12064693', '0'], [1514511000000, '0.05021900', '0.05044900', '0.05015000', '0.05026700', '4516.09500000', 1514512799999, '227.02358536', 5898, '1935.18200000', '97.31602857', '0'], [1514512800000, '0.05031800', '0.05033300', '0.04963400', '0.04966600', '6114.74000000', 1514514599999, '305.38667762', 7879, '2652.06400000', '132.46751737', '0'], [1514514600000, '0.04968500', '0.05000000', '0.04950000', '0.04953600', '6478.29200000', 1514516399999, '321.98358220', 7480, '2864.73100000', '142.45181834', '0'], [1514516400000, '0.04958500', '0.04990000', '0.04952900', '0.04981300', '4944.48300000', 1514518199999, '245.98412696', 5957, '2216.21200000', '110.28881429', '0'], [1514518200000, '0.04986000', '0.05001300', '0.04978900', '0.04995800', '4654.59900000', 1514519999999, '232.17254613', 5466, '2217.28700000', '110.62904297', '0'], [1514520000000, '0.04995900', '0.05002000', '0.04956600', '0.04977300', '5475.54700000', 1514521799999, '272.80135797', 6866, '2514.23900000', '125.31697795', '0'], [1514521800000, '0.04977800', '0.05014700', '0.04972000', '0.05008700', '4718.31600000', 1514523599999, '235.57436330', 6003, '2226.85300000', '111.20988920', '0'], [1514523600000, '0.05014700', '0.05029000', '0.04996100', '0.05011200', '5453.23500000', 1514525399999, '272.94142058', 6520, '2702.75400000', '135.33530102', '0'], [1514525400000, '0.05015900', '0.05039900', '0.04994700', '0.05003000', '5683.05200000', 1514527199999, '284.56531050', 6943, '2563.24100000', '128.41565369', '0'], [1514527200000, '0.05003000', '0.05014700', '0.04971100', '0.04989000', '5192.29500000', 1514528999999, '259.25557344', 7117, '2363.54700000', '118.06882296', '0'], [1514529000000, '0.04989000', '0.05028800', '0.04988400', '0.05025600', '5600.39500000', 1514530799999, '280.50830043', 6651, '2390.35500000', '119.75423862', '0'], [1514530800000, '0.05020800', '0.05039900', '0.05004500', '0.05025100', '5317.92200000', 1514532599999, '267.14028416', 6863, '2312.53600000', '116.20420417', '0'], [1514532600000, '0.05020900', '0.05079900', '0.05020100', '0.05061300', '5816.93100000', 1514534399999, '293.47010926', 7117, '2894.42700000', '146.08811123', '0'], [1514534400000, '0.05066400', '0.05100000', '0.05060900', '0.05074500', '6996.00300000', 1514536199999, '355.27911913', 7951, '3375.46000000', '171.49618822', '0'], [1514536200000, '0.05074400', '0.05098900', '0.05070000', '0.05070100', '6294.19500000', 1514537999999, '319.69051897', 7533, '2543.60600000', '129.26151630', '0'], [1514538000000, '0.05070100', '0.05083600', '0.05030100', '0.05067900', '6289.69400000', 1514539799999, '318.88749606', 7313, '2696.88200000', '136.80428431', '0'], [1514539800000, '0.05067900', '0.05073500', '0.05029900', '0.05047400', '5291.23800000', 1514541599999, '267.48907718', 7128, '2577.51300000', '130.37082345', '0'], [1514541600000, '0.05047300', '0.05075000', '0.05034900', '0.05066600', '5538.89100000', 1514543399999, '279.96600275', 6698, '2618.66500000', '132.41932597', '0'], [1514543400000, '0.05072400', '0.05100000', '0.05058000', '0.05090000', '7247.59800000', 1514545199999, '367.94869332', 8931, '3290.65700000', '167.14852069', '0'], [1514545200000, '0.05081000', '0.05108000', '0.05054800', '0.05097600', '8089.01100000', 1514546999999, '411.47107235', 10055, '3679.28500000', '187.25211998', '0'], [1514547000000, '0.05097600', '0.05110900', '0.05085800', '0.05096500', '6658.41100000', 1514548799999, '339.50243994', 8486, '3077.57100000', '156.99874855', '0'], [1514548800000, '0.05096400', '0.05144200', '0.05066700', '0.05129000', '6698.23200000', 1514550599999, '342.55084013', 8803, '2713.98600000', '138.85803460', '0'], [1514550600000, '0.05130100', '0.05144000', '0.05069200', '0.05104000', '6676.49800000', 1514552399999, '341.06045253', 8635, '3188.25700000', '162.91696791', '0'], [1514552400000, '0.05104000', '0.05143000', '0.05090000', '0.05139900', '5443.27900000', 1514554199999, '278.59952468', 7464, '2726.88500000', '139.59468678', '0'], [1514554200000, '0.05135300', '0.05170200', '0.05129400', '0.05170000', '6201.11500000', 1514555999999, '319.65679940', 7487, '3056.67400000', '157.61766767', '0'], [1514556000000, '0.05169900', '0.05182700', '0.05125100', '0.05142000', '6698.07900000', 1514557799999, '345.44549431', 9237, '3352.59600000', '172.98577862', '0'], [1514557800000, '0.05142400', '0.05189700', '0.05142300', '0.05160600', '6481.71600000', 1514559599999, '334.51407457', 9542, '3161.18800000', '163.20448139', '0'], [1514559600000, '0.05160600', '0.05200000', '0.05144100', '0.05180500', '7067.54100000', 1514561399999, '365.48801284', 9445, '3181.57600000', '164.59758306', '0'], [1514561400000, '0.05180600', '0.05186200', '0.05131800', '0.05160300', '7887.13700000', 1514563199999, '406.66518228', 11062, '3412.33500000', '176.01294747', '0'], [1514563200000, '0.05160500', '0.05199600', '0.05141600', '0.05154000', '7553.36800000', 1514564999999, '389.88663232', 10542, '3515.55200000', '181.56793058', '0'], [1514565000000, '0.05162100', '0.05167000', '0.05104700', '0.05111800', '6754.25100000', 1514566799999, '346.49333445', 10067, '3141.21000000', '161.18572070', '0'], [1514566800000, '0.05111800', '0.05159600', '0.04997500', '0.05037800', '11864.06100000', 1514568599999, '601.28740040', 11649, '7725.32300000', '390.59828596', '0'], [1514568600000, '0.05037800', '0.05150000', '0.05030000', '0.05097300', '6441.35600000', 1514570399999, '326.70988676', 8928, '3039.14900000', '154.23561119', '0'], [1514570400000, '0.05092400', '0.05108800', '0.05081300', '0.05086600', '5589.85500000', 1514572199999, '284.73265123', 8502, '2767.45900000', '141.03542072', '0'], [1514572200000, '0.05086700', '0.05105200', '0.05058300', '0.05088000', '6557.32300000', 1514573999999, '332.87612936', 9235, '3055.51100000', '155.18159990', '0'], [1514574000000, '0.05087900', '0.05116100', '0.05070000', '0.05091400', '6686.88100000', 1514575799999, '339.84863936', 8810, '3259.20500000', '165.70695199', '0'], [1514575800000, '0.05095800', '0.05133700', '0.05091400', '0.05111900', '5283.13500000', 1514577599999, '269.98943407', 7430, '2383.62100000', '121.84837727', '0'], [1514577600000, '0.05111900', '0.05125000', '0.05099000', '0.05110000', '5551.74900000', 1514579399999, '283.73562864', 7458, '2883.40100000', '147.43008462', '0'], [1514579400000, '0.05110000', '0.05125000', '0.05095000', '0.05096000', '6736.11500000', 1514581199999, '343.97071298', 8822, '3261.30700000', '166.59963356', '0'], [1514581200000, '0.05099300', '0.05101800', '0.05050000', '0.05085800', '8670.11500000', 1514582999999, '440.81407028', 10558, '4101.21000000', '208.63237286', '0'], [1514583000000, '0.05085800', '0.05117600', '0.05076900', '0.05097700', '7140.58900000', 1514584799999, '364.03423755', 10111, '3571.34300000', '182.14758977', '0'], [1514584800000, '0.05095500', '0.05100000', '0.05050100', '0.05064100', '5787.70500000', 1514586599999, '294.06961517', 8429, '2935.50200000', '149.26574794', '0'], [1514586600000, '0.05064100', '0.05100000', '0.05050400', '0.05082700', '5676.94100000', 1514588399999, '288.20414250', 8296, '2615.80700000', '132.85752884', '0'], [1514588400000, '0.05082600', '0.05095200', '0.05056500', '0.05074600', '7800.84700000', 1514590199999, '395.84270436', 9904, '3600.16000000', '182.76502497', '0'], [1514590200000, '0.05066400', '0.05105500', '0.05050000', '0.05102000', '6659.08900000', 1514591999999, '338.53595624', 10592, '3201.27000000', '162.81775068', '0'], [1514592000000, '0.05102100', '0.05132500', '0.05100200', '0.05114900', '6563.91000000', 1514593799999, '335.51469919', 8070, '2982.57000000', '152.51466707', '0'], [1514593800000, '0.05114300', '0.05166700', '0.05090000', '0.05102900', '8605.25400000', 1514595599999, '440.06938503', 12380, '4149.61000000', '212.31150468', '0'], [1514595600000, '0.05094100', '0.05130000', '0.05083200', '0.05109400', '8057.80600000', 1514597399999, '411.49313022', 11705, '3809.47600000', '194.64310037', '0'], [1514597400000, '0.05109700', '0.05150000', '0.05068300', '0.05147000', '13682.11600000', 1514599199999, '699.13399936', 17559, '6484.97100000', '331.55726022', '0'], [1514599200000, '0.05147000', '0.05240400', '0.05000000', '0.05186400', '14622.82700000', 1514600999999, '757.96157308', 16723, '7143.56200000', '370.74888750', '0'], [1514601000000, '0.05188700', '0.05227800', '0.05151600', '0.05178900', '11088.10100000', 1514602799999, '576.57696927', 13169, '5205.83500000', '270.78560893', '0'], [1514602800000, '0.05174300', '0.05247200', '0.05151400', '0.05180400', '9885.91600000', 1514604599999, '515.82173779', 12499, '4485.67000000', '234.09597223', '0'], [1514604600000, '0.05180500', '0.05189800', '0.05123500', '0.05139800', '7843.13700000', 1514606399999, '405.24970924', 10545, '3945.55500000', '203.96018754', '0'], [1514606400000, '0.05148100', '0.05155000', '0.05080000', '0.05127000', '8421.23500000', 1514608199999, '430.89618041', 11886, '3829.03900000', '196.01920852', '0'], [1514608200000, '0.05127000', '0.05182000', '0.05112200', '0.05156000', '8138.97400000', 1514609999999, '417.73924527', 9748, '3563.35400000', '182.97287338', '0'], [1514610000000, '0.05156000', '0.05185200', '0.05140500', '0.05181000', '6333.21500000', 1514611799999, '327.18183615', 8186, '2461.91200000', '127.23887513', '0'], [1514611800000, '0.05181000', '0.05200000', '0.05158000', '0.05182200', '6388.53800000', 1514613599999, '331.22750099', 7937, '2629.44700000', '136.39393386', '0'], [1514613600000, '0.05187300', '0.05196100', '0.05150000', '0.05171000', '6335.66900000', 1514615399999, '328.07663497', 8554, '3036.65900000', '157.31026712', '0'], [1514615400000, '0.05173400', '0.05200000', '0.05161100', '0.05193400', '6882.47200000', 1514617199999, '356.44116727', 8230, '3323.90900000', '172.25277170', '0'], [1514617200000, '0.05186800', '0.05209000', '0.05180000', '0.05183600', '6959.29600000', 1514618999999, '361.34422208', 8156, '3781.16600000', '196.42260928', '0'], [1514619000000, '0.05192500', '0.05201500', '0.05165000', '0.05178300', '6800.30900000', 1514620799999, '352.29679428', 9153, '3206.53500000', '166.18332685', '0'], [1514620800000, '0.05180100', '0.05250000', '0.05170000', '0.05200200', '9153.92800000', 1514622599999, '476.09379615', 11097, '4599.47000000', '239.38738020', '0'], [1514622600000, '0.05205600', '0.05269600', '0.05187300', '0.05232600', '8128.70700000', 1514624399999, '423.85166929', 9347, '3717.90300000', '193.96751854', '0'], [1514624400000, '0.05228000', '0.05280000', '0.05227800', '0.05252100', '7659.31300000', 1514626199999, '402.05428067', 9545, '3509.66000000', '184.35485349', '0'], [1514626200000, '0.05252100', '0.05300000', '0.05248800', '0.05284700', '8276.64300000', 1514627999999, '436.34731023', 9578, '3798.13100000', '200.36217044', '0'], [1514628000000, '0.05284700', '0.05320200', '0.05281700', '0.05306000', '9383.29900000', 1514629799999, '497.52579352', 11330, '4326.28600000', '229.47576258', '0'], [1514629800000, '0.05306000', '0.05350000', '0.05292300', '0.05320500', '6575.11200000', 1514631599999, '349.24905858', 8626, '3212.31000000', '170.70162887', '0'], [1514631600000, '0.05325000', '0.05325200', '0.05264500', '0.05286800', '7964.32100000', 1514633399999, '421.95397832', 8440, '4179.87100000', '221.55408912', '0'], [1514633400000, '0.05286800', '0.05330000', '0.05276100', '0.05298100', '5954.93300000', 1514635199999, '315.31389824', 7565, '3260.55900000', '172.66676821', '0'], [1514635200000, '0.05303500', '0.05380000', '0.05296700', '0.05356500', '7974.01300000', 1514636999999, '426.21393220', 11007, '3950.04600000', '211.27771960', '0'], [1514637000000, '0.05356500', '0.05389300', '0.05342300', '0.05361700', '8718.77400000', 1514638799999, '467.53542851', 11265, '4218.83100000', '226.31826523', '0'], [1514638800000, '0.05361600', '0.05442300', '0.05352100', '0.05415000', '10388.00600000', 1514640599999, '559.59408671', 12682, '5022.03000000', '270.65451892', '0'], [1514640600000, '0.05421700', '0.05450000', '0.05408800', '0.05430000', '8288.50500000', 1514642399999, '450.01749585', 10000, '4114.31500000', '223.47893918', '0'], [1514642400000, '0.05428600', '0.05499800', '0.05403800', '0.05497000', '8676.37800000', 1514644199999, '472.32646458', 10980, '4195.95400000', '228.50182593', '0'], [1514644200000, '0.05497000', '0.05520000', '0.05461100', '0.05490700', '9429.14100000', 1514645999999, '518.03013125', 10149, '4441.18000000', '244.10670511', '0'], [1514646000000, '0.05490700', '0.05525000', '0.05458100', '0.05502100', '8032.57500000', 1514647799999, '441.55290380', 9476, '3829.37200000', '210.58568197', '0'], [1514647800000, '0.05501300', '0.05509500', '0.05441700', '0.05458800', '6360.43500000', 1514649599999, '348.72229414', 8032, '2945.79100000', '161.52937907', '0'], [1514649600000, '0.05458800', '0.05480000', '0.05434900', '0.05472200', '6736.66600000', 1514651399999, '367.69426698', 9203, '3002.39300000', '163.94170896', '0'], [1514651400000, '0.05472000', '0.05530100', '0.05456700', '0.05521700', '8791.94700000', 1514653199999, '483.65692648', 9912, '3888.95600000', '214.01146567', '0'], [1514653200000, '0.05521800', '0.05530000', '0.05491900', '0.05500200', '6722.22600000', 1514654999999, '370.21565113', 8321, '2964.34900000', '163.29747708', '0'], [1514655000000, '0.05500200', '0.05514600', '0.05411100', '0.05415500', '7408.71600000', 1514656799999, '405.19402543', 9596, '3638.69200000', '199.03395809', '0'], [1514656800000, '0.05415700', '0.05499900', '0.05401200', '0.05485900', '8691.79500000', 1514658599999, '472.99613525', 11477, '4232.54800000', '230.44583586', '0'], [1514658600000, '0.05485800', '0.05520000', '0.05469800', '0.05487500', '9055.17000000', 1514660399999, '497.22362838', 10981, '4520.79300000', '248.37647649', '0'], [1514660400000, '0.05483900', '0.05530100', '0.05382700', '0.05390300', '8604.74000000', 1514662199999, '466.60803711', 11468, '4316.89100000', '234.11296349', '0'], [1514662200000, '0.05396100', '0.05428100', '0.05370400', '0.05374100', '6966.99800000', 1514663999999, '375.95928059', 8959, '3591.80300000', '193.88191046', '0'], [1514664000000, '0.05374200', '0.05445500', '0.05359900', '0.05427400', '7735.70200000', 1514665799999, '417.89031876', 10595, '3769.19400000', '203.70651473', '0'], [1514665800000, '0.05422400', '0.05466300', '0.05418300', '0.05427800', '6875.71300000', 1514667599999, '374.03184274', 9725, '3196.15100000', '173.93609702', '0'], [1514667600000, '0.05427800', '0.05500000', '0.05426600', '0.05491900', '7642.82100000', 1514669399999, '417.66122864', 8953, '3775.17800000', '206.38838679', '0'], [1514669400000, '0.05486600', '0.05511600', '0.05472900', '0.05506000', '6312.34400000', 1514671199999, '346.60420832', 8398, '3095.97600000', '170.04313762', '0'], [1514671200000, '0.05507000', '0.05513000', '0.05459700', '0.05482400', '5520.88100000', 1514672999999, '302.69058188', 7698, '2620.67300000', '143.70399995', '0'], [1514673000000, '0.05488000', '0.05505000', '0.05469400', '0.05480200', '6423.04200000', 1514674799999, '352.34305946', 8084, '3202.00500000', '175.68408430', '0'], [1514674800000, '0.05485500', '0.05493000', '0.05450100', '0.05468800', '5050.32000000', 1514676599999, '276.54811508', 7219, '2310.93600000', '126.59115193', '0'], [1514676600000, '0.05468900', '0.05520000', '0.05467000', '0.05512700', '6042.54700000', 1514678399999, '332.43505977', 7270, '3040.64500000', '167.33943028', '0'], [1514678400000, '0.05506000', '0.05544900', '0.05500000', '0.05522000', '7598.84300000', 1514680199999, '419.67512356', 8768, '3426.56100000', '189.29301871', '0'], [1514680200000, '0.05522000', '0.05538300', '0.05450000', '0.05454200', '5624.43200000', 1514681999999, '309.92812976', 8707, '2623.54700000', '144.62990399', '0'], [1514682000000, '0.05459500', '0.05492300', '0.05432100', '0.05440900', '4864.42700000', 1514683799999, '265.34209101', 8500, '2297.61200000', '125.38744397', '0'], [1514683800000, '0.05440900', '0.05460900', '0.05400000', '0.05412100', '7748.60200000', 1514685599999, '420.07968365', 10962, '3490.61200000', '189.33446094', '0'], [1514685600000, '0.05412500', '0.05445500', '0.05400000', '0.05426400', '6678.64200000', 1514687399999, '362.29420083', 10246, '3174.43900000', '172.29295489', '0'], [1514687400000, '0.05421900', '0.05450000', '0.05316400', '0.05319500', '8759.72400000', 1514689199999, '470.44183612', 12025, '4021.95700000', '216.05851109', '0'], [1514689200000, '0.05319100', '0.05398500', '0.05272800', '0.05281800', '9274.38300000', 1514690999999, '493.85322284', 13328, '4554.41700000', '242.62442778', '0'], [1514691000000, '0.05282500', '0.05370000', '0.05263500', '0.05363000', '8227.95100000', 1514692799999, '438.01358657', 11401, '3552.66700000', '189.20695682', '0'], [1514692800000, '0.05363000', '0.05434800', '0.05361900', '0.05424600', '7348.32000000', 1514694599999, '395.92240258', 9225, '2636.45400000', '142.13413701', '0'], [1514694600000, '0.05424600', '0.05443800', '0.05370400', '0.05406500', '7142.06700000', 1514696399999, '386.17411696', 8973, '3680.49300000', '199.07809550', '0'], [1514696400000, '0.05411700', '0.05450000', '0.05379100', '0.05394000', '7892.79500000', 1514698199999, '426.38038830', 11273, '3574.14100000', '193.20397061', '0'], [1514698200000, '0.05399200', '0.05472200', '0.05388400', '0.05449600', '7490.32900000', 1514699999999, '406.54618050', 10060, '3629.88900000', '197.11361234', '0'], [1514700000000, '0.05449600', '0.05483000', '0.05430900', '0.05464500', '7033.50400000', 1514701799999, '383.48815420', 8915, '3382.76900000', '184.53730891', '0'], [1514701800000, '0.05464500', '0.05500000', '0.05453700', '0.05489300', '7678.36700000', 1514703599999, '420.37269322', 8555, '3441.74700000', '188.50792234', '0'], [1514703600000, '0.05489000', '0.05493900', '0.05435700', '0.05444800', '5569.38700000', 1514705399999, '304.09230572', 7234, '2854.06200000', '155.90092578', '0'], [1514705400000, '0.05439600', '0.05460800', '0.05430000', '0.05447600', '5394.45000000', 1514707199999, '293.82525480', 6815, '2838.04800000', '154.63422985', '0'], [1514707200000, '0.05447600', '0.05493000', '0.05388800', '0.05466300', '5708.07400000', 1514708999999, '311.63226200', 8025, '2648.30200000', '144.66605085', '0'], [1514709000000, '0.05471300', '0.05498600', '0.05434800', '0.05481000', '6230.02500000', 1514710799999, '340.61310874', 9254, '2799.56800000', '153.12731058', '0'], [1514710800000, '0.05486400', '0.05503300', '0.05470600', '0.05501100', '4664.31500000', 1514712599999, '256.23413999', 6179, '2451.02700000', '134.70397439', '0'], [1514712600000, '0.05495000', '0.05505300', '0.05486000', '0.05494100', '4719.03400000', 1514714399999, '259.20355650', 5966, '2120.23300000', '116.50408554', '0'], [1514714400000, '0.05494000', '0.05499700', '0.05466500', '0.05477300', '4430.61100000', 1514716199999, '242.93060768', 6688, '2210.49800000', '121.24666869', '0'], [1514716200000, '0.05477300', '0.05490000', '0.05455000', '0.05477400', '4914.69700000', 1514717999999, '269.02286251', 6421, '2475.90300000', '135.57750657', '0'], [1514718000000, '0.05477400', '0.05489400', '0.05450000', '0.05465100', '5511.05100000', 1514719799999, '301.30218735', 8727, '2637.67700000', '144.28699291', '0'], [1514719800000, '0.05465200', '0.05477900', '0.05440000', '0.05475600', '5822.39400000', 1514721599999, '317.50764758', 9007, '2490.00800000', '135.85549924', '0'], [1514721600000, '0.05475600', '0.05500000', '0.05450000', '0.05450300', '7028.13000000', 1514723399999, '384.89877397', 9537, '3122.57800000', '171.11354174', '0'], [1514723400000, '0.05450300', '0.05490500', '0.05425000', '0.05473700', '7867.99500000', 1514725199999, '429.10707757', 9647, '3465.97500000', '189.10722905', '0'], [1514725200000, '0.05478800', '0.05507000', '0.05442000', '0.05476300', '9248.45900000', 1514726999999, '507.31990757', 11199, '4319.93500000', '237.01576162', '0'], [1514727000000, '0.05470900', '0.05492100', '0.05441800', '0.05463000', '6552.60700000', 1514728799999, '358.61125125', 9398, '3204.10700000', '175.43200236', '0'], [1514728800000, '0.05468000', '0.05475900', '0.05432100', '0.05454400', '7963.19000000', 1514730599999, '434.73819205', 11044, '4160.82500000', '227.24165737', '0'], [1514730600000, '0.05454400', '0.05500000', '0.05427800', '0.05460200', '10302.78200000', 1514732399999, '561.77332568', 13499, '5322.63200000', '290.38367508', '0'], [1514732400000, '0.05469000', '0.05474700', '0.05394600', '0.05449700', '10149.52500000', 1514734199999, '550.85710233', 12140, '5340.04500000', '289.77027310', '0'], [1514734200000, '0.05449800', '0.05487600', '0.05422800', '0.05439900', '7692.32600000', 1514735999999, '419.85003658', 11453, '3405.10600000', '185.95572592', '0'], [1514736000000, '0.05439900', '0.05465500', '0.05337200', '0.05369100', '10004.26600000', 1514737799999, '538.55391440', 13426, '4307.94100000', '232.11074097', '0'], [1514737800000, '0.05365000', '0.05374300', '0.05230900', '0.05262600', '9827.17800000', 1514739599999, '518.80708977', 13747, '4897.71400000', '258.60800981', '0'], [1514739600000, '0.05262600', '0.05353900', '0.05258800', '0.05311900', '7685.70500000', 1514741399999, '408.34344976', 10518, '3960.93400000', '210.53115237', '0'], [1514741400000, '0.05304800', '0.05335000', '0.05300100', '0.05311500', '6033.40600000', 1514743199999, '320.84003060', 8340, '3048.19400000', '162.15437764', '0'], [1514743200000, '0.05311500', '0.05322400', '0.05290100', '0.05311700', '4811.08000000', 1514744999999, '255.36321895', 7090, '2386.24900000', '126.70191762', '0'], [1514745000000, '0.05311700', '0.05322500', '0.05300100', '0.05314800', '4964.48100000', 1514746799999, '263.68098185', 6875, '2358.84700000', '125.32794329', '0'], [1514746800000, '0.05314700', '0.05319500', '0.05273900', '0.05310300', '4939.34800000', 1514748599999, '261.86045819', 7100, '2600.92000000', '137.93335077', '0'], [1514748600000, '0.05310300', '0.05333000', '0.05295400', '0.05313500', '5013.77900000', 1514750399999, '266.42207641', 6941, '2593.15200000', '137.83109766', '0'], [1514750400000, '0.05318900', '0.05331200', '0.05293800', '0.05313200', '5740.52300000', 1514752199999, '304.94843940', 8082, '2933.42900000', '155.90170697', '0'], [1514752200000, '0.05313200', '0.05319500', '0.05265000', '0.05284100', '5577.91700000', 1514753999999, '294.97166981', 8199, '2689.50300000', '142.27419065', '0'], [1514754000000, '0.05284100', '0.05300400', '0.05270000', '0.05284900', '6218.12100000', 1514755799999, '328.55625133', 7663, '3202.90100000', '169.29354678', '0'], [1514755800000, '0.05284400', '0.05306300', '0.05279700', '0.05290300', '4749.64100000', 1514757599999, '251.42029204', 7129, '2417.10700000', '127.98958988', '0'], [1514757600000, '0.05293600', '0.05320000', '0.05280500', '0.05308600', '4742.54700000', 1514759399999, '251.32992486', 6474, '2272.11400000', '120.44373962', '0'], [1514759400000, '0.05304100', '0.05342300', '0.05296100', '0.05319000', '4379.05600000', 1514761199999, '232.78550228', 6059, '1892.49900000', '100.62274961', '0'], [1514761200000, '0.05319000', '0.05339500', '0.05279300', '0.05330600', '5380.03700000', 1514762999999, '286.59471967', 6868, '2559.50300000', '136.42484154', '0'], [1514763000000, '0.05325600', '0.05365400', '0.05308600', '0.05358600', '5444.14000000', 1514764799999, '290.73460321', 7400, '2676.87300000', '143.01872513', '0'], [1514764800000, '0.05358600', '0.05404200', '0.05347400', '0.05375000', '6805.69700000', 1514766599999, '365.88731144', 8785, '3057.09900000', '164.38264393', '0']]
"""

# %%
# fetch weekly klines since it listed
klines = client.get_historical_klines("NEOBTC", Client.KLINE_INTERVAL_1WEEK, "1 Jan, 2017")  
print(f'{klines}')
# Out:
# [[1499644800000, '0.00375000', '0.00375000', '0.00235700', '0.00263800', '473736.36000000', 1500249599999, '1196.77166665', 8973, '286442.84000000', '723.69695083', '218593.00000000'], [1500249600000, '0.00263800', '0.00345800', '0.00255700', '0.00326100', '1594660.22000000', 1500854399999, '4589.96992084', 31760, '1000499.53000000', '2879.09366021', '359801.00000000'], [1500854400000, '0.00326600', '0.00326900', '0.00240100', '0.00261200', '3971754.21000000', 1501459199999, '11114.83093982', 51384, '2219779.02000000', '6233.71564475', '533884.00000000'], [1501459200000, '0.00261100', '0.00498400', '0.00249700', '0.00482100', '4986580.16000000', 1502063999999, '17488.29338244', 69886, '2569264.33000000', '9026.54218521', '630085.00000000'], [1502064000000, '0.00481900', '0.01381600', '0.00440800', '0.01170400', '8971365.12000000', 1502668799999, '70289.94990929', 149558, '4583357.71000000', '35975.96593847', '975334.00000000'], [1502668800000, '0.01170400', '0.01330000', '0.00756800'
# ...

# %%
"""
>>>[[1499644800000, '0.00375000', '0.00375000', '0.00235700', '0.00263800', '473736.36000000', 1500249599999, '1196.77166665', 8973, '286442.84000000', '723.69695083', '218593.00000000'], [1500249600000, '0.00263800', '0.00345800', '0.00255700', '0.00326100', '1594660.22000000', 1500854399999, '4589.96992084', 31760, '1000499.53000000', '2879.09366021', '359801.00000000'], [1500854400000, '0.00326600', '0.00326900', '0.00240100', '0.00261200', '3971754.21000000', 1501459199999, '11114.83093982', 51384, '2219779.02000000', '6233.71564475', '533884.00000000'], [1501459200000, '0.00261100', '0.00498400', '0.00249700', '0.00482100', '4986580.16000000', 1502063999999, '17488.29338244', 69886, '2569264.33000000', '9026.54218521', '630085.00000000'], [1502064000000, '0.00481900', '0.01381600', '0.00440800', '0.01170400', '8971365.12000000', 1502668799999, '70289.94990929', 149558, '4583357.71000000', '35975.96593847', '975334.00000000'], [1502668800000, '0.01170400', '0.01330000', '0.00756800', '0.00929800', '7354935.19000000', 1503273599999, '74278.97967737', 166864, '3807134.04000000', '38512.47450285', '1494621.00000000'], [1503273600000, '0.00931000', '0.01074600', '0.00842300', '0.00920500', '2592193.79000000', 1503878399999, '23966.19393344', 118851, '1330793.01000000', '12284.55099467', '1805071.00000000'], [1503878400000, '0.00916200', '0.00933900', '0.00570100', '0.00669900', '2328378.96000000', 1504483199999, '16915.17702905', 111948, '1140653.23000000', '8260.92633938', '1878716.13000000'], [1504483200000, '0.00669800', '0.00735000', '0.00331900', '0.00557800', '2419624.27000000', 1505087999999, '13383.81703613', 94747, '1278794.99000000', '7076.75322818', '1901402.13000000'], [1505088000000, '0.00557800', '0.00595000', '0.00440200', '0.00536100', '2170095.15000000', 1505692799999, '11096.19770457', 120201, '1095920.49000000', '5610.30638869', '2032269.57887000'], [1505692800000, '0.00536300', '0.00545800', '0.00461700', '0.00540300', '1723681.01000000', 1506297599999, '8824.87522473', 119074, '874922.55000000', '4484.32987530', '2077050.58000000'], [1506297600000, '0.00540300', '0.00833900', '0.00536700', '0.00810500', '3985736.96000000', 1506902399999, '28182.56414476', 167348, '1976511.00000000', '13951.41164814', '2239602.58000000'], [1506902400000, '0.00811400', '0.00882900', '0.00665000', '0.00693700', '3846444.22000000', 1507507199999, '29864.76536690', 179033, '1807998.25000000', '14055.55879919', '2362143.58000000'], [1507507200000, '0.00693600', '0.00712900', '0.00455500', '0.00486800', '3450411.34000000', 1508111999999, '19453.23854126', 144094, '1630255.57000000', '9154.97942502', '2501821.58000000'], [1508112000000, '0.00486800', '0.00588800', '0.00425100', '0.00479400', '2988037.52000000', 1508716799999, '15048.15414045', 102239, '1539351.40000000', '7749.85520494', '2617631.58000000'], [1508716800000, '0.00479400', '0.00580000', '0.00428500', '0.00449400', '3112199.77000000', 1509321599999, '15538.30944565', 109351, '1614888.73000000', '8062.38686734', '2631299.58000000'], [1509321600000, '0.00450000', '0.00513200', '0.00309900', '0.00357500', '3358632.44000000', 1509926399999, '13194.61821863', 132832, '1737244.27000000', '6843.71176713', '2870262.58000000'], [1509926400000, '0.00357400', '0.00487000', '0.00351200', '0.00460900', '3451587.69000000', 1510531199999, '14282.96872073', 136202, '1637577.13000000', '6764.48271934', '2706810.45955000'], [1510531200000, '0.00460900', '0.00630000', '0.00349400', '0.00495800', '5571813.50000000', 1511135999999, '26828.85000446', 231908, '2837395.60000000', '13679.41285759', '3047928.46000000'], [1511136000000, '0.00495800', '0.00546600', '0.00400000', '0.00411900', '3910182.09000000', 1511740799999, '17501.45090555', 190617, '1780108.47000000', '7989.09761841', '2870842.46000000'], [1511740800000, '0.00411900', '0.00438100', '0.00313200', '0.00327500', '3168996.20000000', 1512345599999, '11269.53438873', 164863, '1360118.57000000', '4804.75577662', '3110653.46000000'], [1512345600000, '0.00327500', '0.00382000', '0.00183800', '0.00220500', '5110467.20000000', 1512950399999, '13719.39164606', 236175, '2518893.00000000', '6908.36260226', '3264237.46000000'], [1512950400000, '0.00220200', '0.00397800', '0.00198000', '0.00356100', '9645212.58000000', 1513555199999, '26817.82904376', 432353, '4086405.40000000', '11403.84969005', '3938166.46000000'], [1513555200000, '0.00356800', '0.00476000', '0.00347000', '0.00432500', '7416389.09000000', 1514159999999, '31119.33610944', 462358, '3783027.40000000', '15891.92602080', '0'], [1514160000000, '0.00432300', '0.00598000', '0.00382500', '0.00546100', '6239360.66000000', 1514764799999, '28737.35727401', 448217, '3224236.69000000', '14829.67045937', '0'], [1514764800000, '0.00546100', '0.00735600', '0.00520000', '0.00629500', '5258537.91000000', 1515369599999, '32840.35233575', 611840, '2765034.31000000', '17318.27625889', '0'], [1515369600000, '0.00629800', '0.01370000', '0.00621300', '0.01260000', '5454442.10000000', 1515974399999, '48522.34732727', 772607, '3050908.61000000', '27144.62648409', '0'], [1515974400000, '0.01260000', '0.01441000', '0.00902000', '0.01152000', '6872694.23000000', 1516579199999, '84894.18100385', 1196384, '3446402.44000000', '42765.75411644', '0'], [1516579200000, '0.01152000', '0.01300000', '0.01096000', '0.01297800', '1683689.68000000', 1517183999999, '20111.99773007', 411054, '818339.60000000', '9782.93506087', '0'], [1517184000000, '0.01297900', '0.01520000', '0.01180000', '0.01307500', '2377528.31000000', 1517788799999, '32803.20195546', 685218, '1118122.14000000', '15482.67246283', '0'], [1517788800000, '0.01307500', '0.01449000', '0.01059200', '0.01263000', '2191491.21000000', 1518393599999, '27954.12253793', 661829, '1039231.63000000', '13328.44207766', '0'], [1518393600000, '0.01263000', '0.01343100', '0.01182100', '0.01206300', '1445582.93000000', 1518998399999, '18200.14653659', 520099, '673136.86000000', '8483.81753367', '0'], [1518998400000, '0.01206400', '0.01243400', '0.01088000', '0.01218700', '1149941.66000000', 1519603199999, '13418.35400793', 403560, '566342.76000000', '6605.96008605', '0'], [1519603200000, '0.01218600', '0.01398800', '0.01025400', '0.01035700', '2202764.43000000', 1520207999999, '27132.57485068', 542024, '1100133.17000000', '13497.93592042', '0'], [1520208000000, '0.01035700', '0.01044700', '0.00939300', '0.00949100', '1843443.25000000', 1520812799999, '18196.29373453', 433688, '931443.62000000', '9204.53341141', '0'], [1520812800000, '0.00949100', '0.00960000', '0.00610000', '0.00796000', '2577762.23000000', 1521417599999, '21382.64121103', 431788, '1295545.37000000', '10740.34101363', '0'], [1521417600000, '0.00796000', '0.00882600', '0.00751200', '0.00773400', '2859484.23000000', 1522022399999, '22945.89864408', 449252, '1429521.17000000', '11473.10575426', '0'], [1522022400000, '0.00773400', '0.00779600', '0.00670000', '0.00694000', '2921631.28000000', 1522627199999, '21084.84511908', 387297, '1526747.74000000', '11019.99038074', '0'], [1522627200000, '0.00693400', '0.00722500', '0.00666800', '0.00703400', '2306330.67000000', 1523231999999, '15927.93818350', 297339, '1182855.55000000', '8170.75379790', '0'], [1523232000000, '0.00703400', '0.00873200', '0.00699700', '0.00845500', '4510081.38000000', 1523836799999, '35872.39126509', 597567, '2267785.15000000', '18045.68195878', '0'], [1523836800000, '0.00845300', '0.00915000', '0.00810200', '0.00837200', '3159168.31000000', 1524441599999, '27212.07248458', 484102, '1572584.57000000', '13555.28103639', '0'], [1524441600000, '0.00837200', '0.00986000', '0.00777700', '0.00961700', '3827332.81000000', 1525046399999, '32733.75899798', 584717, '1922092.45000000', '16476.52023584', '0'], [1525046400000, '0.00961700', '0.01000000', '0.00845300', '0.00866000', '3116945.65000000', 1525651199999, '28276.52750444', 503500, '1526482.54000000', '13852.72863869', '0'], [1525651200000, '0.00866300', '0.00866900', '0.00700000', '0.00775800', '2408073.60000000', 1526255999999, '19169.09985469', 402613, '1158950.63000000', '9221.00120364', '0'], [1526256000000, '0.00775700', '0.00795500', '0.00706100', '0.00747300', '2084001.35000000', 1526860799999, '15432.70305754', 338164, '1102466.81000000', '8170.62526437', '0'], [1526860800000, '0.00747200', '0.00774300', '0.00684900', '0.00719900', '1905191.74000000', 1527465599999, '13693.33176341', 297924, '989970.14000000', '7114.19615214', '0'], [1527465600000, '0.00719900', '0.00750000', '0.00670100', '0.00731400', '905144.68000000', 1528070399999, '6459.03192964', 189002, '414640.41000000', '2966.78871898', '0'], [1528070400000, '0.00731500', '0.00739000', '0.00657300', '0.00670100', '739120.52000000', 1528675199999, '5149.39910413', 149143, '367398.67000000', '2558.71953365', '0'], [1528675200000, '0.00669500', '0.00680400', '0.00569000', '0.00598100', '948957.74000000', 1529279999999, '5814.42899684', 200671, '430647.42000000', '2632.62844596', '0'], [1529280000000, '0.00598200', '0.00605700', '0.00500000', '0.00506200', '2384134.84000000', 1529884799999, '13340.56040371', 283596, '1158193.15000000', '6496.42070412', '0'], [1529884800000, '0.00506200', '0.00522900', '0.00464800', '0.00491800', '2346510.20000000', 1530489599999, '11484.85956673', 286112, '1093622.54000000', '5352.01770025', '0'], [1530489600000, '0.00491700', '0.00652100', '0.00489200', '0.00582200', '3942779.12000000', 1531094399999, '22805.44903063', 458564, '1996054.52000000', '11553.74631432', '0'], [1531094400000, '0.00582200', '0.00584300', '0.00500000', '0.00527900', '2539589.86000000', 1531699199999, '13460.03736713', 337472, '1243376.40000000', '6588.75564569', '0'], [1531699200000, '0.00527900', '0.00560000', '0.00441400', '0.00447100', '2884129.80000000', 1532303999999, '14409.37785459', 355433, '1468238.33000000', '7321.28788728', '0'], [1532304000000, '0.00447400', '0.00451200', '0.00368800', '0.00406700', '2360386.42000000', 1532908799999, '9810.23716715', 273688, '1174506.97000000', '4883.99311820', '0'], [1532908800000, '0.00406700', '0.00414000', '0.00362800', '0.00391700', '2233127.82000000', 1533513599999, '8571.79756704', 257457, '1148051.35000000', '4409.54731542', '0'], [1533513600000, '0.00391800', '0.00400000', '0.00285000', '0.00293100', '2864749.45000000', 1534118399999, '9705.51495614', 391150, '1437900.68000000', '4863.00530037', '0'], [1534118400000, '0.00292700', '0.00318800', '0.00234000', '0.00299900', '4888702.22000000', 1534723199999, '13342.92905642', 434535, '2441274.46000000', '6665.83029456', '0'], [1534723200000, '0.00299800', '0.00303700', '0.00253100', '0.00261200', '3674211.75000000', 1535327999999, '9954.42139599', 293766, '1802947.16000000', '4895.65853008', '0'], [1535328000000, '0.00261200', '0.00321400', '0.00259000', '0.00302600', '4632673.13000000', 1535932799999, '13506.91481739', 375734, '2299626.95000000', '6700.48907629', '0'], [1535932800000, '0.00302700', '0.00342000', '0.00280000', '0.00294500', '4540277.24000000', 1536537599999, '13957.31764501', 411888, '2204482.28000000', '6786.74743849', '0'], [1536537600000, '0.00294000', '0.00299400', '0.00259200', '0.00276100', '3235321.15000000', 1537142399999, '9085.36383774', 290680, '1618089.37000000', '4548.20585701', '0'], [1537142400000, '0.00276100', '0.00307600', '0.00260700', '0.00291900', '3463122.49000000', 1537747199999, '9605.35728504', 291958, '1692640.97000000', '4699.09371693', '0'], [1537747200000, '0.00292000', '0.00307900', '0.00268100', '0.00285800', '2792031.99000000', 1538351999999, '7960.44435450', 287040, '1448779.96000000', '4132.47553749', '0'], [1538352000000, '0.00285700', '0.00288600', '0.00270000', '0.00274900', '1821385.24000000', 1538956799999, '5054.18970830', 189371, '816784.60000000', '2267.51842307', '0'], [1538956800000, '0.00275200', '0.00281300', '0.00245800', '0.00249100', '2085691.73000000', 1539561599999, '5460.21678361', 201465, '981631.77000000', '2566.87979539', '0'], [1539561600000, '0.00249200', '0.00270000', '0.00239000', '0.00254600', '2612745.95000000', 1540166399999, '6625.13850418', 232210, '1227537.02000000', '3108.53249989', '0'], [1540166400000, '0.00254600', '0.00263000', '0.00246300', '0.00249900', '1183908.92000000', 1540771199999, '3011.04434858', 127862, '577109.98000000', '1469.81064050', '0'], [1540771200000, '0.00250000', '0.00264500', '0.00234200', '0.00260500', '1431843.46000000', 1541375999999, '3559.33388547', 161926, '671788.54000000', '1667.64586413', '0'], [1541376000000, '0.00260500', '0.00269400', '0.00243700', '0.00250800', '1212954.17000000', 1541980799999, '3097.77268598', 158289, '559637.29000000', '1429.24634976', '0'], [1541980800000, '0.00250800', '0.00252000', '0.00219500', '0.00223900', '1524419.19000000', 1542585599999, '3536.88878120', 178905, '712571.38000000', '1655.32726057', '0'], [1542585600000, '0.00223900', '0.00224000', '0.00185900', '0.00191900', '3472906.63000000', 1543190399999, '6898.83446874', 252677, '1611213.48000000', '3202.44351202', '0'], [1543190400000, '0.00191900', '0.00201900', '0.00183400', '0.00192600', '2316445.83000000', 1543795199999, '4462.68899591', 134132, '1099408.67000000', '2120.27152019', '0'], [1543795200000, '0.00192600', '0.00196000', '0.00167200', '0.00177600', '2752736.54000000', 1544399999999, '4965.71407883', 140895, '1283075.24000000', '2319.92233050', '0'], [1544400000000, '0.00177500', '0.00183000', '0.00169800', '0.00175900', '1697610.23000000', 1545004799999, '2962.89248559', 86953, '862489.69000000', '1506.64355874', '0'], [1545004800000, '0.00176000', '0.00198300', '0.00171100', '0.00192300', '4522807.02000000', 1545609599999, '8247.49378331', 195801, '2327164.30000000', '4241.73317919', '0'], [1545609600000, '0.00192200', '0.00215200', '0.00186800', '0.00209400', '4682330.34000000', 1546214399999, '9431.02273260', 233379, '2325504.46000000', '4689.03703693', '0'], [1546214400000, '0.00209400', '0.00220600', '0.00196000', '0.00212100', '2279050.55000000', 1546819199999, '4676.75612807', 132123, '1114350.74000000', '2289.61176484', '0'], [1546819200000, '0.00212200', '0.00240800', '0.00198100', '0.00200900', '4721377.04000000', 1547423999999, '10369.72803659', 257368, '2326308.28000000', '5119.51641364', '0'], [1547424000000, '0.00201000', '0.00228000', '0.00200900', '0.00210500', '2426868.73000000', 1548028799999, '5131.23515230', 141699, '1220702.71000000', '2583.16867893', '0'], [1548028800000, '0.00210800', '0.00215500', '0.00203900', '0.00206500', '1674753.71000000', 1548633599999, '3520.90714509', 89347, '798368.86000000', '1679.92973021', '0'], [1548633600000, '0.00206400', '0.00208600', '0.00197200', '0.00202700', '1959517.64000000', 1549238399999, '3964.38406739', 91936, '883238.14000000', '1787.66389816', '0'], [1549238400000, '0.00202700', '0.00223000', '0.00197900', '0.00216500', '2099642.14000000', 1549843199999, '4340.21967650', 109456, '1022624.54000000', '2116.56455813', '0'], [1549843200000, '0.00216400', '0.00240000', '0.00210900', '0.00228500', '4258264.44000000', 1550447999999, '9609.57284443', 221014, '2070145.79000000', '4675.07334489', '0'], [1550448000000, '0.00228300', '0.00259800', '0.00214600', '0.00238100', '5654046.53000000', 1551052799999, '13242.60953208', 294482, '2774706.73000000', '6497.03846076', '0'], [1551052800000, '0.00238300', '0.00245000', '0.00225100', '0.00226300', '2909415.49000000', 1551657599999, '6833.87724719', 150876, '1373704.12000000', '3228.06577334', '0'], [1551657600000, '0.00226300', '0.00239200', '0.00215600', '0.00223600', '2428804.12000000', 1552262399999, '5506.48075461', 127695, '1179806.43000000', '2677.86235002', '0'], [1552262400000, '0.00223600', '0.00241400', '0.00220000', '0.00230600', '2938067.59000000', 1552867199999, '6806.93145215', 151246, '1440025.60000000', '3340.24122102', '0'], [1552867200000, '0.00230800', '0.00234500', '0.00221100', '0.00228400', '2171924.91000000', 1553471999999, '4963.65009054', 139414, '1011839.02000000', '2314.03678143', '0'], [1553472000000, '0.00228600', '0.00249300', '0.00218600', '0.00246200', '3390946.03000000', 1554076799999, '7938.35810598', 181701, '1673714.85000000', '3923.19026117', '0'], [1554076800000, '0.00246100', '0.00274300', '0.00220900', '0.00248600', '6226310.08000000', 1554681599999, '15647.34247395', 355646, '3008554.05000000', '7582.04213064', '0'], [1554681600000, '0.00248300', '0.00253200', '0.00212400', '0.00219700', '2506261.60000000', 1555286399999, '5760.00767853', 137731, '1240476.43000000', '2846.90989129', '0'], [1555286400000, '0.00219600', '0.00220900', '0.00194800', '0.00199900', '1706048.74000000', 1555891199999, '3572.11312204', 89933, '787637.33000000', '1649.33742650', '0'], [1555891200000, '0.00199800', '0.00206600', '0.00174100', '0.00176400', '2484752.27000000', 1556495999999, '4594.79512219', 113142, '1192253.05000000', '2204.63017476', '0'], [1556496000000, '0.00176300', '0.00189100', '0.00159700', '0.00160000', '2475644.38000000', 1557100799999, '4379.75938932', 112365, '1187468.95000000', '2101.93611513', '0'], [1557100800000, '0.00160100', '0.00162500', '0.00127800', '0.00133700', '2751647.33000000', 1557705599999, '3975.27222201', 118293, '1326135.39000000', '1919.58663259', '0'], [1557705600000, '0.00133800', '0.00166900', '0.00120900', '0.00142800', '5142496.30000000', 1558310399999, '7485.97408160', 285045, '2465856.77000000', '3591.74593341', '0'], [1558310400000, '0.00142900', '0.00158700', '0.00134600', '0.00137300', '3491863.67000000', 1558915199999, '5171.49721856', 173766, '1715199.09000000', '2543.77667981', '0'], [1558915200000, '0.00137100', '0.00171600', '0.00135800', '0.00161700', '5819145.53000000', 1559519999999, '9027.72150280', 260583, '2838760.58000000', '4403.41076146', '0'], [1559520000000, '0.00161700', '0.00161800', '0.00146200', '0.00150200', '2888592.90000000', 1560124799999, '4372.18420131', 127905, '1370030.50000000', '2074.58875936', '0'], [1560124800000, '0.00150300', '0.00167700', '0.00149900', '0.00156200', '4297107.26000000', 1560729599999, '6770.41896741', 185080, '2081763.18000000', '3283.08390975', '0'], [1560729600000, '0.00156200', '0.00173600', '0.00133200', '0.00154600', '5396133.77000000', 1561334399999, '8360.79883318', 286519, '2565611.20000000', '3984.02590528', '0'], [1561334400000, '0.00154500', '0.00175500', '0.00132600', '0.00154700', '6023737.81000000', 1561939199999, '9364.43959099', 374933, '2960776.33000000', '4601.99842096', '0'], [1561939200000, '0.00154600', '0.00172200', '0.00147000', '0.00150700', '3000803.64000000', 1562543999999, '4713.11963609', 172449, '1488446.23000000', '2340.37823456', '0'], [1562544000000, '0.00150500', '0.00150800', '0.00116900', '0.00118100', '2507283.06000000', 1563148799999, '3297.10458961', 150388, '1149691.21000000', '1510.97089247', '0'], [1563148800000, '0.00118000', '0.00129200', '0.00106700', '0.00122300', '3287149.63000000', 1563753599999, '3850.19359142', 191415, '1600848.38000000', '1877.56049858', '0'], [1563753600000, '0.00122300', '0.00123300', '0.00111900', '0.00117900', '1923365.83000000', 1564358399999, '2269.06767960', 111452, '911248.92000000', '1076.06317677', '0'], [1564358400000, '0.00118000', '0.00123100', '0.00108000', '0.00108600', '1086754.43000000', 1564963199999, '1248.99163530', 70566, '525300.70000000', '604.49423036', '0'], [1564963200000, '0.00108600', '0.00109200', '0.00086500', '0.00096100', '1740610.83000000', 1565567999999, '1671.60258725', 88788, '903856.50000000', '868.97913946', '0'], [1565568000000, '0.00096100', '0.00099100', '0.00090900', '0.00095500', '936193.47000000', 1566172799999, '891.25793381', 60517, '440314.67000000', '419.87371257', '0'], [1566172800000, '0.00095400', '0.00102200', '0.00091100', '0.00095300', '1122912.93000000', 1566777599999, '1076.85042889', 56618, '539583.48000000', '518.32467689', '0'], [1566777600000, '0.00095200', '0.00095600', '0.00089800', '0.00090000', '740952.62000000', 1567382399999, '687.31357719', 39358, '354832.91000000', '329.43079840', '0'], [1567382400000, '0.00090000', '0.00090300', '0.00083200', '0.00089200', '736658.30000000', 1567987199999, '637.89339943', 39518, '346506.34000000', '300.04033917', '0'], [1567987200000, '0.00089200', '0.00089900', '0.00086100', '0.00088000', '671400.63000000', 1568591999999, '587.56312994', 38692, '311801.90000000', '273.31477745', '0'], [1568592000000, '0.00088000', '0.00101600', '0.00087500', '0.00090500', '1155869.53000000', 1569196799999, '1091.26998755', 59378, '544523.64000000', '514.15492521', '0'], [1569196800000, '0.00090500', '0.00092700', '0.00082800', '0.00088700', '1228159.46000000', 1569801599999, '1078.79007020', 64757, '604792.90000000', '531.29169829', '0'], [1569801600000, '0.00088600', '0.00095700', '0.00087900', '0.00090800', '1041958.05000000', 1570406399999, '946.26032425', 52608, '530874.84000000', '482.73569095', '0'], [1570406400000, '0.00090800', '0.00094500', '0.00086200', '0.00088300', '1192389.24000000', 1571011199999, '1071.67583323', 52224, '565773.44000000', '508.96702646', '0'], [1571011200000, '0.00088300', '0.00091400', '0.00085700', '0.00089000', '1070529.68000000', 1571615999999, '950.46101917', 45315, '492760.50000000', '437.78727519', '0'], [1571616000000, '0.00089000', '0.00130000', '0.00087300', '0.00120700', '5453264.94000000', 1572220799999, '5840.61446514', 206324, '2722145.51000000', '2917.28989016', '0'], [1572220800000, '0.00120700', '0.00137500', '0.00109800', '0.00120000', '6178014.12000000', 1572825599999, '7353.68826161', 305080, '2979406.38000000', '3549.39778264', '0'], [1572825600000, '0.00120100', '0.00126000', '0.00116700', '0.00122000', '2156884.81000000', 1573430399999, '2604.51114036', 114470, '1063192.97000000', '1284.88864016', '0'], [1573430400000, '0.00122000', '0.00152800', '0.00120800', '0.00141800', '4152055.94000000', 1574035199999, '5881.91746496', 209658, '2087173.82000000', '2960.87092595', '0'], [1574035200000, '0.00141900', '0.00147300', '0.00129500', '0.00130000', '2304987.87000000', 1574639999999, '3199.61125951', 155358, '1090133.23000000', '1515.82984674', '0'], [1574640000000, '0.00129900', '0.00132200', '0.00121600', '0.00125100', '1618233.87000000', 1575244799999, '2050.36532210', 91312, '786204.14000000', '996.82233549', '0'], [1575244800000, '0.00125200', '0.00125800', '0.00115500', '0.00120300', '1197978.04000000', 1575849599999, '1442.75465797', 55219, '582243.94000000', '701.55011372', '0'], [1575849600000, '0.00120300', '0.00126600', '0.00116600', '0.00125300', '1010141.14000000', 1576454399999, '1224.62131020', 46456, '479265.02000000', '581.89610209', '0'], [1576454400000, '0.00125400', '0.00126200', '0.00117900', '0.00118400', '867285.99000000', 1577059199999, '1046.24479104', 46634, '395724.16000000', '477.62634245', '0'], [1577059200000, '0.00118600', '0.00126500', '0.00116300', '0.00124700', '785835.68000000', 1577663999999, '945.17612486', 41531, '366750.29000000', '441.52145699', '0'], [1577664000000, '0.00124600', '0.00125500', '0.00120200', '0.00122500', '734864.12000000', 1578268799999, '898.81690495', 38350, '350180.49000000', '428.20050191', '0'], [1578268800000, '0.00122600', '0.00129400', '0.00115000', '0.00125500', '1403159.31000000', 1578873599999, '1715.86513475', 75034, '657096.03000000', '804.02396322', '0'], [1578873600000, '0.00125600', '0.00137900', '0.00119400', '0.00128900', '2954363.56000000', 1579478399999, '3800.55678456', 150152, '1430767.20000000', '1842.16483680', '0'], [1579478400000, '0.00129000', '0.00131100', '0.00122700', '0.00125500', '1015027.62000000', 1580083199999, '1289.08355813', 50524, '489075.32000000', '621.32913957', '0'], [1580083200000, '0.00125300', '0.00134400', '0.00117700', '0.00128900', '1406222.99000000', 1580687999999, '1750.71029910', 90902, '687759.57000000', '858.45138096', '0'], [1580688000000, '0.00128900', '0.00140000', '0.00125300', '0.00140000', '3218304.14000000', 1581292799999, '4253.10442876', 143716, '1576453.00000000', '2085.13807625', '0'], [1581292800000, '0.00140000', '0.00163100', '0.00132700', '0.00147600', '6351356.80000000', 1581897599999, '9419.69563055', 271064, '3207368.69000000', '4756.33377388', '0'], [1581897600000, '0.00147700', '0.00158000', '0.00139600', '0.00143800', '2927906.27000000', 1582502399999, '4331.24797992', 151156, '1427925.23000000', '2114.33981260', '0'], [1582502400000, '0.00143800', '0.00144800', '0.00121600', '0.00132500', '2825147.83000000', 1583107199999, '3695.36622503', 131871, '1381692.75000000', '1807.80765152', '0'], [1583107200000, '0.00132500', '0.00137900', '0.00122900', '0.00125000', '1709067.29000000', 1583711999999, '2267.42474485', 86160, '809060.13000000', '1073.90247483', '0'], [1583712000000, '0.00125100', '0.00129800', '0.00101700', '0.00111500', '4437443.43000000', 1584316799999, '5070.61116175', 234735, '2109886.89000000', '2413.96603383', '0'], [1584316800000, '0.00111600', '0.00112500', '0.00098300', '0.00102200', '2594986.16000000', 1584921599999, '2708.07850770', 128096, '1272628.76000000', '1328.02060742', '0'], [1584921600000, '0.00102200', '0.00107500', '0.00099900', '0.00105100', '1528570.86000000', 1585526399999, '1575.42270994', 92146, '759025.32000000', '782.38502866', '0'], [1585526400000, '0.00105100', '0.00107400', '0.00101200', '0.00103700', '1352386.87000000', 1586131199999, '1402.79496967', 71090, '641453.25000000', '665.62789795', '0'], [1586131200000, '0.00103600', '0.00111400', '0.00102900', '0.00106600', '1518475.61000000', 1586735999999, '1632.76818914', 74158, '749519.47000000', '806.12629809', '0'], [1586736000000, '0.00106700', '0.00109300', '0.00104000', '0.00106800', '1038664.59000000', 1587340799999, '1108.28935939', 51841, '498625.68000000', '532.36455128', '0'], [1587340800000, '0.00106800', '0.00113900', '0.00103000', '0.00112200', '1554266.94000000', 1587945599999, '1682.96785296', 68726, '770423.62000000', '835.34562446', '0'], [1587945600000, '0.00112100', '0.00112100', '0.00100100', '0.00102000', '1753099.18000000', 1588550399999, '1852.74955248', 81325, '859903.45000000', '909.21941885', '0'], [1588550400000, '0.00102000', '0.00120600', '0.00097700', '0.00111400', '2684442.73000000', 1589155199999, '2929.93928563', 121057, '1370145.96000000', '1496.25431065', '0'], [1589155200000, '0.00111300', '0.00115600', '0.00102900', '0.00105000', '1535324.06000000', 1589759999999, '1675.70315536', 70601, '708350.29000000', '773.96359197', '0'], [1589760000000, '0.00104900', '0.00115700', '0.00103600', '0.00110500', '1370797.86000000', 1590364799999, '1490.77790502', 65076, '643180.13000000', '699.75835918', '0'], [1590364800000, '0.00110500', '0.00123900', '0.00107400', '0.00115700', '2558925.09000000', 1590969599999, '2905.91086679', 100900, '1249169.45000000', '1421.59320089', '0'], [1590969600000, '0.00115700', '0.00132400', '0.00115400', '0.00120800', '3376368.00000000', 1591574399999, '4234.90264236', 132429, '1591589.89000000', '1997.69709611', '0'], [1591574400000, '0.00120700', '0.00125500', '0.00112700', '0.00113600', '1502058.25000000', 1592179199999, '1782.37072149', 69926, '689497.24000000', '819.57096134', '0'], [1592179200000, '0.00113600', '0.00114600', '0.00108400', '0.00110800', '1076368.33000000', 1592783999999, '1194.98933659', 50721, '494901.74000000', '549.56691858', '0'], [1592784000000, '0.00110900', '0.00116600', '0.00105100', '0.00110100', '1393801.68000000', 1593388799999, '1556.85181264', 60407, '684532.93000000', '764.82827151', '0'], [1593388800000, '0.00110300', '0.00111900', '0.00107300', '0.00110900', '692238.61000000', 1593993599999, '759.03005899', 36929, '322893.48000000', '354.35354913', '0'], [1593993600000, '0.00110900', '0.00122000', '0.00109700', '0.00116200', '2407255.95000000', 1594598399999, '2773.67387252', 80853, '1196066.57000000', '1378.37637640', '0'], [1594598400000, '0.00116100', '0.00123000', '0.00112200', '0.00115600', '1671896.53000000', 1595203199999, '1960.80109254', 65127, '811616.53000000', '952.18544495', '0'], [1595203200000, '0.00115800', '0.00123100', '0.00112500', '0.00117000', '2260739.70000000', 1595807999999, '2679.63330484', 87240, '1104565.80000000', '1310.75327543', '0'], [1595808000000, '0.00117000', '0.00118700', '0.00099000', '0.00109900', '2558139.81000000', 1596412799999, '2770.41942020', 102910, '1240482.39000000', '1343.84060469', '0'], [1596412800000, '0.00109800', '0.00114400', '0.00109300', '0.00111300', '1329501.90000000', 1597017599999, '1479.84636835', 58998, '634365.97000000', '706.37499793', '0'], [1597017600000, '0.00111200', '0.00135200', '0.00110400', '0.00130100', '2815534.10000000', 1597622399999, '3510.18686684', 137029, '1376098.40000000', '1715.10589510', '0'], [1597622400000, '0.00130200', '0.00169500', '0.00129300', '0.00156000', '4046284.28000000', 1598227199999, '5988.62003577', 210544, '2066145.91000000', '3060.63896621', '0'], [1598227200000, '0.00156000', '0.00199000', '0.00144000', '0.00176400', '3120970.26000000', 1598831999999, '5249.98207853', 183048, '1582901.83000000', '2668.08220100', '0'], [1598832000000, '0.00176500', '0.00188400', '0.00161000', '0.00167300', '2760639.84000000', 1599436799999, '4854.14069752', 186375, '1424671.80000000', '2504.71015217', '0'], [1599436800000, '0.00167400', '0.00209200', '0.00158200', '0.00196900', '1970549.55000000', 1600041599999, '3624.27169900', 162774, '996745.24000000', '1833.13282905', '0'], [1600041600000, '0.00196800', '0.00236600', '0.00181900', '0.00215600', '2879849.81000000', 1600646399999, '6088.14724730', 220182, '1435384.98000000', '3046.31031821', '0'], [1600646400000, '0.00216000', '0.00222800', '0.00178600', '0.00196300', '3488721.15000000', 1601251199999, '6918.52241604', 251721, '1768642.36000000', '3505.23857600', '0'], [1601251200000, '0.00196300', '0.00198300', '0.00165100', '0.00169900', '1356072.02000000', 1601855999999, '2446.92493869', 97504, '668643.54000000', '1208.87518721', '0'], [1601856000000, '0.00169900', '0.00170600', '0.00151700', '0.00156200', '864645.94000000', 1602460799999, '1371.79060524', 64791, '400293.93000000', '635.16608184', '0'], [1602460800000, '0.00156300', '0.00162100', '0.00147900', '0.00151600', '807221.79000000', 1603065599999, '1233.99694203', 103072, '412018.91000000', '630.51316544', '0'], [1603065600000, '0.00151500', '0.00151800', '0.00136400', '0.00137000', '795222.01000000', 1603670399999, '1150.04644715', 58312, '375190.23000000', '542.87672565', '0'], [1603670400000, '0.00137100', '0.00138900', '0.00106000', '0.00108700', '718164.24000000', 1604275199999, '847.76567025', 44703, '326500.83000000', '383.66417539', '0'], [1604275200000, '0.00108700', '0.00116500', '0.00091700', '0.00099800', '1130919.27000000', 1604879999999, '1154.16881988', 58490, '554813.10000000', '564.87269651', '0'], [1604880000000, '0.00099900', '0.00103700', '0.00093800', '0.00096000', '527975.74000000', 1605484799999, '521.79288374', 33674, '240147.05000000', '237.30248784', '0'], [1605484800000, '0.00096000', '0.00099300', '0.00086600', '0.00093300', '1068197.47000000', 1606089599999, '987.96026134', 59694, '518984.98000000', '479.73357510', '0'], [1606089600000, '0.00093400', '0.00114700', '0.00092200', '0.00097200', '2953645.06000000', 1606694399999, '3040.63723155', 140013, '1449309.55000000', '1492.86579145', '0'], [1606694400000, '0.00097400', '0.00099200', '0.00090700', '0.00092500', '1135731.86000000', 1607299199999, '1076.92749503', 62082, '529062.73000000', '501.98560008', '0'], [1607299200000, '0.00092500', '0.00092800', '0.00087100', '0.00090000', '840123.05000000', 1607903999999, '754.68999952', 46014, '407366.70000000', '366.02126144', '0'], [1607904000000, '0.00090200', '0.00091800', '0.00073500', '0.00074700', '1522924.24000000', 1608508799999, '1233.91397030', 74404, '735455.87000000', '595.41787515', '0'], [1608508800000, '0.00074700', '0.00075300', '0.00051600', '0.00057600', '1985456.26000000', 1609113599999, '1268.62285399', 80024, '998438.16000000', '639.54534555', '0'], [1609113600000, '0.00057600', '0.00060300', '0.00040400', '0.00048600', '1826277.04000000', 1609718399999, '908.83864235', 67777, '890522.05000000', '443.27432743', '0'], [1609718400000, '0.00048600', '0.00068900', '0.00047600', '0.00065400', '4954888.50000000', 1610323199999, '2683.56263452', 192949, '2355517.64000000', '1276.41660712', '0'], [1610323200000, '0.00065400', '0.00073000', '0.00058000', '0.00066500', '3980211.10000000', 1610927999999, '2588.00619504', 182082, '1977805.33000000', '1288.15629260', '0'], [1610928000000, '0.00066500', '0.00079900', '0.00065500', '0.00075800', '3083216.32000000', 1611532799999, '2279.88590256', 154238, '1527089.14000000', '1130.99192674', '0'], [1611532800000, '0.00075800', '0.00077200', '0.00060100', '0.00067300', '1795753.93000000', 1612137599999, '1219.21322454', 98026, '825107.92000000', '560.45770609', '0'], [1612137600000, '0.00067400', '0.00071400', '0.00059900', '0.00063200', '2291977.65000000', 1612742399999, '1498.67911737', 123927, '1061360.64000000', '695.13877791', '0'], [1612742400000, '0.00063100', '0.00096400', '0.00055900', '0.00090500', '5584663.59000000', 1613347199999, '4283.55708815', 296160, '2780289.92000000', '2143.02315021', '0'], [1613347200000, '0.00090600', '0.00096100', '0.00075800', '0.00095600', '4139463.97000000', 1613951999999, '3598.00903749', 264115, '2023630.64000000', '1762.80016958', '0'], [1613952000000, '0.00095500', '0.00096400', '0.00069600', '0.00078100', '2999551.98000000', 1614556799999, '2485.42397564', 189223, '1479339.18000000', '1229.58010431', '0'], [1614556800000, '0.00078100', '0.00082100', '0.00075900', '0.00077000', '1246811.52000000', 1615161599999, '975.02655088', 83705, '631638.83000000', '494.33580251', '0'], [1615161600000, '0.00077100', '0.00079200', '0.00066500', '0.00067000', '1438316.07000000', 1615766399999, '1046.84869425', 90122, '688552.36000000', '501.81274095', '0'], [1615766400000, '0.00067000', '0.00082300', '0.00066300', '0.00074100', '1883659.72000000', 1616371199999, '1418.87296014', 130250, '934900.96000000', '706.05923126', '0'], [1616371200000, '0.00073900', '0.00081100', '0.00072500', '0.00080300', '1943288.44000000', 1616975999999, '1487.12936684', 128032, '954539.50000000', '731.08183496', '0'], [1616976000000, '0.00080200', '0.00095600', '0.00074300', '0.00093800', '2589597.52000000', 1617580799999, '2229.44567688', 200074, '1364864.89000000', '1180.18291524', '0'], [1617580800000, '0.00093800', '0.00118300', '0.00090400', '0.00106600', '2819236.37000000', 1618185599999, '2957.35907808', 259324, '1456401.20000000', '1529.17033901', '0'], [1618185600000, '0.00106500', '0.00214200', '0.00099000', '0.00213200', '4680253.06000000', 1618790399999, '6625.55222612', 515046, '2518206.45000000', '3580.80850627', '0'], [1618790400000, '0.00213300', '0.00236600', '0.00150800', '0.00162100', '4056199.74000000', 1619395199999, '7690.06161759', 482248, '2012667.29000000', '3818.38773193', '0'], [1619395200000, '0.00162300', '0.00193400', '0.00160600', '0.00188900', '1545302.32000000', 1619999999999, '2653.53525526', 193810, '735097.69000000', '1265.15925120', '0'], [1620000000000, '0.00188900', '0.00250000', '0.00175200', '0.00205500', '2971493.87000000', 1620604799999, '6073.18444988', 399254, '1505392.11000000', '3077.46659355', '0'], [1620604800000, '0.00205400', '0.00209100', '0.00179900', '0.00200000', '1547185.66000000', 1621209599999, '3035.48647867', 233676, '773952.11000000', '1519.95207723', '0'], [1621209600000, '0.00200200', '0.00206300', '0.00114200', '0.00124300', '2416570.47000000', 1621814399999, '3853.46774429', 323348, '1186191.25000000', '1885.01247365', '0'], [1621814400000, '0.00124300', '0.00168900', '0.00119000', '0.00144600', '1515867.53000000', 1622419199999, '2220.73218409', 202273, '787723.39000000', '1156.79935950', '0'], [1622419200000, '0.00144500', '0.00167200', '0.00142100', '0.00158200', '800557.77000000', 1623023999999, '1235.03940274', 115266, '402160.88000000', '620.42124274', '0'], [1623024000000, '0.00158300', '0.00159100', '0.00123500', '0.00126000', '679326.15000000', 1623628799999, '939.60638296', 93314, '334153.91000000', '462.83258262', '0'], [1623628800000, '0.00126000', '0.00129900', '0.00121700', '0.00125500', '536753.23000000', 1624233599999, '674.06947855', 64033, '274780.57000000', '344.90568505', '0'], [1624233600000, '0.00125500', '0.00126000', '0.00089200', '0.00092100', '1532664.78000000', 1624838399999, '1531.64430814', 115092, '738376.36000000', '736.98114186', '0'], [1624838400000, '0.00092200', '0.00108800', '0.00089400', '0.00106500', '1222355.48000000', 1625443199999, '1235.19127030', 98222, '631554.73000000', '639.03624459', '0'], [1625443200000, '0.00106300', '0.00110300', '0.00099300', '0.00099900', '662212.70000000', 1626047999999, '697.40088152', 62763, '291981.11000000', '307.32377038', '0'], [1626048000000, '0.00099900', '0.00103400', '0.00092500', '0.00093600', '698861.06000000', 1626652799999, '686.80315852', 51685, '340616.06000000', '334.65823420', '0'], [1626652800000, '0.00093600', '0.00093900', '0.00085000', '0.00086900', '964239.11000000', 1627257599999, '853.81860458', 60658, '533429.35000000', '471.98935436', '0'], [1627257600000, '0.00086900', '0.00116300', '0.00081700', '0.00105700', '1905454.30000000', 1627862399999, '1840.37583295', 162476, '1013473.33000000', '982.21932506', '0'], [1627862400000, '0.00105600', '0.00117600', '0.00100600', '0.00102900', '877356.69000000', 1628467199999, '950.84706774', 104534, '452308.90000000', '490.60392570', '0'], [1628467200000, '0.00102900', '0.00127000', '0.00099300', '0.00125500', '912467.71000000', 1629071999999, '1008.98003957', 109775, '460826.30000000', '510.27833266', '0'], [1629072000000, '0.00125500', '0.00128400', '0.00109800', '0.00112700', '785915.46000000', 1629676799999, '920.53175807', 91249, '369120.50000000', '432.75227777', '0'], [1629676800000, '0.00112600', '0.00127000', '0.00106300', '0.00111600', '1047810.85000000', 1630281599999, '1223.46997854', 94329, '528759.72000000', '618.43102358', '0'], [1630281600000, '0.00111700', '0.00129400', '0.00107800', '0.00127200', '989430.69000000', 1630886399999, '1150.95754677', 83026, '508204.85000000', '593.07945621', '0'], [1630886400000, '0.00127000', '0.00128900', '0.00097400', '0.00112100', '1151435.42000000', 1631491199999, '1278.23293085', 107877, '567384.19000000', '629.54474685', '0'], [1631491200000, '0.00111900', '0.00113300', '0.00101000', '0.00101800', '609632.03000000', 1632095999999, '655.95085102', 65064, '293452.77000000', '315.86263941', '0'], [1632096000000, '0.00101900', '0.00102000', '0.00087000', '0.00089700', '528257.43000000', 1632700799999, '501.33569832', 62431, '252069.03000000', '239.79620858', '0'], [1632700800000, '0.00089700', '0.00095800', '0.00087100', '0.00092200', '391436.00000000', 1633305599999, '351.79061074', 45067, '181455.06000000', '163.12197957', '0'], [1633305600000, '0.00092200', '0.00094800', '0.00082600', '0.00082900', '631378.67000000', 1633910399999, '554.50444827', 73028, '288189.05000000', '253.18208532', '0'], [1633910400000, '0.00082800', '0.00083100', '0.00070000', '0.00070300', '388175.13000000', 1634515199999, '296.96587184', 45222, '179437.12000000', '137.68197971', '0'], [1634515200000, '0.00070300', '0.00073800', '0.00066100', '0.00072000', '369732.76000000', 1635119999999, '261.58429505', 35106, '181815.36000000', '128.79080806', '0'], [1635120000000, '0.00071900', '0.00077400', '0.00065000', '0.00072900', '488403.14000000', 1635724799999, '345.43194961', 45712, '238971.66000000', '169.18041923', '0'], [1635724800000, '0.00072900', '0.00077400', '0.00070700', '0.00073200', '481040.93000000', 1636329599999, '355.64203757', 54234, '251455.44000000', '186.00756904', '0'], [1636329600000, '0.00073100', '0.00079500', '0.00070200', '0.00074100', '555366.51000000', 1636934399999, '417.82731802', 63214, '281469.15000000', '211.86104409', '0'], [1636934400000, '0.00074000', '0.00075700', '0.00067700', '0.00070900', '387176.58000000', 1637539199999, '276.72272036', 36426, '195246.11000000', '139.56310847', '0'], [1637539200000, '0.00071000', '0.00073000', '0.00065200', '0.00066400', '375523.37000000', 1638143999999, '259.77082117', 34747, '194490.41000000', '134.53361242', '0'], [1638144000000, '0.00066300', '0.00067400', '0.00052700', '0.00057200', '591710.79000000', 1638748799999, '363.55128211', 43985, '299695.09000000', '184.89077244', '0'], [1638748800000, '0.00057200', '0.00062700', '0.00055100', '0.00056100', '419045.86000000', 1639353599999, '244.82100406', 28845, '222794.26000000', '130.36844293', '0'], [1639353600000, '0.00056100', '0.00059400', '0.00053200', '0.00054300', '323220.18000000', 1639958399999, '178.18484929', 18950, '168603.92000000', '92.95492328', '0'], [1639958400000, '0.00054200', '0.00059400', '0.00052700', '0.00058200', '358328.70000000', 1640563199999, '201.79529293', 27818, '202536.17000000', '114.08656102', '0'], [1640563200000, '0.00058200', '0.00059400', '0.00054500', '0.00057100', '310788.77000000', 1641167999999, '174.46850860', 26799, '167181.74000000', '93.97307270', '0'], [1641168000000, '0.00057100', '0.00059300', '0.00055200', '0.00056600', '459963.07000000', 1641772799999, '261.54113892', 25401, '257019.87000000', '146.25044794', '0'], [1641772800000, '0.00056600', '0.00060200', '0.00053800', '0.00058400', '316232.52000000', 1642377599999, '180.17496995', 30387, '177656.01000000', '101.22516236', '0'], [1642377600000, '0.00058400', '0.00062300', '0.00047600', '0.00051200', '683373.48000000', 1642982399999, '372.24051934', 58352, '336558.74000000', '183.29711419', '0'], [1642982400000, '0.00051200', '0.00052900', '0.00048400', '0.00051600', '502128.40000000', 1643587199999, '250.82309975', 33818, '270075.04000000', '135.06243055', '0'], [1643587200000, '0.00051700', '0.00058800', '0.00050700', '0.00053300', '489423.02000000', 1644191999999, '265.77541094', 42705, '263378.92000000', '143.22333689', '0'], [1644192000000, '0.00053300', '0.00058700', '0.00049800', '0.00051700', '556479.95000000', 1644796799999, '300.42510571', 44085, '268381.07000000', '145.37837902', '0'], [1644796800000, '0.00051800', '0.00068200', '0.00049200', '0.00060100', '1160866.70000000', 1645401599999, '694.48757506', 67176, '585137.90000000', '350.28636471', '0'], [1645401600000, '0.00060100', '0.00062200', '0.00049300', '0.00052800', '698393.79000000', 1646006399999, '377.05254259', 48429, '349725.05000000', '188.75638523', '0'], [1646006400000, '0.00052700', '0.00057900', '0.00050900', '0.00053400', '489018.53000000', 1646611199999, '268.25000826', 43062, '230502.72000000', '126.68247833', '0'], [1646611200000, '0.00053300', '0.00054700', '0.00050200', '0.00050300', '295703.17000000', 1647215999999, '154.17691473', 24165, '131870.90000000', '68.86142242', '0'], [1647216000000, '0.00050400', '0.00056800', '0.00048200', '0.00055000', '344215.83000000', 1647820799999, '180.21324327', 20491, '167655.54000000', '88.54017324', '0'], [1647820800000, '0.00054900', '0.00059500', '0.00053200', '0.00055600', '588420.20000000', 1648425599999, '328.77826549', 44151, '290707.93000000', '162.74569026', '0'], [1648425600000, '0.00055500', '0.00062500', '0.00053500', '0.00060400', '670322.15000000', 1649030399999, '395.03362797', 62285, '338536.94000000', '199.79444618', '0'], [1649030400000, '0.00060400', '0.00060400', '0.00051100', '0.00051200', '327004.00000000', 1649635199999, '179.95416982', 30300, '137923.42000000', '75.56016072', '0'], [1649635200000, '0.00051200', '0.00054700', '0.00048300', '0.00051700', '266709.77000000', 1650239999999, '137.19297032', 20686, '130747.28000000', '67.30923332', '0'], [1650240000000, '0.00051700', '0.00053900', '0.00050700', '0.00051200', '287311.49000000', 1650844799999, '149.90983206', 29793, '121322.51000000', '63.41508680', '0'], [1650844800000, '0.00051200', '0.00051300', '0.00043800', '0.00045800', '292005.30000000', 1651449599999, '137.71998499', 25294, '127175.29000000', '60.13569064', '0'], [1651449600000, '0.00046000', '0.00049500', '0.00044200', '0.00046700', '290911.91000000', 1652054399999, '136.44085483', 26577, '138602.67000000', '65.11165639', '0'], [1652054400000, '0.00046700', '0.00047800', '0.00031400', '0.00035200', '971248.90000000', 1652659199999, '365.87706258', 50144, '475551.69000000', '177.88013062', '0'], [1652659200000, '0.00035200', '0.00036600', '0.00033300', '0.00035800', '472541.01000000', 1653263999999, '165.31358002', 18852, '239430.34000000', '83.88738931', '0'], [1653264000000, '0.00035900', '0.00041500', '0.00035100', '0.00036200', '823729.42000000', 1653868799999, '314.01505425', 51470, '404475.57000000', '154.42748760', '0'], [1653868800000, '0.00036200', '0.00040300', '0.00035400', '0.00038300', '694042.48000000', 1654473599999, '262.18974490', 36823, '338957.16000000', '128.35868018', '0'], [1654473600000, '0.00038300', '0.00048500', '0.00036500', '0.00043700', '1193370.58000000', 1655078399999, '496.44976252', 62521, '642142.62000000', '268.34851000', '0'], [1655078400000, '0.00043800', '0.00046000', '0.00039400', '0.00044100', '940844.10000000', 1655683199999, '405.89002861', 64201, '484747.49000000', '209.28472007', '0'], [1655683200000, '0.00044200', '0.00045700', '0.00043100', '0.00045600', '197230.32000000', 1656287999999, '87.86430151', 16762, '102561.75000000', '45.75128281', '0']]
"""

# %%
from datetime import datetime
now = datetime.today()
print(now)
# Out:
# 2022-06-28 15:27:10.868859

# %%
from datetime import timedelta
print(now+timedelta(days=1))
then = now +timedelta(days=1)
then-now
# Out:
# 2022-06-29 15:27:10.868859
# datetime.timedelta(days=1)

# %%
"""# UNTESTED BELOW THIS
# binance-python NEEDS A REFACTORING such that it does not rely on pytz (depricated) for UTC localization
https://pypi.org/project/pytz-deprecation-shim/
"""

#####
# UNTESTED SOLUTION:1 - date_to_milliseconds
##########
# import time
# import dateparser
# import zoneinfo
# import json
# from datetime import datetime
# from binance.client import Client

# def date_to_milliseconds(date_str):
#     dt_obj = datetime.strptime('20.12.2016 09:38:42,76',
#                            '%d.%m.%Y %H:%M:%S,%f')
#     millisec = dt_obj.timestamp() * 1000
#     return int(millisec)

#############
# END SOLUTION:1
#############

# 
"""
ORIGINAL python-binance which fails due to its use of pytz (depricated)
"""#

# import time
# import dateparser
# import pytz
# import json

# from datetime import datetime
# from binance.client import Client

# def date_to_milliseconds(date_str):
#     """Convert UTC date to milliseconds
#     If using offset strings add "UTC" to date string e.g. "now UTC", "11 hours ago UTC"
#     See dateparse docs for formats http://dateparser.readthedocs.io/en/latest/
#     :param date_str: date in readable format, i.e. "January 01, 2018", "11 hours ago UTC", "now UTC"
#     :type date_str: str
#     """
#     # get epoch value in UTC
#     epoch = datetime.utcfromtimestamp(0).replace(tzinfo=pytz.utc)
#     # parse our date string
#     d = dateparser.parse(date_str)
#     # if the date is not timezone aware apply UTC timezone
#     if d.tzinfo is None or d.tzinfo.utcoffset(d) is None:
#         d = d.replace(tzinfo=pytz.utc)

#     # return the difference in time
#     return int((d - epoch).total_seconds() * 1000.0)
# def interval_to_milliseconds(interval):
#     """Convert a Binance interval string to milliseconds
#     :param interval: Binance interval string 1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w
#     :type interval: str
#     :return:
#          None if unit not one of m, h, d or w
#          None if string not in correct format
#          int value of interval in milliseconds
#     """
#     ms = None
#     seconds_per_unit = {
#         "m": 60,
#         "h": 60 * 60,
#         "d": 24 * 60 * 60,
#         "w": 7 * 24 * 60 * 60
#     }

#     unit = interval[-1]
#     if unit in seconds_per_unit:
#         try:
#             ms = int(interval[:-1]) * seconds_per_unit[unit] * 1000
#         except ValueError:
#             pass
#     return ms


# def get_historical_klines(symbol, interval, start_str, end_str=None):
#     """Get Historical Klines from Binance
#     See dateparse docs for valid start and end string formats http://dateparser.readthedocs.io/en/latest/
#     If using offset strings for dates add "UTC" to date string e.g. "now UTC", "11 hours ago UTC"
#     :param symbol: Name of symbol pair e.g BNBBTC
#     :type symbol: str
#     :param interval: Biannce Kline interval
#     :type interval: str
#     :param start_str: Start date string in UTC format
#     :type start_str: str
#     :param end_str: optional - end date string in UTC format
#     :type end_str: str
#     :return: list of OHLCV values
#     """
#     # create the Binance client, no need for api key
#     client = Client("", "")

#     # init our list
#     output_data = []

#     # setup the max limit
#     limit = 500

#     # convert interval to useful value in seconds
#     timeframe = interval_to_milliseconds(interval)

#     # convert our date strings to milliseconds
#     start_ts = date_to_milliseconds(start_str)

#     # if an end time was passed convert it
#     end_ts = None
#     if end_str:
#         end_ts = date_to_milliseconds(end_str)

#     idx = 0
#     # it can be difficult to know when a symbol was listed on Binance so allow start time to be before list date
#     symbol_existed = False
#     while True:
#         # fetch the klines from start_ts up to max 500 entries or the end_ts if set
#         temp_data = client.get_klines(
#             symbol=symbol,
#             interval=interval,
#             limit=limit,
#             startTime=start_ts,
#             endTime=end_ts
#         )

#         # handle the case where our start date is before the symbol pair listed on Binance
#         if not symbol_existed and len(temp_data):
#             symbol_existed = True

#         if symbol_existed:
#             # append this loops data to our output data
#             output_data += temp_data

#             # update our start timestamp using the last value in the array and add the interval timeframe
#             start_ts = temp_data[len(temp_data) - 1][0] + timeframe
#         else:
#             # it wasn't listed yet, increment our start date
#             start_ts += timeframe

#         idx += 1
#         # check if we received less than the required limit and exit the loop
#         if len(temp_data) < limit:
#             # exit the while loop
#             break

#         # sleep after every 3rd call to be kind to the API
#         if idx % 3 == 0:
#             time.sleep(1)

#     return output_data


# symbol = "ETHBTC"
# start = "1 Dec, 2017"
# end = "1 Jan, 2018"
# interval = Client.KLINE_INTERVAL_30MINUTE

# klines = get_historical_klines(symbol, interval, start, end)

# # open a file with filename including symbol, interval and start and end converted to milliseconds
# with open(
#     "Binance_{}_{}_{}-{}.json".format(
#         symbol,
#         interval,
#         date_to_milliseconds(start),
#         date_to_milliseconds(end)
#     ),
#     'w'  # set file write mode
# ) as f:
#     f.write(json.dumps(klines))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-ab52bf0fcf57> in <module>
#       1 import time
#       2 import dateparser
# ----> 3 import zoneinfo
#       4 import json
#       5 from datetime import datetime
#
# ModuleNotFoundError: No module named 'zoneinfo'

# %%
def interval_to_milliseconds(interval):
    """Convert a Binance interval string to milliseconds
    :param interval: Binance interval string 1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w
    :type interval: str
    :return:
         None if unit not one of m, h, d or w
         None if string not in correct format
         int value of interval in milliseconds
    """
    ms = None
    seconds_per_unit = {
        "m": 60,
        "h": 60 * 60,
        "d": 24 * 60 * 60,
        "w": 7 * 24 * 60 * 60
    }

    unit = interval[-1]
    if unit in seconds_per_unit:
        try:
            ms = int(interval[:-1]) * seconds_per_unit[unit] * 1000
        except ValueError:
            pass
    return ms


def get_historical_klines(symbol, interval, start_str, end_str=None):
    """Get Historical Klines from Binance
    See dateparse docs for valid start and end string formats http://dateparser.readthedocs.io/en/latest/
    If using offset strings for dates add "UTC" to date string e.g. "now UTC", "11 hours ago UTC"
    :param symbol: Name of symbol pair e.g BNBBTC
    :type symbol: str
    :param interval: Biannce Kline interval
    :type interval: str
    :param start_str: Start date string in UTC format
    :type start_str: str
    :param end_str: optional - end date string in UTC format
    :type end_str: str
    :return: list of OHLCV values
    """
    # create the Binance client, no need for api key
    client = Client("", "")

    # init our list
    output_data = []

    # setup the max limit
    limit = 500

    # convert interval to useful value in seconds
    timeframe = interval_to_milliseconds(interval)

    # convert our date strings to milliseconds
    start_ts = date_to_milliseconds(start_str)

    # if an end time was passed convert it
    end_ts = None
    if end_str:
        end_ts = date_to_milliseconds(end_str)

    idx = 0
    # it can be difficult to know when a symbol was listed on Binance so allow start time to be before list date
    symbol_existed = False
    while True:
        # fetch the klines from start_ts up to max 500 entries or the end_ts if set
        temp_data = client.get_klines(
            symbol=symbol,
            interval=interval,
            limit=limit,
            startTime=start_ts,
            endTime=end_ts
        )

        # handle the case where our start date is before the symbol pair listed on Binance
        if not symbol_existed and len(temp_data):
            symbol_existed = True

        if symbol_existed:
            # append this loops data to our output data
            output_data += temp_data

            # update our start timestamp using the last value in the array and add the interval timeframe
            start_ts = temp_data[len(temp_data) - 1][0] + timeframe
        else:
            # it wasn't listed yet, increment our start date
            start_ts += timeframe

        idx += 1
        # check if we received less than the required limit and exit the loop
        if len(temp_data) < limit:
            # exit the while loop
            break

        # sleep after every 3rd call to be kind to the API
        if idx % 3 == 0:
            time.sleep(1)

    return output_data


symbol = "ETHBTC"
start = "1 Dec, 2017"
end = "1 Jan, 2018"
interval = Client.KLINE_INTERVAL_30MINUTE

klines = get_historical_klines(symbol, interval, start, end)

# open a file with filename including symbol, interval and start and end converted to milliseconds
with open(
    "Binance_{}_{}_{}-{}.json".format(
        symbol,
        interval,
        date_to_milliseconds(start),
        date_to_milliseconds(end)
    ),
    'w'  # set file write mode
) as f:
    f.write(json.dumps(klines))
# Out:
# C:\Users\d3v\anaconda3\lib\site-packages\dateparser\date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)

# %%
#####
"""
Further Research needs to be done on this before folding in as refactor into Portfolio Model
"""
# withdraw 100 ETH
# check docs for assumptions around withdrawals
# from binance.exceptions import BinanceAPIException, BinanceWithdrawException
# try:
#     result = client.withdraw(
#         asset='ETH',
#         address='<eth_address>',
#         amount=100)
# except BinanceAPIException as e:
#     print(e)
# except BinanceWithdrawException as e:
#     print(e)
# else:
#     print("Success")

# # fetch list of withdrawals
# withdraws = client.get_withdraw_history()

# # fetch list of ETH withdrawals
# eth_withdraws = client.get_withdraw_history(asset='ETH')

# # get a deposit address for BTC
# address = client.get_deposit_address(asset='BTC')

# start aggregated trade websocket for BNBBTC
# def process_message(msg):
#     print("message type: {}".format(msg['e']))
#     print(msg)
#     # do something

# from binance.websockets import BinanceSocketManager
# bm = BinanceSocketManager(client)
# bm.start_aggtrade_socket('BNBBTC', process_message)
# bm.start()

# %%
import unittest
class unit
